# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results 

rules_log = "fico_heloc_simpleNN_rules_25-00_06-06-2025.txt"
entries_log = "fico_heloc_simpleNN_entries_25-00_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 1758 (Original: Bad , Predicted: Bad)
#                                    Value
# ExternalRiskEstimate                55.0
# MSinceOldestTradeOpen               39.0
# MSinceMostRecentTradeOpen            2.0
# AverageMInFile                      17.0
# NumSatisfactoryTrades               21.0
# NumTrades60Ever2DerogPubRec          0.0
# NumTrades90Ever2DerogPubRec          0.0
# PercentTradesNeverDelq              96.0
# MSinceMostRecentDelq                -7.0
# MaxDelq2PublicRecLast12M               5
# MaxDelqEver                            7
# NumTotalTrades                      23.0
# NumTradesOpeninLast12M               7.0
# PercentInstallTrades                26.0
# MSinceMostRecentInqexcl7days         0.0
# NumInqLast6M                         2.0
# NumInqLast6Mexcl7days                2.0
# NetFractionRevolvingBurden          64.0
# NetFractionInstallBurden            77.0
# NumRevolvingTradesWBalance           9.0
# NumInstallTradesWBalance             4.0
# NumBank2NatlTradesWHighUtilization   0.0
# PercentTradesWBalance               78.0
# ### Rules for Instance 1758
#    Instance_Name Explainer   Rule_ID  \
# 0           1758    ANCHOR   ANCHOR1
# 1           1758    ANCHOR   ANCHOR2
# 2           1758    ANCHOR   ANCHOR3
# 3           1758    ANCHOR   ANCHOR4
# 4           1758    ANCHOR   ANCHOR5
# 5           1758      LORE     LORE1
# 6           1758      LORE     LORE2
# 7           1758      LORE     LORE3
# 8           1758      LORE     LORE4
# 9           1758      LORE     LORE5
# 10          1758   LORE_SA  LORE_SA1
# 11          1758   LORE_SA  LORE_SA2
# 12          1758   LORE_SA  LORE_SA3
# 13          1758   LORE_SA  LORE_SA4
# 14          1758   LORE_SA  LORE_SA5
# 15          1758    EXPLAN   EXPLAN1
# 16          1758    EXPLAN   EXPLAN2
# 17          1758    EXPLAN   EXPLAN3
# 18          1758    EXPLAN   EXPLAN4
# 19          1758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                              Rule  \
# 0                                                                                                                                                                                                                                          IF ExternalRiskEstimate <= 63.0 AND NetFractionRevolvingBurden > 25.0 THEN class = Bad
# 1                                                                                                                                                                                                                                                     IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad
# 2                                                                                                                                                                                                                                                     IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                                                                                                                     IF AverageMInFile <= 52.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad
# 4                                                                                                                                                                                                                                                IF ExternalRiskEstimate <= 71.0 AND NumInqLast6Mexcl7days > 1.0 THEN class = Bad
# 5                                                                                                                                                                                                              IF NumInstallTradesWBalance <= 4.0 AND NumRevolvingTradesWBalance > -8.0 AND NumTotalTrades > 7.0 THEN class = Bad
# 6                                                                                                                               IF AverageMInFile <= 17.0 AND MSinceMostRecentTradeOpen <= 2.0 AND NumBank2NatlTradesWHighUtilization <= 56.0 AND NumInstallTradesWBalance <= 28.194552 AND NumTotalTrades > 6.0 THEN class = Bad
# 7                                                                                                                                                                    IF NumInstallTradesWBalance <= 30.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 59.0 AND PercentInstallTrades > 24.0 THEN class = Bad
# 8                                                                                                                                                                                            IF NumBank2NatlTradesWHighUtilization <= 89.0 AND NumInstallTradesWBalance <= 4.0 AND NumSatisfactoryTrades <= 73.0 THEN class = Bad
# 9   IF MSinceMostRecentTradeOpen > 1.860985 AND NetFractionInstallBurden > 73.0 AND NumBank2NatlTradesWHighUtilization <= 0.020979 AND NumInstallTradesWBalance <= 11.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 87.0 AND NumTotalTrades > 6.0 AND NumTrades60Ever2DerogPubRec <= 32.0 THEN class = Bad
# 10                                                                                                                                                         IF MSinceMostRecentTradeOpen <= 364.1134338378906 AND NumRevolvingTradesWBalance > 0.24002157524228096 AND NumSatisfactoryTrades <= 70.77135467529297 THEN class = Bad
# 11                                                                                                                                                           IF NumSatisfactoryTrades <= 63.835981369018555 AND NumTrades60Ever2DerogPubRec > -8.036439895629883 AND PercentTradesWBalance > -0.8786664009094238 THEN class = Bad
# 12                                                                                                                                                      IF NumInstallTradesWBalance <= 20.63279438018799 AND NumInstallTradesWBalance > -8.018319129943848 AND NumTrades60Ever2DerogPubRec > -1.3539665341377258 THEN class = Bad
# 13                                                                                                                       IF AverageMInFile <= 366.85975646972656 AND MSinceMostRecentDelq <= 81.80145645141602 AND NumInstallTradesWBalance > 3.6677093505859375 AND NumSatisfactoryTrades <= 48.291690826416016 THEN class = Bad
# 14                                                                                                                                                                                                                   IF AverageMInFile <= 340.28456115722656 AND NumRevolvingTradesWBalance > 3.1006942987442017 THEN class = Bad
# 15                                                                                                              IF NetFractionInstallBurden > 73.458589 AND NumRevolvingTradesWBalance > 4.572987 AND NumSatisfactoryTrades > 19.0 AND NumTrades60Ever2DerogPubRec > -5.962701 AND PercentTradesNeverDelq > 91.0 THEN class = Bad
# 16                                                IF ExternalRiskEstimate <= 87.996897 AND MSinceOldestTradeOpen <= 104.441951 AND NumInqLast6Mexcl7days > -5.46259 AND NumRevolvingTradesWBalance > 1.0 AND NumSatisfactoryTrades <= 22.857461 AND NumTotalTrades > -9.0 AND NumTrades60Ever2DerogPubRec > -9.0 THEN class = Bad
# 17                                                                                                                                                                           IF MSinceOldestTradeOpen <= 75.0 AND NumInqLast6M > -9.0 AND NumRevolvingTradesWBalance > 8.370698 AND NumSatisfactoryTrades > 18.0 THEN class = Bad
# 18                                                     IF AverageMInFile <= 58.0 AND MSinceMostRecentInqexcl7days > -5.689952 AND MSinceOldestTradeOpen <= 82.0 AND NetFractionInstallBurden > 36.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades > 17.426141 AND PercentInstallTrades <= 43.0 THEN class = Bad
# 19                                                                                                                                                                                                               IF AverageMInFile <= 34.0 AND ExternalRiskEstimate <= 59.49445 AND NumSatisfactoryTrades > 18.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.16705    0.26511  0.82829    2       0       3.45537       False
# 1   0.33520    0.47239  0.73553    2       0       4.70856       False
# 2   0.22715    0.33159  0.76188    2       1       6.81062       False
# 3   0.19478    0.27480  0.73633    2       0       3.07180       False
# 4   0.18836    0.26799  0.74257    2       0       3.63994       False
# 5   0.77421    0.73750  0.49718    3       0      59.69534       False
# 6   0.00505    0.00785  0.81081    5       0      69.65521       False
# 7   0.63311    0.65533  0.54024    4       0      58.32553       False
# 8   0.92815    0.91756  0.51597    3       0      54.36948       False
# 9   0.11351    0.09317  0.42840    8       0      55.64925       False
# 10  0.89851    0.88956  0.51672    3       0      18.42998       False
# 11  0.94004    0.93824  0.52092    3       0      17.16368       False
# 12  0.94345    0.94164  0.52092    3       0      20.05867       False
# 13  0.15135    0.16933  0.58394    4       0      17.59610       False
# 14  0.44953    0.49071  0.56974    2       0      17.10405       False
# 15  0.06912    0.07014  0.52964    5       0       2.07041       False
# 16  0.09316    0.13086  0.73314    7       0       3.85701       False
# 17  0.00410    0.00576  0.73333    4       0       2.61702       False
# 18  0.00669    0.00995  0.77551    7       0       2.02970       False
# 19  0.00205    0.00288  0.73333    3       0       2.23679       False
# ### Rules for Instance 1758, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0           1758    ANCHOR   ANCHOR1
# 1           1758    ANCHOR   ANCHOR2
# 2           1758    ANCHOR   ANCHOR3
# 3           1758    ANCHOR   ANCHOR4
# 4           1758    ANCHOR   ANCHOR5
# 5           1758      LORE     LORE1
# 6           1758      LORE     LORE2
# 7           1758      LORE     LORE3
# 8           1758      LORE     LORE4
# 9           1758      LORE     LORE5
# 10          1758   LORE_SA  LORE_SA1
# 11          1758   LORE_SA  LORE_SA2
# 12          1758   LORE_SA  LORE_SA3
# 13          1758   LORE_SA  LORE_SA4
# 14          1758   LORE_SA  LORE_SA5
# 15          1758    EXPLAN   EXPLAN1
# 16          1758    EXPLAN   EXPLAN2
# 17          1758    EXPLAN   EXPLAN3
# 18          1758    EXPLAN   EXPLAN4
# 19          1758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                              Rule  \
# 0                                                                                                                                                                                                                                          IF ExternalRiskEstimate <= 63.0 AND NetFractionRevolvingBurden > 25.0 THEN class = Bad
# 1                                                                                                                                                                                                                                                     IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad
# 2                                                                                                                                                                                                                                                     IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                                                                                                                     IF AverageMInFile <= 52.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad
# 4                                                                                                                                                                                                                                                IF ExternalRiskEstimate <= 71.0 AND NumInqLast6Mexcl7days > 1.0 THEN class = Bad
# 5                                                                                                                                                                                                              IF NumInstallTradesWBalance <= 4.0 AND NumRevolvingTradesWBalance > -8.0 AND NumTotalTrades > 7.0 THEN class = Bad
# 6                                                                                                                               IF AverageMInFile <= 17.0 AND MSinceMostRecentTradeOpen <= 2.0 AND NumBank2NatlTradesWHighUtilization <= 56.0 AND NumInstallTradesWBalance <= 28.194552 AND NumTotalTrades > 6.0 THEN class = Bad
# 7                                                                                                                                                                    IF NumInstallTradesWBalance <= 30.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 59.0 AND PercentInstallTrades > 24.0 THEN class = Bad
# 8                                                                                                                                                                                            IF NumBank2NatlTradesWHighUtilization <= 89.0 AND NumInstallTradesWBalance <= 4.0 AND NumSatisfactoryTrades <= 73.0 THEN class = Bad
# 9   IF MSinceMostRecentTradeOpen > 1.860985 AND NetFractionInstallBurden > 73.0 AND NumBank2NatlTradesWHighUtilization <= 0.020979 AND NumInstallTradesWBalance <= 11.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 87.0 AND NumTotalTrades > 6.0 AND NumTrades60Ever2DerogPubRec <= 32.0 THEN class = Bad
# 10                                                                                                                                                         IF MSinceMostRecentTradeOpen <= 364.1134338378906 AND NumRevolvingTradesWBalance > 0.24002157524228096 AND NumSatisfactoryTrades <= 70.77135467529297 THEN class = Bad
# 11                                                                                                                                                           IF NumSatisfactoryTrades <= 63.835981369018555 AND NumTrades60Ever2DerogPubRec > -8.036439895629883 AND PercentTradesWBalance > -0.8786664009094238 THEN class = Bad
# 12                                                                                                                                                      IF NumInstallTradesWBalance <= 20.63279438018799 AND NumInstallTradesWBalance > -8.018319129943848 AND NumTrades60Ever2DerogPubRec > -1.3539665341377258 THEN class = Bad
# 13                                                                                                                       IF AverageMInFile <= 366.85975646972656 AND MSinceMostRecentDelq <= 81.80145645141602 AND NumInstallTradesWBalance > 3.6677093505859375 AND NumSatisfactoryTrades <= 48.291690826416016 THEN class = Bad
# 14                                                                                                                                                                                                                   IF AverageMInFile <= 340.28456115722656 AND NumRevolvingTradesWBalance > 3.1006942987442017 THEN class = Bad
# 15                                                                                                              IF NetFractionInstallBurden > 73.458589 AND NumRevolvingTradesWBalance > 4.572987 AND NumSatisfactoryTrades > 19.0 AND NumTrades60Ever2DerogPubRec > -5.962701 AND PercentTradesNeverDelq > 91.0 THEN class = Bad
# 16                                                IF ExternalRiskEstimate <= 87.996897 AND MSinceOldestTradeOpen <= 104.441951 AND NumInqLast6Mexcl7days > -5.46259 AND NumRevolvingTradesWBalance > 1.0 AND NumSatisfactoryTrades <= 22.857461 AND NumTotalTrades > -9.0 AND NumTrades60Ever2DerogPubRec > -9.0 THEN class = Bad
# 17                                                                                                                                                                           IF MSinceOldestTradeOpen <= 75.0 AND NumInqLast6M > -9.0 AND NumRevolvingTradesWBalance > 8.370698 AND NumSatisfactoryTrades > 18.0 THEN class = Bad
# 18                                                     IF AverageMInFile <= 58.0 AND MSinceMostRecentInqexcl7days > -5.689952 AND MSinceOldestTradeOpen <= 82.0 AND NetFractionInstallBurden > 36.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades > 17.426141 AND PercentInstallTrades <= 43.0 THEN class = Bad
# 19                                                                                                                                                                                                               IF AverageMInFile <= 34.0 AND ExternalRiskEstimate <= 59.49445 AND NumSatisfactoryTrades > 18.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.16705    0.26511  0.82829    2       0       3.45537       False
# 1   0.33520    0.47239  0.73553    2       0       4.70856       False
# 2   0.22715    0.33159  0.76188    2       1       6.81062       False
# 3   0.19478    0.27480  0.73633    2       0       3.07180       False
# 4   0.18836    0.26799  0.74257    2       0       3.63994       False
# 5   0.77421    0.73750  0.49718    3       0      59.69534       False
# 6   0.00505    0.00785  0.81081    5       0      69.65521       False
# 7   0.63311    0.65533  0.54024    4       0      58.32553       False
# 8   0.92815    0.91756  0.51597    3       0      54.36948       False
# 9   0.11351    0.09317  0.42840    8       0      55.64925       False
# 10  0.89851    0.88956  0.51672    3       0      18.42998       False
# 11  0.94004    0.93824  0.52092    3       0      17.16368       False
# 12  0.94345    0.94164  0.52092    3       0      20.05867       False
# 13  0.15135    0.16933  0.58394    4       0      17.59610       False
# 14  0.44953    0.49071  0.56974    2       0      17.10405       False
# 15  0.06912    0.07014  0.52964    5       0       2.07041       False
# 16  0.09316    0.13086  0.73314    7       0       3.85701       False
# 17  0.00410    0.00576  0.73333    4       0       2.61702       False
# 18  0.00669    0.00995  0.77551    7       0       2.02970       False
# 19  0.00205    0.00288  0.73333    3       0       2.23679       False
# ### Rules for Instance 1758, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0           1758    ANCHOR   ANCHOR1
# 1           1758    ANCHOR   ANCHOR2
# 2           1758    ANCHOR   ANCHOR3
# 3           1758    ANCHOR   ANCHOR4
# 4           1758    ANCHOR   ANCHOR5
# 5           1758      LORE     LORE1
# 6           1758      LORE     LORE3
# 7           1758      LORE     LORE4
# 8           1758      LORE     LORE5
# 9           1758   LORE_SA  LORE_SA1
# 10          1758   LORE_SA  LORE_SA2
# 11          1758   LORE_SA  LORE_SA3
# 12          1758   LORE_SA  LORE_SA4
# 13          1758   LORE_SA  LORE_SA5
# 14          1758    EXPLAN   EXPLAN1
# 15          1758    EXPLAN   EXPLAN2
#
#                                                                                                                                                                                                                                                                                                                              Rule  \
# 0                                                                                                                                                                                                                                          IF ExternalRiskEstimate <= 63.0 AND NetFractionRevolvingBurden > 25.0 THEN class = Bad
# 1                                                                                                                                                                                                                                                     IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad
# 2                                                                                                                                                                                                                                                     IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                                                                                                                     IF AverageMInFile <= 52.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad
# 4                                                                                                                                                                                                                                                IF ExternalRiskEstimate <= 71.0 AND NumInqLast6Mexcl7days > 1.0 THEN class = Bad
# 5                                                                                                                                                                                                              IF NumInstallTradesWBalance <= 4.0 AND NumRevolvingTradesWBalance > -8.0 AND NumTotalTrades > 7.0 THEN class = Bad
# 6                                                                                                                                                                    IF NumInstallTradesWBalance <= 30.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 59.0 AND PercentInstallTrades > 24.0 THEN class = Bad
# 7                                                                                                                                                                                            IF NumBank2NatlTradesWHighUtilization <= 89.0 AND NumInstallTradesWBalance <= 4.0 AND NumSatisfactoryTrades <= 73.0 THEN class = Bad
# 8   IF MSinceMostRecentTradeOpen > 1.860985 AND NetFractionInstallBurden > 73.0 AND NumBank2NatlTradesWHighUtilization <= 0.020979 AND NumInstallTradesWBalance <= 11.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 87.0 AND NumTotalTrades > 6.0 AND NumTrades60Ever2DerogPubRec <= 32.0 THEN class = Bad
# 9                                                                                                                                                          IF MSinceMostRecentTradeOpen <= 364.1134338378906 AND NumRevolvingTradesWBalance > 0.24002157524228096 AND NumSatisfactoryTrades <= 70.77135467529297 THEN class = Bad
# 10                                                                                                                                                           IF NumSatisfactoryTrades <= 63.835981369018555 AND NumTrades60Ever2DerogPubRec > -8.036439895629883 AND PercentTradesWBalance > -0.8786664009094238 THEN class = Bad
# 11                                                                                                                                                      IF NumInstallTradesWBalance <= 20.63279438018799 AND NumInstallTradesWBalance > -8.018319129943848 AND NumTrades60Ever2DerogPubRec > -1.3539665341377258 THEN class = Bad
# 12                                                                                                                       IF AverageMInFile <= 366.85975646972656 AND MSinceMostRecentDelq <= 81.80145645141602 AND NumInstallTradesWBalance > 3.6677093505859375 AND NumSatisfactoryTrades <= 48.291690826416016 THEN class = Bad
# 13                                                                                                                                                                                                                   IF AverageMInFile <= 340.28456115722656 AND NumRevolvingTradesWBalance > 3.1006942987442017 THEN class = Bad
# 14                                                                                                              IF NetFractionInstallBurden > 73.458589 AND NumRevolvingTradesWBalance > 4.572987 AND NumSatisfactoryTrades > 19.0 AND NumTrades60Ever2DerogPubRec > -5.962701 AND PercentTradesNeverDelq > 91.0 THEN class = Bad
# 15                                                IF ExternalRiskEstimate <= 87.996897 AND MSinceOldestTradeOpen <= 104.441951 AND NumInqLast6Mexcl7days > -5.46259 AND NumRevolvingTradesWBalance > 1.0 AND NumSatisfactoryTrades <= 22.857461 AND NumTotalTrades > -9.0 AND NumTrades60Ever2DerogPubRec > -9.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.16705    0.26511  0.82829    2       0       3.45537       False
# 1   0.33520    0.47239  0.73553    2       0       4.70856       False
# 2   0.22715    0.33159  0.76188    2       1       6.81062       False
# 3   0.19478    0.27480  0.73633    2       0       3.07180       False
# 4   0.18836    0.26799  0.74257    2       0       3.63994       False
# 5   0.77421    0.73750  0.49718    3       0      59.69534       False
# 6   0.63311    0.65533  0.54024    4       0      58.32553       False
# 7   0.92815    0.91756  0.51597    3       0      54.36948       False
# 8   0.11351    0.09317  0.42840    8       0      55.64925       False
# 9   0.89851    0.88956  0.51672    3       0      18.42998       False
# 10  0.94004    0.93824  0.52092    3       0      17.16368       False
# 11  0.94345    0.94164  0.52092    3       0      20.05867       False
# 12  0.15135    0.16933  0.58394    4       0      17.59610       False
# 13  0.44953    0.49071  0.56974    2       0      17.10405       False
# 14  0.06912    0.07014  0.52964    5       0       2.07041       False
# 15  0.09316    0.13086  0.73314    7       0       3.85701       False
# ### Rules for Instance 1758, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.94345, Pre: 0.82829)
# <style type="text/css">
# #T_acf31_row4_col0, #T_acf31_row4_col1, #T_acf31_row4_col2, #T_acf31_row4_col3, #T_acf31_row4_col4, #T_acf31_row4_col5, #T_acf31_row4_col6, #T_acf31_row4_col7, #T_acf31_row4_col8, #T_acf31_row4_col9, #T_acf31_row4_col10, #T_acf31_row4_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_acf31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acf31_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_acf31_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_acf31_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_acf31_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_acf31_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_acf31_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_acf31_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_acf31_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_acf31_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_acf31_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_acf31_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_acf31_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acf31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acf31_row0_col0" class="data row0 col0" >1758</td>
#       <td id="T_acf31_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_acf31_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_acf31_row0_col3" class="data row0 col3" >IF ExternalRiskEstimate <= 63.0 AND NetFractionRevolvingBurden > 25.0 THEN class = Bad</td>
#       <td id="T_acf31_row0_col4" class="data row0 col4" >0.167050</td>
#       <td id="T_acf31_row0_col5" class="data row0 col5" >0.265110</td>
#       <td id="T_acf31_row0_col6" class="data row0 col6" >0.828290</td>
#       <td id="T_acf31_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_acf31_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_acf31_row0_col9" class="data row0 col9" >3.455370</td>
#       <td id="T_acf31_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_acf31_row0_col11" class="data row0 col11" >0.776400</td>
#     </tr>
#     <tr>
#       <th id="T_acf31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acf31_row1_col0" class="data row1 col0" >1758</td>
#       <td id="T_acf31_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_acf31_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_acf31_row1_col3" class="data row1 col3" >IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad</td>
#       <td id="T_acf31_row1_col4" class="data row1 col4" >0.335200</td>
#       <td id="T_acf31_row1_col5" class="data row1 col5" >0.472390</td>
#       <td id="T_acf31_row1_col6" class="data row1 col6" >0.735530</td>
#       <td id="T_acf31_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_acf31_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_acf31_row1_col9" class="data row1 col9" >4.708560</td>
#       <td id="T_acf31_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_acf31_row1_col11" class="data row1 col11" >0.615282</td>
#     </tr>
#     <tr>
#       <th id="T_acf31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_acf31_row2_col0" class="data row2 col0" >1758</td>
#       <td id="T_acf31_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_acf31_row2_col2" class="data row2 col2" >ANCHOR3</td>
#       <td id="T_acf31_row2_col3" class="data row2 col3" >IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad</td>
#       <td id="T_acf31_row2_col4" class="data row2 col4" >0.227150</td>
#       <td id="T_acf31_row2_col5" class="data row2 col5" >0.331590</td>
#       <td id="T_acf31_row2_col6" class="data row2 col6" >0.761880</td>
#       <td id="T_acf31_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_acf31_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_acf31_row2_col9" class="data row2 col9" >6.810620</td>
#       <td id="T_acf31_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_acf31_row2_col11" class="data row2 col11" >0.719372</td>
#     </tr>
#     <tr>
#       <th id="T_acf31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_acf31_row3_col0" class="data row3 col0" >1758</td>
#       <td id="T_acf31_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_acf31_row3_col2" class="data row3 col2" >LORE3</td>
#       <td id="T_acf31_row3_col3" class="data row3 col3" >IF NumInstallTradesWBalance <= 30.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 59.0 AND PercentInstallTrades > 24.0 THEN class = Bad</td>
#       <td id="T_acf31_row3_col4" class="data row3 col4" >0.633110</td>
#       <td id="T_acf31_row3_col5" class="data row3 col5" >0.655330</td>
#       <td id="T_acf31_row3_col6" class="data row3 col6" >0.540240</td>
#       <td id="T_acf31_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_acf31_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_acf31_row3_col9" class="data row3 col9" >58.325530</td>
#       <td id="T_acf31_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_acf31_row3_col11" class="data row3 col11" >0.423419</td>
#     </tr>
#     <tr>
#       <th id="T_acf31_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_acf31_row4_col0" class="data row4 col0" >1758</td>
#       <td id="T_acf31_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_acf31_row4_col2" class="data row4 col2" >LORE_SA3</td>
#       <td id="T_acf31_row4_col3" class="data row4 col3" >IF NumInstallTradesWBalance <= 20.63279438018799 AND NumInstallTradesWBalance > -8.018319129943848 AND NumTrades60Ever2DerogPubRec > -1.3539665341377258 THEN class = Bad</td>
#       <td id="T_acf31_row4_col4" class="data row4 col4" >0.943450</td>
#       <td id="T_acf31_row4_col5" class="data row4 col5" >0.941640</td>
#       <td id="T_acf31_row4_col6" class="data row4 col6" >0.520920</td>
#       <td id="T_acf31_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_acf31_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_acf31_row4_col9" class="data row4 col9" >20.058670</td>
#       <td id="T_acf31_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_acf31_row4_col11" class="data row4 col11" >0.307370</td>
#     </tr>
#     <tr>
#       <th id="T_acf31_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_acf31_row5_col0" class="data row5 col0" >1758</td>
#       <td id="T_acf31_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_acf31_row5_col2" class="data row5 col2" >LORE_SA5</td>
#       <td id="T_acf31_row5_col3" class="data row5 col3" >IF AverageMInFile <= 340.28456115722656 AND NumRevolvingTradesWBalance > 3.1006942987442017 THEN class = Bad</td>
#       <td id="T_acf31_row5_col4" class="data row5 col4" >0.449530</td>
#       <td id="T_acf31_row5_col5" class="data row5 col5" >0.490710</td>
#       <td id="T_acf31_row5_col6" class="data row5 col6" >0.569740</td>
#       <td id="T_acf31_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_acf31_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_acf31_row5_col9" class="data row5 col9" >17.104050</td>
#       <td id="T_acf31_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_acf31_row5_col11" class="data row5 col11" >0.557499</td>
#     </tr>
#   </tbody>
# </table>
# ### Rules for Instance 1758, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.94164, Pre: 0.82829, Len: 0.52092)
# <style type="text/css">
# #T_777d0_row1_col0, #T_777d0_row1_col1, #T_777d0_row1_col2, #T_777d0_row1_col3, #T_777d0_row1_col4, #T_777d0_row1_col5, #T_777d0_row1_col6, #T_777d0_row1_col7, #T_777d0_row1_col8, #T_777d0_row1_col9, #T_777d0_row1_col10, #T_777d0_row1_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_777d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_777d0_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_777d0_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_777d0_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_777d0_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_777d0_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_777d0_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_777d0_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_777d0_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_777d0_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_777d0_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_777d0_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_777d0_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_777d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_777d0_row0_col0" class="data row0 col0" >1758</td>
#       <td id="T_777d0_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_777d0_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_777d0_row0_col3" class="data row0 col3" >IF ExternalRiskEstimate <= 63.0 AND NetFractionRevolvingBurden > 25.0 THEN class = Bad</td>
#       <td id="T_777d0_row0_col4" class="data row0 col4" >0.167050</td>
#       <td id="T_777d0_row0_col5" class="data row0 col5" >0.265110</td>
#       <td id="T_777d0_row0_col6" class="data row0 col6" >0.828290</td>
#       <td id="T_777d0_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_777d0_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_777d0_row0_col9" class="data row0 col9" >3.455370</td>
#       <td id="T_777d0_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_777d0_row0_col11" class="data row0 col11" >1.626459</td>
#     </tr>
#     <tr>
#       <th id="T_777d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_777d0_row1_col0" class="data row1 col0" >1758</td>
#       <td id="T_777d0_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_777d0_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_777d0_row1_col3" class="data row1 col3" >IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 71.0 THEN class = Bad</td>
#       <td id="T_777d0_row1_col4" class="data row1 col4" >0.335200</td>
#       <td id="T_777d0_row1_col5" class="data row1 col5" >0.472390</td>
#       <td id="T_777d0_row1_col6" class="data row1 col6" >0.735530</td>
#       <td id="T_777d0_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_777d0_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_777d0_row1_col9" class="data row1 col9" >4.708560</td>
#       <td id="T_777d0_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_777d0_row1_col11" class="data row1 col11" >1.554502</td>
#     </tr>
#     <tr>
#       <th id="T_777d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_777d0_row2_col0" class="data row2 col0" >1758</td>
#       <td id="T_777d0_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_777d0_row2_col2" class="data row2 col2" >ANCHOR3</td>
#       <td id="T_777d0_row2_col3" class="data row2 col3" >IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad</td>
#       <td id="T_777d0_row2_col4" class="data row2 col4" >0.227150</td>
#       <td id="T_777d0_row2_col5" class="data row2 col5" >0.331590</td>
#       <td id="T_777d0_row2_col6" class="data row2 col6" >0.761880</td>
#       <td id="T_777d0_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_777d0_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_777d0_row2_col9" class="data row2 col9" >6.810620</td>
#       <td id="T_777d0_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_777d0_row2_col11" class="data row2 col11" >1.601327</td>
#     </tr>
#     <tr>
#       <th id="T_777d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_777d0_row3_col0" class="data row3 col0" >1758</td>
#       <td id="T_777d0_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_777d0_row3_col2" class="data row3 col2" >LORE3</td>
#       <td id="T_777d0_row3_col3" class="data row3 col3" >IF NumInstallTradesWBalance <= 30.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 59.0 AND PercentInstallTrades > 24.0 THEN class = Bad</td>
#       <td id="T_777d0_row3_col4" class="data row3 col4" >0.633110</td>
#       <td id="T_777d0_row3_col5" class="data row3 col5" >0.655330</td>
#       <td id="T_777d0_row3_col6" class="data row3 col6" >0.540240</td>
#       <td id="T_777d0_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_777d0_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_777d0_row3_col9" class="data row3 col9" >58.325530</td>
#       <td id="T_777d0_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_777d0_row3_col11" class="data row3 col11" >3.502705</td>
#     </tr>
#     <tr>
#       <th id="T_777d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_777d0_row4_col0" class="data row4 col0" >1758</td>
#       <td id="T_777d0_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_777d0_row4_col2" class="data row4 col2" >LORE_SA3</td>
#       <td id="T_777d0_row4_col3" class="data row4 col3" >IF NumInstallTradesWBalance <= 20.63279438018799 AND NumInstallTradesWBalance > -8.018319129943848 AND NumTrades60Ever2DerogPubRec > -1.3539665341377258 THEN class = Bad</td>
#       <td id="T_777d0_row4_col4" class="data row4 col4" >0.943450</td>
#       <td id="T_777d0_row4_col5" class="data row4 col5" >0.941640</td>
#       <td id="T_777d0_row4_col6" class="data row4 col6" >0.520920</td>
#       <td id="T_777d0_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_777d0_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_777d0_row4_col9" class="data row4 col9" >20.058670</td>
#       <td id="T_777d0_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_777d0_row4_col11" class="data row4 col11" >2.498062</td>
#     </tr>
#     <tr>
#       <th id="T_777d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_777d0_row5_col0" class="data row5 col0" >1758</td>
#       <td id="T_777d0_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_777d0_row5_col2" class="data row5 col2" >LORE_SA5</td>
#       <td id="T_777d0_row5_col3" class="data row5 col3" >IF AverageMInFile <= 340.28456115722656 AND NumRevolvingTradesWBalance > 3.1006942987442017 THEN class = Bad</td>
#       <td id="T_777d0_row5_col4" class="data row5 col4" >0.449530</td>
#       <td id="T_777d0_row5_col5" class="data row5 col5" >0.490710</td>
#       <td id="T_777d0_row5_col6" class="data row5 col6" >0.569740</td>
#       <td id="T_777d0_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_777d0_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_777d0_row5_col9" class="data row5 col9" >17.104050</td>
#       <td id="T_777d0_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_777d0_row5_col11" class="data row5 col11" >1.567758</td>
#     </tr>
#   </tbody>
# </table>
# ## Instance 2674 (Original: Bad , Predicted: Bad)
#                                     Value
# ExternalRiskEstimate                 58.0
# MSinceOldestTradeOpen               183.0
# MSinceMostRecentTradeOpen            11.0
# AverageMInFile                       36.0
# NumSatisfactoryTrades                30.0
# NumTrades60Ever2DerogPubRec           0.0
# NumTrades90Ever2DerogPubRec           0.0
# PercentTradesNeverDelq              100.0
# MSinceMostRecentDelq                 -7.0
# MaxDelq2PublicRecLast12M                7
# MaxDelqEver                             8
# NumTotalTrades                       32.0
# NumTradesOpeninLast12M                3.0
# PercentInstallTrades                 17.0
# MSinceMostRecentInqexcl7days         -7.0
# NumInqLast6M                          8.0
# NumInqLast6Mexcl7days                 7.0
# NetFractionRevolvingBurden           87.0
# NetFractionInstallBurden             -8.0
# NumRevolvingTradesWBalance           15.0
# NumInstallTradesWBalance              2.0
# NumBank2NatlTradesWHighUtilization   10.0
# PercentTradesWBalance                81.0
# ### Rules for Instance 2674
#    Instance_Name Explainer   Rule_ID  \
# 0           2674    ANCHOR   ANCHOR1
# 1           2674    ANCHOR   ANCHOR2
# 2           2674    ANCHOR   ANCHOR3
# 3           2674    ANCHOR   ANCHOR4
# 4           2674    ANCHOR   ANCHOR5
# 5           2674      LORE     LORE1
# 6           2674      LORE     LORE2
# 7           2674      LORE     LORE3
# 8           2674      LORE     LORE4
# 9           2674      LORE     LORE5
# 10          2674   LORE_SA  LORE_SA1
# 11          2674   LORE_SA  LORE_SA2
# 12          2674   LORE_SA  LORE_SA3
# 13          2674   LORE_SA  LORE_SA4
# 14          2674   LORE_SA  LORE_SA5
# 15          2674    EXPLAN   EXPLAN1
# 16          2674    EXPLAN   EXPLAN2
# 17          2674    EXPLAN   EXPLAN3
# 18          2674    EXPLAN   EXPLAN4
# 19          2674    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                           Rule  \
# 0                                                                                                                                                       IF ExternalRiskEstimate <= 63.0 AND NetFractionRevolvingBurden > 25.0 THEN class = Bad
# 1                                                                                                                                                                  IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 2                                                                                                                                                                  IF AverageMInFile <= 52.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                   IF NetFractionRevolvingBurden > 53.0 AND NumRevolvingTradesWBalance > 3.0 THEN class = Bad
# 4                                                                                                                                                             IF ExternalRiskEstimate <= 71.0 AND NumInqLast6Mexcl7days > 1.0 THEN class = Bad
# 5                                                                                                                  IF NumInstallTradesWBalance <= 2.0 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 58.0 THEN class = Bad
# 6                                                                       IF MSinceMostRecentInqexcl7days <= -7.0 AND NumInstallTradesWBalance <= 58.0 AND NumTrades90Ever2DerogPubRec > -9.0 AND PercentTradesNeverDelq > 97.0 THEN class = Bad
# 7      IF MSinceOldestTradeOpen <= 183.0 AND MaxDelq2PublicRecLast12M = 7 AND NumInstallTradesWBalance <= 7.122739 AND NumRevolvingTradesWBalance > -7.671498 AND NumTotalTrades > 7.0 AND NumTrades60Ever2DerogPubRec <= 0.0 THEN class = Bad
# 8                                                                                   IF NumInstallTradesWBalance <= 38.139574 AND NumRevolvingTradesWBalance > -8.0 AND NumSatisfactoryTrades <= 73.0 AND NumTotalTrades > 7.0 THEN class = Bad
# 9                                                                                                                  IF MSinceMostRecentTradeOpen > 10.0 AND NumInstallTradesWBalance <= 60.0 AND NumSatisfactoryTrades <= 51.0 THEN class = Bad
# 10                                                                                                                                                                       IF NumRevolvingTradesWBalance > -0.06557974219322205 THEN class = Bad
# 11                                                                                                                                                                        IF NumRevolvingTradesWBalance > -0.2960152328014374 THEN class = Bad
# 12                                                                                                                   IF NumRevolvingTradesWBalance > -0.9221477955579758 AND NumTrades90Ever2DerogPubRec > -5.819913625717163 THEN class = Bad
# ...
#       <th id="T_b9bf2_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_b9bf2_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_b9bf2_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_b9bf2_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_b9bf2_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_b9bf2_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_b9bf2_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9bf2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9bf2_row0_col0" class="data row0 col0" >779</td>
#       <td id="T_b9bf2_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_b9bf2_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_b9bf2_row0_col3" class="data row0 col3" >IF ExternalRiskEstimate > 80.0 AND MSinceOldestTradeOpen > 116.0 AND NumBank2NatlTradesWHighUtilization <= 1.0 THEN class = Good</td>
#       <td id="T_b9bf2_row0_col4" class="data row0 col4" >0.201610</td>
#       <td id="T_b9bf2_row0_col5" class="data row0 col5" >0.344000</td>
#       <td id="T_b9bf2_row0_col6" class="data row0 col6" >0.815720</td>
#       <td id="T_b9bf2_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_b9bf2_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_b9bf2_row0_col9" class="data row0 col9" >11.663960</td>
#       <td id="T_b9bf2_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_b9bf2_row0_col11" class="data row0 col11" >0.533814</td>
#     </tr>
#     <tr>
#       <th id="T_b9bf2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9bf2_row1_col0" class="data row1 col0" >779</td>
#       <td id="T_b9bf2_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_b9bf2_row1_col2" class="data row1 col2" >ANCHOR3</td>
#       <td id="T_b9bf2_row1_col3" class="data row1 col3" >IF ExternalRiskEstimate > 80.0 AND NumBank2NatlTradesWHighUtilization <= 0.0 AND NumSatisfactoryTrades > 12.0 THEN class = Good</td>
#       <td id="T_b9bf2_row1_col4" class="data row1 col4" >0.152570</td>
#       <td id="T_b9bf2_row1_col5" class="data row1 col5" >0.264290</td>
#       <td id="T_b9bf2_row1_col6" class="data row1 col6" >0.828110</td>
#       <td id="T_b9bf2_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_b9bf2_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_b9bf2_row1_col9" class="data row1 col9" >25.960730</td>
#       <td id="T_b9bf2_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_b9bf2_row1_col11" class="data row1 col11" >0.582710</td>
#     </tr>
#     <tr>
#       <th id="T_b9bf2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9bf2_row2_col0" class="data row2 col0" >779</td>
#       <td id="T_b9bf2_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_b9bf2_row2_col2" class="data row2 col2" >ANCHOR5</td>
#       <td id="T_b9bf2_row2_col3" class="data row2 col3" >IF ExternalRiskEstimate > 80.0 AND MSinceOldestTradeOpen > 116.0 AND NetFractionRevolvingBurden <= 25.0 AND NumBank2NatlTradesWHighUtilization <= 1.0 THEN class = Good</td>
#       <td id="T_b9bf2_row2_col4" class="data row2 col4" >0.184260</td>
#       <td id="T_b9bf2_row2_col5" class="data row2 col5" >0.317140</td>
#       <td id="T_b9bf2_row2_col6" class="data row2 col6" >0.822830</td>
#       <td id="T_b9bf2_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_b9bf2_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_b9bf2_row2_col9" class="data row2 col9" >22.346450</td>
#       <td id="T_b9bf2_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_b9bf2_row2_col11" class="data row2 col11" >0.551045</td>
#     </tr>
#     <tr>
#       <th id="T_b9bf2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9bf2_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_b9bf2_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_b9bf2_row3_col2" class="data row3 col2" >LORE2</td>
#       <td id="T_b9bf2_row3_col3" class="data row3 col3" >IF NumRevolvingTradesWBalance <= 13.0 AND NumTotalTrades > 0.0 AND NumTrades60Ever2DerogPubRec <= 9.0 AND NumTrades90Ever2DerogPubRec <= 0.0 THEN class = Good</td>
#       <td id="T_b9bf2_row3_col4" class="data row3 col4" >0.712880</td>
#       <td id="T_b9bf2_row3_col5" class="data row3 col5" >0.786000</td>
#       <td id="T_b9bf2_row3_col6" class="data row3 col6" >0.527110</td>
#       <td id="T_b9bf2_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_b9bf2_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_b9bf2_row3_col9" class="data row3 col9" >57.595670</td>
#       <td id="T_b9bf2_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_b9bf2_row3_col11" class="data row3 col11" >0.301832</td>
#     </tr>
#     <tr>
#       <th id="T_b9bf2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9bf2_row4_col0" class="data row4 col0" >779</td>
#       <td id="T_b9bf2_row4_col1" class="data row4 col1" >LORE</td>
#       <td id="T_b9bf2_row4_col2" class="data row4 col2" >LORE4</td>
#       <td id="T_b9bf2_row4_col3" class="data row4 col3" >IF ExternalRiskEstimate <= 86.0 AND NetFractionRevolvingBurden > 4.0 AND NumTrades60Ever2DerogPubRec <= 18.0 AND NumTrades90Ever2DerogPubRec <= 29.0 THEN class = Good</td>
#       <td id="T_b9bf2_row4_col4" class="data row4 col4" >0.735280</td>
#       <td id="T_b9bf2_row4_col5" class="data row4 col5" >0.650000</td>
#       <td id="T_b9bf2_row4_col6" class="data row4 col6" >0.422630</td>
#       <td id="T_b9bf2_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_b9bf2_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_b9bf2_row4_col9" class="data row4 col9" >58.950910</td>
#       <td id="T_b9bf2_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_b9bf2_row4_col11" class="data row4 col11" >0.405480</td>
#     </tr>
#     <tr>
#       <th id="T_b9bf2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9bf2_row5_col0" class="data row5 col0" >779</td>
#       <td id="T_b9bf2_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_b9bf2_row5_col2" class="data row5 col2" >LORE_SA2</td>
#       <td id="T_b9bf2_row5_col3" class="data row5 col3" >IF MaxDelqEver != 5 AND NetFractionRevolvingBurden <= 146.11051559448242 AND NumInqLast6M <= 3.477618098258972 AND NumInqLast6Mexcl7days <= 5.83966064453125 AND NumRevolvingTradesWBalance <= 2.520010232925415 AND NumSatisfactoryTrades > 3.692939877510071 AND NumTrades60Ever2DerogPubRec <= 3.9774001836776733 AND NumTrades90Ever2DerogPubRec <= 14.84234619140625 AND NumTradesOpeninLast12M <= 9.619357585906982 AND PercentTradesNeverDelq > 81.01913070678711 THEN class = Good</td>
#       <td id="T_b9bf2_row5_col4" class="data row5 col4" >0.227020</td>
#       <td id="T_b9bf2_row5_col5" class="data row5 col5" >0.304000</td>
#       <td id="T_b9bf2_row5_col6" class="data row5 col6" >0.640190</td>
#       <td id="T_b9bf2_row5_col7" class="data row5 col7" >10</td>
#       <td id="T_b9bf2_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_b9bf2_row5_col9" class="data row5 col9" >16.691980</td>
#       <td id="T_b9bf2_row5_c
# ### Rules for Instance 779, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.786, Pre: 0.82811, Len: 0.52711)
# <style type="text/css">
# #T_f0270_row0_col0, #T_f0270_row0_col1, #T_f0270_row0_col2, #T_f0270_row0_col3, #T_f0270_row0_col4, #T_f0270_row0_col5, #T_f0270_row0_col6, #T_f0270_row0_col7, #T_f0270_row0_col8, #T_f0270_row0_col9, #T_f0270_row0_col10, #T_f0270_row0_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f0270">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0270_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_f0270_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_f0270_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_f0270_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_f0270_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_f0270_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_f0270_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_f0270_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_f0270_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_f0270_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_f0270_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_f0270_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0270_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0270_row0_col0" class="data row0 col0" >779</td>
#       <td id="T_f0270_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_f0270_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_f0270_row0_col3" class="data row0 col3" >IF ExternalRiskEstimate > 80.0 AND MSinceOldestTradeOpen > 116.0 AND NumBank2NatlTradesWHighUtilization <= 1.0 THEN class = Good</td>
#       <td id="T_f0270_row0_col4" class="data row0 col4" >0.201610</td>
#       <td id="T_f0270_row0_col5" class="data row0 col5" >0.344000</td>
#       <td id="T_f0270_row0_col6" class="data row0 col6" >0.815720</td>
#       <td id="T_f0270_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_f0270_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_f0270_row0_col9" class="data row0 col9" >11.663960</td>
#       <td id="T_f0270_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_f0270_row0_col11" class="data row0 col11" >2.512111</td>
#     </tr>
#     <tr>
#       <th id="T_f0270_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0270_row1_col0" class="data row1 col0" >779</td>
#       <td id="T_f0270_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_f0270_row1_col2" class="data row1 col2" >ANCHOR3</td>
#       <td id="T_f0270_row1_col3" class="data row1 col3" >IF ExternalRiskEstimate > 80.0 AND NumBank2NatlTradesWHighUtilization <= 0.0 AND NumSatisfactoryTrades > 12.0 THEN class = Good</td>
#       <td id="T_f0270_row1_col4" class="data row1 col4" >0.152570</td>
#       <td id="T_f0270_row1_col5" class="data row1 col5" >0.264290</td>
#       <td id="T_f0270_row1_col6" class="data row1 col6" >0.828110</td>
#       <td id="T_f0270_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_f0270_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_f0270_row1_col9" class="data row1 col9" >25.960730</td>
#       <td id="T_f0270_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_f0270_row1_col11" class="data row1 col11" >2.527324</td>
#     </tr>
#     <tr>
#       <th id="T_f0270_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0270_row2_col0" class="data row2 col0" >779</td>
#       <td id="T_f0270_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_f0270_row2_col2" class="data row2 col2" >ANCHOR5</td>
#       <td id="T_f0270_row2_col3" class="data row2 col3" >IF ExternalRiskEstimate > 80.0 AND MSinceOldestTradeOpen > 116.0 AND NetFractionRevolvingBurden <= 25.0 AND NumBank2NatlTradesWHighUtilization <= 1.0 THEN class = Good</td>
#       <td id="T_f0270_row2_col4" class="data row2 col4" >0.184260</td>
#       <td id="T_f0270_row2_col5" class="data row2 col5" >0.317140</td>
#       <td id="T_f0270_row2_col6" class="data row2 col6" >0.822830</td>
#       <td id="T_f0270_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_f0270_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_f0270_row2_col9" class="data row2 col9" >22.346450</td>
#       <td id="T_f0270_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_f0270_row2_col11" class="data row2 col11" >3.504400</td>
#     </tr>
#     <tr>
#       <th id="T_f0270_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0270_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_f0270_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_f0270_row3_col2" class="data row3 col2" >LORE2</td>
#       <td id="T_f0270_row3_col3" class="data row3 col3" >IF NumRevolvingTradesWBalance <= 13.0 AND NumTotalTrades > 0.0 AND NumTrades60Ever2DerogPubRec <= 9.0 AND NumTrades90Ever2DerogPubRec <= 0.0 THEN class = Good</td>
#       <td id="T_f0270_row3_col4" class="data row3 col4" >0.712880</td>
#       <td id="T_f0270_row3_col5" class="data row3 col5" >0.786000</td>
#       <td id="T_f0270_row3_col6" class="data row3 col6" >0.527110</td>
#       <td id="T_f0270_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_f0270_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_f0270_row3_col9" class="data row3 col9" >57.595670</td>
#       <td id="T_f0270_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_f0270_row3_col11" class="data row3 col11" >3.485910</td>
#     </tr>
#   </tbody>
# </table>
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         0.5
# LORE                                           0.9
# LORE_SA                                        0.5
# EXPLAN                                         0.5
# Overall Average                                2.4
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                  0.000000
# LORE                                    0.400000
# LORE_SA                                 0.000000
# EXPLAN                                  1.666667
# Overall Average                         1.900000
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 2.222222
# LORE                                   2.300000
# LORE_SA                                2.888889
# EXPLAN                                 3.222222
# Overall Average                        9.800000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 2.111111
# LORE                                   2.200000
# LORE_SA                                3.000000
# EXPLAN                                 3.222222
# Overall Average                        9.700000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.778816  0.203990   0.314553  2.851852  0.370370
# LORE            0.513973  0.596218   0.605917  4.416667  0.000000
# LORE_SA         0.584176  0.533019   0.581292  7.281481  0.000000
# EXPLAN          0.687690  0.134270   0.193140  3.000000  0.000000
# Global_Average  0.632089  0.427300   0.485299  4.797531  0.123457
#
#                 Elapsed_time
# ANCHOR             10.713947
# LORE               62.784321
# LORE_SA            18.994816
# EXPLAN              3.282170
# Global_Average     28.627245
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.777240  0.197335   0.303959  2.777778  0.185185
# LORE            0.522169  0.602753   0.624817  4.370370  0.000000
# LORE_SA         0.573326  0.583339   0.623655  6.885417  0.000000
# EXPLAN          0.687690  0.134270   0.193140  3.000000  0.000000
# Global_Average  0.628481  0.444510   0.501532  4.533951  0.061728
#
#                 Elapsed_time
# ANCHOR             10.140485
# LORE               62.376826
# LORE_SA            19.191598
# EXPLAN              3.282170
# Global_Average     29.980398
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
