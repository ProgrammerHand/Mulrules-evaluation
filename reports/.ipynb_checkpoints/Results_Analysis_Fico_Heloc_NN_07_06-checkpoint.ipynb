# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results 

rules_log = "german_simpleNN_rules_53-23_06-06-2025.txt"
entries_log = "german_simpleNN_entries_53-23_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 844 (Original: good , Predicted: good)
#                                       Value
# checking_status                 no checking
# duration                               18.0
# credit_history                existing paid
# purpose                 furniture/equipment
# credit_amount                        3422.0
# savings_status                     less 100
# employment                  greater 7 years
# installment_commitment                  4.0
# personal_status                 male single
# other_parties                          none
# residence_since                         4.0
# property_magnitude           life insurance
# age                                    47.0
# other_payment_plans                    bank
# housing                                 own
# existing_credits                        3.0
# job                                 skilled
# num_dependents                          2.0
# own_telephone                           yes
# foreign_worker                          yes
# ### Rules for Instance 844
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844      LORE     LORE2
# 7            844      LORE     LORE3
# 8            844      LORE     LORE4
# 9            844      LORE     LORE5
# 10           844   LORE_SA  LORE_SA1
# 11           844   LORE_SA  LORE_SA2
# 12           844   LORE_SA  LORE_SA3
# 13           844   LORE_SA  LORE_SA4
# 14           844   LORE_SA  LORE_SA5
# 15           844    EXPLAN   EXPLAN1
# 16           844    EXPLAN   EXPLAN2
# 17           844    EXPLAN   EXPLAN3
# 18           844    EXPLAN   EXPLAN4
# 19           844    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Rule  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           IF credit_history = existing paid AND duration > 12.0 AND existing_credits > 1.0 AND installment_commitment > 3.24 AND job = skilled AND other_parties = none AND savings_status = less 100 THEN class = good
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    IF checking_status = no checking AND housing = own THEN class = good
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      IF age > 26.72 AND checking_status = no checking THEN class = good
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       IF credit_amount > 2319.5 AND credit_history = existing paid AND duration > 12.0 AND existing_credits > 2.0 AND foreign_worker = yes AND installment_commitment > 3.24 AND installment_commitment <= 4.0 AND job = skilled AND other_parties = none AND other_payment_plans = bank AND personal_status = male single AND purpose = furniture/equipment AND residence_since <= 4.0 AND savings_status = less 100 THEN class = good
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF checking_status = no checking AND duration <= 18.403629 THEN class = bad
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF checking_status = no checking AND duration <= 30.080163 THEN class = bad
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF checking_status = no checking AND duration <= 31.799547 THEN class = bad
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF checking_status = no checking AND duration <= 26.669003 THEN class = bad
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF checking_status = no checking AND duration <= 34.287775 THEN class = bad
# 10                                                                                    IF age <= 47.25358963012695 AND age > 40.972707748413086 AND checking_status = no checking AND credit_amount <= 4618.39453125 AND credit_history = existing paid AND duration <= 18.002692222595215 AND duration > 17.425070762634277 AND employment != unemployed AND employment = greater 7 years AND existing_credits <= 3.0370434522628784 AND existing_credits > 2.991695284843445 AND foreign_worker != no AND housing != for free AND housing = own AND installment_commitment > 3.930368661880493 AND job = skilled AND num_dependents > 1.9967041611671448 AND other_parties = none AND own_telephone = yes AND personal_status = male single AND property_magnitude != no known property AND property_magnitude != car AND property_magnitude != real estate AND purpose != new car AND purpose != education AND purpose = furniture/equipment AND residence_since > 3.9202569723129272 THEN class = good
# 11                                                                                                                        IF checking_status = no checking AND credit_amount <= 3729.041748046875 AND credit_history = existing paid AND duration <= 18.52749538421631 AND duration > 15.291162014007568 AND employment != less 1 year AND employment = greater 7 years AND existing_credits <= 3.030575394630432 AND existing_credits > 2.9991430044174194 AND foreign_worker = yes AND housing != for free AND housing != rent AND installment_commitment > 3.9196702241897583 AND job != unemp/unskilled non res AND job = skilled AND num_dependents > 1.996793806552887 AND other_parties != co applicant AND other_payment_plans = bank AND own_telephone != none AND personal_status = male single AND property_magnitude != car AND property_magnitude = life insurance AND purpose = furniture/equipment AND residence_since > 3.980507254600525 AND savings_status = less 100 THEN class = good
# 12   IF age <= 47.2462272644043 AND age > 46.846967697143555 AND checking_status != less 0 AND checking_status = no checking AND credit_amount <= 8073.6162109375 AND credit_amount > 2694.8709106445312 AND credit_history = existing paid AND duration <= 38.538888931274414 AND duration > 17.670019149780273 AND employment != unemployed AND employment != less 1 year AND existing_credits <= 3.0012422800064087 AND existing_credits > 2.957472085952759 AND foreign_worker = yes AND housing = own AND installment_commitment > 3.955679774284363 AND job = skilled AND num_dependents > 1.993779718875885 AND other_parties != guarantor AND other_payment_plans = bank AND own_telephone = yes AND personal_status = male single AND property_magnitude != no known property AND property_magnitude = life insurance AND purpose != education AND purpose != new car AND purpose = furniture/equipment AND residence_since > 3.9734197854995728 AND savings_status = less 100 THEN class = good
# 13                              IF age <= 49.85687828063965 AND age > 46.762460708618164 AND checking_status != less 0 AND checking_status = no checking AND credit_amount <= 11115.98876953125 AND credit_amount > 3387.2928466796875 AND credit_history != no credits/all paid AND credit_history != all paid AND duration <= 18.480554580688477 AND duration > 16.89264440536499 AND employment = greater 7 years AND existing_credits <= 3.009175419807434 AND existing_credits > 2.9384807348251343 AND foreign_worker = yes AND housing != for free AND housing != rent AND installment_commitment > 3.8083670139312744 AND job = skilled AND num_dependents > 1.9950151443481445 AND other_parties = none AND other_payment_plans = bank AND own_telephone = yes AND personal_status = male single AND property_magnitude != car AND property_magnitude = life insurance AND purpose = furniture/equipment AND residence_since > 3.999993324279785 AND savings_status = less 100 THEN class = good
# 14  IF age <= 47.036916732788086 AND age > 37.5438346862793 AND checking_status = no checking AND credit_amount <= 4448.032958984375 AND credit_amount > 2298.4163818359375 AND credit_history = existing paid AND duration <= 33.58477592468262 AND duration > 17.79329490661621 AND employment != less 1 year AND employment = greater 7 years AND existing_credits <= 3.0097098350524902 AND existing_credits > 2.8341702222824097 AND housing != for free AND housing != rent AND installment_commitment > 3.980890154838562 AND job = skilled AND num_dependents > 1.9824331998825073 AND other_parties = none AND other_payment_plans = bank AND own_telephone != none AND personal_status != female div/dep/mar AND personal_status = male single AND property_magnitude != no known property AND property_magnitude = life insurance AND purpose != new car AND purpose = furniture/equipment AND residence_since > 3.922324061393738 AND savings_status != between 100 and 500 THEN class = good
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            IF checking_status = no checking AND duration <= 41.438399 THEN class = bad
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               IF checking_status = no checking AND credit_amount > 2629.0 AND credit_amount <= 3780.0 THEN class = bad
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           IF checking_status = no checking AND credit_amount > 3092.0 THEN class = bad
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           IF checking_status = no checking AND credit_amount > 2718.0 THEN class = bad
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              IF checking_status = no checking AND credit_amount <= 4304.613225 AND other_parties = none AND savings_status = less 100 THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.03469    0.00204  0.02941    7       0      19.85508       False
# 1   0.23163    0.40816  0.88106    2       0       1.49341       False
# 2   0.23163    0.39388  0.85022    2       0       1.46498       False
# 3   0.24592    0.41837  0.85062    2       3       6.48467       False
# 4   0.00000    0.00000  0.00000   14       4      45.89303       False
# 5   0.16020    0.03265  0.10191    2       0      40.54449       False
# 6   0.24592    0.05918  0.12033    2       0      40.62325       False
# 7   0.24592    0.05918  0.12033    2       0      40.51656       False
# 8   0.23163    0.05510  0.11894    2       0      40.42889       False
# 9   0.24898    0.06122  0.12295    2       0      39.39691       False
# 10  0.00000    0.00000  0.00000   27       0       8.35034       False
# 11  0.00000    0.00000  0.00000   25       0       8.69482       False
# 12  0.00000    0.00000  0.00000   29       0       8.94965       False
# 13  0.00000    0.00000  0.00000   28       0       8.75955       False
# 14  0.00000    0.00000  0.00000   28       0       8.72150       False
# 15  0.27959    0.08163  0.14599    2       0       1.50542       False
# 16  0.04898    0.01224  0.12500    3       0       2.23056       False
# 17  0.10714    0.05510  0.25714    2       0       2.24392       False
# 18  0.12551    0.05918  0.23577    2       0       1.36694       False
# 19  0.10408    0.03061  0.14706    4       0       1.54454       False
# ### Rules for Instance 844, Correct Prediction
#   Instance_Name Explainer   Rule_ID  \
# 0           844    ANCHOR   ANCHOR1
# 1           844    ANCHOR   ANCHOR2
# 2           844    ANCHOR   ANCHOR3
# 3           844    ANCHOR   ANCHOR4
# 4           844    ANCHOR   ANCHOR5
# 5           844   LORE_SA  LORE_SA1
# 6           844   LORE_SA  LORE_SA2
# 7           844   LORE_SA  LORE_SA3
# 8           844   LORE_SA  LORE_SA4
# 9           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Rule  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          IF credit_history = existing paid AND duration > 12.0 AND existing_credits > 1.0 AND installment_commitment > 3.24 AND job = skilled AND other_parties = none AND savings_status = less 100 THEN class = good
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   IF checking_status = no checking AND housing = own THEN class = good
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     IF age > 26.72 AND checking_status = no checking THEN class = good
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      IF credit_amount > 2319.5 AND credit_history = existing paid AND duration > 12.0 AND existing_credits > 2.0 AND foreign_worker = yes AND installment_commitment > 3.24 AND installment_commitment <= 4.0 AND job = skilled AND other_parties = none AND other_payment_plans = bank AND personal_status = male single AND purpose = furniture/equipment AND residence_since <= 4.0 AND savings_status = less 100 THEN class = good
# 5                                                                                    IF age <= 47.25358963012695 AND age > 40.972707748413086 AND checking_status = no checking AND credit_amount <= 4618.39453125 AND credit_history = existing paid AND duration <= 18.002692222595215 AND duration > 17.425070762634277 AND employment != unemployed AND employment = greater 7 years AND existing_credits <= 3.0370434522628784 AND existing_credits > 2.991695284843445 AND foreign_worker != no AND housing != for free AND housing = own AND installment_commitment > 3.930368661880493 AND job = skilled AND num_dependents > 1.9967041611671448 AND other_parties = none AND own_telephone = yes AND personal_status = male single AND property_magnitude != no known property AND property_magnitude != car AND property_magnitude != real estate AND purpose != new car AND purpose != education AND purpose = furniture/equipment AND residence_since > 3.9202569723129272 THEN class = good
# 6                                                                                                                        IF checking_status = no checking AND credit_amount <= 3729.041748046875 AND credit_history = existing paid AND duration <= 18.52749538421631 AND duration > 15.291162014007568 AND employment != less 1 year AND employment = greater 7 years AND existing_credits <= 3.030575394630432 AND existing_credits > 2.9991430044174194 AND foreign_worker = yes AND housing != for free AND housing != rent AND installment_commitment > 3.9196702241897583 AND job != unemp/unskilled non res AND job = skilled AND num_dependents > 1.996793806552887 AND other_parties != co applicant AND other_payment_plans = bank AND own_telephone != none AND personal_status = male single AND property_magnitude != car AND property_magnitude = life insurance AND purpose = furniture/equipment AND residence_since > 3.980507254600525 AND savings_status = less 100 THEN class = good
# 7   IF age <= 47.2462272644043 AND age > 46.846967697143555 AND checking_status != less 0 AND checking_status = no checking AND credit_amount <= 8073.6162109375 AND credit_amount > 2694.8709106445312 AND credit_history = existing paid AND duration <= 38.538888931274414 AND duration > 17.670019149780273 AND employment != unemployed AND employment != less 1 year AND existing_credits <= 3.0012422800064087 AND existing_credits > 2.957472085952759 AND foreign_worker = yes AND housing = own AND installment_commitment > 3.955679774284363 AND job = skilled AND num_dependents > 1.993779718875885 AND other_parties != guarantor AND other_payment_plans = bank AND own_telephone = yes AND personal_status = male single AND property_magnitude != no known property AND property_magnitude = life insurance AND purpose != education AND purpose != new car AND purpose = furniture/equipment AND residence_since > 3.9734197854995728 AND savings_status = less 100 THEN class = good
# 8                              IF age <= 49.85687828063965 AND age > 46.762460708618164 AND checking_status != less 0 AND checking_status = no checking AND credit_amount <= 11115.98876953125 AND credit_amount > 3387.2928466796875 AND credit_history != no credits/all paid AND credit_history != all paid AND duration <= 18.480554580688477 AND duration > 16.89264440536499 AND employment = greater 7 years AND existing_credits <= 3.009175419807434 AND existing_credits > 2.9384807348251343 AND foreign_worker = yes AND housing != for free AND housing != rent AND installment_commitment > 3.8083670139312744 AND job = skilled AND num_dependents > 1.9950151443481445 AND other_parties = none AND other_payment_plans = bank AND own_telephone = yes AND personal_status = male single AND property_magnitude != car AND property_magnitude = life insurance AND purpose = furniture/equipment AND residence_since > 3.999993324279785 AND savings_status = less 100 THEN class = good
# 9  IF age <= 47.036916732788086 AND age > 37.5438346862793 AND checking_status = no checking AND credit_amount <= 4448.032958984375 AND credit_amount > 2298.4163818359375 AND credit_history = existing paid AND duration <= 33.58477592468262 AND duration > 17.79329490661621 AND employment != less 1 year AND employment = greater 7 years AND existing_credits <= 3.0097098350524902 AND existing_credits > 2.8341702222824097 AND housing != for free AND housing != rent AND installment_commitment > 3.980890154838562 AND job = skilled AND num_dependents > 1.9824331998825073 AND other_parties = none AND other_payment_plans = bank AND own_telephone != none AND personal_status != female div/dep/mar AND personal_status = male single AND property_magnitude != no known property AND property_magnitude = life insurance AND purpose != new car AND purpose = furniture/equipment AND residence_since > 3.922324061393738 AND savings_status != between 100 and 500 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03469    0.00204  0.02941    7       0      19.85508       False
# 1  0.23163    0.40816  0.88106    2       0       1.49341       False
# 2  0.23163    0.39388  0.85022    2       0       1.46498       False
# 3  0.24592    0.41837  0.85062    2       3       6.48467       False
# 4  0.00000    0.00000  0.00000   14       4      45.89303       False
# 5  0.00000    0.00000  0.00000   27       0       8.35034       False
# 6  0.00000    0.00000  0.00000   25       0       8.69482       False
# 7  0.00000    0.00000  0.00000   29       0       8.94965       False
# 8  0.00000    0.00000  0.00000   28       0       8.75955       False
# 9  0.00000    0.00000  0.00000   28       0       8.72150       False
# ### Rules for Instance 844, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer  Rule_ID  \
# 0           844    ANCHOR  ANCHOR2
# 1           844    ANCHOR  ANCHOR3
# 2           844    ANCHOR  ANCHOR4
#
#                                                                        Rule  \
# 0  IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 1      IF checking_status = no checking AND housing = own THEN class = good
# 2        IF age > 26.72 AND checking_status = no checking THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.40816  0.88106    2       0       1.49341       False
# 1  0.23163    0.39388  0.85022    2       0       1.46498       False
# 2  0.24592    0.41837  0.85062    2       3       6.48467       False
# ### Rules for Instance 844, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer  Rule_ID  \
# 0           844    ANCHOR  ANCHOR2
# 1           844    ANCHOR  ANCHOR4
#
#                                                                        Rule  \
# 0  IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 1        IF age > 26.72 AND checking_status = no checking THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.40816  0.88106    2       0       1.49341       False
# 1  0.24592    0.41837  0.85062    2       3       6.48467       False
# ### Rules for Instance 844, Non-dominated (Cov_class↑, Pre↑, Len↓)
#   Instance_Name Explainer  Rule_ID  \
# 0           844    ANCHOR  ANCHOR2
# 1           844    ANCHOR  ANCHOR4
#
#                                                                        Rule  \
# 0  IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 1        IF age > 26.72 AND checking_status = no checking THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.40816  0.88106    2       0       1.49341       False
# 1  0.24592    0.41837  0.85062    2       3       6.48467       False
# ## Instance 480 (Original: good , Predicted: good)
#                                                  Value
# checking_status                      between 0 and 200
# duration                                          12.0
# credit_history          critical/other existing credit
# purpose                                       radio/tv
# credit_amount                                   3573.0
# savings_status                                less 100
# employment                       between 1 and 4 years
# installment_commitment                             1.0
# personal_status                     female div/dep/mar
# other_parties                                     none
# residence_since                                    1.0
# property_magnitude                         real estate
# age                                               23.0
# other_payment_plans                               none
# housing                                            own
# existing_credits                                   1.0
# job                                 unskilled resident
# num_dependents                                     1.0
# own_telephone                                     none
# foreign_worker                                     yes
# ### Rules for Instance 480
#    Instance_Name Explainer   Rule_ID  \
# 0            480    ANCHOR   ANCHOR1
# 1            480    ANCHOR   ANCHOR2
# 2            480    ANCHOR   ANCHOR3
# 3            480    ANCHOR   ANCHOR4
# 4            480    ANCHOR   ANCHOR5
# 5            480      LORE     LORE1
# 6            480      LORE     LORE2
# 7            480      LORE     LORE3
# 8            480      LORE     LORE4
# 9            480      LORE     LORE5
# 10           480   LORE_SA  LORE_SA1
# 11           480   LORE_SA  LORE_SA2
# 12           480   LORE_SA  LORE_SA3
# 13           480   LORE_SA  LORE_SA4
# 14           480   LORE_SA  LORE_SA5
# 15           480    EXPLAN   EXPLAN1
# 16           480    EXPLAN   EXPLAN2
# 17           480    EXPLAN   EXPLAN3
# 18           480    EXPLAN   EXPLAN4
# 19           480    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Rule  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            IF credit_history = critical/other existing credit AND duration <= 18.0 AND installment_commitment <= 3.24 THEN class = good
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         IF credit_history = critical/other existing credit AND duration <= 25.78 AND property_magnitude = real estate THEN class = good
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF credit_history = critical/other existing credit AND duration <= 12.0 AND housing = own THEN class = good
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                IF credit_history = critical/other existing credit AND housing = own AND installment_commitment <= 2.0 THEN class = good
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 THEN class = good
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               IF duration <= 20.249137 THEN class = bad
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           IF credit_history = critical/other existing credit AND duration <= 19.547314 THEN class = bad
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               IF duration <= 12.475314 THEN class = bad
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           IF credit_history = critical/other existing credit AND duration <= 22.746279 THEN class = bad
# ...
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01327    0.00204  0.07692    4       0       3.82413       False
# 1   0.00408    0.00816  1.00000    6       0       8.69993       False
# 2   0.02551    0.00612  0.12000    5       0       3.70329       False
# 3   0.02551    0.04694  0.92000    5       0       8.21245       False
# 4   0.00918    0.00408  0.22222    4       1       6.33613       False
# 5   0.03571    0.00612  0.08571    4       0      39.51969       False
# 6   0.12347    0.07551  0.30579    2       0      39.64529       False
# 7   0.00510    0.00000  0.00000    3       0      39.86809       False
# 8   0.00000    0.00000  0.00000    7       0      40.22119       False
# 9   0.06429    0.02653  0.20635    2       0      39.64143       False
# 10  0.00000    0.00000  0.00000   33       0       8.01729       False
# 11  0.00000    0.00000  0.00000   29       0       8.62608       False
# 12  0.00000    0.00000  0.00000   25       0       8.77380       False
# 13  0.00000    0.00000  0.00000   31       0       7.79167       False
# 14  0.00000    0.00000  0.00000   25       0       7.99806       False
# 15  0.00510    0.00000  0.00000    6       0       1.67183       False
# 16  0.00204    0.00408  1.00000    7       0       1.98300       False
# 17  0.00000    0.00000  0.00000    9       0       1.68392       False
# 18  0.01122    0.01224  0.54545    7       0       1.70975       False
# 19  0.00918    0.00204  0.11111    3       0       1.15831       False
# ### Rules for Instance 216, Correct Prediction
#   Instance_Name Explainer   Rule_ID  \
# 0           216   LORE_SA  LORE_SA1
# 1           216   LORE_SA  LORE_SA2
# 2           216   LORE_SA  LORE_SA3
# 3           216   LORE_SA  LORE_SA4
# 4           216   LORE_SA  LORE_SA5
# 5           216    EXPLAN   EXPLAN1
# 6           216    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Rule  \
# 0  IF age <= 42.98436737060547 AND age > 30.63681411743164 AND checking_status != greater 200 AND checking_status = less 0 AND credit_amount <= 5991.5537109375 AND credit_amount > 3048.8968505859375 AND credit_history != critical/other existing credit AND credit_history != all paid AND credit_history != delayed previously AND duration <= 21.644817352294922 AND duration > 17.524585723876953 AND employment = between 4 and 7 years AND existing_credits <= 1.0124475955963135 AND foreign_worker = yes AND housing = own AND installment_commitment <= 3.0693482160568237 AND installment_commitment > 2.8896193504333496 AND job = skilled AND num_dependents <= 1.004823088645935 AND other_parties != co applicant AND other_parties != guarantor AND other_payment_plans != stores AND other_payment_plans = bank AND own_telephone = yes AND personal_status != male div/sep AND personal_status != female div/dep/mar AND property_magnitude = life insurance AND purpose != domestic appliance AND purpose != other AND purpose != furniture/equipment AND purpose = business AND residence_since <= 1.0151851177215576 AND savings_status = less 100 THEN class = good
# 1                                                                                                                                                                                  IF age <= 46.25736427307129 AND age > 30.638808250427246 AND checking_status = less 0 AND credit_amount <= 4188.114501953125 AND credit_amount > 2581.901123046875 AND credit_history != existing paid AND duration <= 18.201661109924316 AND employment != less 1 year AND employment != greater 7 years AND employment != between 1 and 4 years AND existing_credits <= 1.0824811458587646 AND foreign_worker != no AND housing != for free AND housing != rent AND installment_commitment <= 3.074464201927185 AND installment_commitment > 2.9901537895202637 AND job != unemp/unskilled non res AND job != unskilled resident AND job = skilled AND num_dependents <= 1.0357210040092468 AND other_parties = none AND other_payment_plans != none AND other_payment_plans = bank AND own_telephone = yes AND personal_status = male single AND property_magnitude = life insurance AND purpose = business AND residence_since <= 1.0083581805229187 AND savings_status = less 100 THEN class = good
# 2                                                                                                                                                                                                                                                                                     IF age <= 31.290276527404785 AND checking_status = less 0 AND credit_amount <= 3868.394775390625 AND credit_amount > 2065.7208862304688 AND credit_history = no credits/all paid AND duration <= 18.171175003051758 AND employment = between 4 and 7 years AND existing_credits <= 1.0354505777359009 AND foreign_worker = yes AND housing = own AND installment_commitment <= 3.036020278930664 AND installment_commitment > 2.9696574211120605 AND job != unemp/unskilled non res AND job = skilled AND num_dependents <= 1.0147238373756409 AND other_parties = none AND other_payment_plans != none AND other_payment_plans = bank AND own_telephone = yes AND personal_status != female div/dep/mar AND personal_status != male mar/wid AND property_magnitude = life insurance AND purpose != new car AND residence_since <= 1.0027741193771362 AND savings_status = less 100 THEN class = good
# 3                                                                                             IF age <= 31.404093742370605 AND age > 30.587284088134766 AND checking_status = less 0 AND credit_amount <= 3886.584228515625 AND credit_amount > 2991.0091552734375 AND credit_history = no credits/all paid AND duration <= 27.800479888916016 AND duration > 17.621461868286133 AND employment = between 4 and 7 years AND existing_credits <= 1.1782987117767334 AND foreign_worker = yes AND housing != rent AND housing != for free AND installment_commitment <= 3.029358148574829 AND installment_commitment > 2.9093176126480103 AND job != unskilled resident AND job != unemp/unskilled non res AND job = skilled AND num_dependents <= 1.0833178162574768 AND other_parties = none AND other_payment_plans != stores AND other_payment_plans = bank AND own_telephone != none AND personal_status = male single AND property_magnitude != no known property AND property_magnitude != real estate AND property_magnitude = life insurance AND purpose != new car AND purpose = business AND residence_since <= 1.0255072116851807 AND savings_status = less 100 THEN class = good
# 4                                                                                                                                                                                                                                                                                                    IF age <= 31.49677848815918 AND age > 24.706568717956543 AND checking_status != between 0 and 200 AND credit_amount <= 7936.6724853515625 AND credit_history = no credits/all paid AND duration <= 18.399264335632324 AND duration > 17.283148765563965 AND employment = between 4 and 7 years AND existing_credits <= 1.011988639831543 AND foreign_worker = yes AND housing = own AND installment_commitment <= 3.0041913986206055 AND installment_commitment > 2.9759843349456787 AND job != unemp/unskilled non res AND job = skilled AND num_dependents <= 1.002467393875122 AND other_parties = none AND other_payment_plans = bank AND own_telephone = yes AND personal_status = male single AND property_magnitude = life insurance AND purpose != education AND purpose != radio/tv AND residence_since <= 1.0088977813720703 AND savings_status = less 100 THEN class = good
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    IF checking_status = less 0 AND credit_amount > 2870.865778 AND credit_history = no credits/all paid AND foreign_worker = yes AND other_parties = none AND savings_status = less 100 THEN class = good
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      IF checking_status = less 0 AND credit_history = no credits/all paid AND savings_status = less 100 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.00000    0.00000  0.00000   33       0       8.01729       False
# 1  0.00000    0.00000  0.00000   29       0       8.62608       False
# 2  0.00000    0.00000  0.00000   25       0       8.77380       False
# 3  0.00000    0.00000  0.00000   31       0       7.79167       False
# 4  0.00000    0.00000  0.00000   25       0       7.99806       False
# 5  0.00510    0.00000  0.00000    6       0       1.67183       False
# 6  0.00918    0.00204  0.11111    3       0       1.15831       False
# ### Rules for Instance 216, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# ### Rules for Instance 216, Non-dominated (Cov↑, Pre↑)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# C:\Politechnika_poznanska\Master thesis\Mulrules-evaluation\reports\parser_util.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# C:\Politechnika_poznanska\Master thesis\Mulrules-evaluation\reports\parser_util.py:139: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Explainer', bbox_to_anchor=(1.05, 1), loc='upper left')
# C:\Politechnika_poznanska\Master thesis\Mulrules-evaluation\reports\parser_util.py:221: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# Empty dataframe: nothing to plot.
# ### Rules for Instance 216, Non-dominated (Cov_class↑, Pre↑, Len↓)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# Empty dataframe: nothing to plot.
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         1.5
# EXPLAN                                         4.6
# LORE                                           4.6
# LORE_SA                                        0.5
# Overall Average                               11.2
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                  0.285714
# EXPLAN                                  2.000000
# LORE                                    3.000000
# LORE_SA                                 2.666667
# Overall Average                         3.300000
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 1.571429
# EXPLAN                                 0.000000
# LORE                                   0.000000
# LORE_SA                                2.600000
# Overall Average                        2.400000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 1.285714
# EXPLAN                                 0.000000
# LORE                                   0.000000
# LORE_SA                                3.000000
# Overall Average                        2.400000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.889631  0.162639   0.284975  3.071429  1.333333
# LORE_SA         0.890856  0.092858   0.155203  4.250000  0.000000
# LORE            0.380950  0.042860   0.032650  5.000000  0.000000
# Global_Average  0.850973  0.126586   0.215653  3.673077  0.717949
#
#                 Elapsed_time
# ANCHOR              5.442078
# LORE_SA             8.479261
# LORE               40.148380
# Global_Average      9.279941
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.890921  0.161084   0.282740  2.988095  1.261905
# LORE_SA         0.910943  0.067552   0.118163  4.200000  0.000000
# LORE            0.380950  0.042860   0.032650  5.000000  0.000000
# Global_Average  0.859393  0.116016   0.200203  3.608974  0.679487
#
#                 Elapsed_time
# ANCHOR              5.000219
# LORE_SA             8.447223
# LORE               40.148380
# Global_Average      9.029694
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
