# %%
import json
from collections import defaultdict
from tabulate import tabulate
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from numpy import *

def load_entries_to_df(file_path):
    entries = []
    with open(file_path, "r") as f:
        for line in f:
            data = json.loads(line)
            if data.get("type") == "entry":
                instance_name = data.get("entry_name")
                instance = data.get("instance", {})
                features = instance.get("features", {})
                original = instance.get("original_outcome")
                predicted = instance.get("predicted_outcome")

                entry_dict = {
                    "Instance_Name": instance_name,
                    "Original_Outcome": original,
                    "Predicted_Outcome": predicted,
                    **features
                }
                entries.append(entry_dict)
    df = pd.DataFrame(entries)
    return df


def load_and_group_rules(file_path):
    grouped_rules = defaultdict(lambda: defaultdict(list))

    with open(file_path, "r") as f:
        for line in f:
            data = json.loads(line)
            if data.get("type") == "rule":
                premises = data["rule"]["premises"]
                premises_str = " AND ".join(f'{p["attr"]} {p["op"]} {p["val"]}' for p in premises)
                consequence = data["rule"]["consequence"]
                consequence_str = f'{consequence["attr"]} {consequence["op"]} {consequence["val"]}'
                rule_str = f'IF {premises_str} THEN {consequence_str}'

                metrics = data.get("metrics", {})
                rule_dict = {
                    "Premises": premises,
                    "Rule_ID": None,
                    "Rule": rule_str,
                    "Cov": round(metrics.get("coverage", 0), 5),
                    "Cov_class": round(metrics.get("local_class_coverage", 0), 5),
                    "Pre": round(metrics.get("precision", 0), 5),
                    "Len": metrics.get("rule_length", 0),
                    "Reject": metrics.get("rejected", 0),
                    "Elapsed_time": round(metrics.get("elapsed_time", 0), 5),
                    "Iter_Limit": data.get("at_limit", False)
                }

                instance_name = data.get("entry_name")
                explainer = data.get("explainer")
                grouped_rules[instance_name][explainer].append(rule_dict)

    return grouped_rules

def grouped_rules_to_df(grouped_rules):
    rows = []
    for instance_name, explainers_dict in grouped_rules.items():
        for explainer, rules_list in explainers_dict.items():
           for i, rule_dict in enumerate(rules_list, start=1):
                row = {
                    "Instance_Name": instance_name,
                    "Explainer": explainer,
                }
                row.update(rule_dict)
                row["Rule_ID"] = f"{explainer}{i}"
                rows.append(row)
    return pd.DataFrame(rows)


def filter_non_dominated(df, cov_col='Cov', pre_col='Pre'):
    non_dominated_indices = []
    for i, row_i in df.iterrows():
        dominated = False
        for j, row_j in df.iterrows():
            if i != j:
                if (row_j[cov_col] >= row_i[cov_col] and
                    row_j[pre_col] >= row_i[pre_col] and
                    (row_j[cov_col] > row_i[cov_col] or row_j[pre_col] > row_i[pre_col])):
                    dominated = True
                    break
        if not dominated:
            non_dominated_indices.append(i)

    return df.loc[non_dominated_indices].reset_index(drop=True).copy()

def ideal_point_rule_2d(df, col_1='Cov', col_1_prop="gain", col_2='Pre', col_2_prop="gain"):
    if not df.empty:
        if col_1_prop == "loss":
            col_1_ideal = df[col_1].min()
        else:
            col_1_ideal = df[col_1].max()
        if col_2_prop == "loss":
            col_2_ideal = df[col_2].min()
        else:
            col_2_ideal = df[col_2].max()
            
        df['Distance_idp_eucl'] = numpy.sqrt((df[col_1] - col_1_ideal)**2 + (df[col_2] - col_2_ideal)**2)
        
        return df['Distance_idp_eucl'].idxmin(), [col_1_ideal,col_2_ideal]

def ideal_point_rule_3d(df, col_1='Cov_class', col_1_prop="gain", col_2='Pre', col_2_prop="gain", col_3='Len', col_3_prop="loss"):
    if not df.empty:
        if col_1_prop == "loss":
            col_1_ideal = df[col_1].min()
        else:
            col_1_ideal = df[col_1].max()
        if col_2_prop == "loss":
            col_2_ideal = df[col_2].min()
        else:
            col_2_ideal = df[col_2].max()
        if col_3_prop == "loss":
            col_3_ideal = df[col_2].min()
        else:
            col_3_ideal = df[col_2].max()
            
        df['Distance_idp_eucl'] = numpy.sqrt((df[col_1] - col_1_ideal)**2 + (df[col_2] - col_2_ideal)**2 + (df[col_3] - col_3_ideal)**2)
        # df.loc[df['Distance_idp_eucl'].idxmin()]
        return df['Distance_idp_eucl'].idxmin(), [col_1_ideal,col_2_ideal,col_3_ideal]

def filter_non_dominated_3d(df, cov_col='Cov_class', pre_col='Pre', len_col='Len'):
    # convert to numpy for speed
    data = df[[cov_col, pre_col, len_col]].to_numpy()

    non_dominated_mask = []
    for i, candidate in enumerate(data):
        dominated = False
        for j, other in enumerate(data):
            if i == j:
                continue
            # check if 'other' dominates 'candidate':
            # other is better or equal in all objectives AND strictly better in at least one
            # for cov_col and pre_col (to maximize): other >= candidate
            # for len_col (to minimize): other <= candidate
            if (other[0] >= candidate[0] and
                other[1] >= candidate[1] and
                other[2] <= candidate[2] and
                (other[0] > candidate[0] or other[1] > candidate[1] or other[2] < candidate[2])):
                dominated = True
                break
        non_dominated_mask.append(not dominated)

    return df.loc[non_dominated_mask].reset_index(drop=True).copy()
    
def plot_non_dominated_rules(non_dominated_rules, instance_name, coord_1 = 'Cov', coord_2 = 'Pre'):
    ideal_rule_idx, ideal_point = ideal_point_rule_2d(non_dominated_rules)
    ideal_rule = non_dominated_rules.loc[ideal_rule_idx]
    plt.figure(figsize=(8,6))
    sns.scatterplot(
        data=non_dominated_rules,
        x= coord_1,
        y= coord_2,
        hue='Explainer',
        style='Explainer',
        palette='tab10',
        s=100
    )

    plt.scatter(
        ideal_point[0], ideal_point[1],
        color='black',
        marker='X',
        s=100,
        label='Ideal Point'
    )

    plt.plot(
        [ideal_point[0], ideal_rule[coord_1]],
        [ideal_point[1], ideal_rule[coord_2]],
        'k--',  # black dashed line
        linewidth=1.5
    )

    plt.title(f"Non-dominated Rules for Instance {instance_name} (Coverage ↑, Precision ↑)")
    plt.xlabel("Coverage")
    plt.ylabel("Precision")
    plt.legend(title='Explainer', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def count_unique_attributes_from_rules(df_rules):
    attr_counter = Counter()

    for premises in df_rules['Premises']:
        seen_attrs = set()
        for cond in premises:
            attr = cond['attr']
            seen_attrs.add(attr)
        for attr in seen_attrs:
            attr_counter[attr] += 1  # count only once per rule
    return dict(attr_counter)

def build_attr_usage_df(df_rules):
    rows = []
    for explainer, group in df_rules.groupby('Explainer'):
        attr_counts = count_unique_attributes_from_rules(group)
        for attr, count in attr_counts.items():
            rows.append({"Explainer": explainer, "Feature": attr, "Count": count})
    return pd.DataFrame(rows)

def plot_feature_usage_heatmap(df: pd.DataFrame,
                               feature_col: str,
                               explainer_col: str,
                               count_col: str,
                               all_features: list,
                               vmax: float = None,
                               figsize=(10,8),
                               cmap='YlOrRd'):

    if df.empty:
        print("Empty dataframe: nothing to plot.")
        return
    # pivot table with counts: rows=features, columns=explainers
    heatmap_data = df.pivot_table(index=feature_col, columns=explainer_col, values=count_col, fill_value=0)
    heatmap_data = heatmap_data.reindex(all_features, fill_value=0)

    explainers_with_features = heatmap_data.columns.tolist()
    top_feature_names = heatmap_data.index.tolist()
    actual_max_count = heatmap_data.values.max()
    theoretical_max = vmax if vmax is not None else actual_max_count

    if heatmap_data is not None and theoretical_max > 0:
        plt.figure(figsize=figsize)
        plt.imshow(heatmap_data, cmap=cmap, vmax=theoretical_max, aspect='auto')
        plt.colorbar(label='Rule Count')
        plt.xticks(ticks=range(len(explainers_with_features)), labels=explainers_with_features, rotation=45, ha='right')
        plt.yticks(ticks=range(len(top_feature_names)), labels=top_feature_names)
        plt.title(f'Feature Usage Across Explainers\n(Scale: 0 to {theoretical_max}, Actual max: {actual_max_count})')
        plt.tight_layout()
        plt.show()
    else:
        print("No data to display or vmax <= 0.")

def plot_rules_comparison(all_rules, filtered_rules, instance_name, coord_1 = 'Cov', coord_2 = 'Pre'):
    plt.figure(figsize=(8,6))

    # palette for explainers across both datasets
    explainers = sorted(all_rules['Explainer'].unique())
    palette = sns.color_palette('tab10', n_colors=len(explainers))
    explainer_palette = dict(zip(explainers, palette))
    ideal_rule_idx, ideal_point = ideal_point_rule_2d(filtered_rules)
    ideal_rule = filtered_rules.loc[ideal_rule_idx]
    # all rules - circles
    sns.scatterplot(
        data=all_rules,
        x=coord_1,
        y=coord_2,
        hue='Explainer',
        palette=explainer_palette,
        s=60,
        alpha=0.5,
        marker='o'
    )

    # filtered rules - X markers with edgecolors
    sns.scatterplot(
        data=filtered_rules,
        x=coord_1,
        y=coord_2,
        hue='Explainer',
        palette=explainer_palette,
        s=120,
        marker='X',
        edgecolor='black'
    )

    plt.scatter(
        ideal_point[0], ideal_point[1],
        color='black',
        marker='X',
        s=100,
        label='Ideal Point'
    )

    plt.plot(
        [ideal_point[0], ideal_rule[coord_1]],
        [ideal_point[1], ideal_rule[coord_2]],
        'k--',  # black dashed line
        linewidth=1.5
    )

    # lines connecting filtered rules sorted by Coverage
    filtered_sorted = filtered_rules.sort_values(by=coord_1)
    plt.plot(filtered_sorted[coord_1], filtered_sorted[coord_2], color='gray', linestyle='--', linewidth=1)

    plt.title(f"Rules for Instance {instance_name} (Coverage ↑, Precision ↑)")
    plt.xlabel("Coverage")
    plt.ylabel("Precision")

    handles, labels = plt.gca().get_legend_handles_labels()

    by_label = dict(zip(labels, handles))

    plt.legend(by_label.values(), by_label.keys(), title='Explainer', bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.grid(True)
    plt.tight_layout()
    plt.show()

def summarize_explainer_metrics_with_global_average(explainer_dict):
    summary = {}
    all_rows = []

    for explainer, metrics_list in explainer_dict.items():
        df = pd.DataFrame(metrics_list)
        summary[explainer] = df.mean()
        all_rows.append(df)

    df_summary = pd.DataFrame(summary).T

    global_df = pd.concat(all_rows, ignore_index=True)
    df_summary.loc["Global_Average"] = global_df.mean()

    return df_summary

def highlight_row(s, highlight_idx):
    return ['font-weight: bold' if s.name == highlight_idx else '' for _ in s]

# %%
from IPython.display import display, Markdown
pd.set_option('display.max_colwidth', None)

def analyze_results(rules_log, entries_log, path = "./experiments_log/", min_cov = 0.1, min_cov_class = 0.1, min_pre = 0.1):
    rules_grouped = load_and_group_rules(path + rules_log)
    df_instances = load_entries_to_df(path + entries_log)
    df_rules = grouped_rules_to_df(rules_grouped)
    instance_names = df_rules['Instance_Name'].unique()
    filtered_counts = defaultdict(list)
    non_dom1_by_explainer = defaultdict(list)
    non_dom2_by_explainer = defaultdict(list)
    filtered_counts_by_explainer = {
        'Correct Prediction': defaultdict(list),
        'Threshold Filter': defaultdict(list),
        'Non-dominated 1': defaultdict(list),
        'Non-dominated 2': defaultdict(list),
    }
    agg_all_dom1 = []
    agg_all_dom2 = []
    
    for i, instance_name in enumerate(instance_names, start=1):
        max_rules = df_rules[df_rules['Instance_Name'] == instance_name].groupby('Explainer').size().max()
        orig = df_instances.loc[df_instances['Instance_Name'] == instance_name, "Original_Outcome"].iloc[0]
        pred = df_instances.loc[df_instances['Instance_Name'] == instance_name, "Predicted_Outcome"].iloc[0]
        display(Markdown(f"## Instance {instance_name} (Original: {orig} , Predicted: {pred})"))
        instance = df_instances[df_instances['Instance_Name'] == instance_name]
        exclude_cols = ['Instance_Name', 'Original_Outcome', 'Predicted_Outcome']
        attributes = [col for col in instance.columns if col not in exclude_cols]
        display(instance.drop(columns=['Instance_Name', 'Original_Outcome', 'Predicted_Outcome']).T.rename(columns={df_instances[df_instances['Instance_Name'] == instance_name].index[0]: 'Value'}))
        
        display(Markdown(f"### Rules for Instance {instance_name}"))
        display(df_rules[df_rules['Instance_Name'] == instance_name].drop(columns=["Premises"]).reset_index(drop=True))
       
        display(Markdown(f"### Rules for Instance {instance_name}, Correct Prediction"))
        original_outcome = df_instances.loc[df_instances['Instance_Name'] == instance_name, 'Original_Outcome'].values[0]
        correct_pred_rules = df_rules[
        (df_rules['Instance_Name'] == instance_name) &
        (df_rules['Rule'].str.contains(f'class = {original_outcome}', na=False))
        ]
        display(correct_pred_rules.drop(columns=["Premises"]).reset_index(drop=True))

        display(Markdown(f"### Rules for Instance {instance_name}, Min_treshold (Cov {min_cov}, Cov_class {min_cov_class}, Pre {min_pre})"))
        tresholded_rules = correct_pred_rules[
        (correct_pred_rules['Cov'] >= min_cov) &
        (correct_pred_rules['Cov_class'] >= min_cov_class) &
        (correct_pred_rules['Pre'] >= min_pre)
        ]
        display(tresholded_rules.drop(columns=["Premises"]).reset_index(drop=True))
    

        non_dominated_rules1 = filter_non_dominated(tresholded_rules)
        if not non_dominated_rules1.empty:
            ideal_rule_idx, ideal_point = ideal_point_rule_2d(non_dominated_rules1)
        display(Markdown(f"### Rules for Instance {instance_name}, Non-dominated (Cov↑, Pre↑), Ideal (Cov: {ideal_point[0]}, Pre: {ideal_point[1]})"))

        
        df_display = non_dominated_rules1.drop(columns=["Premises"]).reset_index(drop=True)

        display(df_display.style.apply(highlight_row, highlight_idx=ideal_rule_idx, axis=1))
        if not non_dominated_rules1.empty:
            plot_non_dominated_rules(non_dominated_rules1, instance_name)
            plot_rules_comparison(all_rules=df_rules[df_rules['Instance_Name'] == instance_name],
                                          filtered_rules=non_dominated_rules1,
                                          instance_name=instance_name)
        
        agg_df = build_attr_usage_df(non_dominated_rules1)
        agg_all_dom1.append(agg_df)
        plot_feature_usage_heatmap(agg_df, feature_col="Feature", explainer_col="Explainer", count_col="Count", all_features=attributes, vmax = max_rules)

        non_dominated_rules2 = filter_non_dominated_3d(tresholded_rules)
        if not non_dominated_rules2.empty:
            ideal_rule_idx, ideal_point = ideal_point_rule_3d(non_dominated_rules2)
        display(Markdown(f"### Rules for Instance {instance_name}, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: {ideal_point[0]}, Pre: {ideal_point[1]}, Len: {ideal_point[2]})"))
        df_display = non_dominated_rules2.drop(columns=["Premises"]).reset_index(drop=True)

        display(df_display.style.apply(highlight_row, highlight_idx=ideal_rule_idx, axis=1))
        agg_df = build_attr_usage_df(non_dominated_rules2)
        agg_all_dom2.append(agg_df)
        plot_feature_usage_heatmap(agg_df, feature_col="Feature", explainer_col="Explainer", count_col="Count", all_features=attributes, vmax = max_rules)
    
        all_rules_count = len(df_rules[df_rules['Instance_Name'] == instance_name])
        correct_pred_count = len(correct_pred_rules)
        tresholded_count = len(tresholded_rules)
        non_dom1_count = len(non_dominated_rules1)
        non_dom2_count = len(non_dominated_rules2)
        
        # filtered counts
        filtered_counts['Correct Prediction'].append(all_rules_count - correct_pred_count)
        filtered_counts['Threshold Filter'].append(correct_pred_count - tresholded_count)
        filtered_counts['Non-dominated 1'].append(tresholded_count - non_dom1_count)
        filtered_counts['Non-dominated 2'].append(tresholded_count - non_dom2_count)
    
        original_rules_instance = df_rules[df_rules['Instance_Name'] == instance_name]
        orig_counts = original_rules_instance['Explainer'].value_counts()
        correct_pred_counts = correct_pred_rules['Explainer'].value_counts()
        filtered_per_explainer_cp = (orig_counts - correct_pred_counts).fillna(orig_counts).astype(int)
        for explainer, count in filtered_per_explainer_cp.items():
            filtered_counts_by_explainer['Correct Prediction'][explainer].append(count)
        tresholded_counts = tresholded_rules['Explainer'].value_counts()
        filtered_per_explainer_thresh = (correct_pred_counts - tresholded_counts).fillna(correct_pred_counts).astype(int)
        for explainer, count in filtered_per_explainer_thresh.items():
            filtered_counts_by_explainer['Threshold Filter'][explainer].append(count)
        non_dom1_counts = non_dominated_rules1['Explainer'].value_counts()
        filtered_per_explainer_non_dom1 = (tresholded_counts - non_dom1_counts).fillna(tresholded_counts).astype(int)
        for explainer, count in filtered_per_explainer_non_dom1.items():
            filtered_counts_by_explainer['Non-dominated 1'][explainer].append(count)
        non_dominated_rules2 = filter_non_dominated_3d(tresholded_rules)
        non_dom2_counts = non_dominated_rules2['Explainer'].value_counts()
        filtered_per_explainer_non_dom2 = (tresholded_counts - non_dom2_counts).fillna(tresholded_counts).astype(int)
        for explainer, count in filtered_per_explainer_non_dom2.items():
            filtered_counts_by_explainer['Non-dominated 2'][explainer].append(count)
    
        
        if not non_dominated_rules1.empty:
            for explainer, group in non_dominated_rules1.groupby("Explainer"):
                non_dom1_by_explainer[explainer].append(
                    group[['Pre', 'Cov', 'Cov_class', 'Len', 'Reject', 'Elapsed_time']].mean()
                )
    
        if not non_dominated_rules2.empty:
            for explainer, group in non_dominated_rules2.groupby("Explainer"):
                non_dom2_by_explainer[explainer].append(
                    group[['Pre', 'Cov', 'Cov_class', 'Len', 'Reject', 'Elapsed_time']].mean()
                )
        
    
    # average filtered rules per stage
    display(Markdown("### Average Number of Filtered Rules at Each Step"))
    filtration_summary = pd.DataFrame({stage: pd.Series(values).mean() for stage, values in filtered_counts.items()}, index=["Avg Filtered"]).T
    # display(filtration_summary)
    step_avg_dfs = {}
    for step, explainer_dict in filtered_counts_by_explainer.items():
        df = pd.DataFrame({expl: pd.Series(counts) for expl, counts in explainer_dict.items()})
        step_avg_dfs[step] = df.mean().rename(step)  # Series with index=explainer, values=avg filtered
    
    combined_df = pd.concat(step_avg_dfs.values(), axis=1).fillna(0)
    combined_df.index.name = 'Explainer'
    combined_df.columns = [f"Avg Filtered ({col})" for col in combined_df.columns]
    
    mapping = {
        'Correct Prediction': 'Avg Filtered (Correct Prediction)',
        'Threshold Filter': 'Avg Filtered (Threshold Filter)',
        'Non-dominated 1': 'Avg Filtered (Non-dominated 1)',
        'Non-dominated 2': 'Avg Filtered (Non-dominated 2)'
    }
    new_row = {}
    for step, col_name in mapping.items():
        new_row[col_name] = filtration_summary.loc[step, 'Avg Filtered']
    
    combined_df.loc['Overall Average'] = pd.Series(new_row)
    display(combined_df)
    
    # average metrics for non-dominated rules
    display(Markdown("### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)"))
    explainer_summary1 = summarize_explainer_metrics_with_global_average(non_dom1_by_explainer)
    display(explainer_summary1)

    display(Markdown("### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)"))
    explainer_summary2 = summarize_explainer_metrics_with_global_average(non_dom2_by_explainer)
    display(explainer_summary2)

    agg_all_dom1_df = pd.concat(agg_all_dom1).groupby(['Feature', 'Explainer']).sum().reset_index()
    agg_all_dom2_df = pd.concat(agg_all_dom2).groupby(['Feature', 'Explainer']).sum().reset_index()

    all_features = [col for col in df_instances.columns if col not in ['Instance_Name', 'Original_Outcome', 'Predicted_Outcome']]
    
    display(Markdown("## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)"))
    plot_feature_usage_heatmap(agg_all_dom1_df, feature_col="Feature", explainer_col="Explainer", count_col="Count", all_features=all_features, vmax =max_rules * len(instance_names))
    
    display(Markdown("## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)"))
    plot_feature_usage_heatmap(agg_all_dom2_df, feature_col="Feature", explainer_col="Explainer", count_col="Count", all_features=all_features, vmax =max_rules * len(instance_names))

# %%
rules_log = "adult_simpleNN_rules_19-23_06-06-2025.txt"
entries_log = "adult_simpleNN_entries_19-23_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 5988 (Original: <=50K , Predicted: <=50K)
#                              Value
# age                           41.0
# workclass                  Private
# education             Some-college
# education.num                   10
# marital.status  Married-civ-spouse
# occupation         Farming-fishing
# relationship               Husband
# race                         White
# sex                           Male
# capital.gain                   0.0
# capital.loss                   0.0
# hours.per.week                16.0
# native.country       United-States
# ### Rules for Instance 5988
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988    ANCHOR   ANCHOR3
# 3           5988    ANCHOR   ANCHOR4
# 4           5988    ANCHOR   ANCHOR5
# 5           5988      LORE     LORE1
# 6           5988      LORE     LORE2
# 7           5988      LORE     LORE3
# 8           5988      LORE     LORE4
# 9           5988      LORE     LORE5
# 10          5988   LORE_SA  LORE_SA1
# 11          5988   LORE_SA  LORE_SA2
# 12          5988   LORE_SA  LORE_SA3
# 13          5988   LORE_SA  LORE_SA4
# 14          5988   LORE_SA  LORE_SA5
# 15          5988    EXPLAN   EXPLAN1
# 16          5988    EXPLAN   EXPLAN2
# 17          5988    EXPLAN   EXPLAN3
# 18          5988    EXPLAN   EXPLAN4
# 19          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                                            IF capital.gain <= 0.0 AND capital.loss <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                                                                                                                                                    IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                                                                                       IF age <= 47.0 AND capital.gain <= 0.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 3                                                                                                                                                                                    IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 4                                                                                                                                                                                               IF age <= 47.0 AND capital.gain <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 5                                                                                                                                                                                                            IF hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 6                                                                                                                                                                                                            IF hours.per.week <= 32.0 AND occupation = Farming-fishing THEN class = <=50K
# 7                                                                                                                                                                                                                                          IF age > 39.0 AND age <= 41.0 THEN class = >50K
# 8                                                                                                                                                                                                            IF hours.per.week <= 50.0 AND occupation = Farming-fishing THEN class = <=50K
# 9                                                                                                                                                                                                                                             IF hours.per.week <= 35.0 THEN class = <=50K
# 10  IF capital.gain <= 2874.854736328125 AND capital.loss <= 2694.723388671875 AND education.num != 15 AND hours.per.week <= 57.859853744506836 AND occupation != Exec-managerial AND occupation != Tech-support AND occupation != Craft-repair AND occupation != Sales THEN class = <=50K
# 11                                                                                                                  IF capital.gain <= 13079.5849609375 AND capital.loss <= 3071.783447265625 AND hours.per.week <= 48.838104248046875 AND occupation = Farming-fishing THEN class = <=50K
# 12                                                                                                                                          IF capital.gain <= 4119.5072021484375 AND education.num != 14 AND occupation = Farming-fishing AND workclass != Federal-gov THEN class = <=50K
# 13                                                                                                                                                         IF capital.gain <= 8678.97607421875 AND hours.per.week <= 51.03134536743164 AND occupation = Farming-fishing THEN class = <=50K
# 14                                                                                   IF capital.gain <= 4757.0059814453125 AND capital.loss <= 1754.4028930664062 AND education != Doctorate AND hours.per.week <= 17.114296913146973 AND occupation != Exec-managerial THEN class = <=50K
# 15                                                                                                                                                                                                                                            IF hours.per.week <= 30.0 THEN class = <=50K
# 16                                                                                                                                                                                                                                            IF hours.per.week <= 35.0 THEN class = <=50K
# 17                                                                                                                                                                                                                            IF age <= 49.0 AND hours.per.week <= 30.0 THEN class = <=50K
# 18                                                                                                                                                                                                                                            IF hours.per.week <= 28.0 THEN class = <=50K
# 19                                                                                                                                                                                                                            IF age <= 41.0 AND hours.per.week <= 34.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01571    0.01971  0.95251    4       0       1.54453       False
# 1   0.01615    0.02023  0.95109    3       0       1.68503       False
# 2   0.01816    0.02254  0.94203    4       0       1.55565       False
# 3   0.01474    0.01855  0.95536    3       3       6.51489       False
# 4   0.01887    0.02306  0.92791    3       0       1.49903       False
# 5   0.01571    0.01936  0.93575    2       0      42.03551       False
# 6   0.00461    0.00589  0.97143    2       0      40.73262       False
# 7   0.04866    0.06868  0.33995    2       0      35.27999       False
# 8   0.02119    0.02560  0.91718    2       0      35.37699       False
# 9   0.21231    0.25574  0.91445    1       0      35.56768       False
# 10  0.52733    0.59903  0.86238    8       0      10.22085       False
# 11  0.01742    0.02144  0.93451    4       0      10.33955       False
# 12  0.02817    0.03416  0.92056    4       0      10.51624       False
# 13  0.02075    0.02543  0.93023    3       0      10.27089       False
# 14  0.04611    0.05843  0.96194    5       0      10.65501       False
# 15  0.16234    0.19910  0.93108    1       0       0.65897       False
# 16  0.21231    0.25574  0.91445    1       0       0.66278       False
# 17  0.12061    0.15148  0.95344    2       4       3.37851       False
# 18  0.12614    0.15494  0.93252    1       0       0.74988       False
# 19  0.11412    0.14489  0.96386    2       0       1.04409       False
# ### Rules for Instance 5988, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988    ANCHOR   ANCHOR3
# 3           5988    ANCHOR   ANCHOR4
# 4           5988    ANCHOR   ANCHOR5
# 5           5988      LORE     LORE1
# 6           5988      LORE     LORE2
# 7           5988      LORE     LORE4
# 8           5988      LORE     LORE5
# 9           5988   LORE_SA  LORE_SA1
# 10          5988   LORE_SA  LORE_SA2
# 11          5988   LORE_SA  LORE_SA3
# 12          5988   LORE_SA  LORE_SA4
# 13          5988   LORE_SA  LORE_SA5
# 14          5988    EXPLAN   EXPLAN1
# 15          5988    EXPLAN   EXPLAN2
# 16          5988    EXPLAN   EXPLAN3
# 17          5988    EXPLAN   EXPLAN4
# 18          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                                            IF capital.gain <= 0.0 AND capital.loss <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                                                                                                                                                    IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                                                                                       IF age <= 47.0 AND capital.gain <= 0.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 3                                                                                                                                                                                    IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 4                                                                                                                                                                                               IF age <= 47.0 AND capital.gain <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 5                                                                                                                                                                                                            IF hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 6                                                                                                                                                                                                            IF hours.per.week <= 32.0 AND occupation = Farming-fishing THEN class = <=50K
# 7                                                                                                                                                                                                            IF hours.per.week <= 50.0 AND occupation = Farming-fishing THEN class = <=50K
# 8                                                                                                                                                                                                                                             IF hours.per.week <= 35.0 THEN class = <=50K
# 9   IF capital.gain <= 2874.854736328125 AND capital.loss <= 2694.723388671875 AND education.num != 15 AND hours.per.week <= 57.859853744506836 AND occupation != Exec-managerial AND occupation != Tech-support AND occupation != Craft-repair AND occupation != Sales THEN class = <=50K
# 10                                                                                                                  IF capital.gain <= 13079.5849609375 AND capital.loss <= 3071.783447265625 AND hours.per.week <= 48.838104248046875 AND occupation = Farming-fishing THEN class = <=50K
# 11                                                                                                                                          IF capital.gain <= 4119.5072021484375 AND education.num != 14 AND occupation = Farming-fishing AND workclass != Federal-gov THEN class = <=50K
# 12                                                                                                                                                         IF capital.gain <= 8678.97607421875 AND hours.per.week <= 51.03134536743164 AND occupation = Farming-fishing THEN class = <=50K
# 13                                                                                   IF capital.gain <= 4757.0059814453125 AND capital.loss <= 1754.4028930664062 AND education != Doctorate AND hours.per.week <= 17.114296913146973 AND occupation != Exec-managerial THEN class = <=50K
# 14                                                                                                                                                                                                                                            IF hours.per.week <= 30.0 THEN class = <=50K
# 15                                                                                                                                                                                                                                            IF hours.per.week <= 35.0 THEN class = <=50K
# 16                                                                                                                                                                                                                            IF age <= 49.0 AND hours.per.week <= 30.0 THEN class = <=50K
# 17                                                                                                                                                                                                                                            IF hours.per.week <= 28.0 THEN class = <=50K
# 18                                                                                                                                                                                                                            IF age <= 41.0 AND hours.per.week <= 34.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01571    0.01971  0.95251    4       0       1.54453       False
# 1   0.01615    0.02023  0.95109    3       0       1.68503       False
# 2   0.01816    0.02254  0.94203    4       0       1.55565       False
# 3   0.01474    0.01855  0.95536    3       3       6.51489       False
# 4   0.01887    0.02306  0.92791    3       0       1.49903       False
# 5   0.01571    0.01936  0.93575    2       0      42.03551       False
# 6   0.00461    0.00589  0.97143    2       0      40.73262       False
# 7   0.02119    0.02560  0.91718    2       0      35.37699       False
# 8   0.21231    0.25574  0.91445    1       0      35.56768       False
# 9   0.52733    0.59903  0.86238    8       0      10.22085       False
# 10  0.01742    0.02144  0.93451    4       0      10.33955       False
# 11  0.02817    0.03416  0.92056    4       0      10.51624       False
# 12  0.02075    0.02543  0.93023    3       0      10.27089       False
# 13  0.04611    0.05843  0.96194    5       0      10.65501       False
# 14  0.16234    0.19910  0.93108    1       0       0.65897       False
# 15  0.21231    0.25574  0.91445    1       0       0.66278       False
# 16  0.12061    0.15148  0.95344    2       4       3.37851       False
# 17  0.12614    0.15494  0.93252    1       0       0.74988       False
# 18  0.11412    0.14489  0.96386    2       0       1.04409       False
# ### Rules for Instance 5988, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988    ANCHOR   ANCHOR3
# 3           5988    ANCHOR   ANCHOR4
# 4           5988    ANCHOR   ANCHOR5
# 5           5988      LORE     LORE1
# 6           5988      LORE     LORE4
# 7           5988      LORE     LORE5
# 8           5988   LORE_SA  LORE_SA1
# 9           5988   LORE_SA  LORE_SA2
# 10          5988   LORE_SA  LORE_SA3
# 11          5988   LORE_SA  LORE_SA4
# 12          5988   LORE_SA  LORE_SA5
# 13          5988    EXPLAN   EXPLAN1
# 14          5988    EXPLAN   EXPLAN2
# 15          5988    EXPLAN   EXPLAN3
# 16          5988    EXPLAN   EXPLAN4
# 17          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                                            IF capital.gain <= 0.0 AND capital.loss <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                                                                                                                                                    IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                                                                                       IF age <= 47.0 AND capital.gain <= 0.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 3                                                                                                                                                                                    IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 4                                                                                                                                                                                               IF age <= 47.0 AND capital.gain <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 5                                                                                                                                                                                                            IF hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 6                                                                                                                                                                                                            IF hours.per.week <= 50.0 AND occupation = Farming-fishing THEN class = <=50K
# 7                                                                                                                                                                                                                                             IF hours.per.week <= 35.0 THEN class = <=50K
# 8   IF capital.gain <= 2874.854736328125 AND capital.loss <= 2694.723388671875 AND education.num != 15 AND hours.per.week <= 57.859853744506836 AND occupation != Exec-managerial AND occupation != Tech-support AND occupation != Craft-repair AND occupation != Sales THEN class = <=50K
# 9                                                                                                                   IF capital.gain <= 13079.5849609375 AND capital.loss <= 3071.783447265625 AND hours.per.week <= 48.838104248046875 AND occupation = Farming-fishing THEN class = <=50K
# 10                                                                                                                                          IF capital.gain <= 4119.5072021484375 AND education.num != 14 AND occupation = Farming-fishing AND workclass != Federal-gov THEN class = <=50K
# 11                                                                                                                                                         IF capital.gain <= 8678.97607421875 AND hours.per.week <= 51.03134536743164 AND occupation = Farming-fishing THEN class = <=50K
# 12                                                                                   IF capital.gain <= 4757.0059814453125 AND capital.loss <= 1754.4028930664062 AND education != Doctorate AND hours.per.week <= 17.114296913146973 AND occupation != Exec-managerial THEN class = <=50K
# 13                                                                                                                                                                                                                                            IF hours.per.week <= 30.0 THEN class = <=50K
# 14                                                                                                                                                                                                                                            IF hours.per.week <= 35.0 THEN class = <=50K
# 15                                                                                                                                                                                                                            IF age <= 49.0 AND hours.per.week <= 30.0 THEN class = <=50K
# 16                                                                                                                                                                                                                                            IF hours.per.week <= 28.0 THEN class = <=50K
# 17                                                                                                                                                                                                                            IF age <= 41.0 AND hours.per.week <= 34.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01571    0.01971  0.95251    4       0       1.54453       False
# 1   0.01615    0.02023  0.95109    3       0       1.68503       False
# 2   0.01816    0.02254  0.94203    4       0       1.55565       False
# 3   0.01474    0.01855  0.95536    3       3       6.51489       False
# 4   0.01887    0.02306  0.92791    3       0       1.49903       False
# 5   0.01571    0.01936  0.93575    2       0      42.03551       False
# 6   0.02119    0.02560  0.91718    2       0      35.37699       False
# 7   0.21231    0.25574  0.91445    1       0      35.56768       False
# 8   0.52733    0.59903  0.86238    8       0      10.22085       False
# 9   0.01742    0.02144  0.93451    4       0      10.33955       False
# 10  0.02817    0.03416  0.92056    4       0      10.51624       False
# 11  0.02075    0.02543  0.93023    3       0      10.27089       False
# 12  0.04611    0.05843  0.96194    5       0      10.65501       False
# 13  0.16234    0.19910  0.93108    1       0       0.65897       False
# 14  0.21231    0.25574  0.91445    1       0       0.66278       False
# 15  0.12061    0.15148  0.95344    2       4       3.37851       False
# 16  0.12614    0.15494  0.93252    1       0       0.74988       False
# 17  0.11412    0.14489  0.96386    2       0       1.04409       False
# ### Rules for Instance 5988, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.52733, Pre: 0.96386)
# <style type="text/css">
# #T_8f8a5_row1_col0, #T_8f8a5_row1_col1, #T_8f8a5_row1_col2, #T_8f8a5_row1_col3, #T_8f8a5_row1_col4, #T_8f8a5_row1_col5, #T_8f8a5_row1_col6, #T_8f8a5_row1_col7, #T_8f8a5_row1_col8, #T_8f8a5_row1_col9, #T_8f8a5_row1_col10, #T_8f8a5_row1_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8f8a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f8a5_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_8f8a5_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_8f8a5_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_8f8a5_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_8f8a5_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_8f8a5_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_8f8a5_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_8f8a5_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_8f8a5_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_8f8a5_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_8f8a5_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_8f8a5_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f8a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f8a5_row0_col0" class="data row0 col0" >5988</td>
#       <td id="T_8f8a5_row0_col1" class="data row0 col1" >LORE</td>
#       <td id="T_8f8a5_row0_col2" class="data row0 col2" >LORE5</td>
#       <td id="T_8f8a5_row0_col3" class="data row0 col3" >IF hours.per.week <= 35.0 THEN class = <=50K</td>
#       <td id="T_8f8a5_row0_col4" class="data row0 col4" >0.212310</td>
#       <td id="T_8f8a5_row0_col5" class="data row0 col5" >0.255740</td>
#       <td id="T_8f8a5_row0_col6" class="data row0 col6" >0.914450</td>
#       <td id="T_8f8a5_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_8f8a5_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_8f8a5_row0_col9" class="data row0 col9" >35.567680</td>
#       <td id="T_8f8a5_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_8f8a5_row0_col11" class="data row0 col11" >0.318871</td>
#     </tr>
#     <tr>
#       <th id="T_8f8a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f8a5_row1_col0" class="data row1 col0" >5988</td>
#       <td id="T_8f8a5_row1_col1" class="data row1 col1" >LORE_SA</td>
#       <td id="T_8f8a5_row1_col2" class="data row1 col2" >LORE_SA1</td>
#       <td id="T_8f8a5_row1_col3" class="data row1 col3" >IF capital.gain <= 2874.854736328125 AND capital.loss <= 2694.723388671875 AND education.num != 15 AND hours.per.week <= 57.859853744506836 AND occupation != Exec-managerial AND occupation != Tech-support AND occupation != Craft-repair AND occupation != Sales THEN class = <=50K</td>
#       <td id="T_8f8a5_row1_col4" class="data row1 col4" >0.527330</td>
#       <td id="T_8f8a5_row1_col5" class="data row1 col5" >0.599030</td>
#       <td id="T_8f8a5_row1_col6" class="data row1 col6" >0.862380</td>
#       <td id="T_8f8a5_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_8f8a5_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_8f8a5_row1_col9" class="data row1 col9" >10.220850</td>
#       <td id="T_8f8a5_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_8f8a5_row1_col11" class="data row1 col11" >0.101480</td>
#     </tr>
#     <tr>
#       <th id="T_8f8a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f8a5_row2_col0" class="data row2 col0" >5988</td>
#       <td id="T_8f8a5_row2_col1" class="data row2 col1" >EXPLAN</td>
#       <td id="T_8f8a5_row2_col2" class="data row2 col2" >EXPLAN1</td>
#       <td id="T_8f8a5_row2_col3" class="data row2 col3" >IF hours.per.week <= 30.0 THEN class = <=50K</td>
#       <td id="T_8f8a5_row2_col4" class="data row2 col4" >0.162340</td>
#       <td id="T_8f8a5_row2_col5" class="data row2 col5" >0.199100</td>
#       <td id="T_8f8a5_row2_col6" class="data row2 col6" >0.931080</td>
#       <td id="T_8f8a5_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_8f8a5_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_8f8a5_row2_col9" class="data row2 col9" >0.658970</td>
#       <td id="T_8f8a5_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_8f8a5_row2_col11" class="data row2 col11" >0.366459</td>
#     </tr>
#     <tr>
#       <th id="T_8f8a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f8a5_row3_col0" class="data row3 col0" >5988</td>
#       <td id="T_8f8a5_row3_col1" class="data row3 col1" >EXPLAN</td>
#       <td id="T_8f8a5_row3_col2" class="data row3 col2" >EXPLAN2</td>
#       <td id="T_8f8a5_row3_col3" class="data row3 col3" >IF hours.per.week <= 35.0 THEN class = <=50K</td>
#       <td id="T_8f8a5_row3_col4" class="data row3 col4" >0.212310</td>
#       <td id="T_8f8a5_row3_col5" class="data row3 col5" >0.255740</td>
#       <td id="T_8f8a5_row3_col6" class="data row3 col6" >0.914450</td>
#       <td id="T_8f8a5_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_8f8a5_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_8f8a5_row3_col9" class="data row3 col9" >0.662780</td>
#       <td id="T_8f8a5_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_8f8a5_row3_col11" class="data row3 col11" >0.318871</td>
#     </tr>
#     <tr>
#       <th id="T_8f8a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f8a5_row4_col0" class="data row4 col0" >5988</td>
#       <td id="T_8f8a5_row4_col1" class="data row4 col1" >EXPLAN</td>
#       <td id="T_8f8a5_row4_col2" class="data row4 col2" >EXPLAN3</td>
#       <td id="T_8f8a5_row4_col3" class="data row4 col3" >IF age <= 49.0 AND hours.per.week <= 30.0 THEN class = <=50K</td>
#       <td id="T_8f8a5_row4_col4" class="data row4 col4" >0.120610</td>
#       <td id="T_8f8a5_row4_col5" class="data row4 col5" >0.151480</td>
#       <td id="T_8f8a5_row4_col6" class="data row4 col6" >0.953440</td>
#       <td id="T_8f8a5_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_8f8a5_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_8f8a5_row4_col9" class="data row4 col9" >3.378510</td>
#       <td id="T_8f8a5_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_8f8a5_row4_col11" class="data row4 col11" >0.406853</td>
#     </tr>
#     <tr>
#       <th id="T_8f8a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8f8a5_row5_col0" class="data row5 col0" >5988</td>
#       <td id="T_8f8a5_row5_col1" class="data row5 col1" >EXPLAN</td>
#       <td id="T_8f8a5_row5_col2" class="data row5 col2" >EXPLAN4</td>
#       <td id="T_8f8a5_row5_col3" class="data row5 col3" >IF hours.per.week <= 28.0 THEN class = <=50K</td>
#       <td id="T_8f8a5_row5_col4" class="data row5 col4" >0.126140</td>
#       <td id="T_8f8a5_row5_col5" class="data row5 col5" >0.154940</td>
#       <td id="T_8f8a5_row5_col6" class="data row5 col6" >0.932520</td>
#       <td id="T_8f8a5_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_8f8a5_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_8f8a5_row5_col9" class="data row5 col9" >0.749880</td>
#       <td id="T_8f8a5_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_8f8a5_row5_col11" class="data row5 col11" >0.402412</td>
#     </tr>
#     <tr>
#       <th id="T_8f8a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8f8a5_row6_col0" class="data row6 col0" >5988</td>
#       <td id="T_8f8a5_row6_col1" class="data row6 col1" >EXPLAN</td>
#       <td id="T_8f8a5_row6_col2" class="data row6 col2" >EXPLAN5</td>
#       <td id="T_8f8a5_row6_col3" class="data row6 col3" >IF age <= 41.0 AND hours.per.week <= 34.0 THEN class = <=50K</td>
#       <td id="T_8f8a5_row6_col4" class="data row6 col4" >0.114120</td>
#       <td id="T_8f8a5_row6_col5" class="data row6 col5" >0.144890</td>
#       <td id="T_8f8a5
# ### Rules for Instance 5988, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.59903, Pre: 0.96386, Len: 0.86238)
# <style type="text/css">
# #T_267a8_row0_col0, #T_267a8_row0_col1, #T_267a8_row0_col2, #T_267a8_row0_col3, #T_267a8_row0_col4, #T_267a8_row0_col5, #T_267a8_row0_col6, #T_267a8_row0_col7, #T_267a8_row0_col8, #T_267a8_row0_col9, #T_267a8_row0_col10, #T_267a8_row0_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_267a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_267a8_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_267a8_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_267a8_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_267a8_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_267a8_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_267a8_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_267a8_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_267a8_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_267a8_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_267a8_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_267a8_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_267a8_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_267a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_267a8_row0_col0" class="data row0 col0" >5988</td>
#       <td id="T_267a8_row0_col1" class="data row0 col1" >LORE</td>
#       <td id="T_267a8_row0_col2" class="data row0 col2" >LORE5</td>
#       <td id="T_267a8_row0_col3" class="data row0 col3" >IF hours.per.week <= 35.0 THEN class = <=50K</td>
#       <td id="T_267a8_row0_col4" class="data row0 col4" >0.212310</td>
#       <td id="T_267a8_row0_col5" class="data row0 col5" >0.255740</td>
#       <td id="T_267a8_row0_col6" class="data row0 col6" >0.914450</td>
#       <td id="T_267a8_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_267a8_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_267a8_row0_col9" class="data row0 col9" >35.567680</td>
#       <td id="T_267a8_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_267a8_row0_col11" class="data row0 col11" >0.373134</td>
#     </tr>
#     <tr>
#       <th id="T_267a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_267a8_row1_col0" class="data row1 col0" >5988</td>
#       <td id="T_267a8_row1_col1" class="data row1 col1" >LORE_SA</td>
#       <td id="T_267a8_row1_col2" class="data row1 col2" >LORE_SA1</td>
#       <td id="T_267a8_row1_col3" class="data row1 col3" >IF capital.gain <= 2874.854736328125 AND capital.loss <= 2694.723388671875 AND education.num != 15 AND hours.per.week <= 57.859853744506836 AND occupation != Exec-managerial AND occupation != Tech-support AND occupation != Craft-repair AND occupation != Sales THEN class = <=50K</td>
#       <td id="T_267a8_row1_col4" class="data row1 col4" >0.527330</td>
#       <td id="T_267a8_row1_col5" class="data row1 col5" >0.599030</td>
#       <td id="T_267a8_row1_col6" class="data row1 col6" >0.862380</td>
#       <td id="T_267a8_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_267a8_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_267a8_row1_col9" class="data row1 col9" >10.220850</td>
#       <td id="T_267a8_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_267a8_row1_col11" class="data row1 col11" >7.138341</td>
#     </tr>
#     <tr>
#       <th id="T_267a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_267a8_row2_col0" class="data row2 col0" >5988</td>
#       <td id="T_267a8_row2_col1" class="data row2 col1" >EXPLAN</td>
#       <td id="T_267a8_row2_col2" class="data row2 col2" >EXPLAN1</td>
#       <td id="T_267a8_row2_col3" class="data row2 col3" >IF hours.per.week <= 30.0 THEN class = <=50K</td>
#       <td id="T_267a8_row2_col4" class="data row2 col4" >0.162340</td>
#       <td id="T_267a8_row2_col5" class="data row2 col5" >0.199100</td>
#       <td id="T_267a8_row2_col6" class="data row2 col6" >0.931080</td>
#       <td id="T_267a8_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_267a8_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_267a8_row2_col9" class="data row2 col9" >0.658970</td>
#       <td id="T_267a8_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_267a8_row2_col11" class="data row2 col11" >0.424214</td>
#     </tr>
#     <tr>
#       <th id="T_267a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_267a8_row3_col0" class="data row3 col0" >5988</td>
#       <td id="T_267a8_row3_col1" class="data row3 col1" >EXPLAN</td>
#       <td id="T_267a8_row3_col2" class="data row3 col2" >EXPLAN2</td>
#       <td id="T_267a8_row3_col3" class="data row3 col3" >IF hours.per.week <= 35.0 THEN class = <=50K</td>
#       <td id="T_267a8_row3_col4" class="data row3 col4" >0.212310</td>
#       <td id="T_267a8_row3_col5" class="data row3 col5" >0.255740</td>
#       <td id="T_267a8_row3_col6" class="data row3 col6" >0.914450</td>
#       <td id="T_267a8_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_267a8_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_267a8_row3_col9" class="data row3 col9" >0.662780</td>
#       <td id="T_267a8_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_267a8_row3_col11" class="data row3 col11" >0.373134</td>
#     </tr>
#     <tr>
#       <th id="T_267a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_267a8_row4_col0" class="data row4 col0" >5988</td>
#       <td id="T_267a8_row4_col1" class="data row4 col1" >EXPLAN</td>
#       <td id="T_267a8_row4_col2" class="data row4 col2" >EXPLAN3</td>
#       <td id="T_267a8_row4_col3" class="data row4 col3" >IF age <= 49.0 AND hours.per.week <= 30.0 THEN class = <=50K</td>
#       <td id="T_267a8_row4_col4" class="data row4 col4" >0.120610</td>
#       <td id="T_267a8_row4_col5" class="data row4 col5" >0.151480</td>
#       <td id="T_267a8_row4_col6" class="data row4 col6" >0.953440</td>
#       <td id="T_267a8_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_267a8_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_267a8_row4_col9" class="data row4 col9" >3.378510</td>
#       <td id="T_267a8_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_267a8_row4_col11" class="data row4 col11" >1.222534</td>
#     </tr>
#     <tr>
#       <th id="T_267a8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_267a8_row5_col0" class="data row5 col0" >5988</td>
#       <td id="T_267a8_row5_col1" class="data row5 col1" >EXPLAN</td>
#       <td id="T_267a8_row5_col2" class="data row5 col2" >EXPLAN4</td>
#       <td id="T_267a8_row5_col3" class="data row5 col3" >IF hours.per.week <= 28.0 THEN class = <=50K</td>
#       <td id="T_267a8_row5_col4" class="data row5 col4" >0.126140</td>
#       <td id="T_267a8_row5_col5" class="data row5 col5" >0.154940</td>
#       <td id="T_267a8_row5_col6" class="data row5 col6" >0.932520</td>
#       <td id="T_267a8_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_267a8_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_267a8_row5_col9" class="data row5 col9" >0.749880</td>
#       <td id="T_267a8_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_267a8_row5_col11" class="data row5 col11" >0.465980</td>
#     </tr>
#     <tr>
#       <th id="T_267a8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_267a8_row6_col0" class="data row6 col0" >5988</td>
#       <td id="T_267a8_row6_col1" class="data row6 col1" >EXPLAN</td>
#       <td id="T_267a8_row6_col2" class="data row6 col2" >EXPLAN5</td>
#       <td id="T_267a8_row6_col3" class="data row6 col3" >IF age <= 41.0 AND hours.per.week <= 34.0 THEN class = <=50K</td>
#       <td id="T_267a8_row6_col4" class="data row6 col4" >0.114120</td>
#       <td id="T_267a8_row6_col5" class="data row6 col5" >0.144890</td>
#       <td id="T_267a8
# ## Instance 18073 (Original: <=50K , Predicted: <=50K)
#                             Value
# age                          19.0
# workclass                 Private
# education                    12th
# education.num                   8
# marital.status      Never-married
# occupation      Handlers-cleaners
# relationship            Own-child
# race                        Black
# sex                        Female
# capital.gain                  0.0
# capital.loss                  0.0
# hours.per.week               52.0
# native.country      United-States
# ### Rules for Instance 18073
#    Instance_Name Explainer   Rule_ID  \
# 0          18073    ANCHOR   ANCHOR1
# 1          18073    ANCHOR   ANCHOR2
# 2          18073    ANCHOR   ANCHOR3
# 3          18073    ANCHOR   ANCHOR4
# 4          18073    ANCHOR   ANCHOR5
# 5          18073      LORE     LORE1
# 6          18073      LORE     LORE2
# 7          18073      LORE     LORE3
# 8          18073      LORE     LORE4
# 9          18073      LORE     LORE5
# 10         18073   LORE_SA  LORE_SA1
# 11         18073   LORE_SA  LORE_SA2
# 12         18073   LORE_SA  LORE_SA3
# 13         18073   LORE_SA  LORE_SA4
# 14         18073   LORE_SA  LORE_SA5
# 15         18073    EXPLAN   EXPLAN1
# 16         18073    EXPLAN   EXPLAN2
# 17         18073    EXPLAN   EXPLAN3
# 18         18073    EXPLAN   EXPLAN4
# 19         18073    EXPLAN   EXPLAN5
#
#                                                                                                                                                                 Rule  \
# 0                                                                                               IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                               IF age <= 47.0 AND marital.status = Never-married THEN class = <=50K
# 2                                                                                               IF age <= 28.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                                               IF age <= 47.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                               IF age <= 28.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                                 IF capital.gain <= 16288.190482 THEN class = <=50K
# 6                                                                                                                       IF capital.gain <= 7298.0 THEN class = <=50K
# 7                                                                                                             IF age <= 29.75392 AND sex = Female THEN class = <=50K
# 8                                                                                               IF age <= 39.0 AND marital.status = Never-married THEN class = <=50K
# 9                                                                                                                      IF capital.gain <= 15024.0 THEN class = <=50K
# 10                                    IF capital.gain <= 27709.966796875 AND capital.loss <= 27.544450759887695 AND occupation != Exec-managerial THEN class = <=50K
# 11                                          IF capital.gain <= 23362.1826171875 AND marital.status = Never-married AND occupation != Tech-support THEN class = <=50K
# 12                                            IF age <= 31.66552734375 AND capital.gain <= 25536.275390625 AND capital.loss <= 4084.7440185546875 THEN class = <=50K
# 13  IF capital.gain <= 10857.252197265625 AND capital.loss <= 3399.3585205078125 AND education.num != 12 AND hours.per.week <= 54.187286376953125 THEN class = <=50K
# 14                                                                              IF age <= 21.567317962646484 AND capital.gain <= 22424.5087890625 THEN class = <=50K
# 15                                                                                                              IF marital.status = Never-married THEN class = <=50K
# 16                                                                                              IF age <= 35.0 AND marital.status = Never-married THEN class = <=50K
# 17                                                                                              IF age <= 33.0 AND marital.status = Never-married THEN class = <=50K
# 18                                                                                         IF age <= 31.954002 AND marital.status = Never-married THEN class = <=50K
# 19                                                                                                           IF age <= 32.0 AND education.num = 8 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       0.76695       False
# 1   0.31081    0.39294  0.95977    2       0       0.87127       False
# 2   0.20898    0.27226  0.98908    2       0       0.76020       False
# 3   0.31081    0.39294  0.95977    2      10       9.61520        True
# 4   0.20898    0.27226  0.98908    2       0       0.99089        True
# 5   0.99180    0.99954  0.76510    1       0      35.17056       False
# 6   0.96363    0.99890  0.78696    1       0      34.90664       False
# 7   0.12364    0.15760  0.96771    2       1      87.26376       False
# 8   0.28940    0.36855  0.96680    2       0      39.09615       False
# 9   0.99162    0.99954  0.76523    1       0      41.67622       False
# 10  0.83367    0.88863  0.80922    3       0      12.27484       False
# 11  0.31687    0.39947  0.95708    3       0      12.01534       False
# 12  0.35245    0.42952  0.92518    3       0      11.37124       False
# 13  0.84920    0.88915  0.79489    4       0      11.16322       False
# 14  0.09582    0.12611  0.99908    2       0      10.89100       False
# 15  0.32757    0.41178  0.95433    1       0       1.86566       False
# 16  0.26957    0.34560  0.97331    2       0       1.16257       False
# 17  0.25522    0.32884  0.97817    2       0       1.69731       False
# 18  0.23916    0.30937  0.98202    2       0       1.14530       False
# 19  0.00763    0.00982  0.97701    2       0       0.93144       False
# ### Rules for Instance 18073, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0          18073    ANCHOR   ANCHOR1
# 1          18073    ANCHOR   ANCHOR2
# 2          18073    ANCHOR   ANCHOR3
# 3          18073    ANCHOR   ANCHOR4
# 4          18073    ANCHOR   ANCHOR5
# 5          18073      LORE     LORE1
# 6          18073      LORE     LORE2
# 7          18073      LORE     LORE3
# 8          18073      LORE     LORE4
# 9          18073      LORE     LORE5
# 10         18073   LORE_SA  LORE_SA1
# 11         18073   LORE_SA  LORE_SA2
# 12         18073   LORE_SA  LORE_SA3
# 13         18073   LORE_SA  LORE_SA4
# ...
#       <td id="T_6f9db_row4_col6" class="data row4 col6" >0.996360</td>
#       <td id="T_6f9db_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_6f9db_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_6f9db_row4_col9" class="data row4 col9" >39.510590</td>
#       <td id="T_6f9db_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_6f9db_row4_col11" class="data row4 col11" >1.429721</td>
#     </tr>
#     <tr>
#       <th id="T_6f9db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6f9db_row5_col0" class="data row5 col0" >12191</td>
#       <td id="T_6f9db_row5_col1" class="data row5 col1" >LORE</td>
#       <td id="T_6f9db_row5_col2" class="data row5 col2" >LORE4</td>
#       <td id="T_6f9db_row5_col3" class="data row5 col3" >IF age <= 38.0 AND capital.gain <= 4787.0 AND marital.status = Never-married THEN class = <=50K</td>
#       <td id="T_6f9db_row5_col4" class="data row5 col4" >0.281240</td>
#       <td id="T_6f9db_row5_col5" class="data row5 col5" >0.362600</td>
#       <td id="T_6f9db_row5_col6" class="data row5 col6" >0.978780</td>
#       <td id="T_6f9db_row5_col7" class="data row5 col7" >3</td>
#       <td id="T_6f9db_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_6f9db_row5_col9" class="data row5 col9" >39.563690</td>
#       <td id="T_6f9db_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_6f9db_row5_col11" class="data row5 col11" >2.284971</td>
#     </tr>
#     <tr>
#       <th id="T_6f9db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6f9db_row6_col0" class="data row6 col0" >12191</td>
#       <td id="T_6f9db_row6_col1" class="data row6 col1" >LORE_SA</td>
#       <td id="T_6f9db_row6_col2" class="data row6 col2" >LORE_SA1</td>
#       <td id="T_6f9db_row6_col3" class="data row6 col3" >IF capital.gain <= 14119.2470703125 AND hours.per.week <= 40.177955627441406 AND native.country != Haiti AND occupation != Prof-specialty AND occupation != Exec-managerial THEN class = <=50K</td>
#       <td id="T_6f9db_row6_col4" class="data row6 col4" >0.509040</td>
#       <td id="T_6f9db_row6_col5" class="data row6
# ## Instance 3374 (Original: <=50K , Predicted: >50K)
#                              Value
# age                           59.0
# workclass                  Private
# education             Some-college
# education.num                   10
# marital.status  Married-civ-spouse
# occupation                   Sales
# relationship               Husband
# race                         White
# sex                           Male
# capital.gain                4064.0
# capital.loss                   0.0
# hours.per.week                40.0
# native.country       United-States
# ### Rules for Instance 3374
#    Instance_Name Explainer   Rule_ID  \
# 0           3374    ANCHOR   ANCHOR1
# 1           3374    ANCHOR   ANCHOR2
# 2           3374    ANCHOR   ANCHOR3
# 3           3374    ANCHOR   ANCHOR4
# 4           3374    ANCHOR   ANCHOR5
# 5           3374      LORE     LORE1
# 6           3374      LORE     LORE2
# 7           3374      LORE     LORE3
# 8           3374      LORE     LORE4
# 9           3374      LORE     LORE5
# 10          3374   LORE_SA  LORE_SA1
# 11          3374   LORE_SA  LORE_SA2
# 12          3374   LORE_SA  LORE_SA3
# 13          3374   LORE_SA  LORE_SA4
# 14          3374   LORE_SA  LORE_SA5
# 15          3374    EXPLAN   EXPLAN1
# 16          3374    EXPLAN   EXPLAN2
# 17          3374    EXPLAN   EXPLAN3
# 18          3374    EXPLAN   EXPLAN4
# 19          3374    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                               Rule  \
# 0                                                                                                    IF capital.gain > 0.0 AND marital.status = Married-civ-spouse AND native.country = United-States AND relationship = Husband THEN class = >50K
# 1                                                                                                                        IF capital.gain > 0.0 AND marital.status = Married-civ-spouse AND relationship = Husband AND sex = Male THEN class = >50K
# 2                                                                                                                                       IF capital.gain > 0.0 AND marital.status = Married-civ-spouse AND relationship = Husband THEN class = >50K
# 3                                                                                                         IF age > 28.0 AND capital.gain > 0.0 AND marital.status = Married-civ-spouse AND relationship = Husband AND sex = Male THEN class = >50K
# 4                                                                                                                        IF age > 28.0 AND capital.gain > 0.0 AND marital.status = Married-civ-spouse AND relationship = Husband THEN class = >50K
# 5                                                                                                                                                               IF hours.per.week > 10.0 AND marital.status = Married-civ-spouse THEN class = >50K
# 6                                                                                                                           IF age > 23.0 AND age <= 59.0 AND hours.per.week > 32.242271 AND marital.status = Married-civ-spouse THEN class = >50K
# 7                                                                                                                                                               IF hours.per.week > 24.0 AND marital.status = Married-civ-spouse THEN class = >50K
# 8                                                                                                                     IF age > 29.0 AND hours.per.week > 20.0 AND hours.per.week <= 40.0 AND marital.status = Married-civ-spouse THEN class = >50K
# 9                                                                                                                                                                          IF age > 46.0 AND marital.status = Married-civ-spouse THEN class = >50K
# 10                                   IF age > 21.10032558441162 AND marital.status = Married-civ-spouse AND occupation != Armed-Forces AND occupation != Priv-house-serv AND workclass != Without-pay AND workclass != State-gov THEN class = >50K
# 11  IF hours.per.week > 9.28683614730835 AND marital.status = Married-civ-spouse AND native.country != Outlying-US(Guam-USVI-etc) AND native.country != Scotland AND relationship != Other-relative AND workclass != Without-pay THEN class = >50K
# 12                                                                                                                              IF education != Preschool AND marital.status = Married-civ-spouse AND occupation != Armed-Forces THEN class = >50K
# 13                   IF education != 5th-6th AND education.num != 3 AND marital.status = Married-civ-spouse AND native.country != Greece AND native.country != Hungary AND native.country != Peru AND occupation != Armed-Forces THEN class = >50K
# 14                                  IF age > 33.383111000061035 AND education != 11th AND education.num != 1 AND hours.per.week > 26.104106903076172 AND marital.status != Never-married AND marital.status = Married-civ-spouse THEN class = >50K
# 15                                                                                                                                               IF age > 36.0 AND hours.per.week > 35.0 AND marital.status = Married-civ-spouse THEN class = >50K
# 16                                                                                                                   IF age > 37.0 AND hours.per.week > 36.767304 AND marital.status = Married-civ-spouse AND occupation = Sales THEN class = >50K
# 17                                                          IF age > 30.0 AND hours.per.week > 30.0 AND marital.status = Married-civ-spouse AND native.country = United-States AND occupation = Sales AND relationship = Husband THEN class = >50K
# 18                                                                                                                   IF age > 31.0 AND hours.per.week > 30.055573 AND marital.status = Married-civ-spouse AND occupation = Sales THEN class = >50K
# 19                                                                                                                        IF age > 42.0 AND hours.per.week > 35.0 AND marital.status = Married-civ-spouse AND occupation = Sales THEN class = >50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.04624    0.14611  0.76091    4       0       5.53648       False
# 1   0.05015    0.15613  0.74978    4       0       3.98707       False
# 2   0.05015    0.15613  0.74978    3       0       5.08813       False
# 3   0.04752    0.15249  0.77285    5       0       4.25054       False
# 4   0.04752    0.15249  0.77285    4       4      15.11682       False
# 5   0.45240    0.84915  0.45204    2       0      48.45413       False
# 6   0.37697    0.75515  0.48243    4       0      50.62037       False
# 7   0.43335    0.82948  0.46097    2       0      47.36966       False
# 8   0.22310    0.39424  0.42557    4       0      48.50996       False
# 9   0.16787    0.33412  0.47935    2       0      51.51428       False
# 10  0.43634    0.81636  0.45058    6       0      17.17699       False
# 11  0.44994    0.84897  0.45441    6       0      15.86431       False
# 12  0.45854    0.85553  0.44933    3       0      15.69185       False
# 13  0.45292    0.85280  0.45345    7       0      17.49085       False
# 14  0.31862    0.69466  0.52506    6       0      17.76788       False
# 15  0.26580    0.59428  0.53846    3       0       3.44628       False
# 16  0.02795    0.07032  0.60597    4       0       5.90327       False
# 17  0.03497    0.08490  0.58469    6       0       6.40479       False
# 18  0.03769    0.09054  0.57858    4       0       5.09628       False
# 19  0.02163    0.05429  0.60446    4       0       6.22971       False
# ### Rules for Instance 3374, Correct Prediction
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# ### Rules for Instance 3374, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# ### Rules for Instance 3374, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.9581, Pre: 0.99845)
# <style type="text/css">
# </style>
# <table id="T_5f678">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f678_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_5f678_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_5f678_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_5f678_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_5f678_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_5f678_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_5f678_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_5f678_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_5f678_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_5f678_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_5f678_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Empty dataframe: nothing to plot.
# ### Rules for Instance 3374, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.9581, Pre: 0.99845, Len: 0.79408)
# <style type="text/css">
# </style>
# <table id="T_e1f2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1f2b_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_e1f2b_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_e1f2b_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_e1f2b_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_e1f2b_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_e1f2b_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_e1f2b_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_e1f2b_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_e1f2b_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_e1f2b_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_e1f2b_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Empty dataframe: nothing to plot.
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         0.5
# EXPLAN                                         0.5
# LORE                                           0.8
# LORE_SA                                        0.5
# Overall Average                                2.3
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                  0.555556
# EXPLAN                                  0.777778
# LORE                                    0.666667
# LORE_SA                                 0.555556
# Overall Average                         2.300000
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 2.375000
# EXPLAN                                 2.375000
# LORE                                   1.222222
# LORE_SA                                1.222222
# Overall Average                        6.000000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 2.250000
# EXPLAN                                 1.750000
# LORE                                   1.111111
# LORE_SA                                1.666667
# Overall Average                        5.700000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# EXPLAN          0.800201  0.190748   0.321346  2.569444  0.133333
# LORE            0.766740  0.322002   0.449556  1.729167  0.000000
# LORE_SA         0.663391  0.481802   0.613669  5.653704  0.000000
# ANCHOR          0.867292  0.165588   0.248472  2.761905  0.404762
# Global_Average  0.765890  0.307194   0.426228  3.315556  0.121111
#
#                 Elapsed_time
# EXPLAN              2.938884
# LORE               37.922694
# LORE_SA            12.621688
# ANCHOR              1.836721
# Global_Average     14.915570
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# EXPLAN          0.801765  0.167481   0.274924  2.345238  0.114286
# LORE            0.770007  0.304383   0.423356  1.722917  0.000000
# LORE_SA         0.663466  0.489983   0.622704  5.546296  0.000000
# ANCHOR          0.860947  0.169342   0.254293  2.714286  0.428571
# Global_Average  0.766782  0.296860   0.409539  3.197312  0.122581
#
#                 Elapsed_time
# EXPLAN              2.669176
# LORE               38.046169
# LORE_SA            12.642879
# ANCHOR              1.856175
# Global_Average     14.510733
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
