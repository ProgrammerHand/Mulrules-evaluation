# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results

rules_log = "fico_heloc_random_forest_rules_12-00_06-06-2025.txt"
entries_log = "fico_heloc_random_forest_entries_12-00_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 1758 (Original: Bad , Predicted: Bad)
#                                    Value
# ExternalRiskEstimate                55.0
# MSinceOldestTradeOpen               39.0
# MSinceMostRecentTradeOpen            2.0
# AverageMInFile                      17.0
# NumSatisfactoryTrades               21.0
# NumTrades60Ever2DerogPubRec          0.0
# NumTrades90Ever2DerogPubRec          0.0
# PercentTradesNeverDelq              96.0
# MSinceMostRecentDelq                -7.0
# MaxDelq2PublicRecLast12M               5
# MaxDelqEver                            7
# NumTotalTrades                      23.0
# NumTradesOpeninLast12M               7.0
# PercentInstallTrades                26.0
# MSinceMostRecentInqexcl7days         0.0
# NumInqLast6M                         2.0
# NumInqLast6Mexcl7days                2.0
# NetFractionRevolvingBurden          64.0
# NetFractionInstallBurden            77.0
# NumRevolvingTradesWBalance           9.0
# NumInstallTradesWBalance             4.0
# NumBank2NatlTradesWHighUtilization   0.0
# PercentTradesWBalance               78.0
# ### Rules for Instance 1758
#    Instance_Name Explainer   Rule_ID  \
# 0           1758    ANCHOR   ANCHOR1
# 1           1758    ANCHOR   ANCHOR2
# 2           1758    ANCHOR   ANCHOR3
# 3           1758    ANCHOR   ANCHOR4
# 4           1758    ANCHOR   ANCHOR5
# 5           1758      LORE     LORE1
# 6           1758      LORE     LORE2
# 7           1758      LORE     LORE3
# 8           1758      LORE     LORE4
# 9           1758      LORE     LORE5
# 10          1758   LORE_SA  LORE_SA1
# 11          1758   LORE_SA  LORE_SA2
# 12          1758   LORE_SA  LORE_SA3
# 13          1758   LORE_SA  LORE_SA4
# 14          1758   LORE_SA  LORE_SA5
# 15          1758    EXPLAN   EXPLAN1
# 16          1758    EXPLAN   EXPLAN2
# 17          1758    EXPLAN   EXPLAN3
# 18          1758    EXPLAN   EXPLAN4
# 19          1758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                           Rule  \
# 0                                                                                                                                          IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 AND MSinceMostRecentInqexcl7days <= 1.0 THEN class = Bad
# 1                                                                                                                                                                                  IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 2                                                                                                                                                                                  IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 AND NumSatisfactoryTrades <= 27.0 THEN class = Bad
# 4                                                                                                                                        IF ExternalRiskEstimate <= 63.0 AND NumSatisfactoryTrades <= 27.0 AND PercentTradesNeverDelq <= 96.0 THEN class = Bad
# 5                                                                                                                           IF ExternalRiskEstimate <= 65.0 AND MSinceMostRecentTradeOpen <= 11.0 AND NumRevolvingTradesWBalance <= 13.859723 THEN class = Bad
# 6                                                                                                                                   IF ExternalRiskEstimate <= 57.0 AND NetFractionRevolvingBurden > 46.0 AND NumInstallTradesWBalance <= 9.0 THEN class = Bad
# 7                                                                                                                                                                           IF ExternalRiskEstimate <= 55.0 AND NumSatisfactoryTrades <= 45.0 THEN class = Bad
# 8                                                                                                                                                                       IF ExternalRiskEstimate <= 67.0 AND NetFractionRevolvingBurden > 46.0 THEN class = Bad
# 9                                                                                                                                  IF ExternalRiskEstimate <= 70.0 AND NetFractionInstallBurden <= 82.0 AND NetFractionRevolvingBurden > 56.0 THEN class = Bad
# 10                                                                                                 IF AverageMInFile <= 370.5026550292969 AND ExternalRiskEstimate <= 83.35953521728516 AND MSinceMostRecentInqexcl7days <= 9.509681940078735 THEN class = Bad
# 11  IF AverageMInFile <= 344.0649108886719 AND ExternalRiskEstimate <= 81.12110137939453 AND MSinceMostRecentInqexcl7days <= 5.13841438293457 AND NetFractionInstallBurden > 52.35957336425781 AND NumInqLast6Mexcl7days <= 64.12469863891602 THEN class = Bad
# 12                                                                                                                                                        IF ExternalRiskEstimate <= 69.28391647338867 AND NumTotalTrades > 8.151997566223145 THEN class = Bad
# 13                                  IF NetFractionInstallBurden <= 86.09918975830078 AND NetFractionRevolvingBurden > 31.799015045166016 AND NumInqLast6Mexcl7days > -0.9713006764650345 AND NumTrades90Ever2DerogPubRec > -7.150922536849976 THEN class = Bad
# 14                                                                                                                                        IF ExternalRiskEstimate <= 84.22287368774414 AND MSinceMostRecentInqexcl7days <= 6.1736838817596436 THEN class = Bad
# 15                                                                                                                                               IF AverageMInFile <= 60.0 AND ExternalRiskEstimate <= 70.0 AND MSinceOldestTradeOpen <= 65.0 THEN class = Bad
# 16                                                                                                     IF AverageMInFile <= 59.0 AND ExternalRiskEstimate > 40.418116 AND ExternalRiskEstimate <= 72.179245 AND PercentTradesNeverDelq > 74.0 THEN class = Bad
# 17                                                                                            IF AverageMInFile <= 54.323663 AND ExternalRiskEstimate <= 72.586493 AND MSinceOldestTradeOpen <= 84.378876 AND NetFractionInstallBurden > 28.0 THEN class = Bad
# 18                                                                                                                                                                         IF MSinceOldestTradeOpen <= 43.0 AND PercentTradesNeverDelq > 91.0 THEN class = Bad
# 19                                                                                            IF AverageMInFile <= 69.886397 AND ExternalRiskEstimate <= 74.380087 AND MSinceOldestTradeOpen <= 134.97816 AND NetFractionInstallBurden > 21.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.20202    0.29416  0.75997    3       0       5.01575       False
# 1   0.22715    0.33159  0.76188    2       0       4.22431       False
# 2   0.18440    0.26982  0.76370    2       1      11.31137       False
# 3   0.16050    0.23345  0.75915    3       1      11.73720       False
# 4   0.18986    0.27061  0.74388    3       0       4.47327       False
# 5   0.26199    0.36980  0.73670    3       0      51.56265       False
# 6   0.04180    0.06831  0.85294    3       0      52.50879       False
# 7   0.08400    0.10102  0.62764    2       0      52.42272       False
# 8   0.19547    0.30175  0.80573    2       0      51.51678       False
# 9   0.14329    0.21774  0.79314    3       0      50.84149       False
# 10  0.80085    0.91416  0.59577    3       0      10.46542       False
# 11  0.36293    0.44884  0.64546    5       0       9.84881       False
# 12  0.34613    0.48678  0.73402    2       0      10.00525       False
# 13  0.35186    0.45041  0.66809    4       0      10.63782       False
# 14  0.79497    0.90107  0.59158    2       0       9.76152       False
# 15  0.10122    0.13295  0.68556    3       0       1.54883       False
# 16  0.17074    0.25779  0.78800    4       0       1.59872       False
# 17  0.05013    0.08061  0.83924    4       0       1.29343       False
# 18  0.04152    0.05130  0.64474    2       0       0.83414       False
# 19  0.11979    0.18241  0.79475    4       0       1.79499       False
# ### Rules for Instance 1758, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0           1758    ANCHOR   ANCHOR1
# 1           1758    ANCHOR   ANCHOR2
# 2           1758    ANCHOR   ANCHOR3
# 3           1758    ANCHOR   ANCHOR4
# 4           1758    ANCHOR   ANCHOR5
# 5           1758      LORE     LORE1
# 6           1758      LORE     LORE2
# 7           1758      LORE     LORE3
# 8           1758      LORE     LORE4
# 9           1758      LORE     LORE5
# 10          1758   LORE_SA  LORE_SA1
# 11          1758   LORE_SA  LORE_SA2
# 12          1758   LORE_SA  LORE_SA3
# 13          1758   LORE_SA  LORE_SA4
# 14          1758   LORE_SA  LORE_SA5
# 15          1758    EXPLAN   EXPLAN1
# 16          1758    EXPLAN   EXPLAN2
# 17          1758    EXPLAN   EXPLAN3
# 18          1758    EXPLAN   EXPLAN4
# 19          1758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                           Rule  \
# 0                                                                                                                                          IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 AND MSinceMostRecentInqexcl7days <= 1.0 THEN class = Bad
# 1                                                                                                                                                                                  IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 2                                                                                                                                                                                  IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 AND NumSatisfactoryTrades <= 27.0 THEN class = Bad
# 4                                                                                                                                        IF ExternalRiskEstimate <= 63.0 AND NumSatisfactoryTrades <= 27.0 AND PercentTradesNeverDelq <= 96.0 THEN class = Bad
# 5                                                                                                                           IF ExternalRiskEstimate <= 65.0 AND MSinceMostRecentTradeOpen <= 11.0 AND NumRevolvingTradesWBalance <= 13.859723 THEN class = Bad
# 6                                                                                                                                   IF ExternalRiskEstimate <= 57.0 AND NetFractionRevolvingBurden > 46.0 AND NumInstallTradesWBalance <= 9.0 THEN class = Bad
# 7                                                                                                                                                                           IF ExternalRiskEstimate <= 55.0 AND NumSatisfactoryTrades <= 45.0 THEN class = Bad
# 8                                                                                                                                                                       IF ExternalRiskEstimate <= 67.0 AND NetFractionRevolvingBurden > 46.0 THEN class = Bad
# 9                                                                                                                                  IF ExternalRiskEstimate <= 70.0 AND NetFractionInstallBurden <= 82.0 AND NetFractionRevolvingBurden > 56.0 THEN class = Bad
# 10                                                                                                 IF AverageMInFile <= 370.5026550292969 AND ExternalRiskEstimate <= 83.35953521728516 AND MSinceMostRecentInqexcl7days <= 9.509681940078735 THEN class = Bad
# 11  IF AverageMInFile <= 344.0649108886719 AND ExternalRiskEstimate <= 81.12110137939453 AND MSinceMostRecentInqexcl7days <= 5.13841438293457 AND NetFractionInstallBurden > 52.35957336425781 AND NumInqLast6Mexcl7days <= 64.12469863891602 THEN class = Bad
# 12                                                                                                                                                        IF ExternalRiskEstimate <= 69.28391647338867 AND NumTotalTrades > 8.151997566223145 THEN class = Bad
# 13                                  IF NetFractionInstallBurden <= 86.09918975830078 AND NetFractionRevolvingBurden > 31.799015045166016 AND NumInqLast6Mexcl7days > -0.9713006764650345 AND NumTrades90Ever2DerogPubRec > -7.150922536849976 THEN class = Bad
# 14                                                                                                                                        IF ExternalRiskEstimate <= 84.22287368774414 AND MSinceMostRecentInqexcl7days <= 6.1736838817596436 THEN class = Bad
# 15                                                                                                                                               IF AverageMInFile <= 60.0 AND ExternalRiskEstimate <= 70.0 AND MSinceOldestTradeOpen <= 65.0 THEN class = Bad
# 16                                                                                                     IF AverageMInFile <= 59.0 AND ExternalRiskEstimate > 40.418116 AND ExternalRiskEstimate <= 72.179245 AND PercentTradesNeverDelq > 74.0 THEN class = Bad
# 17                                                                                            IF AverageMInFile <= 54.323663 AND ExternalRiskEstimate <= 72.586493 AND MSinceOldestTradeOpen <= 84.378876 AND NetFractionInstallBurden > 28.0 THEN class = Bad
# 18                                                                                                                                                                         IF MSinceOldestTradeOpen <= 43.0 AND PercentTradesNeverDelq > 91.0 THEN class = Bad
# 19                                                                                            IF AverageMInFile <= 69.886397 AND ExternalRiskEstimate <= 74.380087 AND MSinceOldestTradeOpen <= 134.97816 AND NetFractionInstallBurden > 21.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.20202    0.29416  0.75997    3       0       5.01575       False
# 1   0.22715    0.33159  0.76188    2       0       4.22431       False
# 2   0.18440    0.26982  0.76370    2       1      11.31137       False
# 3   0.16050    0.23345  0.75915    3       1      11.73720       False
# 4   0.18986    0.27061  0.74388    3       0       4.47327       False
# 5   0.26199    0.36980  0.73670    3       0      51.56265       False
# 6   0.04180    0.06831  0.85294    3       0      52.50879       False
# 7   0.08400    0.10102  0.62764    2       0      52.42272       False
# 8   0.19547    0.30175  0.80573    2       0      51.51678       False
# 9   0.14329    0.21774  0.79314    3       0      50.84149       False
# 10  0.80085    0.91416  0.59577    3       0      10.46542       False
# 11  0.36293    0.44884  0.64546    5       0       9.84881       False
# 12  0.34613    0.48678  0.73402    2       0      10.00525       False
# 13  0.35186    0.45041  0.66809    4       0      10.63782       False
# 14  0.79497    0.90107  0.59158    2       0       9.76152       False
# 15  0.10122    0.13295  0.68556    3       0       1.54883       False
# 16  0.17074    0.25779  0.78800    4       0       1.59872       False
# 17  0.05013    0.08061  0.83924    4       0       1.29343       False
# 18  0.04152    0.05130  0.64474    2       0       0.83414       False
# 19  0.11979    0.18241  0.79475    4       0       1.79499       False
# ### Rules for Instance 1758, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0           1758    ANCHOR   ANCHOR1
# 1           1758    ANCHOR   ANCHOR2
# 2           1758    ANCHOR   ANCHOR3
# 3           1758    ANCHOR   ANCHOR4
# 4           1758    ANCHOR   ANCHOR5
# 5           1758      LORE     LORE1
# 6           1758      LORE     LORE2
# 7           1758      LORE     LORE3
# 8           1758      LORE     LORE4
# 9           1758      LORE     LORE5
# 10          1758   LORE_SA  LORE_SA1
# 11          1758   LORE_SA  LORE_SA2
# 12          1758   LORE_SA  LORE_SA3
# 13          1758   LORE_SA  LORE_SA4
# 14          1758   LORE_SA  LORE_SA5
# 15          1758    EXPLAN   EXPLAN1
# 16          1758    EXPLAN   EXPLAN2
# 17          1758    EXPLAN   EXPLAN3
# 18          1758    EXPLAN   EXPLAN4
# 19          1758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                           Rule  \
# 0                                                                                                                                          IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 AND MSinceMostRecentInqexcl7days <= 1.0 THEN class = Bad
# 1                                                                                                                                                                                  IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 2                                                                                                                                                                                  IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                                                                                                                IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 AND NumSatisfactoryTrades <= 27.0 THEN class = Bad
# 4                                                                                                                                        IF ExternalRiskEstimate <= 63.0 AND NumSatisfactoryTrades <= 27.0 AND PercentTradesNeverDelq <= 96.0 THEN class = Bad
# 5                                                                                                                           IF ExternalRiskEstimate <= 65.0 AND MSinceMostRecentTradeOpen <= 11.0 AND NumRevolvingTradesWBalance <= 13.859723 THEN class = Bad
# 6                                                                                                                                   IF ExternalRiskEstimate <= 57.0 AND NetFractionRevolvingBurden > 46.0 AND NumInstallTradesWBalance <= 9.0 THEN class = Bad
# 7                                                                                                                                                                           IF ExternalRiskEstimate <= 55.0 AND NumSatisfactoryTrades <= 45.0 THEN class = Bad
# 8                                                                                                                                                                       IF ExternalRiskEstimate <= 67.0 AND NetFractionRevolvingBurden > 46.0 THEN class = Bad
# 9                                                                                                                                  IF ExternalRiskEstimate <= 70.0 AND NetFractionInstallBurden <= 82.0 AND NetFractionRevolvingBurden > 56.0 THEN class = Bad
# 10                                                                                                 IF AverageMInFile <= 370.5026550292969 AND ExternalRiskEstimate <= 83.35953521728516 AND MSinceMostRecentInqexcl7days <= 9.509681940078735 THEN class = Bad
# 11  IF AverageMInFile <= 344.0649108886719 AND ExternalRiskEstimate <= 81.12110137939453 AND MSinceMostRecentInqexcl7days <= 5.13841438293457 AND NetFractionInstallBurden > 52.35957336425781 AND NumInqLast6Mexcl7days <= 64.12469863891602 THEN class = Bad
# 12                                                                                                                                                        IF ExternalRiskEstimate <= 69.28391647338867 AND NumTotalTrades > 8.151997566223145 THEN class = Bad
# 13                                  IF NetFractionInstallBurden <= 86.09918975830078 AND NetFractionRevolvingBurden > 31.799015045166016 AND NumInqLast6Mexcl7days > -0.9713006764650345 AND NumTrades90Ever2DerogPubRec > -7.150922536849976 THEN class = Bad
# 14                                                                                                                                        IF ExternalRiskEstimate <= 84.22287368774414 AND MSinceMostRecentInqexcl7days <= 6.1736838817596436 THEN class = Bad
# 15                                                                                                                                               IF AverageMInFile <= 60.0 AND ExternalRiskEstimate <= 70.0 AND MSinceOldestTradeOpen <= 65.0 THEN class = Bad
# 16                                                                                                     IF AverageMInFile <= 59.0 AND ExternalRiskEstimate > 40.418116 AND ExternalRiskEstimate <= 72.179245 AND PercentTradesNeverDelq > 74.0 THEN class = Bad
# 17                                                                                            IF AverageMInFile <= 54.323663 AND ExternalRiskEstimate <= 72.586493 AND MSinceOldestTradeOpen <= 84.378876 AND NetFractionInstallBurden > 28.0 THEN class = Bad
# 18                                                                                                                                                                         IF MSinceOldestTradeOpen <= 43.0 AND PercentTradesNeverDelq > 91.0 THEN class = Bad
# 19                                                                                            IF AverageMInFile <= 69.886397 AND ExternalRiskEstimate <= 74.380087 AND MSinceOldestTradeOpen <= 134.97816 AND NetFractionInstallBurden > 21.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.20202    0.29416  0.75997    3       0       5.01575       False
# 1   0.22715    0.33159  0.76188    2       0       4.22431       False
# 2   0.18440    0.26982  0.76370    2       1      11.31137       False
# 3   0.16050    0.23345  0.75915    3       1      11.73720       False
# 4   0.18986    0.27061  0.74388    3       0       4.47327       False
# 5   0.26199    0.36980  0.73670    3       0      51.56265       False
# 6   0.04180    0.06831  0.85294    3       0      52.50879       False
# 7   0.08400    0.10102  0.62764    2       0      52.42272       False
# 8   0.19547    0.30175  0.80573    2       0      51.51678       False
# 9   0.14329    0.21774  0.79314    3       0      50.84149       False
# 10  0.80085    0.91416  0.59577    3       0      10.46542       False
# 11  0.36293    0.44884  0.64546    5       0       9.84881       False
# 12  0.34613    0.48678  0.73402    2       0      10.00525       False
# 13  0.35186    0.45041  0.66809    4       0      10.63782       False
# 14  0.79497    0.90107  0.59158    2       0       9.76152       False
# 15  0.10122    0.13295  0.68556    3       0       1.54883       False
# 16  0.17074    0.25779  0.78800    4       0       1.59872       False
# 17  0.05013    0.08061  0.83924    4       0       1.29343       False
# 18  0.04152    0.05130  0.64474    2       0       0.83414       False
# 19  0.11979    0.18241  0.79475    4       0       1.79499       False
# ### Rules for Instance 1758, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.80085, Pre: 0.85294)
# <style type="text/css">
# #T_8d568_row4_col0, #T_8d568_row4_col1, #T_8d568_row4_col2, #T_8d568_row4_col3, #T_8d568_row4_col4, #T_8d568_row4_col5, #T_8d568_row4_col6, #T_8d568_row4_col7, #T_8d568_row4_col8, #T_8d568_row4_col9, #T_8d568_row4_col10, #T_8d568_row4_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8d568">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d568_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_8d568_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_8d568_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_8d568_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_8d568_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_8d568_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_8d568_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_8d568_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_8d568_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_8d568_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_8d568_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_8d568_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d568_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d568_row0_col0" class="data row0 col0" >1758</td>
#       <td id="T_8d568_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_8d568_row0_col2" class="data row0 col2" >ANCHOR2</td>
#       <td id="T_8d568_row0_col3" class="data row0 col3" >IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad</td>
#       <td id="T_8d568_row0_col4" class="data row0 col4" >0.227150</td>
#       <td id="T_8d568_row0_col5" class="data row0 col5" >0.331590</td>
#       <td id="T_8d568_row0_col6" class="data row0 col6" >0.761880</td>
#       <td id="T_8d568_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_8d568_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_8d568_row0_col9" class="data row0 col9" >4.224310</td>
#       <td id="T_8d568_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_8d568_row0_col11" class="data row0 col11" >0.580882</td>
#     </tr>
#     <tr>
#       <th id="T_8d568_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d568_row1_col0" class="data row1 col0" >1758</td>
#       <td id="T_8d568_row1_col1" class="data row1 col1" >LORE</td>
#       <td id="T_8d568_row1_col2" class="data row1 col2" >LORE1</td>
#       <td id="T_8d568_row1_col3" class="data row1 col3" >IF ExternalRiskEstimate <= 65.0 AND MSinceMostRecentTradeOpen <= 11.0 AND NumRevolvingTradesWBalance <= 13.859723 THEN class = Bad</td>
#       <td id="T_8d568_row1_col4" class="data row1 col4" >0.261990</td>
#       <td id="T_8d568_row1_col5" class="data row1 col5" >0.369800</td>
#       <td id="T_8d568_row1_col6" class="data row1 col6" >0.736700</td>
#       <td id="T_8d568_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_8d568_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_8d568_row1_col9" class="data row1 col9" >51.562650</td>
#       <td id="T_8d568_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_8d568_row1_col11" class="data row1 col11" >0.551255</td>
#     </tr>
#     <tr>
#       <th id="T_8d568_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d568_row2_col0" class="data row2 col0" >1758</td>
#       <td id="T_8d568_row2_col1" class="data row2 col1" >LORE</td>
#       <td id="T_8d568_row2_col2" class="data row2 col2" >LORE2</td>
#       <td id="T_8d568_row2_col3" class="data row2 col3" >IF ExternalRiskEstimate <= 57.0 AND NetFractionRevolvingBurden > 46.0 AND NumInstallTradesWBalance <= 9.0 THEN class = Bad</td>
#       <td id="T_8d568_row2_col4" class="data row2 col4" >0.041800</td>
#       <td id="T_8d568_row2_col5" class="data row2 col5" >0.068310</td>
#       <td id="T_8d568_row2_col6" class="data row2 col6" >0.852940</td>
#       <td id="T_8d568_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_8d568_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_8d568_row2_col9" class="data row2 col9" >52.508790</td>
#       <td id="T_8d568_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_8d568_row2_col11" class="data row2 col11" >0.759050</td>
#     </tr>
#     <tr>
#       <th id="T_8d568_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d568_row3_col0" class="data row3 col0" >1758</td>
#       <td id="T_8d568_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_8d568_row3_col2" class="data row3 col2" >LORE4</td>
#       <td id="T_8d568_row3_col3" class="data row3 col3" >IF ExternalRiskEstimate <= 67.0 AND NetFractionRevolvingBurden > 46.0 THEN class = Bad</td>
#       <td id="T_8d568_row3_col4" class="data row3 col4" >0.195470</td>
#       <td id="T_8d568_row3_col5" class="data row3 col5" >0.301750</td>
#       <td id="T_8d568_row3_col6" class="data row3 col6" >0.805730</td>
#       <td id="T_8d568_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_8d568_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_8d568_row3_col9" class="data row3 col9" >51.516780</td>
#       <td id="T_8d568_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_8d568_row3_col11" class="data row3 col11" >0.607218</td>
#     </tr>
#     <tr>
#       <th id="T_8d568_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d568_row4_col0" class="data row4 col0" >1758</td>
#       <td id="T_8d568_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_8d568_row4_col2" class="data row4 col2" >LORE_SA1</td>
#       <td id="T_8d568_row4_col3" class="data row4 col3" >IF AverageMInFile <= 370.5026550292969 AND ExternalRiskEstimate <= 83.35953521728516 AND MSinceMostRecentInqexcl7days <= 9.509681940078735 THEN class = Bad</td>
#       <td id="T_8d568_row4_col4" class="data row4 col4" >0.800850</td>
#       <td id="T_8d568_row4_col5" class="data row4 col5" >0.914160</td>
#       <td id="T_8d568_row4_col6" class="data row4 col6" >0.595770</td>
#       <td id="T_8d568_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_8d568_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_8d568_row4_col9" class="data row4 col9" >10.465420</td>
#       <td id="T_8d568_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_8d568_row4_col11" class="data row4 col11" >0.257170</td>
#     </tr>
#     <tr>
#       <th id="T_8d568_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d568_row5_col0" class="data row5 col0" >1758</td>
#       <td id="T_8d568_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_8d568_row5_col2" class="data row5 col2" >LORE_SA2</td>
#       <td id="T_8d568_row5_col3" class="data row5 col3" >IF AverageMInFile <= 344.0649108886719 AND ExternalRiskEstimate <= 81.12110137939453 AND MSinceMostRecentInqexcl7days <= 5.13841438293457 AND NetFractionInstallBurden > 52.35957336425781 AND NumInqLast6Mexcl7days <= 64.12469863891602 THEN class = Bad</td>
#       <td id="T_8d568_row5_col4" class="data row5 col4" >0.362930</td>
#       <td id="T_8d568_row5_col5" class="data row5 col5" >0.448840</td>
#       <td id="T_8d568_row5_col6" class="data row5 col6" >0.645460</td>
#       <td id="T_8d568_row5_col7" class="data row5 col7" >5</td>
#       <td id="T_8d568_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_8d568_row5_col9" class="data row5 col9" >9.848810</td>
#       <td id="T_8d568_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_8d568_row5_col11" class="data row5 col11" >0.484584</td>
#     </tr>
#     <tr>
#       <th id="T_8d568_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d568_row6_col0" class="data row6 col0" >1758</td>
#       <td id="T_8d568_row6_col1" class="data row6 col1" >LORE_SA</td>
#       <td id="T_8d568_row6_col2" class="data row6 col2"
# ### Rules for Instance 1758, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.91416, Pre: 0.85294, Len: 0.59158)
# <style type="text/css">
# #T_d86bd_row6_col0, #T_d86bd_row6_col1, #T_d86bd_row6_col2, #T_d86bd_row6_col3, #T_d86bd_row6_col4, #T_d86bd_row6_col5, #T_d86bd_row6_col6, #T_d86bd_row6_col7, #T_d86bd_row6_col8, #T_d86bd_row6_col9, #T_d86bd_row6_col10, #T_d86bd_row6_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d86bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d86bd_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_d86bd_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_d86bd_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_d86bd_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_d86bd_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_d86bd_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_d86bd_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_d86bd_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_d86bd_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_d86bd_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_d86bd_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_d86bd_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d86bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d86bd_row0_col0" class="data row0 col0" >1758</td>
#       <td id="T_d86bd_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_d86bd_row0_col2" class="data row0 col2" >ANCHOR2</td>
#       <td id="T_d86bd_row0_col3" class="data row0 col3" >IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad</td>
#       <td id="T_d86bd_row0_col4" class="data row0 col4" >0.227150</td>
#       <td id="T_d86bd_row0_col5" class="data row0 col5" >0.331590</td>
#       <td id="T_d86bd_row0_col6" class="data row0 col6" >0.761880</td>
#       <td id="T_d86bd_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_d86bd_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_d86bd_row0_col9" class="data row0 col9" >4.224310</td>
#       <td id="T_d86bd_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_d86bd_row0_col11" class="data row0 col11" >1.526868</td>
#     </tr>
#     <tr>
#       <th id="T_d86bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d86bd_row1_col0" class="data row1 col0" >1758</td>
#       <td id="T_d86bd_row1_col1" class="data row1 col1" >LORE</td>
#       <td id="T_d86bd_row1_col2" class="data row1 col2" >LORE1</td>
#       <td id="T_d86bd_row1_col3" class="data row1 col3" >IF ExternalRiskEstimate <= 65.0 AND MSinceMostRecentTradeOpen <= 11.0 AND NumRevolvingTradesWBalance <= 13.859723 THEN class = Bad</td>
#       <td id="T_d86bd_row1_col4" class="data row1 col4" >0.261990</td>
#       <td id="T_d86bd_row1_col5" class="data row1 col5" >0.369800</td>
#       <td id="T_d86bd_row1_col6" class="data row1 col6" >0.736700</td>
#       <td id="T_d86bd_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_d86bd_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_d86bd_row1_col9" class="data row1 col9" >51.562650</td>
#       <td id="T_d86bd_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_d86bd_row1_col11" class="data row1 col11" >2.471907</td>
#     </tr>
#     <tr>
#       <th id="T_d86bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d86bd_row2_col0" class="data row2 col0" >1758</td>
#       <td id="T_d86bd_row2_col1" class="data row2 col1" >LORE</td>
#       <td id="T_d86bd_row2_col2" class="data row2 col2" >LORE2</td>
#       <td id="T_d86bd_row2_col3" class="data row2 col3" >IF ExternalRiskEstimate <= 57.0 AND NetFractionRevolvingBurden > 46.0 AND NumInstallTradesWBalance <= 9.0 THEN class = Bad</td>
#       <td id="T_d86bd_row2_col4" class="data row2 col4" >0.041800</td>
#       <td id="T_d86bd_row2_col5" class="data row2 col5" >0.068310</td>
#       <td id="T_d86bd_row2_col6" class="data row2 col6" >0.852940</td>
#       <td id="T_d86bd_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_d86bd_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_d86bd_row2_col9" class="data row2 col9" >52.508790</td>
#       <td id="T_d86bd_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_d86bd_row2_col11" class="data row2 col11" >2.552636</td>
#     </tr>
#     <tr>
#       <th id="T_d86bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d86bd_row3_col0" class="data row3 col0" >1758</td>
#       <td id="T_d86bd_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_d86bd_row3_col2" class="data row3 col2" >LORE4</td>
#       <td id="T_d86bd_row3_col3" class="data row3 col3" >IF ExternalRiskEstimate <= 67.0 AND NetFractionRevolvingBurden > 46.0 THEN class = Bad</td>
#       <td id="T_d86bd_row3_col4" class="data row3 col4" >0.195470</td>
#       <td id="T_d86bd_row3_col5" class="data row3 col5" >0.301750</td>
#       <td id="T_d86bd_row3_col6" class="data row3 col6" >0.805730</td>
#       <td id="T_d86bd_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_d86bd_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_d86bd_row3_col9" class="data row3 col9" >51.516780</td>
#       <td id="T_d86bd_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_d86bd_row3_col11" class="data row3 col11" >1.536529</td>
#     </tr>
#     <tr>
#       <th id="T_d86bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d86bd_row4_col0" class="data row4 col0" >1758</td>
#       <td id="T_d86bd_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_d86bd_row4_col2" class="data row4 col2" >LORE_SA1</td>
#       <td id="T_d86bd_row4_col3" class="data row4 col3" >IF AverageMInFile <= 370.5026550292969 AND ExternalRiskEstimate <= 83.35953521728516 AND MSinceMostRecentInqexcl7days <= 9.509681940078735 THEN class = Bad</td>
#       <td id="T_d86bd_row4_col4" class="data row4 col4" >0.800850</td>
#       <td id="T_d86bd_row4_col5" class="data row4 col5" >0.914160</td>
#       <td id="T_d86bd_row4_col6" class="data row4 col6" >0.595770</td>
#       <td id="T_d86bd_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_d86bd_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_d86bd_row4_col9" class="data row4 col9" >10.465420</td>
#       <td id="T_d86bd_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_d86bd_row4_col11" class="data row4 col11" >2.422111</td>
#     </tr>
#     <tr>
#       <th id="T_d86bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d86bd_row5_col0" class="data row5 col0" >1758</td>
#       <td id="T_d86bd_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_d86bd_row5_col2" class="data row5 col2" >LORE_SA3</td>
#       <td id="T_d86bd_row5_col3" class="data row5 col3" >IF ExternalRiskEstimate <= 69.28391647338867 AND NumTotalTrades > 8.151997566223145 THEN class = Bad</td>
#       <td id="T_d86bd_row5_col4" class="data row5 col4" >0.346130</td>
#       <td id="T_d86bd_row5_col5" class="data row5 col5" >0.486780</td>
#       <td id="T_d86bd_row5_col6" class="data row5 col6" >0.734020</td>
#       <td id="T_d86bd_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_d86bd_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_d86bd_row5_col9" class="data row5 col9" >10.005250</td>
#       <td id="T_d86bd_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_d86bd_row5_col11" class="data row5 col11" >1.476632</td>
#     </tr>
#     <tr>
#       <th id="T_d86bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d86bd_row6_col0" class="data row6 col0" >1758</td>
#       <td id="T_d86bd_row6_col1" class="data row6 col1" >LORE_SA</td>
#       <td id="T_d86bd_row6_col2" class="data row6 col2" >LORE_SA5</td>
#       <td id="T_d86bd_row6_col3" class="data row6 col3" >IF ExternalRiskEstimate <= 84.22287368774414 AND MSinceMostRecentInqexcl7day
# ## Instance 2674 (Original: Bad , Predicted: Bad)
#                                     Value
# ExternalRiskEstimate                 58.0
# MSinceOldestTradeOpen               183.0
# MSinceMostRecentTradeOpen            11.0
# AverageMInFile                       36.0
# NumSatisfactoryTrades                30.0
# NumTrades60Ever2DerogPubRec           0.0
# NumTrades90Ever2DerogPubRec           0.0
# PercentTradesNeverDelq              100.0
# MSinceMostRecentDelq                 -7.0
# MaxDelq2PublicRecLast12M                7
# MaxDelqEver                             8
# NumTotalTrades                       32.0
# NumTradesOpeninLast12M                3.0
# PercentInstallTrades                 17.0
# MSinceMostRecentInqexcl7days         -7.0
# NumInqLast6M                          8.0
# NumInqLast6Mexcl7days                 7.0
# NetFractionRevolvingBurden           87.0
# NetFractionInstallBurden             -8.0
# NumRevolvingTradesWBalance           15.0
# NumInstallTradesWBalance              2.0
# NumBank2NatlTradesWHighUtilization   10.0
# PercentTradesWBalance                81.0
# ### Rules for Instance 2674
#    Instance_Name Explainer   Rule_ID  \
# 0           2674    ANCHOR   ANCHOR1
# 1           2674    ANCHOR   ANCHOR2
# 2           2674    ANCHOR   ANCHOR3
# 3           2674    ANCHOR   ANCHOR4
# 4           2674    ANCHOR   ANCHOR5
# 5           2674      LORE     LORE1
# 6           2674      LORE     LORE2
# 7           2674      LORE     LORE3
# 8           2674      LORE     LORE4
# 9           2674      LORE     LORE5
# 10          2674   LORE_SA  LORE_SA1
# 11          2674   LORE_SA  LORE_SA2
# 12          2674   LORE_SA  LORE_SA3
# 13          2674   LORE_SA  LORE_SA4
# 14          2674   LORE_SA  LORE_SA5
# 15          2674    EXPLAN   EXPLAN1
# 16          2674    EXPLAN   EXPLAN2
# 17          2674    EXPLAN   EXPLAN3
# 18          2674    EXPLAN   EXPLAN4
# 19          2674    EXPLAN   EXPLAN5
#
#                                                                                                                                                                        Rule  \
# 0                                                            IF AverageMInFile <= 95.0 AND ExternalRiskEstimate <= 63.0 AND MSinceOldestTradeOpen <= 248.0 THEN class = Bad
# 1                                                           IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 AND PercentTradesNeverDelq <= 100.0 THEN class = Bad
# 2                                                                                               IF AverageMInFile <= 74.0 AND ExternalRiskEstimate <= 63.0 THEN class = Bad
# 3                                                       IF AverageMInFile <= 52.0 AND ExternalRiskEstimate <= 63.0 AND MSinceMostRecentInqexcl7days <= 1.0 THEN class = Bad
# 4                    IF AverageMInFile <= 52.0 AND ExternalRiskEstimate <= 71.0 AND MSinceMostRecentInqexcl7days <= 1.0 AND MSinceOldestTradeOpen <= 248.0 THEN class = Bad
# 5                                                                                         IF ExternalRiskEstimate <= 80.0 AND PercentTradesWBalance > 60.0 THEN class = Bad
# 6                                                                                                                          IF ExternalRiskEstimate <= 71.0 THEN class = Bad
# 7                                                                                                                          IF ExternalRiskEstimate <= 72.0 THEN class = Bad
# 8                                                                                    IF ExternalRiskEstimate <= 73.0 AND NetFractionRevolvingBurden > 66.0 THEN class = Bad
# 9                                                                                                                     IF ExternalRiskEstimate <= 70.689352 THEN class = Bad
# 10                                                                      IF ExternalRiskEstimate <= 81.63618087768555 AND NumInqLast6M > -1.807143121957779 THEN class = Bad
# 11                                                                    IF MaxDelq2PublicRecLast12M = 7 AND NumTrades60Ever2DerogPubRec > -7.985632658004761 THEN class = Bad
# 12                                                                                                            IF PercentTradesWBalance > 66.97013092041016 THEN class = Bad
# 13                     IF AverageMInFile <= 342.6084899902344 AND ExternalRiskEstimate <= 87.78213500976562 AND PercentTradesNeverDelq > 91.94598388671875 THEN class = Bad
# 14                                                                                                      IF NetFractionInstallBurden <= -3.3960574865341187 THEN class = Bad
# 15                                    IF ExternalRiskEstimate <= 76.886848 AND NetFractionInstallBurden <= 46.0 AND NetFractionRevolvingBurden > 31.088529 THEN class = Bad
# 16                                         IF ExternalRiskEstimate <= 78.0 AND NetFractionInstallBurden <= 39.0 AND NumRevolvingTradesWBalance > 10.085707 THEN class = Bad
# 17                                                                         IF ExternalRiskEstimate <= 71.700028 AND NetFractionRevolvingBurden > 44.944318 THEN class = Bad
# 18                                             IF ExternalRiskEstimate <= 71.062858 AND MSinceOldestTradeOpen > 79.0 AND NetFractionRevolvingBurden > 49.0 THEN class = Bad
# 19  IF AverageMInFile <= 82.309062 AND ExternalRiskEstimate <= 79.932174 AND MSinceMostRecentInqexcl7days <= 0.537736 AND NetFractionInstallBurden <= 28.0 THEN class = Bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.20790    0.30385  0.76281    3       0       6.16557       False
# 1   0.18440    0.26982  0.76370    3       0       4.92629       False
# 2   0.18440    0.26982  0.76370    2       0       4.83301       False
# 3   0.11310    0.15703  0.72464    3       0       5.33315       False
# 4   0.17252    0.24444  0.73951    4       0       4.21110       False
# 5   0.49242    0.63439  0.67240    2       0      51.46667       False
# 6   0.51769    0.70191  0.70765    1       0      50.24251       False
# 7   0.55279    0.73829  0.69706    1       0      50.72878       False
# 8   0.15107    0.23188  0.80108    2       1     104.11984       False
# 9   0.49010    0.67391  0.71767    1       1     100.30114       False
# 10  0.74580    0.87124  0.60971    2       0       9.72855       False
# 11  0.40923    0.30568  0.38985    2       0       9.67514       False
# 12  0.50649    0.61214  0.63080    1       0       9.38648       False
# 13  0.60620    0.54174  0.46643    3       0       9.66391       False
# 14  0.38273    0.35724  0.48715    1       0      10.00765       False
# 15  0.15176    0.21146  0.72727    3       0       1.55843       False
# 16  0.01175    0.01675  0.74419    3       0       1.36280       False
# 17  0.25789    0.37713  0.76324    2       0       2.52243       False
# 18  0.19669    0.28500  0.75625    3       0       1.51942       False
# 19  0.15899    0.20361  0.66838    4       0       1.41080       False
# ### Rules for Instance 2674, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# ...
#       <td id="T_b2357_row1_col6" class="data row1 col6" >0.841530</td>
#       <td id="T_b2357_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_b2357_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_b2357_row1_col9" class="data row1 col9" >13.457000</td>
#       <td id="T_b2357_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_b2357_row1_col11" class="data row1 col11" >0.496110</td>
#     </tr>
#     <tr>
#       <th id="T_b2357_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b2357_row2_col0" class="data row2 col0" >779</td>
#       <td id="T_b2357_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_b2357_row2_col2" class="data row2 col2" >ANCHOR5</td>
#       <td id="T_b2357_row2_col3" class="data row2 col3" >IF AverageMInFile > 52.0 AND ExternalRiskEstimate > 80.0 AND NetFractionRevolvingBurden <= 25.0 AND NumTrades60Ever2DerogPubRec <= 0.0 AND PercentTradesNeverDelq > 87.0 THEN class = Good</td>
#       <td id="T_b2357_row2_col4" class="data row2 col4" >0.184950</td>
#       <td id="T_b2357_row2_col5" class="data row2 col5" >0.318860</td>
#       <td id="T_b2357_row2_col6" class="data row2 col6" >0.824220</td>
#       <td id="T_b2357_row2_col7" class="data row2 col7" >5</td>
#       <td id="T_b2357_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_b2357_row2_col9" class="data row2 col9" >20.821810</td>
#       <td id="T_b2357_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_b2357_row2_col11" class="data row2 col11" >0.461465</td>
#     </tr>
#     <tr>
#       <th id="T_b2357_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b2357_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_b2357_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_b2357_row3_col2" class="data row3 col2" >LORE5</td>
#       <td id="T_b2357_row3_col3" class="data row3 col3" >IF ExternalRiskEstimate > 73.0 AND NumRevolvingTradesWBalance <= 6.201246 AND PercentTradesNeverDelq > 88.0 THEN class = Good</td>
#       <td id="T_b2357_row3_col4" class="data row3 col4" >0.368800</td>
#       <td id="T_b2357_row3_col5" class="data row3 col5" >0.562570</td>
#       <td id="T_b2357_row3_col6" class="data row3 col6" >0.729260</td>
#       <td id="T_b2357_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_b2357_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_b2357_row3_col9" class="data row3 col9" >50.743360</td>
#       <td id="T_b2357_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_b2357_row3_col11" class="data row3 col11" >0.299156</td>
#     </tr>
#     <tr>
#       <th id="T_b2357_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b2357_row4_col0" class="data row4 col0" >779</td>
#       <td id="T_b2357_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_b2357_row4_col2" class="data row4 col2" >LORE_SA1</td>
#       <td id="T_b2357_row4_col3" class="data row4 col3" >IF ExternalRiskEstimate > 66.98753356933594 AND NumTrades60Ever2DerogPubRec <= 4.6273133754730225 AND PercentTradesNeverDelq > 91.90027618408203 THEN class = Good</td>
#       <td id="T_b2357_row4_col4" class="data row4 col4" >0.539410</td>
#       <td id="T_b2357_row4_col5" class="data row4 col5" >0.718290</td>
#       <td id="T_b2357_row4_col6" class="data row4 col6" >0.636620</td>
#       <td id="T_b2357_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_b2357_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_b2357_row4_col9" class="data row4 col9" >8.718320</td>
#       <td id="T_b2357_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_b2357_row4_col11" class="data row4 col11" >0.231017</td>
#     </tr>
#     <tr>
#       <th id="T_b2357_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b2357_row5_col0" class="data row5 col0" >779</td>
#       <td id="T_b2357_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_b2357_row5_col2" class="data row5 col2" >LORE_SA5</td>
#       <td id="T_b2357_row5_col3" class="data row5 col3" >IF ExternalRiskEstimate > 37.87645721435547 AND MSinceMostRecentInqexcl7days <= 20.342744827270508 AND MaxDelq2PublicRecLast12M != 4 AND PercentTradesNeverDelq > 88.87310409545898 THEN class = Good</td>
#       <td id="T_b2357_row5_col4" class="data row5 col4" >0.646090</td>
#       <td id="T_b2357_row5_col5" class="data row5 col5" >0.763430</td>
#       <td id="T_b2357_row5_col6" class="data row5 col6" >0.564900</td>
#       <td id="T_b2357_row5_col7" class="data row5 col7" >4</td>
#       <td id="T_b2357_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_b2357_row5_col9" class="data row5 col9" >8.614480</td>
#       <td id="T_b2357_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_b2357_row5_col11" class="data row5 col11" >0.276630</td>
#     </tr>
#     <tr>
#       <th id="T_b2357_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b2357_row6_col0" class="data
# ### Rules for Instance 779, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.76343, Pre: 0.84153, Len: 0.5649)
# <style type="text/css">
# #T_745d8_row7_col0, #T_745d8_row7_col1, #T_745d8_row7_col2, #T_745d8_row7_col3, #T_745d8_row7_col4, #T_745d8_row7_col5, #T_745d8_row7_col6, #T_745d8_row7_col7, #T_745d8_row7_col8, #T_745d8_row7_col9, #T_745d8_row7_col10, #T_745d8_row7_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_745d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_745d8_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_745d8_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_745d8_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_745d8_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_745d8_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_745d8_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_745d8_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_745d8_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_745d8_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_745d8_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_745d8_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_745d8_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_745d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_745d8_row0_col0" class="data row0 col0" >779</td>
#       <td id="T_745d8_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_745d8_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_745d8_row0_col3" class="data row0 col3" >IF AverageMInFile > 52.0 AND ExternalRiskEstimate > 80.0 AND NetFractionRevolvingBurden <= 25.0 AND PercentTradesNeverDelq > 87.0 THEN class = Good</td>
#       <td id="T_745d8_row0_col4" class="data row0 col4" >0.191500</td>
#       <td id="T_745d8_row0_col5" class="data row0 col5" >0.329140</td>
#       <td id="T_745d8_row0_col6" class="data row0 col6" >0.821680</td>
#       <td id="T_745d8_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_745d8_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_745d8_row0_col9" class="data row0 col9" >11.515100</td>
#       <td id="T_745d8_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_745d8_row0_col11" class="data row0 col11" >3.462501</td>
#     </tr>
#     <tr>
#       <th id="T_745d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_745d8_row1_col0" class="data row1 col0" >779</td>
#       <td id="T_745d8_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_745d8_row1_col2" class="data row1 col2" >ANCHOR3</td>
#       <td id="T_745d8_row1_col3" class="data row1 col3" >IF AverageMInFile > 74.0 AND ExternalRiskEstimate > 80.0 AND NetFractionRevolvingBurden <= 25.0 AND PercentTradesNeverDelq > 87.0 THEN class = Good</td>
#       <td id="T_745d8_row1_col4" class="data row1 col4" >0.149980</td>
#       <td id="T_745d8_row1_col5" class="data row1 col5" >0.264000</td>
#       <td id="T_745d8_row1_col6" class="data row1 col6" >0.841530</td>
#       <td id="T_745d8_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_745d8_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_745d8_row1_col9" class="data row1 col9" >13.457000</td>
#       <td id="T_745d8_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_745d8_row1_col11" class="data row1 col11" >3.471216</td>
#     </tr>
#     <tr>
#       <th id="T_745d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_745d8_row2_col0" class="data row2 col0" >779</td>
#       <td id="T_745d8_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_745d8_row2_col2" class="data row2 col2" >ANCHOR5</td>
#       <td id="T_745d8_row2_col3" class="data row2 col3" >IF AverageMInFile > 52.0 AND ExternalRiskEstimate > 80.0 AND NetFractionRevolvingBurden <= 25.0 AND NumTrades60Ever2DerogPubRec <= 0.0 AND PercentTradesNeverDelq > 87.0 THEN class = Good</td>
#       <td id="T_745d8_row2_col4" class="data row2 col4" >0.184950</td>
#       <td id="T_745d8_row2_col5" class="data row2 col5" >0.318860</td>
#       <td id="T_745d8_row2_col6" class="data row2 col6" >0.824220</td>
#       <td id="T_745d8_row2_col7" class="data row2 col7" >5</td>
#       <td id="T_745d8_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_745d8_row2_col9" class="data row2 col9" >20.821810</td>
#       <td id="T_745d8_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_745d8_row2_col11" class="data row2 col11" >4.457360</td>
#     </tr>
#     <tr>
#       <th id="T_745d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_745d8_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_745d8_row3_col1" class="data row3 col1" >LORE</td>
#       <td id="T_745d8_row3_col2" class="data row3 col2" >LORE5</td>
#       <td id="T_745d8_row3_col3" class="data row3 col3" >IF ExternalRiskEstimate > 73.0 AND NumRevolvingTradesWBalance <= 6.201246 AND PercentTradesNeverDelq > 88.0 THEN class = Good</td>
#       <td id="T_745d8_row3_col4" class="data row3 col4" >0.368800</td>
#       <td id="T_745d8_row3_col5" class="data row3 col5" >0.562570</td>
#       <td id="T_745d8_row3_col6" class="data row3 col6" >0.729260</td>
#       <td id="T_745d8_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_745d8_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_745d8_row3_col9" class="data row3 col9" >50.743360</td>
#       <td id="T_745d8_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_745d8_row3_col11" class="data row3 col11" >2.445948</td>
#     </tr>
#     <tr>
#       <th id="T_745d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_745d8_row4_col0" class="data row4 col0" >779</td>
#       <td id="T_745d8_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_745d8_row4_col2" class="data row4 col2" >LORE_SA1</td>
#       <td id="T_745d8_row4_col3" class="data row4 col3" >IF ExternalRiskEstimate > 66.98753356933594 AND NumTrades60Ever2DerogPubRec <= 4.6273133754730225 AND PercentTradesNeverDelq > 91.90027618408203 THEN class = Good</td>
#       <td id="T_745d8_row4_col4" class="data row4 col4" >0.539410</td>
#       <td id="T_745d8_row4_col5" class="data row4 col5" >0.718290</td>
#       <td id="T_745d8_row4_col6" class="data row4 col6" >0.636620</td>
#       <td id="T_745d8_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_745d8_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_745d8_row4_col9" class="data row4 col9" >8.718320</td>
#       <td id="T_745d8_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_745d8_row4_col11" class="data row4 col11" >2.444123</td>
#     </tr>
#     <tr>
#       <th id="T_745d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_745d8_row5_col0" class="data row5 col0" >779</td>
#       <td id="T_745d8_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_745d8_row5_col2" class="data row5 col2" >LORE_SA5</td>
#       <td id="T_745d8_row5_col3" class="data row5 col3" >IF ExternalRiskEstimate > 37.87645721435547 AND MSinceMostRecentInqexcl7days <= 20.342744827270508 AND MaxDelq2PublicRecLast12M != 4 AND PercentTradesNeverDelq > 88.87310409545898 THEN class = Good</td>
#       <td id="T_745d8_row5_col4" class="data row5 col4" >0.646090</td>
#       <td id="T_745d8_row5_col5" class="data row5 col5" >0.763430</td>
#       <td id="T_745d8_row5_col6" class="data row5 col6" >0.564900</td>
#       <td id="T_745d8_row5_col7" class="data row5 col7" >4</td>
#       <td id="T_745d8_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_745d8_row5_col9" class="data row5 col9" >8.614480</td>
#       <td id="T_745d8_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_745d8_row5_col11" class="data row5 col11" >3.446221</td>
#     </tr>
#     <tr>
#       <th id="T_745d8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_745d8_row6_col0" class="data
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         0.0
# LORE                                           0.4
# LORE_SA                                        0.0
# EXPLAN                                         0.1
# Overall Average                                0.5
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                       0.0
# LORE                                         0.4
# LORE_SA                                      0.9
# EXPLAN                                       0.7
# Overall Average                              2.0
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                      2.6
# LORE                                        1.9
# LORE_SA                                     2.1
# EXPLAN                                      2.6
# Overall Average                             9.2
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                      2.2
# LORE                                        1.5
# LORE_SA                                     2.5
# EXPLAN                                      2.5
# Overall Average                             8.7
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.802246  0.164512   0.262254  3.933333  0.141667
# EXPLAN          0.791108  0.224013   0.351826  3.645833  0.000000
# LORE            0.730778  0.315303   0.450899  2.708333  0.050000
# LORE_SA         0.678111  0.451754   0.581799  4.870833  0.000000
# Global_Average  0.752333  0.283452   0.405570  3.737500  0.053241
#
#                 Elapsed_time
# ANCHOR             11.123351
# EXPLAN              1.717070
# LORE               53.727219
# LORE_SA             9.126256
# Global_Average     20.423676
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.800729  0.165983   0.264445  3.723333  0.163333
# EXPLAN          0.777662  0.212418   0.329803  3.462963  0.000000
# LORE            0.746414  0.301209   0.436225  2.908333  0.050000
# LORE_SA         0.688940  0.461666   0.604648  4.829167  0.000000
# Global_Average  0.756268  0.277757   0.400327  3.678829  0.057658
#
#                 Elapsed_time
# ANCHOR             10.956980
# EXPLAN              1.634940
# LORE               53.580928
# LORE_SA             9.128739
# Global_Average     19.814148
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
