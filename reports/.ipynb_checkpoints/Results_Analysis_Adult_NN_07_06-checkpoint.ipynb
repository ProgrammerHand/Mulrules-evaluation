# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results 

rules_log = "adult_simpleNN_rules_19-23_06-06-2025.txt"
entries_log = "adult_simpleNN_entries_19-23_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 5988 (Original: <=50K , Predicted: <=50K)
#                              Value
# age                           41.0
# workclass                  Private
# education             Some-college
# education.num                   10
# marital.status  Married-civ-spouse
# occupation         Farming-fishing
# relationship               Husband
# race                         White
# sex                           Male
# capital.gain                   0.0
# capital.loss                   0.0
# hours.per.week                16.0
# native.country       United-States
# ### Rules for Instance 5988
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988    ANCHOR   ANCHOR3
# 3           5988    ANCHOR   ANCHOR4
# 4           5988    ANCHOR   ANCHOR5
# 5           5988      LORE     LORE1
# 6           5988      LORE     LORE2
# 7           5988      LORE     LORE3
# 8           5988      LORE     LORE4
# 9           5988      LORE     LORE5
# 10          5988   LORE_SA  LORE_SA1
# 11          5988   LORE_SA  LORE_SA2
# 12          5988   LORE_SA  LORE_SA3
# 13          5988   LORE_SA  LORE_SA4
# 14          5988   LORE_SA  LORE_SA5
# 15          5988    EXPLAN   EXPLAN1
# 16          5988    EXPLAN   EXPLAN2
# 17          5988    EXPLAN   EXPLAN3
# 18          5988    EXPLAN   EXPLAN4
# 19          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                      Rule  \
# 0                                                                                                   IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                                                                   IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                      IF capital.gain <= 0.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 3                                                                                                                                      IF age <= 47.0 AND occupation = Farming-fishing THEN class = <=50K
# 4                                                                                                              IF age <= 47.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 5                                                                                                                                                            IF hours.per.week <= 25.0 THEN class = <=50K
# 6                                                                                                                                                            IF hours.per.week <= 35.0 THEN class = <=50K
# 7                                                                                                                                                            IF hours.per.week <= 20.0 THEN class = <=50K
# 8                                                                                                                                                            IF hours.per.week <= 24.0 THEN class = <=50K
# 9                                                                                IF age > 40.0 AND capital.gain <= 20051.0 AND hours.per.week <= 32.0 AND occupation = Farming-fishing THEN class = <=50K
# 10  IF capital.gain <= 4847.57275390625 AND capital.loss <= 3923.0845947265625 AND hours.per.week <= 33.48286724090576 AND native.country != Thailand AND occupation = Farming-fishing THEN class = <=50K
# 11                               IF capital.gain <= 13894.640258789062 AND capital.loss <= 1552.4618530273438 AND hours.per.week <= 48.96787643432617 AND occupation = Farming-fishing THEN class = <=50K
# 12   IF capital.gain <= 12589.81298828125 AND capital.loss <= 2782.22607421875 AND hours.per.week <= 71.10613250732422 AND occupation = Farming-fishing AND race != Asian-Pac-Islander THEN class = <=50K
# 13                                         IF capital.gain <= 9433.59814453125 AND capital.loss <= 3302.761474609375 AND hours.per.week <= 17.314167976379395 AND relationship != Wife THEN class = <=50K
# 14                                          IF capital.gain <= 2050.699462890625 AND capital.loss <= 702.5028076171875 AND hours.per.week <= 51.90324783325195 AND workclass = Private THEN class = <=50K
# 15                                                                                                                                                           IF hours.per.week <= 22.0 THEN class = <=50K
# 16                                                                                                                                                      IF hours.per.week <= 33.746126 THEN class = <=50K
# 17                                                                                                                                                           IF hours.per.week <= 35.0 THEN class = <=50K
# 18                                                                                                                                                           IF hours.per.week <= 32.0 THEN class = <=50K
# 19                                                                                                                                                       IF hours.per.week <= 32.08911 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01615    0.02023  0.95109    3       0       3.76462       False
# 1   0.01474    0.01855  0.95536    3       0       3.84528       False
# 2   0.02637    0.03213  0.92512    3       0       4.51247       False
# 3   0.02027    0.02427  0.90909    2       1       7.45094       False
# 4   0.01957    0.02375  0.92152    3       2      15.77246       False
# 5   0.12171    0.14945  0.93223    1       0     120.30945       False
# 6   0.21231    0.25574  0.91445    1       0     113.40588       False
# 7   0.09073    0.11148  0.93279    1       0     113.02704       False
# 8   0.10069    0.12322  0.92898    1       0     117.24557       False
# 9   0.00254    0.00318  0.94828    4       0     116.47287       False
# 10  0.00452    0.00584  0.98058    5       0      32.21914       False
# 11  0.01698    0.02092  0.93540    4       0      28.36005       False
# 12  0.02650    0.03150  0.90232    5       0      30.24867       False
# 13  0.04624    0.05872  0.96395    4       0      32.25163       False
# 14  0.61188    0.68468  0.84949    4       0      36.39505       False
# 15  0.09262    0.11368  0.93179    1       0       3.39928       False
# 16  0.17208    0.21043  0.92835    1       0       2.96082       False
# 17  0.21231    0.25574  0.91445    1       0       2.66424       False
# 18  0.17076    0.20887  0.92857    1       0       2.74517       False
# 19  0.17076    0.20887  0.92857    1       0       2.75345       False
# ### Rules for Instance 5988, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988    ANCHOR   ANCHOR3
# 3           5988    ANCHOR   ANCHOR4
# 4           5988    ANCHOR   ANCHOR5
# 5           5988      LORE     LORE1
# 6           5988      LORE     LORE2
# 7           5988      LORE     LORE3
# 8           5988      LORE     LORE4
# 9           5988      LORE     LORE5
# 10          5988   LORE_SA  LORE_SA1
# 11          5988   LORE_SA  LORE_SA2
# 12          5988   LORE_SA  LORE_SA3
# 13          5988   LORE_SA  LORE_SA4
# 14          5988   LORE_SA  LORE_SA5
# 15          5988    EXPLAN   EXPLAN1
# 16          5988    EXPLAN   EXPLAN2
# 17          5988    EXPLAN   EXPLAN3
# 18          5988    EXPLAN   EXPLAN4
# 19          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                      Rule  \
# 0                                                                                                   IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                                                                   IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                      IF capital.gain <= 0.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 3                                                                                                                                      IF age <= 47.0 AND occupation = Farming-fishing THEN class = <=50K
# 4                                                                                                              IF age <= 47.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 5                                                                                                                                                            IF hours.per.week <= 25.0 THEN class = <=50K
# 6                                                                                                                                                            IF hours.per.week <= 35.0 THEN class = <=50K
# 7                                                                                                                                                            IF hours.per.week <= 20.0 THEN class = <=50K
# 8                                                                                                                                                            IF hours.per.week <= 24.0 THEN class = <=50K
# 9                                                                                IF age > 40.0 AND capital.gain <= 20051.0 AND hours.per.week <= 32.0 AND occupation = Farming-fishing THEN class = <=50K
# 10  IF capital.gain <= 4847.57275390625 AND capital.loss <= 3923.0845947265625 AND hours.per.week <= 33.48286724090576 AND native.country != Thailand AND occupation = Farming-fishing THEN class = <=50K
# 11                               IF capital.gain <= 13894.640258789062 AND capital.loss <= 1552.4618530273438 AND hours.per.week <= 48.96787643432617 AND occupation = Farming-fishing THEN class = <=50K
# 12   IF capital.gain <= 12589.81298828125 AND capital.loss <= 2782.22607421875 AND hours.per.week <= 71.10613250732422 AND occupation = Farming-fishing AND race != Asian-Pac-Islander THEN class = <=50K
# 13                                         IF capital.gain <= 9433.59814453125 AND capital.loss <= 3302.761474609375 AND hours.per.week <= 17.314167976379395 AND relationship != Wife THEN class = <=50K
# 14                                          IF capital.gain <= 2050.699462890625 AND capital.loss <= 702.5028076171875 AND hours.per.week <= 51.90324783325195 AND workclass = Private THEN class = <=50K
# 15                                                                                                                                                           IF hours.per.week <= 22.0 THEN class = <=50K
# 16                                                                                                                                                      IF hours.per.week <= 33.746126 THEN class = <=50K
# 17                                                                                                                                                           IF hours.per.week <= 35.0 THEN class = <=50K
# 18                                                                                                                                                           IF hours.per.week <= 32.0 THEN class = <=50K
# 19                                                                                                                                                       IF hours.per.week <= 32.08911 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01615    0.02023  0.95109    3       0       3.76462       False
# 1   0.01474    0.01855  0.95536    3       0       3.84528       False
# 2   0.02637    0.03213  0.92512    3       0       4.51247       False
# 3   0.02027    0.02427  0.90909    2       1       7.45094       False
# 4   0.01957    0.02375  0.92152    3       2      15.77246       False
# 5   0.12171    0.14945  0.93223    1       0     120.30945       False
# 6   0.21231    0.25574  0.91445    1       0     113.40588       False
# 7   0.09073    0.11148  0.93279    1       0     113.02704       False
# 8   0.10069    0.12322  0.92898    1       0     117.24557       False
# 9   0.00254    0.00318  0.94828    4       0     116.47287       False
# 10  0.00452    0.00584  0.98058    5       0      32.21914       False
# 11  0.01698    0.02092  0.93540    4       0      28.36005       False
# 12  0.02650    0.03150  0.90232    5       0      30.24867       False
# 13  0.04624    0.05872  0.96395    4       0      32.25163       False
# 14  0.61188    0.68468  0.84949    4       0      36.39505       False
# 15  0.09262    0.11368  0.93179    1       0       3.39928       False
# 16  0.17208    0.21043  0.92835    1       0       2.96082       False
# 17  0.21231    0.25574  0.91445    1       0       2.66424       False
# 18  0.17076    0.20887  0.92857    1       0       2.74517       False
# 19  0.17076    0.20887  0.92857    1       0       2.75345       False
# ### Rules for Instance 5988, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988    ANCHOR   ANCHOR3
# 3           5988    ANCHOR   ANCHOR4
# 4           5988    ANCHOR   ANCHOR5
# 5           5988      LORE     LORE1
# 6           5988      LORE     LORE2
# 7           5988      LORE     LORE3
# 8           5988      LORE     LORE4
# 9           5988   LORE_SA  LORE_SA2
# 10          5988   LORE_SA  LORE_SA3
# 11          5988   LORE_SA  LORE_SA4
# 12          5988   LORE_SA  LORE_SA5
# 13          5988    EXPLAN   EXPLAN1
# 14          5988    EXPLAN   EXPLAN2
# 15          5988    EXPLAN   EXPLAN3
# 16          5988    EXPLAN   EXPLAN4
# 17          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                     Rule  \
# 0                                                                                                  IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                                                                  IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                     IF capital.gain <= 0.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 3                                                                                                                                     IF age <= 47.0 AND occupation = Farming-fishing THEN class = <=50K
# 4                                                                                                             IF age <= 47.0 AND capital.loss <= 0.0 AND occupation = Farming-fishing THEN class = <=50K
# 5                                                                                                                                                           IF hours.per.week <= 25.0 THEN class = <=50K
# 6                                                                                                                                                           IF hours.per.week <= 35.0 THEN class = <=50K
# 7                                                                                                                                                           IF hours.per.week <= 20.0 THEN class = <=50K
# 8                                                                                                                                                           IF hours.per.week <= 24.0 THEN class = <=50K
# 9                               IF capital.gain <= 13894.640258789062 AND capital.loss <= 1552.4618530273438 AND hours.per.week <= 48.96787643432617 AND occupation = Farming-fishing THEN class = <=50K
# 10  IF capital.gain <= 12589.81298828125 AND capital.loss <= 2782.22607421875 AND hours.per.week <= 71.10613250732422 AND occupation = Farming-fishing AND race != Asian-Pac-Islander THEN class = <=50K
# 11                                        IF capital.gain <= 9433.59814453125 AND capital.loss <= 3302.761474609375 AND hours.per.week <= 17.314167976379395 AND relationship != Wife THEN class = <=50K
# 12                                         IF capital.gain <= 2050.699462890625 AND capital.loss <= 702.5028076171875 AND hours.per.week <= 51.90324783325195 AND workclass = Private THEN class = <=50K
# 13                                                                                                                                                          IF hours.per.week <= 22.0 THEN class = <=50K
# 14                                                                                                                                                     IF hours.per.week <= 33.746126 THEN class = <=50K
# 15                                                                                                                                                          IF hours.per.week <= 35.0 THEN class = <=50K
# 16                                                                                                                                                          IF hours.per.week <= 32.0 THEN class = <=50K
# 17                                                                                                                                                      IF hours.per.week <= 32.08911 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01615    0.02023  0.95109    3       0       3.76462       False
# 1   0.01474    0.01855  0.95536    3       0       3.84528       False
# 2   0.02637    0.03213  0.92512    3       0       4.51247       False
# 3   0.02027    0.02427  0.90909    2       1       7.45094       False
# 4   0.01957    0.02375  0.92152    3       2      15.77246       False
# 5   0.12171    0.14945  0.93223    1       0     120.30945       False
# 6   0.21231    0.25574  0.91445    1       0     113.40588       False
# 7   0.09073    0.11148  0.93279    1       0     113.02704       False
# 8   0.10069    0.12322  0.92898    1       0     117.24557       False
# 9   0.01698    0.02092  0.93540    4       0      28.36005       False
# 10  0.02650    0.03150  0.90232    5       0      30.24867       False
# 11  0.04624    0.05872  0.96395    4       0      32.25163       False
# 12  0.61188    0.68468  0.84949    4       0      36.39505       False
# 13  0.09262    0.11368  0.93179    1       0       3.39928       False
# 14  0.17208    0.21043  0.92835    1       0       2.96082       False
# 15  0.21231    0.25574  0.91445    1       0       2.66424       False
# 16  0.17076    0.20887  0.92857    1       0       2.74517       False
# 17  0.17076    0.20887  0.92857    1       0       2.75345       False
# ### Rules for Instance 5988, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer   Rule_ID  \
# 0          5988      LORE     LORE1
# 1          5988      LORE     LORE2
# 2          5988      LORE     LORE3
# 3          5988   LORE_SA  LORE_SA4
# 4          5988   LORE_SA  LORE_SA5
# 5          5988    EXPLAN   EXPLAN2
# 6          5988    EXPLAN   EXPLAN3
# 7          5988    EXPLAN   EXPLAN4
# 8          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                              Rule  \
# 0                                                                                                                    IF hours.per.week <= 25.0 THEN class = <=50K
# 1                                                                                                                    IF hours.per.week <= 35.0 THEN class = <=50K
# 2                                                                                                                    IF hours.per.week <= 20.0 THEN class = <=50K
# 3  IF capital.gain <= 9433.59814453125 AND capital.loss <= 3302.761474609375 AND hours.per.week <= 17.314167976379395 AND relationship != Wife THEN class = <=50K
# 4   IF capital.gain <= 2050.699462890625 AND capital.loss <= 702.5028076171875 AND hours.per.week <= 51.90324783325195 AND workclass = Private THEN class = <=50K
# 5                                                                                                               IF hours.per.week <= 33.746126 THEN class = <=50K
# 6                                                                                                                    IF hours.per.week <= 35.0 THEN class = <=50K
# 7                                                                                                                    IF hours.per.week <= 32.0 THEN class = <=50K
# 8                                                                                                                IF hours.per.week <= 32.08911 THEN class = <=50K
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.12171    0.14945  0.93223    1       0     120.30945       False
# 1  0.21231    0.25574  0.91445    1       0     113.40588       False
# 2  0.09073    0.11148  0.93279    1       0     113.02704       False
# 3  0.04624    0.05872  0.96395    4       0      32.25163       False
# 4  0.61188    0.68468  0.84949    4       0      36.39505       False
# 5  0.17208    0.21043  0.92835    1       0       2.96082       False
# 6  0.21231    0.25574  0.91445    1       0       2.66424       False
# 7  0.17076    0.20887  0.92857    1       0       2.74517       False
# 8  0.17076    0.20887  0.92857    1       0       2.75345       False
# ### Rules for Instance 5988, Non-dominated (Cov_class↑, Pre↑, Len↓)
#    Instance_Name Explainer   Rule_ID  \
# 0           5988    ANCHOR   ANCHOR1
# 1           5988    ANCHOR   ANCHOR2
# 2           5988      LORE     LORE1
# 3           5988      LORE     LORE2
# 4           5988      LORE     LORE3
# 5           5988   LORE_SA  LORE_SA4
# 6           5988   LORE_SA  LORE_SA5
# 7           5988    EXPLAN   EXPLAN2
# 8           5988    EXPLAN   EXPLAN3
# 9           5988    EXPLAN   EXPLAN4
# 10          5988    EXPLAN   EXPLAN5
#
#                                                                                                                                                               Rule  \
# 0                                                            IF capital.gain <= 0.0 AND hours.per.week <= 45.0 AND occupation = Farming-fishing THEN class = <=50K
# 1                                                            IF capital.gain <= 0.0 AND hours.per.week <= 40.0 AND occupation = Farming-fishing THEN class = <=50K
# 2                                                                                                                     IF hours.per.week <= 25.0 THEN class = <=50K
# 3                                                                                                                     IF hours.per.week <= 35.0 THEN class = <=50K
# 4                                                                                                                     IF hours.per.week <= 20.0 THEN class = <=50K
# 5   IF capital.gain <= 9433.59814453125 AND capital.loss <= 3302.761474609375 AND hours.per.week <= 17.314167976379395 AND relationship != Wife THEN class = <=50K
# 6    IF capital.gain <= 2050.699462890625 AND capital.loss <= 702.5028076171875 AND hours.per.week <= 51.90324783325195 AND workclass = Private THEN class = <=50K
# 7                                                                                                                IF hours.per.week <= 33.746126 THEN class = <=50K
# 8                                                                                                                     IF hours.per.week <= 35.0 THEN class = <=50K
# 9                                                                                                                     IF hours.per.week <= 32.0 THEN class = <=50K
# 10                                                                                                                IF hours.per.week <= 32.08911 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.01615    0.02023  0.95109    3       0       3.76462       False
# 1   0.01474    0.01855  0.95536    3       0       3.84528       False
# 2   0.12171    0.14945  0.93223    1       0     120.30945       False
# 3   0.21231    0.25574  0.91445    1       0     113.40588       False
# 4   0.09073    0.11148  0.93279    1       0     113.02704       False
# 5   0.04624    0.05872  0.96395    4       0      32.25163       False
# 6   0.61188    0.68468  0.84949    4       0      36.39505       False
# 7   0.17208    0.21043  0.92835    1       0       2.96082       False
# 8   0.21231    0.25574  0.91445    1       0       2.66424       False
# 9   0.17076    0.20887  0.92857    1       0       2.74517       False
# 10  0.17076    0.20887  0.92857    1       0       2.75345       False
# ## Instance 18073 (Original: <=50K , Predicted: <=50K)
#                             Value
# age                          19.0
# workclass                 Private
# education                    12th
# education.num                   8
# marital.status      Never-married
# occupation      Handlers-cleaners
# relationship            Own-child
# race                        Black
# sex                        Female
# capital.gain                  0.0
# capital.loss                  0.0
# hours.per.week               52.0
# native.country      United-States
# ### Rules for Instance 18073
#    Instance_Name Explainer   Rule_ID  \
# 0          18073    ANCHOR   ANCHOR1
# 1          18073    ANCHOR   ANCHOR2
# 2          18073    ANCHOR   ANCHOR3
# 3          18073    ANCHOR   ANCHOR4
# 4          18073    ANCHOR   ANCHOR5
# 5          18073      LORE     LORE1
# 6          18073      LORE     LORE2
# 7          18073      LORE     LORE3
# 8          18073      LORE     LORE4
# 9          18073      LORE     LORE5
# 10         18073   LORE_SA  LORE_SA1
# 11         18073   LORE_SA  LORE_SA2
# 12         18073   LORE_SA  LORE_SA3
# 13         18073   LORE_SA  LORE_SA4
# 14         18073   LORE_SA  LORE_SA5
# 15         18073    EXPLAN   EXPLAN1
# 16         18073    EXPLAN   EXPLAN2
# 17         18073    EXPLAN   EXPLAN3
# 18         18073    EXPLAN   EXPLAN4
# 19         18073    EXPLAN   EXPLAN5
#
#                                                                                                                                                  Rule  \
# 0                                                                                IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                                IF marital.status = Never-married THEN class = <=50K
# 2                                                                                IF age <= 28.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                        IF capital.gain <= 0.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                IF age <= 47.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                        IF capital.gain <= 7298.0 THEN class = <=50K
# 6                                                                                                  IF capital.gain <= 13108.757964 THEN class = <=50K
# 7                                                                                                                              IF  THEN class = <=50K
# 8                                                                          IF capital.gain <= 15024.0 AND relationship = Own-child THEN class = <=50K
# 9                                                                                                        IF capital.gain <= 7688.0 THEN class = <=50K
# 10                                                                IF age <= 24.531448364257812 AND capital.gain <= 26993.029296875 THEN class = <=50K
# 11          IF age <= 42.58576774597168 AND capital.gain <= 21921.0625 AND native.country != Cambodia AND native.country != Greece THEN class = <=50K
# 12                                    IF age <= 31.34368133544922 AND capital.gain <= 25297.1669921875 AND native.country != China THEN class = <=50K
# 13                                                                IF age <= 20.632044792175293 AND capital.gain <= 7986.7119140625 THEN class = <=50K
# 14  IF capital.gain <= 1912.7019653320312 AND education.num != 13 AND native.country != England AND occupation != Transport-moving THEN class = <=50K
# 15                                                                                               IF marital.status = Never-married THEN class = <=50K
# 16                                                                                                                  IF age <= 31.0 THEN class = <=50K
# 17                                                                                                                  IF age <= 33.0 THEN class = <=50K
# 18                                                                                                                  IF age <= 30.0 THEN class = <=50K
# 19                                                                               IF age <= 36.0 AND marital.status = Never-married THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       2.61896       False
# 1   0.32757    0.41178  0.95433    1       1       5.09178       False
# 2   0.20898    0.27226  0.98908    2       3       9.41508       False
# 3   0.31336    0.39912  0.96696    2       2       7.62217       False
# 4   0.31081    0.39294  0.95977    2       3       9.71576       False
# 5   0.96363    0.99890  0.78696    1       0      95.99735       False
# 6   0.97771    0.99954  0.77612    1       0     111.39349       False
# 7   1.00000    1.00000  0.75917    0       0     142.38236       False
# 8   0.15527    0.20245  0.98983    2       0     135.67273       False
# 9   0.97306    0.99919  0.77956    1       0     132.69111       False
# 10  0.16923    0.22083  0.99067    2       0      34.07927       False
# 11  0.63514    0.69144  0.82647    4       0      34.10601       False
# 12  0.35201    0.42900  0.92522    3       0      35.50092       False
# 13  0.07358    0.09692  1.00000    2       0      34.90464       False
# 14  0.73109    0.79512  0.82566    4       0      35.36729       False
# 15  0.32757    0.41178  0.95433    1       0       2.45797       False
# 16  0.35319    0.42981  0.92385    1       0       3.43306       False
# 17  0.40554    0.48310  0.90436    1       0       2.49374       False
# 18  0.32564    0.40114  0.93519    1       0       4.32498       False
# 19  0.27589    0.35306  0.97153    2       0       3.49572       False
# ### Rules for Instance 18073, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0          18073    ANCHOR   ANCHOR1
# 1          18073    ANCHOR   ANCHOR2
# 2          18073    ANCHOR   ANCHOR3
# 3          18073    ANCHOR   ANCHOR4
# 4          18073    ANCHOR   ANCHOR5
# 5          18073      LORE     LORE1
# 6          18073      LORE     LORE2
# 7          18073      LORE     LORE3
# 8          18073      LORE     LORE4
# 9          18073      LORE     LORE5
# 10         18073   LORE_SA  LORE_SA1
# 11         18073   LORE_SA  LORE_SA2
# 12         18073   LORE_SA  LORE_SA3
# 13         18073   LORE_SA  LORE_SA4
# 14         18073   LORE_SA  LORE_SA5
# 15         18073    EXPLAN   EXPLAN1
# 16         18073    EXPLAN   EXPLAN2
# 17         18073    EXPLAN   EXPLAN3
# 18         18073    EXPLAN   EXPLAN4
# 19         18073    EXPLAN   EXPLAN5
#
#                                                                                                                                                  Rule  \
# 0                                                                                IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                                IF marital.status = Never-married THEN class = <=50K
# 2                                                                                IF age <= 28.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                        IF capital.gain <= 0.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                IF age <= 47.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                        IF capital.gain <= 7298.0 THEN class = <=50K
# 6                                                                                                  IF capital.gain <= 13108.757964 THEN class = <=50K
# 7                                                                                                                              IF  THEN class = <=50K
# 8                                                                          IF capital.gain <= 15024.0 AND relationship = Own-child THEN class = <=50K
# 9                                                                                                        IF capital.gain <= 7688.0 THEN class = <=50K
# 10                                                                IF age <= 24.531448364257812 AND capital.gain <= 26993.029296875 THEN class = <=50K
# 11          IF age <= 42.58576774597168 AND capital.gain <= 21921.0625 AND native.country != Cambodia AND native.country != Greece THEN class = <=50K
# 12                                    IF age <= 31.34368133544922 AND capital.gain <= 25297.1669921875 AND native.country != China THEN class = <=50K
# 13                                                                IF age <= 20.632044792175293 AND capital.gain <= 7986.7119140625 THEN class = <=50K
# 14  IF capital.gain <= 1912.7019653320312 AND education.num != 13 AND native.country != England AND occupation != Transport-moving THEN class = <=50K
# 15                                                                                               IF marital.status = Never-married THEN class = <=50K
# 16                                                                                                                  IF age <= 31.0 THEN class = <=50K
# 17                                                                                                                  IF age <= 33.0 THEN class = <=50K
# 18                                                                                                                  IF age <= 30.0 THEN class = <=50K
# 19                                                                               IF age <= 36.0 AND marital.status = Never-married THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       2.61896       False
# 1   0.32757    0.41178  0.95433    1       1       5.09178       False
# 2   0.20898    0.27226  0.98908    2       3       9.41508       False
# 3   0.31336    0.39912  0.96696    2       2       7.62217       False
# 4   0.31081    0.39294  0.95977    2       3       9.71576       False
# 5   0.96363    0.99890  0.78696    1       0      95.99735       False
# 6   0.97771    0.99954  0.77612    1       0     111.39349       False
# 7   1.00000    1.00000  0.75917    0       0     142.38236       False
# 8   0.15527    0.20245  0.98983    2       0     135.67273       False
# 9   0.97306    0.99919  0.77956    1       0     132.69111       False
# 10  0.16923    0.22083  0.99067    2       0      34.07927       False
# 11  0.63514    0.69144  0.82647    4       0      34.10601       False
# 12  0.35201    0.42900  0.92522    3       0      35.50092       False
# 13  0.07358    0.09692  1.00000    2       0      34.90464       False
# 14  0.73109    0.79512  0.82566    4       0      35.36729       False
# 15  0.32757    0.41178  0.95433    1       0       2.45797       False
# 16  0.35319    0.42981  0.92385    1       0       3.43306       False
# 17  0.40554    0.48310  0.90436    1       0       2.49374       False
# 18  0.32564    0.40114  0.93519    1       0       4.32498       False
# 19  0.27589    0.35306  0.97153    2       0       3.49572       False
# ### Rules for Instance 18073, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0          18073    ANCHOR   ANCHOR1
# 1          18073    ANCHOR   ANCHOR2
# 2          18073    ANCHOR   ANCHOR3
# 3          18073    ANCHOR   ANCHOR4
# 4          18073    ANCHOR   ANCHOR5
# 5          18073      LORE     LORE1
# 6          18073      LORE     LORE2
# 7          18073      LORE     LORE3
# 8          18073      LORE     LORE4
# 9          18073      LORE     LORE5
# 10         18073   LORE_SA  LORE_SA1
# 11         18073   LORE_SA  LORE_SA2
# 12         18073   LORE_SA  LORE_SA3
# 13         18073   LORE_SA  LORE_SA4
# 14         18073   LORE_SA  LORE_SA5
# 15         18073    EXPLAN   EXPLAN1
# 16         18073    EXPLAN   EXPLAN2
# 17         18073    EXPLAN   EXPLAN3
# 18         18073    EXPLAN   EXPLAN4
# 19         18073    EXPLAN   EXPLAN5
#
#                                                                                                                                                  Rule  \
# 0                                                                                IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                                IF marital.status = Never-married THEN class = <=50K
# 2                                                                                IF age <= 28.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                        IF capital.gain <= 0.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                IF age <= 47.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                        IF capital.gain <= 7298.0 THEN class = <=50K
# 6                                                                                                  IF capital.gain <= 13108.757964 THEN class = <=50K
# 7                                                                                                                              IF  THEN class = <=50K
# 8                                                                          IF capital.gain <= 15024.0 AND relationship = Own-child THEN class = <=50K
# 9                                                                                                        IF capital.gain <= 7688.0 THEN class = <=50K
# 10                                                                IF age <= 24.531448364257812 AND capital.gain <= 26993.029296875 THEN class = <=50K
# 11          IF age <= 42.58576774597168 AND capital.gain <= 21921.0625 AND native.country != Cambodia AND native.country != Greece THEN class = <=50K
# 12                                    IF age <= 31.34368133544922 AND capital.gain <= 25297.1669921875 AND native.country != China THEN class = <=50K
# 13                                                                IF age <= 20.632044792175293 AND capital.gain <= 7986.7119140625 THEN class = <=50K
# 14  IF capital.gain <= 1912.7019653320312 AND education.num != 13 AND native.country != England AND occupation != Transport-moving THEN class = <=50K
# 15                                                                                               IF marital.status = Never-married THEN class = <=50K
# 16                                                                                                                  IF age <= 31.0 THEN class = <=50K
# 17                                                                                                                  IF age <= 33.0 THEN class = <=50K
# 18                                                                                                                  IF age <= 30.0 THEN class = <=50K
# 19                                                                               IF age <= 36.0 AND marital.status = Never-married THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       2.61896       False
# 1   0.32757    0.41178  0.95433    1       1       5.09178       False
# 2   0.20898    0.27226  0.98908    2       3       9.41508       False
# 3   0.31336    0.39912  0.96696    2       2       7.62217       False
# 4   0.31081    0.39294  0.95977    2       3       9.71576       False
# 5   0.96363    0.99890  0.78696    1       0      95.99735       False
# 6   0.97771    0.99954  0.77612    1       0     111.39349       False
# 7   1.00000    1.00000  0.75917    0       0     142.38236       False
# 8   0.15527    0.20245  0.98983    2       0     135.67273       False
# 9   0.97306    0.99919  0.77956    1       0     132.69111       False
# 10  0.16923    0.22083  0.99067    2       0      34.07927       False
# 11  0.63514    0.69144  0.82647    4       0      34.10601       False
# 12  0.35201    0.42900  0.92522    3       0      35.50092       False
# 13  0.07358    0.09692  1.00000    2       0      34.90464       False
# 14  0.73109    0.79512  0.82566    4       0      35.36729       False
# 15  0.32757    0.41178  0.95433    1       0       2.45797       False
# 16  0.35319    0.42981  0.92385    1       0       3.43306       False
# 17  0.40554    0.48310  0.90436    1       0       2.49374       False
# 18  0.32564    0.40114  0.93519    1       0       4.32498       False
# 19  0.27589    0.35306  0.97153    2       0       3.49572       False
# ### Rules for Instance 18073, Non-dominated (Cov↑, Pre↑)
#    Instance_Name Explainer   Rule_ID  \
# 0          18073    ANCHOR   ANCHOR1
# 1          18073    ANCHOR   ANCHOR2
# 2          18073    ANCHOR   ANCHOR3
# 3          18073    ANCHOR   ANCHOR4
# 4          18073      LORE     LORE1
# 5          18073      LORE     LORE2
# 6          18073      LORE     LORE3
# 7          18073      LORE     LORE5
# 8          18073   LORE_SA  LORE_SA1
# 9          18073   LORE_SA  LORE_SA2
# 10         18073   LORE_SA  LORE_SA3
# 11         18073   LORE_SA  LORE_SA4
# 12         18073   LORE_SA  LORE_SA5
# 13         18073    EXPLAN   EXPLAN1
# 14         18073    EXPLAN   EXPLAN2
# 15         18073    EXPLAN   EXPLAN3
# 16         18073    EXPLAN   EXPLAN5
#
#                                                                                                                                                  Rule  \
# 0                                                                                IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                                IF marital.status = Never-married THEN class = <=50K
# 2                                                                                IF age <= 28.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                        IF capital.gain <= 0.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                                        IF capital.gain <= 7298.0 THEN class = <=50K
# 5                                                                                                  IF capital.gain <= 13108.757964 THEN class = <=50K
# 6                                                                                                                              IF  THEN class = <=50K
# 7                                                                                                        IF capital.gain <= 7688.0 THEN class = <=50K
# 8                                                                 IF age <= 24.531448364257812 AND capital.gain <= 26993.029296875 THEN class = <=50K
# 9           IF age <= 42.58576774597168 AND capital.gain <= 21921.0625 AND native.country != Cambodia AND native.country != Greece THEN class = <=50K
# 10                                    IF age <= 31.34368133544922 AND capital.gain <= 25297.1669921875 AND native.country != China THEN class = <=50K
# 11                                                                IF age <= 20.632044792175293 AND capital.gain <= 7986.7119140625 THEN class = <=50K
# 12  IF capital.gain <= 1912.7019653320312 AND education.num != 13 AND native.country != England AND occupation != Transport-moving THEN class = <=50K
# 13                                                                                               IF marital.status = Never-married THEN class = <=50K
# 14                                                                                                                  IF age <= 31.0 THEN class = <=50K
# 15                                                                                                                  IF age <= 33.0 THEN class = <=50K
# 16                                                                               IF age <= 36.0 AND marital.status = Never-married THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       2.61896       False
# 1   0.32757    0.41178  0.95433    1       1       5.09178       False
# 2   0.20898    0.27226  0.98908    2       3       9.41508       False
# 3   0.31336    0.39912  0.96696    2       2       7.62217       False
# 4   0.96363    0.99890  0.78696    1       0      95.99735       False
# 5   0.97771    0.99954  0.77612    1       0     111.39349       False
# 6   1.00000    1.00000  0.75917    0       0     142.38236       False
# 7   0.97306    0.99919  0.77956    1       0     132.69111       False
# ...
# 10  IF age <= 59.24299240112305 AND age > 58.54019546508789 AND capital.gain <= 23397.32421875 AND capital.gain > 2387.209197998047 AND education != 7th-8th AND education = Some-college AND education.num != 7 AND education.num = 10 AND hours.per.week <= 40.54838180541992 AND hours.per.week > 39.577938079833984 AND marital.status != Never-married AND marital.status != Married-spouse-absent AND marital.status != Widowed AND marital.status != Divorced AND marital.status != Separated AND marital.status != Married-AF-spouse AND native.country != Iran AND native.country != Laos AND native.country != Scotland AND native.country != Greece AND native.country != South AND native.country = United-States AND occupation != Armed-Forces AND occupation != Priv-house-serv AND occupation != Tech-support AND occupation = Sales AND race = White AND relationship != Own-child AND relationship = Husband AND sex != Female AND workclass = Private THEN class = >50K
# 11                                                                                                                                                                                                                     IF age > 58.4968204498291 AND capital.gain <= 5640.343994140625 AND capital.loss <= 1856.712646484375 AND education != 5th-6th AND education = Some-college AND education.num != 4 AND education.num != 2 AND education.num = 10 AND hours.per.week <= 40.071998596191406 AND hours.per.week > 38.63673973083496 AND marital.status != Never-married AND marital.status = Married-civ-spouse AND native.country != Trinadad&Tobago AND native.country != Portugal AND native.country = United-States AND occupation != Farming-fishing AND occupation != Other-service AND occupation != Machine-op-inspct AND occupation = Sales AND race = White AND relationship = Husband AND sex = Male AND workclass != Without-pay AND workclass = Private THEN class = >50K
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           IF age > 50.190778732299805 AND education != 11th AND education.num != 4 AND hours.per.week > 13.656131744384766 AND marital.status != Never-married AND marital.status = Married-civ-spouse AND native.country != Outlying-US(Guam-USVI-etc) AND native.country != Haiti AND native.country != Columbia AND occupation = Sales AND race != Amer-Indian-Eskimo AND workclass != Without-pay THEN class = >50K
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   IF age > 34.981056213378906 AND education != 5th-6th AND hours.per.week > 8.912961959838867 AND marital.status != Never-married AND marital.status = Married-civ-spouse AND occupation != Armed-Forces AND occupation != Other-service AND occupation != Farming-fishing AND relationship = Husband THEN class = >50K
# 14                                                                                                                                                                                                                                                                                                                                                                                                                           IF age <= 59.06833076477051 AND age > 25.922123908996582 AND capital.gain <= 15106.3916015625 AND capital.loss <= 197.94239807128906 AND education != 10th AND education != 11th AND education = Some-college AND education.num != 1 AND education.num != 4 AND education.num = 10 AND hours.per.week > 34.4630069732666 AND marital.status = Married-civ-spouse AND native.country = United-States AND occupation = Sales AND race = White AND relationship = Husband AND sex = Male AND workclass != Never-worked AND workclass = Private THEN class = >50K
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            IF age > 41.0 AND marital.status = Married-civ-spouse AND native.country = United-States AND occupation = Sales AND relationship = Husband THEN class = >50K
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF age > 46.0 AND hours.per.week > 30.565857 AND marital.status = Married-civ-spouse AND native.country = United-States AND occupation = Sales AND relationship = Husband THEN class = >50K
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  IF age > 33.045107 AND education = Some-college AND marital.status = Married-civ-spouse AND native.country = United-States AND occupation = Sales AND relationship = Husband AND workclass = Private THEN class = >50K
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          IF age > 38.055223 AND marital.status = Married-civ-spouse AND occupation = Sales AND relationship = Husband THEN class = >50K
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        IF age > 38.127378 AND hours.per.week > 30.0 AND marital.status = Married-civ-spouse AND relationship = Husband AND sex = Male THEN class = >50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.03378    0.11022  0.78571    5       0       6.82283       False
# 1   0.04388    0.14265  0.78300    5       0       8.72234       False
# 2   0.03738    0.12115  0.78052    4       0       7.94773       False
# 3   0.04094    0.13372  0.78671    6       0       8.90322       False
# 4   0.03440    0.11314  0.79209    6       0      11.75752       False
# 5   0.26299    0.54946  0.50317    2       0     191.41566       False
# 6   0.35069    0.73966  0.50794    3       0     213.02005       False
# 7   0.22170    0.45965  0.49931    2       0     214.70865       False
# 8   0.41098    0.82000  0.48052    3       0     190.34417       False
# 9   0.38334    0.78739  0.49468    3       0     207.80886       False
# 10  0.00000    0.00000  0.00000   31       0      44.04413       False
# 11  0.00018    0.00055  0.75000   24       0      64.64968       False
# 12  0.01404    0.03079  0.52812   12       0      62.05049       False
# 13  0.27461    0.61068  0.53555    9       0      54.61676       False
# 14  0.00570    0.01166  0.49231   19       0      59.60747       False
# 15  0.02418    0.05684  0.56624    5       0      19.39008       False
# 16  0.01531    0.03717  0.58453    6       0      14.77669       False
# 17  0.00592    0.01403  0.57037    7       0      14.08061       False
# 18  0.02883    0.06850  0.57230    4       0      16.92296       False
# 19  0.22745    0.50774  0.53762    5       0      16.06178       False
# ### Rules for Instance 3374, Correct Prediction
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# ### Rules for Instance 3374, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# ### Rules for Instance 3374, Non-dominated (Cov↑, Pre↑)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# C:\Politechnika_poznanska\Master thesis\Mulrules-evaluation\reports\parser_util.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# C:\Politechnika_poznanska\Master thesis\Mulrules-evaluation\reports\parser_util.py:139: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Explainer', bbox_to_anchor=(1.05, 1), loc='upper left')
# C:\Politechnika_poznanska\Master thesis\Mulrules-evaluation\reports\parser_util.py:221: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# Empty dataframe: nothing to plot.
# ### Rules for Instance 3374, Non-dominated (Cov_class↑, Pre↑, Len↓)
# Empty DataFrame
# Columns: [Instance_Name, Explainer, Rule_ID, Rule, Cov, Cov_class, Pre, Len, Reject, Elapsed_time, Iter_Limit]
# Index: []
# Empty dataframe: nothing to plot.
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         0.5
# LORE                                           0.5
# LORE_SA                                        0.5
# EXPLAN                                         0.6
# Overall Average                                2.1
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                  0.444444
# LORE                                    0.777778
# LORE_SA                                 1.000000
# EXPLAN                                  0.666667
# Overall Average                         2.600000
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 2.555556
# LORE                                   1.250000
# LORE_SA                                1.500000
# EXPLAN                                 2.222222
# Overall Average                        6.500000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 2.666667
# LORE                                   0.875000
# LORE_SA                                1.625000
# EXPLAN                                 1.888889
# Overall Average                        6.100000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# EXPLAN          0.892299  0.165404   0.246784  1.731250  0.000000
# LORE            0.781277  0.383300   0.492078  1.625000  0.025000
# LORE_SA         0.719628  0.396013   0.562671  4.092857  0.000000
# ANCHOR          0.770703  0.225653   0.254567  2.678571  0.380952
# Global_Average  0.794031  0.291377   0.387719  2.475000  0.095556
#
#                 Elapsed_time
# EXPLAN              9.922778
# LORE              161.962014
# LORE_SA            40.862761
# ANCHOR              6.229690
# Global_Average     56.824183
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.919473  0.204180   0.266842  2.375000  0.444444
# EXPLAN          0.894484  0.149608   0.220093  1.501852  0.000000
# LORE            0.787663  0.380775   0.483810  1.541667  0.025000
# LORE_SA         0.715419  0.411490   0.584884  3.950000  0.000000
# Global_Average  0.829214  0.283273   0.384885  2.258333  0.095556
#
#                 Elapsed_time
# ANCHOR              5.466022
# EXPLAN              9.684847
# LORE              159.850603
# LORE_SA            40.853659
# Global_Average     56.158006
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
