# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results

rules_log = "german_random_forest_rules_24-23_06-06-2025.txt"
entries_log = "german_random_forest_entries_24-23_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 844 (Original: good , Predicted: good)
#                                       Value
# checking_status                 no checking
# duration                               18.0
# credit_history                existing paid
# purpose                 furniture/equipment
# credit_amount                        3422.0
# savings_status                     less 100
# employment                  greater 7 years
# installment_commitment                  4.0
# personal_status                 male single
# other_parties                          none
# residence_since                         4.0
# property_magnitude           life insurance
# age                                    47.0
# other_payment_plans                    bank
# housing                                 own
# existing_credits                        3.0
# job                                 skilled
# num_dependents                          2.0
# own_telephone                           yes
# foreign_worker                          yes
# ### Rules for Instance 844
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844      LORE     LORE2
# 7            844      LORE     LORE3
# 8            844      LORE     LORE4
# 9            844      LORE     LORE5
# 10           844   LORE_SA  LORE_SA1
# 11           844   LORE_SA  LORE_SA2
# 12           844   LORE_SA  LORE_SA3
# 13           844   LORE_SA  LORE_SA4
# 14           844   LORE_SA  LORE_SA5
# 15           844    EXPLAN   EXPLAN1
# 16           844    EXPLAN   EXPLAN2
# 17           844    EXPLAN   EXPLAN3
# 18           844    EXPLAN   EXPLAN4
# 19           844    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                   Rule  \
# 0                                                                                                                                                                   IF age > 26.72 AND checking_status = no checking THEN class = good
# 1                                                                                                                                                             IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                                                                                        IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 3                                                                                                                                                 IF checking_status = no checking AND installment_commitment <= 4.0 THEN class = good
# 4                                                                                                                                                                                   IF checking_status = no checking THEN class = good
# 5                                                                                                 IF credit_history = existing paid AND duration > 17.816387 AND duration <= 19.371857 AND savings_status = less 100 THEN class = good
# 6                                                                                                                                                   IF checking_status = no checking AND installment_commitment > 3.0 THEN class = bad
# 7                                                                                                                          IF checking_status = no checking AND duration > 17.708411 AND installment_commitment > 3.0 THEN class = bad
# 8                                                                                                                                                        IF checking_status = no checking AND credit_amount <= 3577.0 THEN class = bad
# 9                                                                                           IF age <= 54.259163 AND checking_status = no checking AND duration <= 22.610216 AND housing = own AND own_telephone = yes THEN class = bad
# 10                                IF checking_status = no checking AND housing = own AND installment_commitment > 1.7232457995414734 AND personal_status != male div/sep AND property_magnitude != no known property THEN class = good
# 11                                   IF checking_status = no checking AND credit_amount <= 16209.232421875 AND housing = own AND installment_commitment > 2.0242977142333984 AND property_magnitude = life insurance THEN class = good
# 12   IF checking_status = no checking AND housing = own AND personal_status != female div/dep/mar AND property_magnitude != no known property AND property_magnitude != car AND residence_since > 2.2295987606048584 THEN class = good
# 13                                                                                                                         IF checking_status = no checking AND credit_amount <= 14799.02197265625 AND housing = own THEN class = good
# 14  IF checking_status = no checking AND credit_history != delayed previously AND housing != for free AND housing != rent AND installment_commitment > 2.091377854347229 AND property_magnitude != no known property THEN class = good
# 15                                                                                                                                                                                   IF checking_status = no checking THEN class = bad
# 16                                                                                                                                                       IF checking_status = no checking AND credit_amount <= 3676.0 THEN class = bad
# 17                                                                                                                                                        IF checking_status = no checking AND credit_amount > 2828.0 THEN class = bad
# 18                                                                                                                                                        IF checking_status = no checking AND credit_amount > 3249.0 THEN class = bad
# 19                                                                                                                                                        IF checking_status = no checking AND credit_amount > 3244.0 THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.24592    0.41837  0.85062    2       0       2.58213       False
# 1   0.23163    0.40816  0.88106    2       1       5.25257       False
# 2   0.29490    0.49796  0.84429    2       0       2.45714       False
# 3   0.29490    0.49796  0.84429    2       1       5.57357       False
# 4   0.29490    0.49796  0.84429    1       3      11.57350       False
# 5   0.05306    0.03061  0.28846    4       0      55.25577       False
# 6   0.13776    0.04694  0.17037    2       0      55.67036       False
# 7   0.08469    0.03469  0.20482    3       0      54.76579       False
# 8   0.20918    0.04286  0.10244    2       0      54.76157       False
# 9   0.04184    0.00816  0.09756    5       0      56.43852       False
# 10  0.18673    0.31633  0.84699    5       0       9.42589       False
# 11  0.02857    0.04490  0.78571    5       0       9.61013       False
# 12  0.04694    0.09184  0.97826    6       0       9.83330       False
# 13  0.23061    0.39184  0.84956    3       0       8.86310       False
# 14  0.13673    0.23673  0.86567    6       0       9.31078       False
# 15  0.29490    0.09184  0.15571    1       0       1.26381       False
# 16  0.21122    0.04490  0.10628    2       0       0.76018       False
# 17  0.11837    0.05714  0.24138    2       1       1.94774       False
# 18  0.10408    0.05510  0.26471    2       0       0.90820       False
# 19  0.10408    0.05510  0.26471    2       1       1.98667       False
# ### Rules for Instance 844, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844   LORE_SA  LORE_SA1
# 7            844   LORE_SA  LORE_SA2
# 8            844   LORE_SA  LORE_SA3
# 9            844   LORE_SA  LORE_SA4
# 10           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                   Rule  \
# 0                                                                                                                                                                   IF age > 26.72 AND checking_status = no checking THEN class = good
# 1                                                                                                                                                             IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                                                                                        IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 3                                                                                                                                                 IF checking_status = no checking AND installment_commitment <= 4.0 THEN class = good
# 4                                                                                                                                                                                   IF checking_status = no checking THEN class = good
# 5                                                                                                 IF credit_history = existing paid AND duration > 17.816387 AND duration <= 19.371857 AND savings_status = less 100 THEN class = good
# 6                                 IF checking_status = no checking AND housing = own AND installment_commitment > 1.7232457995414734 AND personal_status != male div/sep AND property_magnitude != no known property THEN class = good
# 7                                    IF checking_status = no checking AND credit_amount <= 16209.232421875 AND housing = own AND installment_commitment > 2.0242977142333984 AND property_magnitude = life insurance THEN class = good
# 8    IF checking_status = no checking AND housing = own AND personal_status != female div/dep/mar AND property_magnitude != no known property AND property_magnitude != car AND residence_since > 2.2295987606048584 THEN class = good
# 9                                                                                                                          IF checking_status = no checking AND credit_amount <= 14799.02197265625 AND housing = own THEN class = good
# 10  IF checking_status = no checking AND credit_history != delayed previously AND housing != for free AND housing != rent AND installment_commitment > 2.091377854347229 AND property_magnitude != no known property THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.24592    0.41837  0.85062    2       0       2.58213       False
# 1   0.23163    0.40816  0.88106    2       1       5.25257       False
# 2   0.29490    0.49796  0.84429    2       0       2.45714       False
# 3   0.29490    0.49796  0.84429    2       1       5.57357       False
# 4   0.29490    0.49796  0.84429    1       3      11.57350       False
# 5   0.05306    0.03061  0.28846    4       0      55.25577       False
# 6   0.18673    0.31633  0.84699    5       0       9.42589       False
# 7   0.02857    0.04490  0.78571    5       0       9.61013       False
# 8   0.04694    0.09184  0.97826    6       0       9.83330       False
# 9   0.23061    0.39184  0.84956    3       0       8.86310       False
# 10  0.13673    0.23673  0.86567    6       0       9.31078       False
# ### Rules for Instance 844, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844   LORE_SA  LORE_SA1
# 7            844   LORE_SA  LORE_SA2
# 8            844   LORE_SA  LORE_SA3
# 9            844   LORE_SA  LORE_SA4
# 10           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                   Rule  \
# 0                                                                                                                                                                   IF age > 26.72 AND checking_status = no checking THEN class = good
# 1                                                                                                                                                             IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                                                                                        IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 3                                                                                                                                                 IF checking_status = no checking AND installment_commitment <= 4.0 THEN class = good
# 4                                                                                                                                                                                   IF checking_status = no checking THEN class = good
# 5                                                                                                 IF credit_history = existing paid AND duration > 17.816387 AND duration <= 19.371857 AND savings_status = less 100 THEN class = good
# 6                                 IF checking_status = no checking AND housing = own AND installment_commitment > 1.7232457995414734 AND personal_status != male div/sep AND property_magnitude != no known property THEN class = good
# 7                                    IF checking_status = no checking AND credit_amount <= 16209.232421875 AND housing = own AND installment_commitment > 2.0242977142333984 AND property_magnitude = life insurance THEN class = good
# 8    IF checking_status = no checking AND housing = own AND personal_status != female div/dep/mar AND property_magnitude != no known property AND property_magnitude != car AND residence_since > 2.2295987606048584 THEN class = good
# 9                                                                                                                          IF checking_status = no checking AND credit_amount <= 14799.02197265625 AND housing = own THEN class = good
# 10  IF checking_status = no checking AND credit_history != delayed previously AND housing != for free AND housing != rent AND installment_commitment > 2.091377854347229 AND property_magnitude != no known property THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.24592    0.41837  0.85062    2       0       2.58213       False
# 1   0.23163    0.40816  0.88106    2       1       5.25257       False
# 2   0.29490    0.49796  0.84429    2       0       2.45714       False
# 3   0.29490    0.49796  0.84429    2       1       5.57357       False
# 4   0.29490    0.49796  0.84429    1       3      11.57350       False
# 5   0.05306    0.03061  0.28846    4       0      55.25577       False
# 6   0.18673    0.31633  0.84699    5       0       9.42589       False
# 7   0.02857    0.04490  0.78571    5       0       9.61013       False
# 8   0.04694    0.09184  0.97826    6       0       9.83330       False
# 9   0.23061    0.39184  0.84956    3       0       8.86310       False
# 10  0.13673    0.23673  0.86567    6       0       9.31078       False
# ### Rules for Instance 844, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.2949, Pre: 0.97826)
# <style type="text/css">
# #T_5b80c_row1_col0, #T_5b80c_row1_col1, #T_5b80c_row1_col2, #T_5b80c_row1_col3, #T_5b80c_row1_col4, #T_5b80c_row1_col5, #T_5b80c_row1_col6, #T_5b80c_row1_col7, #T_5b80c_row1_col8, #T_5b80c_row1_col9, #T_5b80c_row1_col10, #T_5b80c_row1_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_5b80c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b80c_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_5b80c_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_5b80c_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_5b80c_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_5b80c_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_5b80c_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_5b80c_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_5b80c_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_5b80c_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_5b80c_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_5b80c_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_5b80c_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b80c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b80c_row0_col0" class="data row0 col0" >844</td>
#       <td id="T_5b80c_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_5b80c_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_5b80c_row0_col3" class="data row0 col3" >IF age > 26.72 AND checking_status = no checking THEN class = good</td>
#       <td id="T_5b80c_row0_col4" class="data row0 col4" >0.245920</td>
#       <td id="T_5b80c_row0_col5" class="data row0 col5" >0.418370</td>
#       <td id="T_5b80c_row0_col6" class="data row0 col6" >0.850620</td>
#       <td id="T_5b80c_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_5b80c_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_5b80c_row0_col9" class="data row0 col9" >2.582130</td>
#       <td id="T_5b80c_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_5b80c_row0_col11" class="data row0 col11" >0.136715</td>
#     </tr>
#     <tr>
#       <th id="T_5b80c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b80c_row1_col0" class="data row1 col0" >844</td>
#       <td id="T_5b80c_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_5b80c_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_5b80c_row1_col3" class="data row1 col3" >IF checking_status = no checking AND duration <= 25.78 THEN class = good</td>
#       <td id="T_5b80c_row1_col4" class="data row1 col4" >0.231630</td>
#       <td id="T_5b80c_row1_col5" class="data row1 col5" >0.408160</td>
#       <td id="T_5b80c_row1_col6" class="data row1 col6" >0.881060</td>
#       <td id="T_5b80c_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_5b80c_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_5b80c_row1_col9" class="data row1 col9" >5.252570</td>
#       <td id="T_5b80c_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_5b80c_row1_col11" class="data row1 col11" >0.115978</td>
#     </tr>
#     <tr>
#       <th id="T_5b80c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b80c_row2_col0" class="data row2 col0" >844</td>
#       <td id="T_5b80c_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_5b80c_row2_col2" class="data row2 col2" >ANCHOR3</td>
#       <td id="T_5b80c_row2_col3" class="data row2 col3" >IF checking_status = no checking AND residence_since <= 4.0 THEN class = good</td>
#       <td id="T_5b80c_row2_col4" class="data row2 col4" >0.294900</td>
#       <td id="T_5b80c_row2_col5" class="data row2 col5" >0.497960</td>
#       <td id="T_5b80c_row2_col6" class="data row2 col6" >0.844290</td>
#       <td id="T_5b80c_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_5b80c_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_5b80c_row2_col9" class="data row2 col9" >2.457140</td>
#       <td id="T_5b80c_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_5b80c_row2_col11" class="data row2 col11" >0.133970</td>
#     </tr>
#     <tr>
#       <th id="T_5b80c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b80c_row3_col0" class="data row3 col0" >844</td>
#       <td id="T_5b80c_row3_col1" class="data row3 col1" >ANCHOR</td>
#       <td id="T_5b80c_row3_col2" class="data row3 col2" >ANCHOR4</td>
#       <td id="T_5b80c_row3_col3" class="data row3 col3" >IF checking_status = no checking AND installment_commitment <= 4.0 THEN class = good</td>
#       <td id="T_5b80c_row3_col4" class="data row3 col4" >0.294900</td>
#       <td id="T_5b80c_row3_col5" class="data row3 col5" >0.497960</td>
#       <td id="T_5b80c_row3_col6" class="data row3 col6" >0.844290</td>
#       <td id="T_5b80c_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_5b80c_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_5b80c_row3_col9" class="data row3 col9" >5.573570</td>
#       <td id="T_5b80c_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_5b80c_row3_col11" class="data row3 col11" >0.133970</td>
#     </tr>
#     <tr>
#       <th id="T_5b80c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b80c_row4_col0" class="data row4 col0" >844</td>
#       <td id="T_5b80c_row4_col1" class="data row4 col1" >ANCHOR</td>
#       <td id="T_5b80c_row4_col2" class="data row4 col2" >ANCHOR5</td>
#       <td id="T_5b80c_row4_col3" class="data row4 col3" >IF checking_status = no checking THEN class = good</td>
#       <td id="T_5b80c_row4_col4" class="data row4 col4" >0.294900</td>
#       <td id="T_5b80c_row4_col5" class="data row4 col5" >0.497960</td>
#       <td id="T_5b80c_row4_col6" class="data row4 col6" >0.844290</td>
#       <td id="T_5b80c_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_5b80c_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_5b80c_row4_col9" class="data row4 col9" >11.573500</td>
#       <td id="T_5b80c_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_5b80c_row4_col11" class="data row4 col11" >0.133970</td>
#     </tr>
#     <tr>
#       <th id="T_5b80c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b80c_row5_col0" class="data row5 col0" >844</td>
#       <td id="T_5b80c_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_5b80c_row5_col2" class="data row5 col2" >LORE_SA3</td>
#       <td id="T_5b80c_row5_col3" class="data row5 col3" >IF checking_status = no checking AND housing = own AND personal_status != female div/dep/mar AND property_magnitude != no known property AND property_magnitude != car AND residence_since > 2.2295987606048584 THEN class = good</td>
#       <td id="T_5b80c_row5_col4" class="data row5 col4" >0.046940</td>
#       <td id="T_5b80c_row5_col5" class="data row5 col5" >0.091840</td>
#       <td id="T_5b80c_row5_col6" class="data row5 col6" >0.978260</td>
#       <td id="T_5b80c_row5_col7" class="data row5 col7" >6</td>
#       <td id="T_5b80c_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_5b80c_row5_col9" class="data row5 col9" >9.833300</td>
#       <td id="T_5b80c_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_5b80c_row5_col11" class="data row5 col11" >0.247960</td>
#     </tr>
#   </tbody>
# </table>
# ### Rules for Instance 844, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.49796, Pre: 0.97826, Len: 0.84429)
# <style type="text/css">
# #T_e9485_row2_col0, #T_e9485_row2_col1, #T_e9485_row2_col2, #T_e9485_row2_col3, #T_e9485_row2_col4, #T_e9485_row2_col5, #T_e9485_row2_col6, #T_e9485_row2_col7, #T_e9485_row2_col8, #T_e9485_row2_col9, #T_e9485_row2_col10, #T_e9485_row2_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_e9485">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9485_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_e9485_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_e9485_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_e9485_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_e9485_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_e9485_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_e9485_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_e9485_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_e9485_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_e9485_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_e9485_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_e9485_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9485_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9485_row0_col0" class="data row0 col0" >844</td>
#       <td id="T_e9485_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_e9485_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_e9485_row0_col3" class="data row0 col3" >IF age > 26.72 AND checking_status = no checking THEN class = good</td>
#       <td id="T_e9485_row0_col4" class="data row0 col4" >0.245920</td>
#       <td id="T_e9485_row0_col5" class="data row0 col5" >0.418370</td>
#       <td id="T_e9485_row0_col6" class="data row0 col6" >0.850620</td>
#       <td id="T_e9485_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_e9485_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_e9485_row0_col9" class="data row0 col9" >2.582130</td>
#       <td id="T_e9485_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_e9485_row0_col11" class="data row0 col11" >1.165458</td>
#     </tr>
#     <tr>
#       <th id="T_e9485_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9485_row1_col0" class="data row1 col0" >844</td>
#       <td id="T_e9485_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_e9485_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_e9485_row1_col3" class="data row1 col3" >IF checking_status = no checking AND duration <= 25.78 THEN class = good</td>
#       <td id="T_e9485_row1_col4" class="data row1 col4" >0.231630</td>
#       <td id="T_e9485_row1_col5" class="data row1 col5" >0.408160</td>
#       <td id="T_e9485_row1_col6" class="data row1 col6" >0.881060</td>
#       <td id="T_e9485_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_e9485_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_e9485_row1_col9" class="data row1 col9" >5.252570</td>
#       <td id="T_e9485_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_e9485_row1_col11" class="data row1 col11" >1.163262</td>
#     </tr>
#     <tr>
#       <th id="T_e9485_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9485_row2_col0" class="data row2 col0" >844</td>
#       <td id="T_e9485_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_e9485_row2_col2" class="data row2 col2" >ANCHOR5</td>
#       <td id="T_e9485_row2_col3" class="data row2 col3" >IF checking_status = no checking THEN class = good</td>
#       <td id="T_e9485_row2_col4" class="data row2 col4" >0.294900</td>
#       <td id="T_e9485_row2_col5" class="data row2 col5" >0.497960</td>
#       <td id="T_e9485_row2_col6" class="data row2 col6" >0.844290</td>
#       <td id="T_e9485_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_e9485_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_e9485_row2_col9" class="data row2 col9" >11.573500</td>
#       <td id="T_e9485_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_e9485_row2_col11" class="data row2 col11" >0.205411</td>
#     </tr>
#     <tr>
#       <th id="T_e9485_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9485_row3_col0" class="data row3 col0" >844</td>
#       <td id="T_e9485_row3_col1" class="data row3 col1" >LORE_SA</td>
#       <td id="T_e9485_row3_col2" class="data row3 col2" >LORE_SA3</td>
#       <td id="T_e9485_row3_col3" class="data row3 col3" >IF checking_status = no checking AND housing = own AND personal_status != female div/dep/mar AND property_magnitude != no known property AND property_magnitude != car AND residence_since > 2.2295987606048584 THEN class = good</td>
#       <td id="T_e9485_row3_col4" class="data row3 col4" >0.046940</td>
#       <td id="T_e9485_row3_col5" class="data row3 col5" >0.091840</td>
#       <td id="T_e9485_row3_col6" class="data row3 col6" >0.978260</td>
#       <td id="T_e9485_row3_col7" class="data row3 col7" >6</td>
#       <td id="T_e9485_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_e9485_row3_col9" class="data row3 col9" >9.833300</td>
#       <td id="T_e9485_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_e9485_row3_col11" class="data row3 col11" >5.171680</td>
#     </tr>
#   </tbody>
# </table>
# ## Instance 480 (Original: good , Predicted: good)
#                                                  Value
# checking_status                      between 0 and 200
# duration                                          12.0
# credit_history          critical/other existing credit
# purpose                                       radio/tv
# credit_amount                                   3573.0
# savings_status                                less 100
# employment                       between 1 and 4 years
# installment_commitment                             1.0
# personal_status                     female div/dep/mar
# other_parties                                     none
# residence_since                                    1.0
# property_magnitude                         real estate
# age                                               23.0
# other_payment_plans                               none
# housing                                            own
# existing_credits                                   1.0
# job                                 unskilled resident
# num_dependents                                     1.0
# own_telephone                                     none
# foreign_worker                                     yes
# ### Rules for Instance 480
#    Instance_Name Explainer   Rule_ID  \
# 0            480    ANCHOR   ANCHOR1
# 1            480    ANCHOR   ANCHOR2
# 2            480    ANCHOR   ANCHOR3
# 3            480    ANCHOR   ANCHOR4
# 4            480    ANCHOR   ANCHOR5
# 5            480      LORE     LORE1
# 6            480      LORE     LORE2
# 7            480      LORE     LORE3
# 8            480      LORE     LORE4
# 9            480      LORE     LORE5
# 10           480   LORE_SA  LORE_SA1
# 11           480   LORE_SA  LORE_SA2
# 12           480   LORE_SA  LORE_SA3
# 13           480   LORE_SA  LORE_SA4
# 14           480   LORE_SA  LORE_SA5
# 15           480    EXPLAN   EXPLAN1
# 16           480    EXPLAN   EXPLAN2
# 17           480    EXPLAN   EXPLAN3
# 18           480    EXPLAN   EXPLAN4
# 19           480    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                  Rule  \
# 0                                                                                                                                                      IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                     IF credit_amount > 1374.0 AND credit_history = critical/other existing credit AND duration <= 18.0 AND residence_since <= 3.0 THEN class = good
# 2                                                                                                                                                        IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 THEN class = good
# 3                                                                                                                              IF credit_amount <= 4109.58 AND duration <= 12.0 AND housing = own AND job = unskilled resident AND property_magnitude = real estate THEN class = good
# 4                                                                 IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 AND other_payment_plans = none AND residence_since <= 4.0 THEN class = good
# 5                                                                                                                                                                                                                                           IF duration <= 14.290692 THEN class = bad
# 6                                                                                                                                                                                                                                            IF duration <= 12.44342 THEN class = bad
# 7                                                                                                                                                                                                                                                IF duration <= 12.0 THEN class = bad
# 8                                                                                                                                                                                                                                           IF duration <= 13.139326 THEN class = bad
# 9                                                                                                                                                                                                                                           IF duration <= 12.151326 THEN class = bad
# 10                                                                                                       IF credit_history != all paid AND duration <= 12.512131690979004 AND employment != less 1 year AND job != unemp/unskilled non res AND purpose != education THEN class = good
# 11                                                                                                                                             IF duration <= 13.616754531860352 AND employment != less 1 year AND housing != for free AND job = unskilled resident THEN class = good
# 12                                                                                 IF credit_history != no credits/all paid AND duration <= 12.82935380935669 AND employment != less 1 year AND existing_credits <= 3.8308262825012207 AND job = unskilled resident THEN class = good
# 13  IF credit_amount <= 17136.3564453125 AND credit_amount > 3020.436767578125 AND duration <= 13.997911930084229 AND employment = between 1 and 4 years AND job != high qualif/self emp/mgmt AND job != unemp/unskilled non res AND purpose != furniture/equipment THEN class = good
# 14                                             IF credit_history != no credits/all paid AND duration <= 13.584623336791992 AND employment != less 1 year AND job = unskilled resident AND property_magnitude != car AND purpose != education AND purpose != new car THEN class = good
# 15                                                                                     IF checking_status = between 0 and 200 AND credit_amount > 3414.0 AND credit_history = critical/other existing credit AND duration <= 13.016953 AND savings_status = less 100 THEN class = bad
# 16                                                                                                                                             IF checking_status = between 0 and 200 AND credit_amount <= 3594.0 AND duration <= 13.0 AND savings_status = less 100 THEN class = bad
# 17                                                             IF checking_status = between 0 and 200 AND credit_amount <= 4300.24863 AND duration <= 12.0 AND employment = between 1 and 4 years AND property_magnitude = real estate AND savings_status = less 100 THEN class = bad
# 18                                                                   IF checking_status = between 0 and 200 AND credit_amount > 3136.529519 AND credit_amount <= 3676.0 AND duration <= 12.488746 AND property_magnitude = real estate AND savings_status = less 100 THEN class = bad
# 19                                                                                                             IF checking_status = between 0 and 200 AND credit_amount > 3339.525786 AND credit_amount <= 3676.0 AND duration <= 13.0 AND savings_status = less 100 THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.03878    0.07347  0.94737    3       0       4.55370       False
# 1   0.04286    0.07551  0.88095    4       1      12.49791       False
# 2   0.05000    0.09184  0.91837    3       2      13.72937       False
# 3   0.03980    0.07143  0.89744    5       1       9.03008       False
# 4   0.04286    0.07755  0.90476    6       0       5.70842       False
# 5   0.32653    0.22449  0.34375    1       0      53.61544       False
# 6   0.30714    0.19388  0.31561    1       0      54.12674       False
# 7   0.30408    0.18776  0.30872    1       0      54.75534       False
# 8   0.31020    0.19796  0.31908    1       1     110.71446       False
# 9   0.30510    0.18980  0.31104    1       0      56.57607       False
# 10  0.21633    0.33265  0.76887    5       0       9.41838       False
# 11  0.07143    0.10204  0.71429    4       0       9.60718       False
# 12  0.07143    0.10000  0.70000    5       0       9.43463       False
# 13  0.01020    0.02041  1.00000    7       0       9.29174       False
# 14  0.03061    0.04898  0.80000    7       0       9.35801       False
# 15  0.00000    0.00000  0.00000    5       0       1.20819       False
# 16  0.05102    0.04898  0.48000    4       0       0.74956       False
# 17  0.00714    0.00000  0.00000    6       0       1.18871       False
# 18  0.00000    0.00000  0.00000    6       0       0.81680       False
# 19  0.00000    0.00000  0.00000    5       0       1.10955       False
# ### Rules for Instance 480, Correct Prediction
#   Instance_Name Explainer   Rule_ID  \
# 0           480    ANCHOR   ANCHOR1
# 1           480    ANCHOR   ANCHOR2
# 2           480    ANCHOR   ANCHOR3
# 3           480    ANCHOR   ANCHOR4
# 4           480    ANCHOR   ANCHOR5
# 5           480   LORE_SA  LORE_SA1
# 6           480   LORE_SA  LORE_SA2
# 7           480   LORE_SA  LORE_SA3
# 8           480   LORE_SA  LORE_SA4
# 9           480   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                                                                 Rule  \
# 0                                                                                                                                                     IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                    IF credit_amount > 1374.0 AND credit_history = critical/other existing credit AND duration <= 18.0 AND residence_since <= 3.0 THEN class = good
# 2                                                                                                                                                       IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 THEN class = good
# 3                                                                                                                             IF credit_amount <= 4109.58 AND duration <= 12.0 AND housing = own AND job = unskilled resident AND property_magnitude = real estate THEN class = good
# 4                                                                IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 AND other_payment_plans = none AND residence_since <= 4.0 THEN class = good
# 5                                                                                                       IF credit_history != all paid AND duration <= 12.512131690979004 AND employment != less 1 year AND job != unemp/unskilled non res AND purpose != education THEN class = good
# 6                                                                                                                                             IF duration <= 13.616754531860352 AND employment != less 1 year AND housing != for free AND job = unskilled resident THEN class = good
# 7                                                                                 IF credit_history != no credits/all paid AND duration <= 12.82935380935669 AND employment != less 1 year AND existing_credits <= 3.8308262825012207 AND job = unskilled resident THEN class = good
# 8  IF credit_amount <= 17136.3564453125 AND credit_amount > 3020.436767578125 AND duration <= 13.997911930084229 AND employment = between 1 and 4 years AND job != high qualif/self emp/mgmt AND job != unemp/unskilled non res AND purpose != furniture/equipment THEN class = good
# 9                                             IF credit_history != no credits/all paid AND duration <= 13.584623336791992 AND employment != less 1 year AND job = unskilled resident AND property_magnitude != car AND purpose != education AND purpose != new car THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03878    0.07347  0.94737    3       0       4.55370       False
# 1  0.04286    0.07551  0.88095    4       1      12.49791       False
# 2  0.05000    0.09184  0.91837    3       2      13.72937       False
# 3  0.03980    0.07143  0.89744    5       1       9.03008       False
# 4  0.04286    0.07755  0.90476    6       0       5.70842       False
# 5  0.21633    0.33265  0.76887    5       0       9.41838       False
# 6  0.07143    0.10204  0.71429    4       0       9.60718       False
# 7  0.07143    0.10000  0.70000    5       0       9.43463       False
# 8  0.01020    0.02041  1.00000    7       0       9.29174       False
# 9  0.03061    0.04898  0.80000    7       0       9.35801       False
# ### Rules for Instance 480, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer   Rule_ID  \
# 0           480    ANCHOR   ANCHOR1
# 1           480    ANCHOR   ANCHOR2
# 2           480    ANCHOR   ANCHOR3
# 3           480    ANCHOR   ANCHOR4
# 4           480    ANCHOR   ANCHOR5
# 5           480   LORE_SA  LORE_SA1
# 6           480   LORE_SA  LORE_SA2
# 7           480   LORE_SA  LORE_SA3
# 8           480   LORE_SA  LORE_SA4
# 9           480   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                                                                 Rule  \
# 0                                                                                                                                                     IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                    IF credit_amount > 1374.0 AND credit_history = critical/other existing credit AND duration <= 18.0 AND residence_since <= 3.0 THEN class = good
# 2                                                                                                                                                       IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 THEN class = good
# 3                                                                                                                             IF credit_amount <= 4109.58 AND duration <= 12.0 AND housing = own AND job = unskilled resident AND property_magnitude = real estate THEN class = good
# 4                                                                IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 AND other_payment_plans = none AND residence_since <= 4.0 THEN class = good
# 5                                                                                                       IF credit_history != all paid AND duration <= 12.512131690979004 AND employment != less 1 year AND job != unemp/unskilled non res AND purpose != education THEN class = good
# 6                                                                                                                                             IF duration <= 13.616754531860352 AND employment != less 1 year AND housing != for free AND job = unskilled resident THEN class = good
# 7                                                                                 IF credit_history != no credits/all paid AND duration <= 12.82935380935669 AND employment != less 1 year AND existing_credits <= 3.8308262825012207 AND job = unskilled resident THEN class = good
# 8  IF credit_amount <= 17136.3564453125 AND credit_amount > 3020.436767578125 AND duration <= 13.997911930084229 AND employment = between 1 and 4 years AND job != high qualif/self emp/mgmt AND job != unemp/unskilled non res AND purpose != furniture/equipment THEN class = good
# 9                                             IF credit_history != no credits/all paid AND duration <= 13.584623336791992 AND employment != less 1 year AND job = unskilled resident AND property_magnitude != car AND purpose != education AND purpose != new car THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03878    0.07347  0.94737    3       0       4.55370       False
# 1  0.04286    0.07551  0.88095    4       1      12.49791       False
# 2  0.05000    0.09184  0.91837    3       2      13.72937       False
# 3  0.03980    0.07143  0.89744    5       1       9.03008       False
# 4  0.04286    0.07755  0.90476    6       0       5.70842       False
# 5  0.21633    0.33265  0.76887    5       0       9.41838       False
# 6  0.07143    0.10204  0.71429    4       0       9.60718       False
# ...
#       <td id="T_cb5bf_row5_col4" class="data row5 col4" >0.060200</td>
#       <td id="T_cb5bf_row5_col5" class="data row5 col5" >0.102040</td>
#       <td id="T_cb5bf_row5_col6" class="data row5 col6" >0.847460</td>
#       <td id="T_cb5bf_row5_col7" class="data row5 col7" >5</td>
#       <td id="T_cb5bf_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_cb5bf_row5_col9" class="data row5 col9" >8.445670</td>
#       <td id="T_cb5bf_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_cb5bf_row5_col11" class="data row5 col11" >4.290271</td>
#     </tr>
#     <tr>
#       <th id="T_cb5bf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb5bf_row6_col0" class="data row6 col0" >301</td>
#       <td id="T_cb5bf_row6_col1" class="data row6 col1" >
# ## Instance 915 (Original: bad , Predicted: good)
#                                             Value
# checking_status                 between 0 and 200
# duration                                     48.0
# credit_history                no credits/all paid
# purpose                                     other
# credit_amount                             18424.0
# savings_status                           less 100
# employment                  between 1 and 4 years
# installment_commitment                        1.0
# personal_status                female div/dep/mar
# other_parties                                none
# residence_since                               2.0
# property_magnitude                 life insurance
# age                                          32.0
# other_payment_plans                          bank
# housing                                       own
# existing_credits                              1.0
# job                     high qualif/self emp/mgmt
# num_dependents                                1.0
# own_telephone                                 yes
# foreign_worker                                 no
# ### Rules for Instance 915
#    Instance_Name Explainer   Rule_ID  \
# 0            915    ANCHOR   ANCHOR1
# 1            915    ANCHOR   ANCHOR2
# 2            915    ANCHOR   ANCHOR3
# 3            915    ANCHOR   ANCHOR4
# 4            915    ANCHOR   ANCHOR5
# 5            915      LORE     LORE1
# 6            915      LORE     LORE2
# 7            915      LORE     LORE3
# 8            915      LORE     LORE4
# 9            915      LORE     LORE5
# 10           915   LORE_SA  LORE_SA1
# 11           915   LORE_SA  LORE_SA2
# 12           915   LORE_SA  LORE_SA3
# 13           915   LORE_SA  LORE_SA4
# 14           915   LORE_SA  LORE_SA5
# 15           915    EXPLAN   EXPLAN1
# 16           915    EXPLAN   EXPLAN2
# 17           915    EXPLAN   EXPLAN3
# 18           915    EXPLAN   EXPLAN4
# 19           915    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                     Rule  \
# 0                  IF age > 26.72 AND existing_credits <= 1.0 AND foreign_worker = no AND installment_commitment <= 2.0 AND job = high qualif/self emp/mgmt AND other_payment_plans = bank AND own_telephone = yes AND purpose = other THEN class = good
# 1   IF age > 26.72 AND credit_amount > 2319.5 AND foreign_worker = no AND installment_commitment <= 2.0 AND job = high qualif/self emp/mgmt AND other_payment_plans = bank AND property_magnitude = life insurance AND purpose = other THEN class = good
# 2      IF age > 26.72 AND foreign_worker = no AND installment_commitment <= 2.0 AND job = high qualif/self emp/mgmt AND other_payment_plans = bank AND own_telephone = yes AND property_magnitude = life insurance AND purpose = other THEN class = good
# 3                            IF checking_status = between 0 and 200 AND credit_amount > 2319.5 AND foreign_worker = no AND installment_commitment <= 2.0 AND other_payment_plans = bank AND purpose = other AND residence_since <= 2.0 THEN class = good
# 4                IF checking_status = between 0 and 200 AND credit_amount > 2319.5 AND employment = between 1 and 4 years AND foreign_worker = no AND installment_commitment <= 2.0 AND other_payment_plans = bank AND purpose = other THEN class = good
# 5                                                                                                  IF age > 21.543914 AND duration > 12.158202 AND foreign_worker = no AND installment_commitment <= 1.0 AND other_payment_plans = bank THEN class = bad
# 6                                     IF credit_history = no credits/all paid AND duration > 42.16443 AND foreign_worker = no AND installment_commitment <= 1.0 AND other_payment_plans = bank AND personal_status = female div/dep/mar THEN class = bad
# 7                                                                                                                                               IF foreign_worker = no AND installment_commitment <= 1.0 AND other_payment_plans = bank THEN class = bad
# 8                                                                                                                                                         IF age > 25.611728 AND duration > 11.530408 AND installment_commitment <= 1.0 THEN class = bad
# 9                                                                                                            IF credit_history = no credits/all paid AND duration > 23.835507 AND foreign_worker = no AND installment_commitment <= 1.0 THEN class = bad
# 10                             IF credit_history != critical/other existing credit AND existing_credits <= 3.8358824253082275 AND foreign_worker != yes AND installment_commitment <= 1.2316404581069946 AND property_magnitude != car THEN class = good
# 11                                           IF credit_history != critical/other existing credit AND existing_credits <= 2.130845069885254 AND foreign_worker = no AND installment_commitment <= 1.0998173952102661 AND job != skilled THEN class = good
# 12                                             IF employment != greater 7 years AND foreign_worker != yes AND installment_commitment <= 1.1769531965255737 AND other_payment_plans != none AND property_magnitude != no known property THEN class = good
# 13                           IF credit_history != critical/other existing credit AND duration > 12.496353149414062 AND existing_credits <= 2.045291304588318 AND foreign_worker != yes AND installment_commitment <= 1.387006163597107 THEN class = good
# 14  IF credit_history != critical/other existing credit AND employment != unemployed AND employment != less 1 year AND existing_credits <= 2.0495554208755493 AND foreign_worker = no AND installment_commitment <= 1.1430115103721619 THEN class = good
# 15                                                                         IF checking_status = between 0 and 200 AND duration > 12.488746 AND foreign_worker = no AND installment_commitment <= 2.490914 AND savings_status = less 100 THEN class = bad
# 16                                                                                        IF checking_status = between 0 and 200 AND duration > 12.421129 AND foreign_worker = no AND own_telephone = yes AND savings_status = less 100 THEN class = bad
# 17                                               IF checking_status = between 0 and 200 AND credit_history = no credits/all paid AND duration > 13.398162 AND foreign_worker = no AND own_telephone = yes AND savings_status = less 100 THEN class = bad
# 18                                                                                                 IF checking_status = between 0 and 200 AND foreign_worker = no AND property_magnitude = life insurance AND savings_status = less 100 THEN class = bad
# 19                                                                                                                 IF checking_status = between 0 and 200 AND credit_amount > 4933.0 AND duration > 12.0 AND savings_status = less 100 THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.00000    0.00000  0.00000    8       0      11.26598       False
# 1   0.00000    0.00000  0.00000    8       0      11.27826       False
# 2   0.00000    0.00000  0.00000    8       0      13.32693       False
# 3   0.00000    0.00000  0.00000    7       0      10.16482       False
# 4   0.00000    0.00000  0.00000    7       0      11.73632       False
# 5   0.00102    0.00000  0.00000    5       0      58.32883       False
# 6   0.00000    0.00000  0.00000    6       0      58.51054       False
# 7   0.00102    0.00000  0.00000    3       0      57.80118       False
# 8   0.04592    0.03061  0.33333    3       0      56.32011       False
# 9   0.00000    0.00000  0.00000    4       0      56.30365       False
# 10  0.00408    0.00816  1.00000    5       0       9.27389       False
# 11  0.00102    0.00204  1.00000    5       0       8.97235       False
# 12  0.00102    0.00204  1.00000    5       0       9.18460       False
# 13  0.00204    0.00408  1.00000    5       0       9.45168       False
# 14  0.00408    0.00612  0.75000    6       0       9.53630       False
# 15  0.00000    0.00000  0.00000    5       0       2.11016       False
# 16  0.00000    0.00000  0.00000    5       0       2.92237       False
# 17  0.00000    0.00000  0.00000    6       0       2.21572       False
# 18  0.00000    0.00000  0.00000    4       0       0.74356       False
# 19  0.04490    0.02449  0.27273    4       0       2.04941       False
# ### Rules for Instance 915, Correct Prediction
#   Instance_Name Explainer  Rule_ID  \
# 0           915      LORE    LORE1
# 1           915      LORE    LORE2
# 2           915      LORE    LORE3
# 3           915      LORE    LORE4
# 4           915      LORE    LORE5
# 5           915    EXPLAN  EXPLAN1
# 6           915    EXPLAN  EXPLAN2
# 7           915    EXPLAN  EXPLAN3
# 8           915    EXPLAN  EXPLAN4
#
#                                                                                                                                                                                                                  Rule  \
# 0                                                               IF age > 21.543914 AND duration > 12.158202 AND foreign_worker = no AND installment_commitment <= 1.0 AND other_payment_plans = bank THEN class = bad
# 1  IF credit_history = no credits/all paid AND duration > 42.16443 AND foreign_worker = no AND installment_commitment <= 1.0 AND other_payment_plans = bank AND personal_status = female div/dep/mar THEN class = bad
# 2                                                                                                            IF foreign_worker = no AND installment_commitment <= 1.0 AND other_payment_plans = bank THEN class = bad
# 3                                                                                                                      IF age > 25.611728 AND duration > 11.530408 AND installment_commitment <= 1.0 THEN class = bad
# 4                                                                         IF credit_history = no credits/all paid AND duration > 23.835507 AND foreign_worker = no AND installment_commitment <= 1.0 THEN class = bad
# 5                                       IF checking_status = between 0 and 200 AND duration > 12.488746 AND foreign_worker = no AND installment_commitment <= 2.490914 AND savings_status = less 100 THEN class = bad
# 6                                                      IF checking_status = between 0 and 200 AND duration > 12.421129 AND foreign_worker = no AND own_telephone = yes AND savings_status = less 100 THEN class = bad
# 7             IF checking_status = between 0 and 200 AND credit_history = no credits/all paid AND duration > 13.398162 AND foreign_worker = no AND own_telephone = yes AND savings_status = less 100 THEN class = bad
# 8                                                               IF checking_status = between 0 and 200 AND foreign_worker = no AND property_magnitude = life insurance AND savings_status = less 100 THEN class = bad
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.00102    0.00000  0.00000    5       0      58.32883       False
# 1  0.00000    0.00000  0.00000    6       0      58.51054       False
# 2  0.00102    0.00000  0.00000    3       0      57.80118       False
# 3  0.04592    0.03061  0.33333    3       0      56.32011       False
# 4  0.00000    0.00000  0.00000    4       0      56.30365       False
# 5  0.00000    0.00000  0.00000    5       0       2.11016       False
# 6  0.00000    0.00000  0.00000    5       0       2.92237       False
# 7  0.00000    0.00000  0.00000    6       0       2.21572       False
# 8  0.00000    0.00000  0.00000    4       0       0.74356       False
# ### Rules for Instance 915, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer Rule_ID  \
# 0           915      LORE   LORE4
#
#                                                                                              Rule  \
# 0  IF age > 25.611728 AND duration > 11.530408 AND installment_commitment <= 1.0 THEN class = bad
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.04592    0.03061  0.33333    3       0      56.32011       False
# ### Rules for Instance 915, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.04592, Pre: 0.33333)
# <style type="text/css">
# #T_05fed_row0_col0, #T_05fed_row0_col1, #T_05fed_row0_col2, #T_05fed_row0_col3, #T_05fed_row0_col4, #T_05fed_row0_col5, #T_05fed_row0_col6, #T_05fed_row0_col7, #T_05fed_row0_col8, #T_05fed_row0_col9, #T_05fed_row0_col10, #T_05fed_row0_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_05fed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05fed_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_05fed_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_05fed_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_05fed_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_05fed_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_05fed_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_05fed_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_05fed_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_05fed_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_05fed_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_05fed_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_05fed_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05fed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05fed_row0_col0" class="data row0 col0" >915</td>
#       <td id="T_05fed_row0_col1" class="data row0 col1" >LORE</td>
#       <td id="T_05fed_row0_col2" class="data row0 col2" >LORE4</td>
#       <td id="T_05fed_row0_col3" class="data row0 col3" >IF age > 25.611728 AND duration > 11.530408 AND installment_commitment <= 1.0 THEN class = bad</td>
#       <td id="T_05fed_row0_col4" class="data row0 col4" >0.045920</td>
#       <td id="T_05fed_row0_col5" class="data row0 col5" >0.030610</td>
#       <td id="T_05fed_row0_col6" class="data row0 col6" >0.333330</td>
#       <td id="T_05fed_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_05fed_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_05fed_row0_col9" class="data row0 col9" >56.320110</td>
#       <td id="T_05fed_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_05fed_row0_col11" class="data row0 col11" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
