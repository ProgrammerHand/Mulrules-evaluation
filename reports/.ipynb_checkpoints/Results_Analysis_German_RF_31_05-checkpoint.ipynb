# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results

rules_log = "german_random_forest_rules_55-23_31-05-2025.txt"
entries_log = "german_random_forest_entries_55-23_31-05-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 844 (Original: good , Predicted: good)
#                                       Value
# checking_status                 no checking
# duration                               18.0
# credit_history                existing paid
# purpose                 furniture/equipment
# credit_amount                        3422.0
# savings_status                     less 100
# employment                  greater 7 years
# installment_commitment                  4.0
# personal_status                 male single
# other_parties                          none
# residence_since                         4.0
# property_magnitude           life insurance
# age                                    47.0
# other_payment_plans                    bank
# housing                                 own
# existing_credits                        3.0
# job                                 skilled
# num_dependents                          2.0
# own_telephone                           yes
# foreign_worker                          yes
# ### Rules for Instance 844
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844      LORE     LORE2
# 7            844      LORE     LORE3
# 8            844      LORE     LORE4
# 9            844      LORE     LORE5
# 10           844   LORE_SA  LORE_SA1
# 11           844   LORE_SA  LORE_SA2
# 12           844   LORE_SA  LORE_SA3
# 13           844   LORE_SA  LORE_SA4
# 14           844   LORE_SA  LORE_SA5
# 15           844    EXPLAN   EXPLAN1
# 16           844    EXPLAN   EXPLAN2
# 17           844    EXPLAN   EXPLAN3
# 18           844    EXPLAN   EXPLAN4
# 19           844    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                        Rule  \
# 0                                                                                                                                                                                                                        IF checking_status = no checking THEN class = good
# 1                                                                                                                                                                                                        IF age > 26.72 AND checking_status = no checking THEN class = good
# 2                                                                                                                                                                                                  IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 3                                                                                                                                                                                             IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 4                                                                                                                                                                                                      IF checking_status = no checking AND housing = own THEN class = good
# 5                                                                                                                                                                                    IF age > 46.77991 AND duration <= 18.0 AND savings_status = less 100 THEN class = good
# 6                                                                                                                                                                      IF checking_status = no checking AND housing = own AND installment_commitment > 3.0 THEN class = bad
# 7                                                                                                                                                           IF checking_status = no checking AND duration <= 23.488716 AND housing = own AND job = skilled THEN class = bad
# 8   IF age <= 47.0 AND checking_status = no checking AND duration > 17.815815 AND existing_credits > 1.0 AND housing = own AND installment_commitment > 3.0 AND other_payment_plans = bank AND purpose = furniture/equipment AND savings_status = less 100 THEN class = bad
# 9                                                                                                                                                  IF age > 46.339264 AND checking_status = no checking AND housing = own AND installment_commitment > 3.0 THEN class = bad
# 10                                                                                                    IF checking_status = no checking AND credit_amount <= 16227.375 AND employment != unemployed AND housing = own AND job != high qualif/self emp/mgmt THEN class = good
# 11                                                                                                      IF checking_status = no checking AND housing = own AND job != unskilled resident AND purpose != business AND residence_since > 1.5854892134666443 THEN class = good
# 12                                                                                      IF checking_status = no checking AND credit_history != delayed previously AND housing = own AND num_dependents > 1.8686306476593018 AND property_magnitude != car THEN class = good
# 13                                                                                                                                                      IF checking_status = no checking AND housing = own AND installment_commitment > 2.742795467376709 THEN class = good
# 14                                                                   IF checking_status = no checking AND credit_amount <= 14672.31884765625 AND housing = own AND installment_commitment > 2.534257173538208 AND property_magnitude != no known property THEN class = good
# 15                                                                                                                                                                                        IF checking_status = no checking AND credit_amount > 2543.271117 THEN class = bad
# 16                                                                                                                                                                     IF age <= 53.049983 AND checking_status = no checking AND num_dependents > 1.177463 THEN class = bad
# 17                                                                                                                                                                                             IF checking_status = no checking AND credit_amount > 2631.0 THEN class = bad
# 18                                                                                                                                                                                             IF checking_status = no checking AND credit_amount > 3249.0 THEN class = bad
# 19                                                                                                                                                                                            IF checking_status = no checking AND credit_amount <= 3676.0 THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.29490    0.49796  0.84429    1       0       4.13354       False
# 1   0.24592    0.41837  0.85062    2       1      10.98420       False
# 2   0.23163    0.40816  0.88106    2       1      10.65441       False
# 3   0.29490    0.49796  0.84429    2       0       3.10165       False
# 4   0.23163    0.39388  0.85022    2       5      29.88871       False
# 5   0.05000    0.05714  0.57143    3       0      65.01539       False
# 6   0.11633    0.03673  0.15789    3       0     110.07842       False
# 7   0.09082    0.01633  0.08989    4       0     167.97627       False
# 8   0.00000    0.00000  0.00000    9       0     126.92614       False
# 9   0.02041    0.00408  0.10000    4       0      78.44114       False
# 10  0.19490    0.33673  0.86387    5       0      13.00305       False
# 11  0.15714    0.27755  0.88312    5       0      12.93221       False
# 12  0.02143    0.03878  0.90476    5       0      12.46233       False
# 13  0.15612    0.26735  0.85621    3       0      11.38832       False
# 14  0.15408    0.26122  0.84768    5       0      17.27651       False
# 15  0.13571    0.06122  0.22556    2       0       5.83642       False
# 16  0.04898    0.02041  0.20833    3       0       5.97658       False
# 17  0.12959    0.05918  0.22835    2       0       6.44825       False
# 18  0.10408    0.05510  0.26471    2       0       4.68030       False
# 19  0.21122    0.04490  0.10628    2       0       4.76569       False
# ### Rules for Instance 844, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844   LORE_SA  LORE_SA1
# 7            844   LORE_SA  LORE_SA2
# 8            844   LORE_SA  LORE_SA3
# 9            844   LORE_SA  LORE_SA4
# 10           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                                       IF checking_status = no checking THEN class = good
# 1                                                                                                                                       IF age > 26.72 AND checking_status = no checking THEN class = good
# 2                                                                                                                                 IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 3                                                                                                                            IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 4                                                                                                                                     IF checking_status = no checking AND housing = own THEN class = good
# 5                                                                                                                   IF age > 46.77991 AND duration <= 18.0 AND savings_status = less 100 THEN class = good
# 6                                    IF checking_status = no checking AND credit_amount <= 16227.375 AND employment != unemployed AND housing = own AND job != high qualif/self emp/mgmt THEN class = good
# 7                                      IF checking_status = no checking AND housing = own AND job != unskilled resident AND purpose != business AND residence_since > 1.5854892134666443 THEN class = good
# 8                      IF checking_status = no checking AND credit_history != delayed previously AND housing = own AND num_dependents > 1.8686306476593018 AND property_magnitude != car THEN class = good
# 9                                                                                      IF checking_status = no checking AND housing = own AND installment_commitment > 2.742795467376709 THEN class = good
# 10  IF checking_status = no checking AND credit_amount <= 14672.31884765625 AND housing = own AND installment_commitment > 2.534257173538208 AND property_magnitude != no known property THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.29490    0.49796  0.84429    1       0       4.13354       False
# 1   0.24592    0.41837  0.85062    2       1      10.98420       False
# 2   0.23163    0.40816  0.88106    2       1      10.65441       False
# 3   0.29490    0.49796  0.84429    2       0       3.10165       False
# 4   0.23163    0.39388  0.85022    2       5      29.88871       False
# 5   0.05000    0.05714  0.57143    3       0      65.01539       False
# 6   0.19490    0.33673  0.86387    5       0      13.00305       False
# 7   0.15714    0.27755  0.88312    5       0      12.93221       False
# 8   0.02143    0.03878  0.90476    5       0      12.46233       False
# 9   0.15612    0.26735  0.85621    3       0      11.38832       False
# 10  0.15408    0.26122  0.84768    5       0      17.27651       False
# ### Rules for Instance 844, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844   LORE_SA  LORE_SA1
# 7            844   LORE_SA  LORE_SA2
# 8            844   LORE_SA  LORE_SA3
# 9            844   LORE_SA  LORE_SA4
# 10           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                                       IF checking_status = no checking THEN class = good
# 1                                                                                                                                       IF age > 26.72 AND checking_status = no checking THEN class = good
# 2                                                                                                                                 IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 3                                                                                                                            IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 4                                                                                                                                     IF checking_status = no checking AND housing = own THEN class = good
# 5                                                                                                                   IF age > 46.77991 AND duration <= 18.0 AND savings_status = less 100 THEN class = good
# 6                                    IF checking_status = no checking AND credit_amount <= 16227.375 AND employment != unemployed AND housing = own AND job != high qualif/self emp/mgmt THEN class = good
# 7                                      IF checking_status = no checking AND housing = own AND job != unskilled resident AND purpose != business AND residence_since > 1.5854892134666443 THEN class = good
# 8                      IF checking_status = no checking AND credit_history != delayed previously AND housing = own AND num_dependents > 1.8686306476593018 AND property_magnitude != car THEN class = good
# 9                                                                                      IF checking_status = no checking AND housing = own AND installment_commitment > 2.742795467376709 THEN class = good
# 10  IF checking_status = no checking AND credit_amount <= 14672.31884765625 AND housing = own AND installment_commitment > 2.534257173538208 AND property_magnitude != no known property THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.29490    0.49796  0.84429    1       0       4.13354       False
# 1   0.24592    0.41837  0.85062    2       1      10.98420       False
# 2   0.23163    0.40816  0.88106    2       1      10.65441       False
# 3   0.29490    0.49796  0.84429    2       0       3.10165       False
# 4   0.23163    0.39388  0.85022    2       5      29.88871       False
# 5   0.05000    0.05714  0.57143    3       0      65.01539       False
# 6   0.19490    0.33673  0.86387    5       0      13.00305       False
# 7   0.15714    0.27755  0.88312    5       0      12.93221       False
# 8   0.02143    0.03878  0.90476    5       0      12.46233       False
# 9   0.15612    0.26735  0.85621    3       0      11.38832       False
# 10  0.15408    0.26122  0.84768    5       0      17.27651       False
# ### Rules for Instance 844, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.2949, Pre: 0.90476)
# <style type="text/css">
# #T_2db50_row0_col0, #T_2db50_row0_col1, #T_2db50_row0_col2, #T_2db50_row0_col3, #T_2db50_row0_col4, #T_2db50_row0_col5, #T_2db50_row0_col6, #T_2db50_row0_col7, #T_2db50_row0_col8, #T_2db50_row0_col9, #T_2db50_row0_col10, #T_2db50_row0_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2db50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2db50_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_2db50_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_2db50_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_2db50_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_2db50_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_2db50_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_2db50_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_2db50_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_2db50_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_2db50_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_2db50_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_2db50_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2db50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2db50_row0_col0" class="data row0 col0" >844</td>
#       <td id="T_2db50_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_2db50_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_2db50_row0_col3" class="data row0 col3" >IF checking_status = no checking THEN class = good</td>
#       <td id="T_2db50_row0_col4" class="data row0 col4" >0.294900</td>
#       <td id="T_2db50_row0_col5" class="data row0 col5" >0.497960</td>
#       <td id="T_2db50_row0_col6" class="data row0 col6" >0.844290</td>
#       <td id="T_2db50_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_2db50_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_2db50_row0_col9" class="data row0 col9" >4.133540</td>
#       <td id="T_2db50_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_2db50_row0_col11" class="data row0 col11" >0.060470</td>
#     </tr>
#     <tr>
#       <th id="T_2db50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2db50_row1_col0" class="data row1 col0" >844</td>
#       <td id="T_2db50_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_2db50_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_2db50_row1_col3" class="data row1 col3" >IF age > 26.72 AND checking_status = no checking THEN class = good</td>
#       <td id="T_2db50_row1_col4" class="data row1 col4" >0.245920</td>
#       <td id="T_2db50_row1_col5" class="data row1 col5" >0.418370</td>
#       <td id="T_2db50_row1_col6" class="data row1 col6" >0.850620</td>
#       <td id="T_2db50_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_2db50_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_2db50_row1_col9" class="data row1 col9" >10.984200</td>
#       <td id="T_2db50_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_2db50_row1_col11" class="data row1 col11" >0.073008</td>
#     </tr>
#     <tr>
#       <th id="T_2db50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2db50_row2_col0" class="data row2 col0" >844</td>
#       <td id="T_2db50_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_2db50_row2_col2" class="data row2 col2" >ANCHOR3</td>
#       <td id="T_2db50_row2_col3" class="data row2 col3" >IF checking_status = no checking AND duration <= 25.78 THEN class = good</td>
#       <td id="T_2db50_row2_col4" class="data row2 col4" >0.231630</td>
#       <td id="T_2db50_row2_col5" class="data row2 col5" >0.408160</td>
#       <td id="T_2db50_row2_col6" class="data row2 col6" >0.881060</td>
#       <td id="T_2db50_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_2db50_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_2db50_row2_col9" class="data row2 col9" >10.654410</td>
#       <td id="T_2db50_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_2db50_row2_col11" class="data row2 col11" >0.067563</td>
#     </tr>
#     <tr>
#       <th id="T_2db50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2db50_row3_col0" class="data row3 col0" >844</td>
#       <td id="T_2db50_row3_col1" class="data row3 col1" >ANCHOR</td>
#       <td id="T_2db50_row3_col2" class="data row3 col2" >ANCHOR4</td>
#       <td id="T_2db50_row3_col3" class="data row3 col3" >IF checking_status = no checking AND residence_since <= 4.0 THEN class = good</td>
#       <td id="T_2db50_row3_col4" class="data row3 col4" >0.294900</td>
#       <td id="T_2db50_row3_col5" class="data row3 col5" >0.497960</td>
#       <td id="T_2db50_row3_col6" class="data row3 col6" >0.844290</td>
#       <td id="T_2db50_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_2db50_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_2db50_row3_col9" class="data row3 col9" >3.101650</td>
#       <td id="T_2db50_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_2db50_row3_col11" class="data row3 col11" >0.060470</td>
#     </tr>
#     <tr>
#       <th id="T_2db50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2db50_row4_col0" class="data row4 col0" >844</td>
#       <td id="T_2db50_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_2db50_row4_col2" class="data row4 col2" >LORE_SA2</td>
#       <td id="T_2db50_row4_col3" class="data row4 col3" >IF checking_status = no checking AND housing = own AND job != unskilled resident AND purpose != business AND residence_since > 1.5854892134666443 THEN class = good</td>
#       <td id="T_2db50_row4_col4" class="data row4 col4" >0.157140</td>
#       <td id="T_2db50_row4_col5" class="data row4 col5" >0.277550</td>
#       <td id="T_2db50_row4_col6" class="data row4 col6" >0.883120</td>
#       <td id="T_2db50_row4_col7" class="data row4 col7" >5</td>
#       <td id="T_2db50_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_2db50_row4_col9" class="data row4 col9" >12.932210</td>
#       <td id="T_2db50_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_2db50_row4_col11" class="data row4 col11" >0.139449</td>
#     </tr>
#     <tr>
#       <th id="T_2db50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2db50_row5_col0" class="data row5 col0" >844</td>
#       <td id="T_2db50_row5_col1" class="data row5 col1" >LORE_SA</td>
#       <td id="T_2db50_row5_col2" class="data row5 col2" >LORE_SA3</td>
#       <td id="T_2db50_row5_col3" class="data row5 col3" >IF checking_status = no checking AND credit_history != delayed previously AND housing = own AND num_dependents > 1.8686306476593018 AND property_magnitude != car THEN class = good</td>
#       <td id="T_2db50_row5_col4" class="data row5 col4" >0.021430</td>
#       <td id="T_2db50_row5_col5" class="data row5 col5" >0.038780</td>
#       <td id="T_2db50_row5_col6" class="data row5 col6" >0.904760</td>
#       <td id="T_2db50_row5_col7" class="data row5 col7" >5</td>
#       <td id="T_2db50_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_2db50_row5_col9" class="data row5 col9" >12.462330</td>
#       <td id="T_2db50_row5_col10" class="data row5 col10" >False</td>
#       <td id="T_2db50_row5_col11" class="data row5 col11" >0.273470</td>
#     </tr>
#   </tbody>
# </table>
# ### Rules for Instance 844, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.49796, Pre: 0.90476, Len: 0.84429)
# <style type="text/css">
# #T_99df9_row0_col0, #T_99df9_row0_col1, #T_99df9_row0_col2, #T_99df9_row0_col3, #T_99df9_row0_col4, #T_99df9_row0_col5, #T_99df9_row0_col6, #T_99df9_row0_col7, #T_99df9_row0_col8, #T_99df9_row0_col9, #T_99df9_row0_col10, #T_99df9_row0_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_99df9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99df9_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_99df9_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_99df9_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_99df9_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_99df9_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_99df9_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_99df9_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_99df9_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_99df9_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_99df9_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_99df9_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_99df9_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99df9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99df9_row0_col0" class="data row0 col0" >844</td>
#       <td id="T_99df9_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_99df9_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_99df9_row0_col3" class="data row0 col3" >IF checking_status = no checking THEN class = good</td>
#       <td id="T_99df9_row0_col4" class="data row0 col4" >0.294900</td>
#       <td id="T_99df9_row0_col5" class="data row0 col5" >0.497960</td>
#       <td id="T_99df9_row0_col6" class="data row0 col6" >0.844290</td>
#       <td id="T_99df9_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_99df9_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_99df9_row0_col9" class="data row0 col9" >4.133540</td>
#       <td id="T_99df9_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_99df9_row0_col11" class="data row0 col11" >0.167040</td>
#     </tr>
#     <tr>
#       <th id="T_99df9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99df9_row1_col0" class="data row1 col0" >844</td>
#       <td id="T_99df9_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_99df9_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_99df9_row1_col3" class="data row1 col3" >IF age > 26.72 AND checking_status = no checking THEN class = good</td>
#       <td id="T_99df9_row1_col4" class="data row1 col4" >0.245920</td>
#       <td id="T_99df9_row1_col5" class="data row1 col5" >0.418370</td>
#       <td id="T_99df9_row1_col6" class="data row1 col6" >0.850620</td>
#       <td id="T_99df9_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_99df9_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_99df9_row1_col9" class="data row1 col9" >10.984200</td>
#       <td id="T_99df9_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_99df9_row1_col11" class="data row1 col11" >1.159712</td>
#     </tr>
#     <tr>
#       <th id="T_99df9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99df9_row2_col0" class="data row2 col0" >844</td>
#       <td id="T_99df9_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_99df9_row2_col2" class="data row2 col2" >ANCHOR3</td>
#       <td id="T_99df9_row2_col3" class="data row2 col3" >IF checking_status = no checking AND duration <= 25.78 THEN class = good</td>
#       <td id="T_99df9_row2_col4" class="data row2 col4" >0.231630</td>
#       <td id="T_99df9_row2_col5" class="data row2 col5" >0.408160</td>
#       <td id="T_99df9_row2_col6" class="data row2 col6" >0.881060</td>
#       <td id="T_99df9_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_99df9_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_99df9_row2_col9" class="data row2 col9" >10.654410</td>
#       <td id="T_99df9_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_99df9_row2_col11" class="data row2 col11" >1.159436</td>
#     </tr>
#     <tr>
#       <th id="T_99df9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99df9_row3_col0" class="data row3 col0" >844</td>
#       <td id="T_99df9_row3_col1" class="data row3 col1" >LORE_SA</td>
#       <td id="T_99df9_row3_col2" class="data row3 col2" >LORE_SA2</td>
#       <td id="T_99df9_row3_col3" class="data row3 col3" >IF checking_status = no checking AND housing = own AND job != unskilled resident AND purpose != business AND residence_since > 1.5854892134666443 THEN class = good</td>
#       <td id="T_99df9_row3_col4" class="data row3 col4" >0.157140</td>
#       <td id="T_99df9_row3_col5" class="data row3 col5" >0.277550</td>
#       <td id="T_99df9_row3_col6" class="data row3 col6" >0.883120</td>
#       <td id="T_99df9_row3_col7" class="data row3 col7" >5</td>
#       <td id="T_99df9_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_99df9_row3_col9" class="data row3 col9" >12.932210</td>
#       <td id="T_99df9_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_99df9_row3_col11" class="data row3 col11" >4.161607</td>
#     </tr>
#     <tr>
#       <th id="T_99df9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99df9_row4_col0" class="data row4 col0" >844</td>
#       <td id="T_99df9_row4_col1" class="data row4 col1" >LORE_SA</td>
#       <td id="T_99df9_row4_col2" class="data row4 col2" >LORE_SA3</td>
#       <td id="T_99df9_row4_col3" class="data row4 col3" >IF checking_status = no checking AND credit_history != delayed previously AND housing = own AND num_dependents > 1.8686306476593018 AND property_magnitude != car THEN class = good</td>
#       <td id="T_99df9_row4_col4" class="data row4 col4" >0.021430</td>
#       <td id="T_99df9_row4_col5" class="data row4 col5" >0.038780</td>
#       <td id="T_99df9_row4_col6" class="data row4 col6" >0.904760</td>
#       <td id="T_99df9_row4_col7" class="data row4 col7" >5</td>
#       <td id="T_99df9_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_99df9_row4_col9" class="data row4 col9" >12.462330</td>
#       <td id="T_99df9_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_99df9_row4_col11" class="data row4 col11" >4.181001</td>
#     </tr>
#   </tbody>
# </table>
# ## Instance 480 (Original: good , Predicted: good)
#                                                  Value
# checking_status                      between 0 and 200
# duration                                          12.0
# credit_history          critical/other existing credit
# purpose                                       radio/tv
# credit_amount                                   3573.0
# savings_status                                less 100
# employment                       between 1 and 4 years
# installment_commitment                             1.0
# personal_status                     female div/dep/mar
# other_parties                                     none
# residence_since                                    1.0
# property_magnitude                         real estate
# age                                               23.0
# other_payment_plans                               none
# housing                                            own
# existing_credits                                   1.0
# job                                 unskilled resident
# num_dependents                                     1.0
# own_telephone                                     none
# foreign_worker                                     yes
# ### Rules for Instance 480
#    Instance_Name Explainer   Rule_ID  \
# 0            480    ANCHOR   ANCHOR1
# 1            480    ANCHOR   ANCHOR2
# 2            480    ANCHOR   ANCHOR3
# 3            480    ANCHOR   ANCHOR4
# 4            480    ANCHOR   ANCHOR5
# 5            480      LORE     LORE1
# 6            480      LORE     LORE2
# 7            480      LORE     LORE3
# 8            480      LORE     LORE4
# 9            480      LORE     LORE5
# 10           480   LORE_SA  LORE_SA1
# 11           480   LORE_SA  LORE_SA2
# 12           480   LORE_SA  LORE_SA3
# 13           480   LORE_SA  LORE_SA4
# 14           480   LORE_SA  LORE_SA5
# 15           480    EXPLAN   EXPLAN1
# 16           480    EXPLAN   EXPLAN2
# 17           480    EXPLAN   EXPLAN3
# 18           480    EXPLAN   EXPLAN4
# 19           480    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                             Rule  \
# 0                                                                                                                                                                                                 IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                                                    IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 18.0 AND property_magnitude = real estate THEN class = good
# 2                                                                                                                                                                                                    IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 2.0 THEN class = good
# 3                                                                                                                                                                                                         IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 12.0 THEN class = good
# 4                                                                                                                                                                                                   IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 THEN class = good
# 5                                                                                                                                                                                                                                                                                           IF duration <= 12.0 THEN class = bad
# 6                                                                                                                                                                                                                                                                                      IF duration <= 13.410599 THEN class = bad
# 7                                                                                                                                                                                                                                                                                      IF duration <= 12.811666 THEN class = bad
# 8                                                                                                                                                                                                                                                                                      IF duration <= 12.924023 THEN class = bad
# 9                                                                                                                                                                                                                                                                                      IF duration <= 13.159356 THEN class = bad
# 10                                                                                     IF credit_amount <= 10961.72705078125 AND credit_history = critical/other existing credit AND duration <= 12.815183639526367 AND employment != less 1 year AND housing != for free AND job != high qualif/self emp/mgmt THEN class = good
# 11                                                                                                                                                       IF duration <= 12.867148399353027 AND employment != less 1 year AND installment_commitment <= 2.1006107926368713 AND job != high qualif/self emp/mgmt THEN class = good
# 12                                                                                                                                                                     IF duration <= 17.308367252349854 AND employment != less 1 year AND existing_credits <= 1.8395969867706299 AND job = unskilled resident THEN class = good
# 13  IF credit_amount <= 12629.076171875 AND duration <= 14.157926559448242 AND employment != less 1 year AND installment_commitment <= 3.726628541946411 AND job != high qualif/self emp/mgmt AND job != unemp/unskilled non res AND property_magnitude != no known property AND purpose != domestic appliance THEN class = good
# 14                                                                                                                                                                            IF credit_amount <= 9587.39794921875 AND duration <= 17.3874454498291 AND employment != less 1 year AND job = unskilled resident THEN class = good
# 15                                                                                                            IF checking_status = between 0 and 200 AND credit_amount > 3249.0 AND credit_amount <= 4389.809168 AND duration <= 12.072927 AND employment = between 1 and 4 years AND savings_status = less 100 THEN class = bad
# 16                                                                                                                                                IF checking_status = between 0 and 200 AND credit_amount > 3518.0 AND credit_amount <= 3676.0 AND installment_commitment <= 1.0 AND savings_status = less 100 THEN class = bad
# 17                                                                                                         IF checking_status = between 0 and 200 AND credit_amount > 3331.0 AND credit_amount <= 3651.0 AND credit_history = critical/other existing credit AND duration <= 13.0 AND savings_status = less 100 THEN class = bad
# 18                                                                                                                                                                                   IF checking_status = between 0 and 200 AND credit_amount <= 3676.0 AND duration <= 12.072927 AND savings_status = less 100 THEN class = bad
# 19                                                                                                                                    IF checking_status = between 0 and 200 AND credit_amount <= 3656.0 AND credit_history = critical/other existing credit AND duration <= 12.0 AND savings_status = less 100 THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.03878    0.07347  0.94737    3       0      28.28518       False
# 1   0.04694    0.07755  0.82609    4       0      24.53378       False
# 2   0.03878    0.07143  0.92105    3       0      40.22697       False
# 3   0.08265    0.14694  0.88889    3       0      32.39391       False
# 4   0.05000    0.09184  0.91837    3       0      35.27383       False
# 5   0.30408    0.18776  0.30872    1       0     352.43460       False
# 6   0.31122    0.20000  0.32131    1       0     396.59238       False
# 7   0.30918    0.19796  0.32013    1       0     355.71364       False
# 8   0.30918    0.19796  0.32013    1       0     162.02548       False
# 9   0.31020    0.19796  0.31908    1       2     653.01551       False
# 10  0.06633    0.12245  0.92308    6       0      13.02728       False
# 11  0.08673    0.14490  0.83529    4       0      12.39502       False
# 12  0.05918    0.06939  0.58621    4       0      12.16360       False
# 13  0.11020    0.18980  0.86111    8       0      11.64874       False
# 14  0.08265    0.11633  0.70370    4       0      12.17529       False
# 15  0.00000    0.00000  0.00000    6       0       1.28160       False
# 16  0.00000    0.00000  0.00000    5       0       1.21556       False
# 17  0.00000    0.00000  0.00000    6       0       0.92779       False
# 18  0.05000    0.04694  0.46939    4       0       1.40656       False
# 19  0.00612    0.00204  0.16667    5       0       1.12441       False
# ### Rules for Instance 480, Correct Prediction
#   Instance_Name Explainer   Rule_ID  \
# 0           480    ANCHOR   ANCHOR1
# 1           480    ANCHOR   ANCHOR2
# 2           480    ANCHOR   ANCHOR3
# 3           480    ANCHOR   ANCHOR4
# 4           480    ANCHOR   ANCHOR5
# 5           480   LORE_SA  LORE_SA1
# 6           480   LORE_SA  LORE_SA2
# 7           480   LORE_SA  LORE_SA3
# 8           480   LORE_SA  LORE_SA4
# 9           480   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                                                                                                            Rule  \
# 0                                                                                                                                                                                                IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                                                   IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 18.0 AND property_magnitude = real estate THEN class = good
# 2                                                                                                                                                                                                   IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 2.0 THEN class = good
# 3                                                                                                                                                                                                        IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 12.0 THEN class = good
# 4                                                                                                                                                                                                  IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 3.24 THEN class = good
# 5                                                                                     IF credit_amount <= 10961.72705078125 AND credit_history = critical/other existing credit AND duration <= 12.815183639526367 AND employment != less 1 year AND housing != for free AND job != high qualif/self emp/mgmt THEN class = good
# 6                                                                                                                                                       IF duration <= 12.867148399353027 AND employment != less 1 year AND installment_commitment <= 2.1006107926368713 AND job != high qualif/self emp/mgmt THEN class = good
# 7                                                                                                                                                                     IF duration <= 17.308367252349854 AND employment != less 1 year AND existing_credits <= 1.8395969867706299 AND job = unskilled resident THEN class = good
# 8  IF credit_amount <= 12629.076171875 AND duration <= 14.157926559448242 AND employment != less 1 year AND installment_commitment <= 3.726628541946411 AND job != high qualif/self emp/mgmt AND job != unemp/unskilled non res AND property_magnitude != no known property AND purpose != domestic appliance THEN class = good
# 9                                                                                                                                                                            IF credit_amount <= 9587.39794921875 AND duration <= 17.3874454498291 AND employment != less 1 year AND job = unskilled resident THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03878    0.07347  0.94737    3       0      28.28518       False
# 1  0.04694    0.07755  0.82609    4       0      24.53378       False
# 2  0.03878    0.07143  0.92105    3       0      40.22697       False
# 3  0.08265    0.14694  0.88889    3       0      32.39391       False
# 4  0.05000    0.09184  0.91837    3       0      35.27383       False
# 5  0.06633    0.12245  0.92308    6       0      13.02728       False
# 6  0.08673    0.14490  0.83529    4       0      12.39502       False
# 7  0.05918    0.06939  0.58621    4       0      12.16360       False
# 8  0.11020    0.18980  0.86111    8       0      11.64874       False
# 9  0.08265    0.11633  0.70370    4       0      12.17529       False
# ### Rules for Instance 480, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer   Rule_ID  \
# 0           480    ANCHOR   ANCHOR1
# 1           480    ANCHOR   ANCHOR2
# 2           480    ANCHOR   ANCHOR3
# 3           480    ANCHOR   ANCHOR4
# 4           480    ANCHOR   ANCHOR5
# 5           480   LORE_SA  LORE_SA1
# 6           480   LORE_SA  LORE_SA2
# 7           480   LORE_SA  LORE_SA3
# 8           480   LORE_SA  LORE_SA4
# 9           480   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                                                                                                            Rule  \
# 0                                                                                                                                                                                                IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                                                   IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND duration <= 18.0 AND property_magnitude = real estate THEN class = good
# ...
# 2  IF checking_status = less 0 AND credit_amount > 1374.0 AND foreign_worker = yes AND other_parties = none AND savings_status = less 100 THEN class = bad
# 3                                                 IF checking_status = less 0 AND credit_history = existing paid AND other_parties = none THEN class = bad
# 4                           IF checking_status = less 0 AND credit_amount > 2319.5 AND other_parties = none AND savings_status = less 100 THEN class = bad
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.22143    0.36531  0.82488    4       0       4.43100       False
# 1  0.30000    0.48163  0.80272    4       0       3.92891       False
# 2  0.22347    0.37347  0.83562    5       0       3.77984       False
# 3  0.24796    0.40816  0.82305    3       0       5.26595       False
# 4  0.14796    0.25306  0.85517    4       0       5.41831       False
# ### Rules for Instance 917, Non-dominated (Cov↑, Pre↑), Ideal (Cov: 0.3, Pre: 0.85517)
# <style type="text/css">
# #T_2f35a_row0_col0, #T_2f35a_row0_col1, #T_2f35a_row0_col2, #T_2f35a_row0_col3, #T_2f35a_row0_col4, #T_2f35a_row0_col5, #T_2f35a_row0_col6, #T_2f35a_row0_col7, #T_2f35a_row0_col8, #T_2f35a_row0_col9, #T_2f35a_row0_col10, #T_2f35a_row0_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2f35a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f35a_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_2f35a_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_2f35a_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_2f35a_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_2f35a_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_2f35a_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_2f35a_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_2f35a_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_2f35a_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_2f35a_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_2f35a_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_2f35a_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f35a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f35a_row0_col0" class="data row0 col0" >917</td>
#       <td id="T_2f35a_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_2f35a_row0_col2" class="data row0 col2" >ANCHOR2</td>
#       <td id="T_2f35a_row0_col3" class="data row0 col3" >IF checking_status = less 0 AND installment_commitment <= 4.0 AND other_parties = none AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_2f35a_row0_col4" class="data row0 col4" >0.300000</td>
#       <td id="T_2f35a_row0_col5" class="data row0 col5" >0.481630</td>
#       <td id="T_2f35a_row0_col6" class="data row0 col6" >0.802720</td>
#       <td id="T_2f35a_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_2f35a_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_2f35a_row0_col9" class="data row0 col9" >3.928910</td>
#       <td id="T_2f35a_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_2f35a_row0_col11" class="data row0 col11" >0.052450</td>
#     </tr>
#     <tr>
#       <th id="T_2f35a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f35a_row1_col0" class="data row1 col0" >917</td>
#       <td id="T_2f35a_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_2f35a_row1_col2" class="data row1 col2" >ANCHOR3</td>
#       <td id="T_2f35a_row1_col3" class="data row1 col3" >IF checking_status = less 0 AND credit_amount > 1374.0 AND foreign_worker = yes AND other_parties = none AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_2f35a_row1_col4" class="data row1 col4" >0.223470</td>
#       <td id="T_2f35a_row1_col5" class="data row1 col5" >0.373470</td>
#       <td id="T_2f35a_row1_col6" class="data row1 col6" >0.835620</td>
#       <td id="T_2f35a_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_2f35a_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_2f35a_row1_col9" class="data row1 col9" >3.779840</td>
#       <td id="T_2f35a_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_2f35a_row1_col11" class="data row1 col11" >0.078988</td>
#     </tr>
#     <tr>
#       <th id="T_2f35a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f35a_row2_col0" class="data row2 col0" >917</td>
#       <td id="T_2f35a_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_2f35a_row2_col2" class="data row2 col2" >ANCHOR4</td>
#       <td id="T_2f35a_row2_col3" class="data row2 col3" >IF checking_status = less 0 AND credit_history = existing paid AND other_parties = none THEN class = bad</td>
#       <td id="T_2f35a_row2_col4" class="data row2 col4" >0.247960</td>
#       <td id="T_2f35a_row2_col5" class="data row2 col5" >0.408160</td>
#       <td id="T_2f35a_row2_col6" class="data row2 col6" >0.823050</td>
#       <td id="T_2f35a_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_2f35a_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_2f35a_row2_col9" class="data row2 col9" >5.265950</td>
#       <td id="T_2f35a_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_2f35a_row2_col11" class="data row2 col11" >0.061154</td>
#     </tr>
#     <tr>
#       <th id="T_2f35a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f35a_row3_col0" class="data row3 col0" >917</td>
#       <td id="T_2f35a_row3_col1" class="data row3 col1" >ANCHOR</td>
#       <td id="T_2f35a_row3_col2" class="data row3 col2" >ANCHOR5</td>
#       <td id="T_2f35a_row3_col3" class="data row3 col3" >IF checking_status = less 0 AND credit_amount > 2319.5 AND other_parties = none AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_2f35a_row3_col4" class="data row3 col4" >0.147960</td>
#       <td id="T_2f35a_row3_col5" class="data row3 col5" >0.253060</td>
#       <td id="T_2f35a_row3_col6" class="data row3 col6" >0.855170</td>
#       <td id="T_2f35a_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_2f35a_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_2f35a_row3_col9" class="data row3 col9" >5.418310</td>
#       <td id="T_2f35a_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_2f35a_row3_col11" class="data row3 col11" >0.152040</td>
#     </tr>
#   </tbody>
# </table>
# ### Rules for Instance 917, Non-dominated (Cov_class↑, Pre↑, Len↓), Ideal (Cov: 0.48163, Pre: 0.85517, Len: 0.80272)
# <style type="text/css">
# #T_1b35f_row3_col0, #T_1b35f_row3_col1, #T_1b35f_row3_col2, #T_1b35f_row3_col3, #T_1b35f_row3_col4, #T_1b35f_row3_col5, #T_1b35f_row3_col6, #T_1b35f_row3_col7, #T_1b35f_row3_col8, #T_1b35f_row3_col9, #T_1b35f_row3_col10, #T_1b35f_row3_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_1b35f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b35f_level0_col0" class="col_heading level0 col0" >Instance_Name</th>
#       <th id="T_1b35f_level0_col1" class="col_heading level0 col1" >Explainer</th>
#       <th id="T_1b35f_level0_col2" class="col_heading level0 col2" >Rule_ID</th>
#       <th id="T_1b35f_level0_col3" class="col_heading level0 col3" >Rule</th>
#       <th id="T_1b35f_level0_col4" class="col_heading level0 col4" >Cov</th>
#       <th id="T_1b35f_level0_col5" class="col_heading level0 col5" >Cov_class</th>
#       <th id="T_1b35f_level0_col6" class="col_heading level0 col6" >Pre</th>
#       <th id="T_1b35f_level0_col7" class="col_heading level0 col7" >Len</th>
#       <th id="T_1b35f_level0_col8" class="col_heading level0 col8" >Reject</th>
#       <th id="T_1b35f_level0_col9" class="col_heading level0 col9" >Elapsed_time</th>
#       <th id="T_1b35f_level0_col10" class="col_heading level0 col10" >Iter_Limit</th>
#       <th id="T_1b35f_level0_col11" class="col_heading level0 col11" >Distance_idp_eucl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b35f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b35f_row0_col0" class="data row0 col0" >917</td>
#       <td id="T_1b35f_row0_col1" class="data row0 col1" >ANCHOR</td>
#       <td id="T_1b35f_row0_col2" class="data row0 col2" >ANCHOR1</td>
#       <td id="T_1b35f_row0_col3" class="data row0 col3" >IF checking_status = less 0 AND credit_history = existing paid AND foreign_worker = yes AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_1b35f_row0_col4" class="data row0 col4" >0.221430</td>
#       <td id="T_1b35f_row0_col5" class="data row0 col5" >0.365310</td>
#       <td id="T_1b35f_row0_col6" class="data row0 col6" >0.824880</td>
#       <td id="T_1b35f_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_1b35f_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_1b35f_row0_col9" class="data row0 col9" >4.431000</td>
#       <td id="T_1b35f_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_1b35f_row0_col11" class="data row0 col11" >3.199539</td>
#     </tr>
#     <tr>
#       <th id="T_1b35f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b35f_row1_col0" class="data row1 col0" >917</td>
#       <td id="T_1b35f_row1_col1" class="data row1 col1" >ANCHOR</td>
#       <td id="T_1b35f_row1_col2" class="data row1 col2" >ANCHOR2</td>
#       <td id="T_1b35f_row1_col3" class="data row1 col3" >IF checking_status = less 0 AND installment_commitment <= 4.0 AND other_parties = none AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_1b35f_row1_col4" class="data row1 col4" >0.300000</td>
#       <td id="T_1b35f_row1_col5" class="data row1 col5" >0.481630</td>
#       <td id="T_1b35f_row1_col6" class="data row1 col6" >0.802720</td>
#       <td id="T_1b35f_row1_col7" class="data row1 col7" >4</td>
#       <td id="T_1b35f_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_1b35f_row1_col9" class="data row1 col9" >3.928910</td>
#       <td id="T_1b35f_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_1b35f_row1_col11" class="data row1 col11" >3.197710</td>
#     </tr>
#     <tr>
#       <th id="T_1b35f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b35f_row2_col0" class="data row2 col0" >917</td>
#       <td id="T_1b35f_row2_col1" class="data row2 col1" >ANCHOR</td>
#       <td id="T_1b35f_row2_col2" class="data row2 col2" >ANCHOR3</td>
#       <td id="T_1b35f_row2_col3" class="data row2 col3" >IF checking_status = less 0 AND credit_amount > 1374.0 AND foreign_worker = yes AND other_parties = none AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_1b35f_row2_col4" class="data row2 col4" >0.223470</td>
#       <td id="T_1b35f_row2_col5" class="data row2 col5" >0.373470</td>
#       <td id="T_1b35f_row2_col6" class="data row2 col6" >0.835620</td>
#       <td id="T_1b35f_row2_col7" class="data row2 col7" >5</td>
#       <td id="T_1b35f_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_1b35f_row2_col9" class="data row2 col9" >3.779840</td>
#       <td id="T_1b35f_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_1b35f_row2_col11" class="data row2 col11" >4.198719</td>
#     </tr>
#     <tr>
#       <th id="T_1b35f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b35f_row3_col0" class="data row3 col0" >917</td>
#       <td id="T_1b35f_row3_col1" class="data row3 col1" >ANCHOR</td>
#       <td id="T_1b35f_row3_col2" class="data row3 col2" >ANCHOR4</td>
#       <td id="T_1b35f_row3_col3" class="data row3 col3" >IF checking_status = less 0 AND credit_history = existing paid AND other_parties = none THEN class = bad</td>
#       <td id="T_1b35f_row3_col4" class="data row3 col4" >0.247960</td>
#       <td id="T_1b35f_row3_col5" class="data row3 col5" >0.408160</td>
#       <td id="T_1b35f_row3_col6" class="data row3 col6" >0.823050</td>
#       <td id="T_1b35f_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_1b35f_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_1b35f_row3_col9" class="data row3 col9" >5.265950</td>
#       <td id="T_1b35f_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_1b35f_row3_col11" class="data row3 col11" >2.198743</td>
#     </tr>
#     <tr>
#       <th id="T_1b35f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b35f_row4_col0" class="data row4 col0" >917</td>
#       <td id="T_1b35f_row4_col1" class="data row4 col1" >ANCHOR</td>
#       <td id="T_1b35f_row4_col2" class="data row4 col2" >ANCHOR5</td>
#       <td id="T_1b35f_row4_col3" class="data row4 col3" >IF checking_status = less 0 AND credit_amount > 2319.5 AND other_parties = none AND savings_status = less 100 THEN class = bad</td>
#       <td id="T_1b35f_row4_col4" class="data row4 col4" >0.147960</td>
#       <td id="T_1b35f_row4_col5" class="data row4 col5" >0.253060</td>
#       <td id="T_1b35f_row4_col6" class="data row4 col6" >0.855170</td>
#       <td id="T_1b35f_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_1b35f_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_1b35f_row4_col9" class="data row4 col9" >5.418310</td>
#       <td id="T_1b35f_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_1b35f_row4_col11" class="data row4 col11" >3.205440</td>
#     </tr>
#   </tbody>
# </table>
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                        0.00
# EXPLAN                                        5.00
# LORE                                          3.25
# LORE_SA                                       0.00
# Overall Average                               8.25
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                      0.00
# EXPLAN                                      0.00
# LORE                                        2.00
# LORE_SA                                     1.25
# Overall Average                             2.75
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 1.250000
# EXPLAN                                 0.000000
# LORE                                   1.000000
# LORE_SA                                2.666667
# Overall Average                        3.500000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 1.000000
# EXPLAN                                 0.000000
# LORE                                   1.000000
# LORE_SA                                2.666667
# Overall Average                        3.250000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.864289  0.200473   0.340713  2.987500  0.625000
# LORE_SA         0.861841  0.159977   0.265761  5.222222  0.000000
# Global_Average  0.863240  0.183117   0.308591  3.945238  0.357143
#
#                 Elapsed_time
# ANCHOR             14.315268
# LORE_SA            11.136034
# Global_Average     12.952740
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.864994  0.196821   0.334966  2.966667  0.666667
# LORE_SA         0.861841  0.159977   0.265761  5.222222  0.000000
# Global_Average  0.863643  0.181030   0.305306  3.933333  0.380952
#
#                 Elapsed_time
# ANCHOR             15.061163
# LORE_SA            11.136034
# Global_Average     13.378965
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
