# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results 

rules_log = "german_simpleNN_rules_53-23_06-06-2025.txt"
entries_log = "german_simpleNN_entries_53-23_06-06-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 844 (Original: good , Predicted: good)
#                                       Value
# checking_status                 no checking
# duration                               18.0
# credit_history                existing paid
# purpose                 furniture/equipment
# credit_amount                        3422.0
# savings_status                     less 100
# employment                  greater 7 years
# installment_commitment                  4.0
# personal_status                 male single
# other_parties                          none
# residence_since                         4.0
# property_magnitude           life insurance
# age                                    47.0
# other_payment_plans                    bank
# housing                                 own
# existing_credits                        3.0
# job                                 skilled
# num_dependents                          2.0
# own_telephone                           yes
# foreign_worker                          yes
# ### Rules for Instance 844
#    Instance_Name Explainer   Rule_ID  \
# 0            844    ANCHOR   ANCHOR1
# 1            844    ANCHOR   ANCHOR2
# 2            844    ANCHOR   ANCHOR3
# 3            844    ANCHOR   ANCHOR4
# 4            844    ANCHOR   ANCHOR5
# 5            844      LORE     LORE1
# 6            844      LORE     LORE2
# 7            844      LORE     LORE3
# 8            844      LORE     LORE4
# 9            844      LORE     LORE5
# 10           844   LORE_SA  LORE_SA1
# 11           844   LORE_SA  LORE_SA2
# 12           844   LORE_SA  LORE_SA3
# 13           844   LORE_SA  LORE_SA4
# 14           844   LORE_SA  LORE_SA5
# 15           844    EXPLAN   EXPLAN1
# 16           844    EXPLAN   EXPLAN2
# 17           844    EXPLAN   EXPLAN3
# 18           844    EXPLAN   EXPLAN4
# 19           844    EXPLAN   EXPLAN5
#
#                                                                                                                                                            Rule  \
# 0                                                                                          IF checking_status = no checking AND housing = own THEN class = good
# 1                                                                                      IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                            IF age > 26.72 AND checking_status = no checking THEN class = good
# 3                                                                      IF age > 26.72 AND checking_status = no checking AND duration <= 25.78 THEN class = good
# 4                                                                                 IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 5   IF checking_status = no checking AND duration > 17.72923 AND duration <= 33.650418 AND residence_since > 1.0 AND savings_status = less 100 THEN class = bad
# 6                         IF checking_status = no checking AND duration > 16.716476 AND duration <= 35.099584 AND installment_commitment > 0.0 THEN class = bad
# 7                                                                                        IF checking_status = no checking AND duration <= 42.0 THEN class = bad
# 8                                                                                   IF checking_status = no checking AND duration <= 22.746279 THEN class = bad
# 9                                                                                                             IF checking_status = no checking THEN class = bad
# 10                                                                                                           IF checking_status = no checking THEN class = good
# 11                                                                         IF checking_status = no checking AND duration <= 36.50271224975586 THEN class = good
# 12      IF checking_status = no checking AND duration <= 35.46357536315918 AND property_magnitude != no known property AND purpose != new car THEN class = good
# 13                                                                         IF checking_status = no checking AND duration <= 37.12722396850586 THEN class = good
# 14                                              IF age > 40.0283317565918 AND checking_status = no checking AND duration <= 46.21773147583008 THEN class = good
# 15                 IF checking_status = no checking AND credit_amount > 2941.446512 AND credit_amount <= 3874.087562 AND duration <= 36.846825 THEN class = bad
# 16                                                                           IF checking_status = no checking AND credit_amount <= 4304.613225 THEN class = bad
# 17                                                       IF checking_status = no checking AND credit_amount > 2538.0 AND duration <= 31.910358 THEN class = bad
# 18                                                            IF checking_status = no checking AND credit_amount > 2848.0 AND duration <= 30.0 THEN class = bad
# 19                      IF checking_status = no checking AND credit_amount > 2955.135675 AND credit_amount <= 3656.0 AND duration <= 22.746279 THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.23163    0.39388  0.85022    2       0       1.96190       False
# 1   0.23163    0.40816  0.88106    2       0       2.05368       False
# 2   0.24592    0.41837  0.85062    2       2       7.23343       False
# 3   0.19796    0.34490  0.87113    3       1       4.42542       False
# 4   0.29490    0.49796  0.84429    2       6      14.43827       False
# 5   0.05306    0.02653  0.25000    5       0      45.96504       False
# 6   0.11531    0.04286  0.18584    4       0      43.53787       False
# 7   0.28163    0.08163  0.14493    2       0      47.09994       False
# 8   0.17143    0.03878  0.11310    2       0      46.32122       False
# 9   0.29490    0.09184  0.15571    1       0      50.59659       False
# 10  0.29490    0.49796  0.84429    1       0      10.81119       False
# 11  0.27551    0.47347  0.85926    2       0      10.79727       False
# 12  0.17755    0.30816  0.86782    4       0      10.05237       False
# 13  0.27551    0.47347  0.85926    2       0       9.79630       False
# 14  0.07857    0.13878  0.88312    3       0       9.45617       False
# 15  0.04082    0.01020  0.12500    4       0       1.60930       False
# 16  0.22755    0.05306  0.11659    2       0       1.16498       False
# 17  0.08980    0.03061  0.17045    3       0       1.26193       False
# 18  0.07551    0.02653  0.17568    3       0       1.26796       False
# 19  0.02245    0.00204  0.04545    4       0       1.28501       False
# ### Rules for Instance 844, Correct Prediction
#   Instance_Name Explainer   Rule_ID  \
# 0           844    ANCHOR   ANCHOR1
# 1           844    ANCHOR   ANCHOR2
# 2           844    ANCHOR   ANCHOR3
# 3           844    ANCHOR   ANCHOR4
# 4           844    ANCHOR   ANCHOR5
# 5           844   LORE_SA  LORE_SA1
# 6           844   LORE_SA  LORE_SA2
# 7           844   LORE_SA  LORE_SA3
# 8           844   LORE_SA  LORE_SA4
# 9           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                       Rule  \
# 0                                                                                     IF checking_status = no checking AND housing = own THEN class = good
# 1                                                                                 IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                       IF age > 26.72 AND checking_status = no checking THEN class = good
# 3                                                                 IF age > 26.72 AND checking_status = no checking AND duration <= 25.78 THEN class = good
# 4                                                                            IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 5                                                                                                       IF checking_status = no checking THEN class = good
# 6                                                                     IF checking_status = no checking AND duration <= 36.50271224975586 THEN class = good
# 7  IF checking_status = no checking AND duration <= 35.46357536315918 AND property_magnitude != no known property AND purpose != new car THEN class = good
# 8                                                                     IF checking_status = no checking AND duration <= 37.12722396850586 THEN class = good
# 9                                          IF age > 40.0283317565918 AND checking_status = no checking AND duration <= 46.21773147583008 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.39388  0.85022    2       0       1.96190       False
# 1  0.23163    0.40816  0.88106    2       0       2.05368       False
# 2  0.24592    0.41837  0.85062    2       2       7.23343       False
# 3  0.19796    0.34490  0.87113    3       1       4.42542       False
# 4  0.29490    0.49796  0.84429    2       6      14.43827       False
# 5  0.29490    0.49796  0.84429    1       0      10.81119       False
# 6  0.27551    0.47347  0.85926    2       0      10.79727       False
# 7  0.17755    0.30816  0.86782    4       0      10.05237       False
# 8  0.27551    0.47347  0.85926    2       0       9.79630       False
# 9  0.07857    0.13878  0.88312    3       0       9.45617       False
# ### Rules for Instance 844, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer   Rule_ID  \
# 0           844    ANCHOR   ANCHOR1
# 1           844    ANCHOR   ANCHOR2
# 2           844    ANCHOR   ANCHOR3
# 3           844    ANCHOR   ANCHOR4
# 4           844    ANCHOR   ANCHOR5
# 5           844   LORE_SA  LORE_SA1
# 6           844   LORE_SA  LORE_SA2
# 7           844   LORE_SA  LORE_SA3
# 8           844   LORE_SA  LORE_SA4
# 9           844   LORE_SA  LORE_SA5
#
#                                                                                                                                                       Rule  \
# 0                                                                                     IF checking_status = no checking AND housing = own THEN class = good
# 1                                                                                 IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 2                                                                                       IF age > 26.72 AND checking_status = no checking THEN class = good
# 3                                                                 IF age > 26.72 AND checking_status = no checking AND duration <= 25.78 THEN class = good
# 4                                                                            IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 5                                                                                                       IF checking_status = no checking THEN class = good
# 6                                                                     IF checking_status = no checking AND duration <= 36.50271224975586 THEN class = good
# 7  IF checking_status = no checking AND duration <= 35.46357536315918 AND property_magnitude != no known property AND purpose != new car THEN class = good
# 8                                                                     IF checking_status = no checking AND duration <= 37.12722396850586 THEN class = good
# 9                                          IF age > 40.0283317565918 AND checking_status = no checking AND duration <= 46.21773147583008 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.39388  0.85022    2       0       1.96190       False
# 1  0.23163    0.40816  0.88106    2       0       2.05368       False
# 2  0.24592    0.41837  0.85062    2       2       7.23343       False
# 3  0.19796    0.34490  0.87113    3       1       4.42542       False
# 4  0.29490    0.49796  0.84429    2       6      14.43827       False
# 5  0.29490    0.49796  0.84429    1       0      10.81119       False
# 6  0.27551    0.47347  0.85926    2       0      10.79727       False
# 7  0.17755    0.30816  0.86782    4       0      10.05237       False
# 8  0.27551    0.47347  0.85926    2       0       9.79630       False
# 9  0.07857    0.13878  0.88312    3       0       9.45617       False
# ### Rules for Instance 844, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer   Rule_ID  \
# 0           844    ANCHOR   ANCHOR2
# 1           844    ANCHOR   ANCHOR5
# 2           844   LORE_SA  LORE_SA1
# 3           844   LORE_SA  LORE_SA2
# 4           844   LORE_SA  LORE_SA4
# 5           844   LORE_SA  LORE_SA5
#
#                                                                                                               Rule  \
# 0                                         IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 1                                    IF checking_status = no checking AND residence_since <= 4.0 THEN class = good
# 2                                                               IF checking_status = no checking THEN class = good
# 3                             IF checking_status = no checking AND duration <= 36.50271224975586 THEN class = good
# 4                             IF checking_status = no checking AND duration <= 37.12722396850586 THEN class = good
# 5  IF age > 40.0283317565918 AND checking_status = no checking AND duration <= 46.21773147583008 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.40816  0.88106    2       0       2.05368       False
# 1  0.29490    0.49796  0.84429    2       6      14.43827       False
# 2  0.29490    0.49796  0.84429    1       0      10.81119       False
# 3  0.27551    0.47347  0.85926    2       0      10.79727       False
# 4  0.27551    0.47347  0.85926    2       0       9.79630       False
# 5  0.07857    0.13878  0.88312    3       0       9.45617       False
# ### Rules for Instance 844, Non-dominated (Cov_class↑, Pre↑, Len↓)
#   Instance_Name Explainer   Rule_ID  \
# 0           844    ANCHOR   ANCHOR2
# 1           844   LORE_SA  LORE_SA1
# 2           844   LORE_SA  LORE_SA2
# 3           844   LORE_SA  LORE_SA4
# 4           844   LORE_SA  LORE_SA5
#
#                                                                                                               Rule  \
# 0                                         IF checking_status = no checking AND duration <= 25.78 THEN class = good
# 1                                                               IF checking_status = no checking THEN class = good
# 2                             IF checking_status = no checking AND duration <= 36.50271224975586 THEN class = good
# 3                             IF checking_status = no checking AND duration <= 37.12722396850586 THEN class = good
# 4  IF age > 40.0283317565918 AND checking_status = no checking AND duration <= 46.21773147583008 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23163    0.40816  0.88106    2       0       2.05368       False
# 1  0.29490    0.49796  0.84429    1       0      10.81119       False
# 2  0.27551    0.47347  0.85926    2       0      10.79727       False
# 3  0.27551    0.47347  0.85926    2       0       9.79630       False
# 4  0.07857    0.13878  0.88312    3       0       9.45617       False
# ## Instance 480 (Original: good , Predicted: good)
#                                                  Value
# checking_status                      between 0 and 200
# duration                                          12.0
# credit_history          critical/other existing credit
# purpose                                       radio/tv
# credit_amount                                   3573.0
# savings_status                                less 100
# employment                       between 1 and 4 years
# installment_commitment                             1.0
# personal_status                     female div/dep/mar
# other_parties                                     none
# residence_since                                    1.0
# property_magnitude                         real estate
# age                                               23.0
# other_payment_plans                               none
# housing                                            own
# existing_credits                                   1.0
# job                                 unskilled resident
# num_dependents                                     1.0
# own_telephone                                     none
# foreign_worker                                     yes
# ### Rules for Instance 480
#    Instance_Name Explainer   Rule_ID  \
# 0            480    ANCHOR   ANCHOR1
# 1            480    ANCHOR   ANCHOR2
# 2            480    ANCHOR   ANCHOR3
# 3            480    ANCHOR   ANCHOR4
# 4            480    ANCHOR   ANCHOR5
# 5            480      LORE     LORE1
# 6            480      LORE     LORE2
# 7            480      LORE     LORE3
# 8            480      LORE     LORE4
# 9            480      LORE     LORE5
# 10           480   LORE_SA  LORE_SA1
# 11           480   LORE_SA  LORE_SA2
# 12           480   LORE_SA  LORE_SA3
# 13           480   LORE_SA  LORE_SA4
# 14           480   LORE_SA  LORE_SA5
# 15           480    EXPLAN   EXPLAN1
# 16           480    EXPLAN   EXPLAN2
# 17           480    EXPLAN   EXPLAN3
# 18           480    EXPLAN   EXPLAN4
# 19           480    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                           IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                                 IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND purpose = radio/tv THEN class = good
# 2                                                                                                                         IF credit_history = critical/other existing credit AND duration <= 18.0 AND housing = own AND property_magnitude = real estate THEN class = good
# 3                                                                                                                                                                  IF duration <= 12.0 AND job = unskilled resident AND property_magnitude = real estate THEN class = good
# 4                                                                                                                                              IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 2.0 THEN class = good
# 5                                                                                                                                                                             IF credit_history = critical/other existing credit AND duration <= 15.53196 THEN class = bad
# 6                                                                                                                                                                            IF credit_history = critical/other existing credit AND duration <= 21.722954 THEN class = bad
# 7                                                                                                                                          IF credit_history = critical/other existing credit AND duration <= 19.095275 AND installment_commitment <= 2.0 THEN class = bad
# 8   IF age <= 24.0 AND checking_status = between 0 and 200 AND duration > 10.268155 AND duration <= 12.0 AND other_parties = none AND own_telephone = none AND personal_status = female div/dep/mar AND purpose = radio/tv AND savings_status = less 100 THEN class = good
# 9                                                                                                                                                                                                                                IF duration <= 15.902819 THEN class = bad
# 10                                                                                          IF checking_status != less 0 AND credit_history = critical/other existing credit AND duration <= 44.54001808166504 AND job != skilled AND purpose != new car THEN class = good
# 11                                             IF checking_status != less 0 AND credit_history != all paid AND credit_history != existing paid AND duration <= 19.06803607940674 AND job != unemp/unskilled non res AND property_magnitude = real estate THEN class = good
# 12                                                                            IF credit_history = critical/other existing credit AND duration <= 31.55443572998047 AND installment_commitment <= 3.4545352458953857 AND property_magnitude = real estate THEN class = good
# 13                         IF credit_history != existing paid AND credit_history != all paid AND credit_history != no credits/all paid AND duration <= 25.824785232543945 AND job != skilled AND property_magnitude = real estate AND purpose != new car THEN class = good
# 14                                                                               IF credit_history = critical/other existing credit AND duration <= 25.845947265625 AND installment_commitment <= 3.917534828186035 AND property_magnitude = real estate THEN class = good
# 15                                             IF checking_status = between 0 and 200 AND credit_amount > 3331.0 AND duration <= 12.275694 AND housing = own AND installment_commitment <= 2.37626 AND other_parties = none AND savings_status = less 100 THEN class = bad
# 16     IF checking_status = between 0 and 200 AND credit_amount > 3092.0 AND credit_amount <= 3676.0 AND duration <= 21.154957 AND installment_commitment <= 2.490914 AND job = unskilled resident AND other_parties = none AND savings_status = less 100 THEN class = bad
# 17                                                                         IF checking_status = between 0 and 200 AND credit_amount <= 4389.809168 AND credit_history = critical/other existing credit AND duration <= 33.0 AND savings_status = less 100 THEN class = bad
# 18                  IF checking_status = between 0 and 200 AND credit_amount > 3144.604148 AND credit_amount <= 3676.0 AND credit_history = critical/other existing credit AND duration <= 18.100609 AND purpose = radio/tv AND savings_status = less 100 THEN class = bad
# 19                                                                                                       IF checking_status = between 0 and 200 AND credit_amount > 3249.0 AND credit_amount <= 4152.214849 AND duration <= 12.0 AND other_parties = none THEN class = bad
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.03878    0.07347  0.94737    3       0       3.57736       False
# 1   0.04694    0.08776  0.93478    3       0       3.21159       False
# 2   0.03980    0.06735  0.84615    4       0       4.40502       False
# 3   0.04694    0.08367  0.89130    3       1       6.50577       False
# 4   0.03878    0.07143  0.92105    3       0       3.54967       False
# 5   0.10204    0.02653  0.13000    2       0      44.75305       False
# 6   0.13980    0.06327  0.22628    2       0      48.52966       False
# 7   0.04898    0.01224  0.12500    3       0      51.14633       False
# 8   0.00204    0.00000  0.00000    9       0      46.95820       False
# 9   0.39082    0.28163  0.36031    1       0      47.26219       False
# 10  0.04286    0.05918  0.69048    5       0       9.95457       False
# 11  0.03571    0.06122  0.85714    6       0       9.92144       False
# 12  0.03367    0.05306  0.78788    4       0       9.83519       False
# 13  0.01327    0.02041  0.76923    7       0       9.38978       False
# 14  0.03367    0.05306  0.78788    4       0       9.53502       False
# 15  0.00102    0.00000  0.00000    7       0       0.97667       False
# 16  0.00102    0.00000  0.00000    8       0       1.33425       False
# 17  0.02245    0.03061  0.68182    5       0       1.38923       False
# 18  0.00000    0.00000  0.00000    7       0       1.54881       False
# 19  0.00000    0.00000  0.00000    5       0       0.89595       False
# ### Rules for Instance 480, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0            480    ANCHOR   ANCHOR1
# 1            480    ANCHOR   ANCHOR2
# 2            480    ANCHOR   ANCHOR3
# 3            480    ANCHOR   ANCHOR4
# 4            480    ANCHOR   ANCHOR5
# 5            480      LORE     LORE4
# 6            480   LORE_SA  LORE_SA1
# 7            480   LORE_SA  LORE_SA2
# 8            480   LORE_SA  LORE_SA3
# 9            480   LORE_SA  LORE_SA4
# 10           480   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                                                       Rule  \
# 0                                                                                                                                           IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                                                 IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND purpose = radio/tv THEN class = good
# 2                                                                                                                         IF credit_history = critical/other existing credit AND duration <= 18.0 AND housing = own AND property_magnitude = real estate THEN class = good
# 3                                                                                                                                                                  IF duration <= 12.0 AND job = unskilled resident AND property_magnitude = real estate THEN class = good
# 4                                                                                                                                              IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 2.0 THEN class = good
# 5   IF age <= 24.0 AND checking_status = between 0 and 200 AND duration > 10.268155 AND duration <= 12.0 AND other_parties = none AND own_telephone = none AND personal_status = female div/dep/mar AND purpose = radio/tv AND savings_status = less 100 THEN class = good
# 6                                                                                           IF checking_status != less 0 AND credit_history = critical/other existing credit AND duration <= 44.54001808166504 AND job != skilled AND purpose != new car THEN class = good
# 7                                              IF checking_status != less 0 AND credit_history != all paid AND credit_history != existing paid AND duration <= 19.06803607940674 AND job != unemp/unskilled non res AND property_magnitude = real estate THEN class = good
# 8                                                                             IF credit_history = critical/other existing credit AND duration <= 31.55443572998047 AND installment_commitment <= 3.4545352458953857 AND property_magnitude = real estate THEN class = good
# 9                          IF credit_history != existing paid AND credit_history != all paid AND credit_history != no credits/all paid AND duration <= 25.824785232543945 AND job != skilled AND property_magnitude = real estate AND purpose != new car THEN class = good
# 10                                                                               IF credit_history = critical/other existing credit AND duration <= 25.845947265625 AND installment_commitment <= 3.917534828186035 AND property_magnitude = real estate THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.03878    0.07347  0.94737    3       0       3.57736       False
# 1   0.04694    0.08776  0.93478    3       0       3.21159       False
# 2   0.03980    0.06735  0.84615    4       0       4.40502       False
# 3   0.04694    0.08367  0.89130    3       1       6.50577       False
# 4   0.03878    0.07143  0.92105    3       0       3.54967       False
# 5   0.00204    0.00000  0.00000    9       0      46.95820       False
# 6   0.04286    0.05918  0.69048    5       0       9.95457       False
# 7   0.03571    0.06122  0.85714    6       0       9.92144       False
# 8   0.03367    0.05306  0.78788    4       0       9.83519       False
# 9   0.01327    0.02041  0.76923    7       0       9.38978       False
# 10  0.03367    0.05306  0.78788    4       0       9.53502       False
# ### Rules for Instance 480, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer   Rule_ID  \
# 0           480    ANCHOR   ANCHOR1
# 1           480    ANCHOR   ANCHOR2
# 2           480    ANCHOR   ANCHOR3
# 3           480    ANCHOR   ANCHOR4
# 4           480    ANCHOR   ANCHOR5
# 5           480   LORE_SA  LORE_SA1
# 6           480   LORE_SA  LORE_SA2
# 7           480   LORE_SA  LORE_SA3
# 8           480   LORE_SA  LORE_SA4
# 9           480   LORE_SA  LORE_SA5
#
#                                                                                                                                                                                                                                               Rule  \
# 0                                                                                                                   IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1                                                                                                                         IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND purpose = radio/tv THEN class = good
# 2                                                                                                 IF credit_history = critical/other existing credit AND duration <= 18.0 AND housing = own AND property_magnitude = real estate THEN class = good
# 3                                                                                                                                          IF duration <= 12.0 AND job = unskilled resident AND property_magnitude = real estate THEN class = good
# 4                                                                                                                      IF credit_history = critical/other existing credit AND duration <= 12.0 AND installment_commitment <= 2.0 THEN class = good
# 5                                                                   IF checking_status != less 0 AND credit_history = critical/other existing credit AND duration <= 44.54001808166504 AND job != skilled AND purpose != new car THEN class = good
# 6                      IF checking_status != less 0 AND credit_history != all paid AND credit_history != existing paid AND duration <= 19.06803607940674 AND job != unemp/unskilled non res AND property_magnitude = real estate THEN class = good
# 7                                                     IF credit_history = critical/other existing credit AND duration <= 31.55443572998047 AND installment_commitment <= 3.4545352458953857 AND property_magnitude = real estate THEN class = good
# 8  IF credit_history != existing paid AND credit_history != all paid AND credit_history != no credits/all paid AND duration <= 25.824785232543945 AND job != skilled AND property_magnitude = real estate AND purpose != new car THEN class = good
# 9                                                        IF credit_history = critical/other existing credit AND duration <= 25.845947265625 AND installment_commitment <= 3.917534828186035 AND property_magnitude = real estate THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03878    0.07347  0.94737    3       0       3.57736       False
# 1  0.04694    0.08776  0.93478    3       0       3.21159       False
# 2  0.03980    0.06735  0.84615    4       0       4.40502       False
# 3  0.04694    0.08367  0.89130    3       1       6.50577       False
# 4  0.03878    0.07143  0.92105    3       0       3.54967       False
# 5  0.04286    0.05918  0.69048    5       0       9.95457       False
# 6  0.03571    0.06122  0.85714    6       0       9.92144       False
# 7  0.03367    0.05306  0.78788    4       0       9.83519       False
# 8  0.01327    0.02041  0.76923    7       0       9.38978       False
# 9  0.03367    0.05306  0.78788    4       0       9.53502       False
# ### Rules for Instance 480, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer  Rule_ID  \
# 0           480    ANCHOR  ANCHOR1
# 1           480    ANCHOR  ANCHOR2
#
#                                                                                                                              Rule  \
# 0  IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1        IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND purpose = radio/tv THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03878    0.07347  0.94737    3       0       3.57736       False
# 1  0.04694    0.08776  0.93478    3       0       3.21159       False
# ### Rules for Instance 480, Non-dominated (Cov_class↑, Pre↑, Len↓)
#   Instance_Name Explainer  Rule_ID  \
# 0           480    ANCHOR  ANCHOR1
# 1           480    ANCHOR  ANCHOR2
#
#                                                                                                                              Rule  \
# 0  IF credit_history = critical/other existing credit AND duration <= 12.0 AND property_magnitude = real estate THEN class = good
# 1        IF credit_amount <= 4109.58 AND credit_history = critical/other existing credit AND purpose = radio/tv THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.03878    0.07347  0.94737    3       0       3.57736       False
# 1  0.04694    0.08776  0.93478    3       0       3.21159       False
# ## Instance 11 (Original: bad , Predicted: bad)
#                                      Value
# checking_status                     less 0
# duration                              48.0
# credit_history               existing paid
# purpose                           business
# credit_amount                       4308.0
# savings_status                    less 100
# employment                     less 1 year
# installment_commitment                 3.0
# personal_status         female div/dep/mar
# other_parties                         none
# residence_since                        4.0
# property_magnitude          life insurance
# age                                   24.0
# other_payment_plans                   none
# housing                               rent
# existing_credits                       1.0
# job                                skilled
# num_dependents                         1.0
# own_telephone                         none
# foreign_worker                         yes
# ### Rules for Instance 11
#    Instance_Name Explainer   Rule_ID  \
# 0             11    ANCHOR   ANCHOR1
# 1             11    ANCHOR   ANCHOR2
# 2             11    ANCHOR   ANCHOR3
# 3             11    ANCHOR   ANCHOR4
# 4             11    ANCHOR   ANCHOR5
# 5             11      LORE     LORE1
# 6             11      LORE     LORE2
# 7             11      LORE     LORE3
# 8             11      LORE     LORE4
# 9             11      LORE     LORE5
# 10            11   LORE_SA  LORE_SA1
# 11            11   LORE_SA  LORE_SA2
# 12            11   LORE_SA  LORE_SA3
# 13            11   LORE_SA  LORE_SA4
# 14            11   LORE_SA  LORE_SA5
# 15            11    EXPLAN   EXPLAN1
# 16            11    EXPLAN   EXPLAN2
# 17            11    EXPLAN   EXPLAN3
# 18            11    EXPLAN   EXPLAN4
# 19            11    EXPLAN   EXPLAN5
#
#                                                                                                                                                                  Rule  \
# 0                                                                        IF checking_status = less 0 AND job = skilled AND savings_status = less 100 THEN class = bad
# 1                                                                      IF checking_status = less 0 AND duration > 12.0 AND savings_status = less 100 THEN class = bad
# 2                                                                 IF checking_status = less 0 AND foreign_worker = yes AND savings_status = less 100 THEN class = bad
# 3                                                       IF checking_status = less 0 AND credit_history = existing paid AND savings_status = less 100 THEN class = bad
# 4                                                               IF checking_status = less 0 AND credit_amount > 1374.0 AND savings_status = less 100 THEN class = bad
# 5                                                                IF checking_status = less 0 AND duration > 46.048869 AND savings_status = less 100 THEN class = good
# 6                                                                                             IF duration > 26.343973 AND savings_status = less 100 THEN class = good
# 7                                                                                                   IF checking_status = less 0 AND duration > 24.0 THEN class = good
# 8                                                                                             IF credit_history = existing paid AND duration > 36.0 THEN class = good
# 9                                                                                                                           IF duration > 31.963827 THEN class = good
# 10                                                                                       IF checking_status = less 0 AND duration > 6.94842004776001 THEN class = bad
# 11                                             IF checking_status != no checking AND checking_status != greater 200 AND duration > 8.174288749694824 THEN class = bad
# 12                                            IF checking_status != no checking AND checking_status != greater 200 AND duration > 10.439859390258789 THEN class = bad
# 13                                IF checking_status != no checking AND savings_status != no known savings AND savings_status != between 100 and 500 THEN class = bad
# 14  IF checking_status != no checking AND checking_status != greater 200 AND duration > 15.429767608642578 AND savings_status != between 100 and 500 THEN class = bad
# 15                                                             IF checking_status = less 0 AND credit_amount > 3656.0 AND savings_status = less 100 THEN class = good
# 16                                 IF checking_status = less 0 AND credit_amount > 3835.0 AND credit_amount <= 4870.0 AND savings_status = less 100 THEN class = good
# 17                                                             IF checking_status = less 0 AND credit_amount > 3868.0 AND savings_status = less 100 THEN class = good
# 18                                                                       IF checking_status = less 0 AND credit_amount > 3757.0 AND duration > 15.0 THEN class = good
# 19                                 IF checking_status = less 0 AND credit_amount > 2580.0 AND credit_amount <= 4933.0 AND savings_status = less 100 THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.24286    0.40408  0.83193    3       0       1.98341       False
# 1   0.24082    0.41224  0.85593    3       0       2.61629       False
# 2   0.31633    0.49796  0.78710    3       0       1.96852       False
# 3   0.22347    0.36531  0.81735    3       0       2.31797       False
# 4   0.24796    0.38980  0.78601    3       0       2.74946       False
# 5   0.02755    0.00612  0.11111    3       0      45.97395       False
# 6   0.17755    0.08367  0.23563    2       0      49.21549       False
# 7   0.10816    0.03061  0.14151    2       0      46.73132       False
# 8   0.05408    0.02245  0.20755    2       0      46.11088       False
# 9   0.18878    0.13673  0.36216    1       1      90.98468       False
# 10  0.35816    0.54286  0.75783    2       0       9.33132       False
# 11  0.62041    0.86122  0.69408    3       0       9.67621       False
# 12  0.58061    0.82041  0.70650    3       0       9.20696       False
# 13  0.57653    0.79592  0.69027    3       0       9.49244       False
# 14  0.39796    0.61020  0.76667    4       0       9.43675       False
# 15  0.08367    0.02857  0.17073    3       0       2.34861       False
# 16  0.02959    0.01020  0.17241    4       0       1.00669       False
# 17  0.08265    0.02653  0.16049    3       0       1.59381       False
# 18  0.08571    0.03469  0.20238    3       0       1.43983       False
# 19  0.08163    0.03469  0.21250    4       0       2.20535       False
# ### Rules for Instance 11, Correct Prediction
#   Instance_Name Explainer   Rule_ID  \
# 0            11    ANCHOR   ANCHOR1
# 1            11    ANCHOR   ANCHOR2
# 2            11    ANCHOR   ANCHOR3
# 3            11    ANCHOR   ANCHOR4
# 4            11    ANCHOR   ANCHOR5
# 5            11   LORE_SA  LORE_SA1
# 6            11   LORE_SA  LORE_SA2
# 7            11   LORE_SA  LORE_SA3
# 8            11   LORE_SA  LORE_SA4
# 9            11   LORE_SA  LORE_SA5
#
#                                                                                                                                                                 Rule  \
# 0                                                                       IF checking_status = less 0 AND job = skilled AND savings_status = less 100 THEN class = bad
# 1                                                                     IF checking_status = less 0 AND duration > 12.0 AND savings_status = less 100 THEN class = bad
# 2                                                                IF checking_status = less 0 AND foreign_worker = yes AND savings_status = less 100 THEN class = bad
# 3                                                      IF checking_status = less 0 AND credit_history = existing paid AND savings_status = less 100 THEN class = bad
# 4                                                              IF checking_status = less 0 AND credit_amount > 1374.0 AND savings_status = less 100 THEN class = bad
# 5                                                                                       IF checking_status = less 0 AND duration > 6.94842004776001 THEN class = bad
# 6                                             IF checking_status != no checking AND checking_status != greater 200 AND duration > 8.174288749694824 THEN class = bad
# 7                                            IF checking_status != no checking AND checking_status != greater 200 AND duration > 10.439859390258789 THEN class = bad
# 8                                IF checking_status != no checking AND savings_status != no known savings AND savings_status != between 100 and 500 THEN class = bad
# 9  IF checking_status != no checking AND checking_status != greater 200 AND duration > 15.429767608642578 AND savings_status != between 100 and 500 THEN class = bad
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.24286    0.40408  0.83193    3       0       1.98341       False
# 1  0.24082    0.41224  0.85593    3       0       2.61629       False
# 2  0.31633    0.49796  0.78710    3       0       1.96852       False
# 3  0.22347    0.36531  0.81735    3       0       2.31797       False
# 4  0.24796    0.38980  0.78601    3       0       2.74946       False
# 5  0.35816    0.54286  0.75783    2       0       9.33132       False
# 6  0.62041    0.86122  0.69408    3       0       9.67621       False
# 7  0.58061    0.82041  0.70650    3       0       9.20696       False
# 8  0.57653    0.79592  0.69027    3       0       9.49244       False
# 9  0.39796    0.61020  0.76667    4       0       9.43675       False
# ### Rules for Instance 11, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer   Rule_ID  \
# 0            11    ANCHOR   ANCHOR1
# 1            11    ANCHOR   ANCHOR2
# 2            11    ANCHOR   ANCHOR3
# 3            11    ANCHOR   ANCHOR4
# 4            11    ANCHOR   ANCHOR5
# 5            11   LORE_SA  LORE_SA1
# 6            11   LORE_SA  LORE_SA2
# 7            11   LORE_SA  LORE_SA3
# 8            11   LORE_SA  LORE_SA4
# 9            11   LORE_SA  LORE_SA5
#
#                                                                                                                                                                 Rule  \
# 0                                                                       IF checking_status = less 0 AND job = skilled AND savings_status = less 100 THEN class = bad
# 1                                                                     IF checking_status = less 0 AND duration > 12.0 AND savings_status = less 100 THEN class = bad
# 2                                                                IF checking_status = less 0 AND foreign_worker = yes AND savings_status = less 100 THEN class = bad
# 3                                                      IF checking_status = less 0 AND credit_history = existing paid AND savings_status = less 100 THEN class = bad
# 4                                                              IF checking_status = less 0 AND credit_amount > 1374.0 AND savings_status = less 100 THEN class = bad
# 5                                                                                       IF checking_status = less 0 AND duration > 6.94842004776001 THEN class = bad
# 6                                             IF checking_status != no checking AND checking_status != greater 200 AND duration > 8.174288749694824 THEN class = bad
# 7                                            IF checking_status != no checking AND checking_status != greater 200 AND duration > 10.439859390258789 THEN class = bad
# 8                                IF checking_status != no checking AND savings_status != no known savings AND savings_status != between 100 and 500 THEN class = bad
# 9  IF checking_status != no checking AND checking_status != greater 200 AND duration > 15.429767608642578 AND savings_status != between 100 and 500 THEN class = bad
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.24286    0.40408  0.83193    3       0       1.98341       False
# ...
# 11                                                                  IF checking_status = less 0 AND credit_history != critical/other existing credit AND duration > 11.00618052482605 AND foreign_worker = yes AND installment_commitment > 2.1531015634536743 AND job = skilled AND num_dependents <= 1.495632290840149 AND other_parties = none AND other_payment_plans != stores AND personal_status != male mar/wid AND personal_status != male div/sep AND property_magnitude != real estate AND purpose = business AND residence_since <= 2.5827475786209106 AND savings_status = less 100 THEN class = bad
# 12  IF checking_status = less 0 AND credit_amount <= 13628.67919921875 AND credit_history != critical/other existing credit AND duration > 17.995211601257324 AND foreign_worker = yes AND installment_commitment > 2.219866633415222 AND job != unskilled resident AND job != high qualif/self emp/mgmt AND num_dependents <= 1.7309122681617737 AND other_parties = none AND other_payment_plans = bank AND personal_status != male mar/wid AND property_magnitude != real estate AND purpose != other AND purpose != used car AND purpose != domestic appliance AND savings_status = less 100 THEN class = bad
# 13                                                                              IF checking_status = less 0 AND credit_amount <= 5683.428955078125 AND credit_history = no credits/all paid AND duration > 14.820496559143066 AND foreign_worker != no AND installment_commitment > 2.3335496187210083 AND job != high qualif/self emp/mgmt AND num_dependents <= 1.7776713371276855 AND other_parties = none AND other_payment_plans != stores AND personal_status = male single AND purpose != domestic appliance AND purpose != retraining AND purpose != other AND savings_status = less 100 THEN class = bad
# 14                                                               IF age <= 36.346052169799805 AND checking_status = less 0 AND credit_history != critical/other existing credit AND duration > 12.556987285614014 AND foreign_worker = yes AND installment_commitment > 2.9399338960647583 AND job != high qualif/self emp/mgmt AND job != unskilled resident AND num_dependents <= 1.8052623271942139 AND other_parties = none AND other_payment_plans != stores AND personal_status != male mar/wid AND property_magnitude != real estate AND purpose = business AND savings_status = less 100 THEN class = bad
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                           IF checking_status = less 0 AND credit_amount > 2799.0 AND credit_history = no credits/all paid AND duration <= 30.0 AND savings_status = less 100 THEN class = good
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         IF checking_status = less 0 AND credit_amount > 2782.0 AND savings_status = less 100 THEN class = good
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             IF checking_status = less 0 AND credit_amount <= 3676.0 AND duration > 16.162435 THEN class = good
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     IF checking_status = less 0 AND credit_amount > 2064.0 AND duration > 12.0 AND savings_status = less 100 THEN class = good
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                        IF checking_status = less 0 AND credit_amount > 2856.018281 AND credit_amount <= 3676.0 AND savings_status = less 100 THEN class = good
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.30000    0.48163  0.80272    3       0       4.35166       False
# 1   0.26122    0.44082  0.84375    3       0       5.20915       False
# 2   0.24082    0.41224  0.85593    3       0       5.93758       False
# 3   0.23673    0.41020  0.86638    4       0       4.13785       False
# 4   0.27551    0.45714  0.82963    3       1      10.31561       False
# 5   0.18776    0.04898  0.13043    3       0      50.36485       False
# 6   0.59898    0.50000  0.41738    2       0      45.77380       False
# 7   0.42755    0.31429  0.36754    2       0      44.89234       False
# 8   0.00000    0.00000  0.00000   10       0      51.31038       False
# 9   0.42143    0.31429  0.37288    2       0      65.99754       False
# 10  0.00000    0.00000  0.00000   15       0      13.10397       False
# 11  0.00102    0.00204  1.00000   15       0      12.30484       False
# 12  0.00816    0.01633  1.00000   17       0      14.09560       False
# 13  0.00102    0.00204  1.00000   15       0      14.50379       False
# 14  0.00102    0.00204  1.00000   15       0      14.02991       False
# 15  0.00510    0.00204  0.20000    5       0       1.85792       False
# 16  0.12551    0.05102  0.20325    3       0       2.31527       False
# 17  0.16735    0.05510  0.16463    3       0       2.16545       False
# 18  0.15918    0.04694  0.14744    4       0       3.83095       False
# 19  0.04184    0.02245  0.26829    4       0       2.85504       False
# ### Rules for Instance 216, Correct Prediction
#   Instance_Name Explainer  Rule_ID  \
# 0           216      LORE    LORE1
# 1           216      LORE    LORE2
# 2           216      LORE    LORE3
# 3           216      LORE    LORE5
# 4           216    EXPLAN  EXPLAN1
# 5           216    EXPLAN  EXPLAN2
# 6           216    EXPLAN  EXPLAN3
# 7           216    EXPLAN  EXPLAN4
# 8           216    EXPLAN  EXPLAN5
#
#                                                                                                                                                                    Rule  \
# 0                                                               IF checking_status = less 0 AND duration > 17.137553 AND installment_commitment > 2.0 THEN class = good
# 1                                                                                                   IF duration > 17.020911 AND num_dependents <= 2.0 THEN class = good
# 2                                                                                            IF duration > 15.532319 AND installment_commitment > 2.0 THEN class = good
# 3                                                                                            IF duration > 16.172901 AND installment_commitment > 2.0 THEN class = good
# 4  IF checking_status = less 0 AND credit_amount > 2799.0 AND credit_history = no credits/all paid AND duration <= 30.0 AND savings_status = less 100 THEN class = good
# 5                                                                IF checking_status = less 0 AND credit_amount > 2782.0 AND savings_status = less 100 THEN class = good
# 6                                                                    IF checking_status = less 0 AND credit_amount <= 3676.0 AND duration > 16.162435 THEN class = good
# 7                                            IF checking_status = less 0 AND credit_amount > 2064.0 AND duration > 12.0 AND savings_status = less 100 THEN class = good
# 8                               IF checking_status = less 0 AND credit_amount > 2856.018281 AND credit_amount <= 3676.0 AND savings_status = less 100 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.18776    0.04898  0.13043    3       0      50.36485       False
# 1  0.59898    0.50000  0.41738    2       0      45.77380       False
# 2  0.42755    0.31429  0.36754    2       0      44.89234       False
# 3  0.42143    0.31429  0.37288    2       0      65.99754       False
# 4  0.00510    0.00204  0.20000    5       0       1.85792       False
# 5  0.12551    0.05102  0.20325    3       0       2.31527       False
# 6  0.16735    0.05510  0.16463    3       0       2.16545       False
# 7  0.15918    0.04694  0.14744    4       0       3.83095       False
# 8  0.04184    0.02245  0.26829    4       0       2.85504       False
# ### Rules for Instance 216, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#   Instance_Name Explainer  Rule_ID  \
# 0           216      LORE    LORE1
# 1           216      LORE    LORE2
# 2           216      LORE    LORE3
# 3           216      LORE    LORE5
# 4           216    EXPLAN  EXPLAN2
# 5           216    EXPLAN  EXPLAN3
# 6           216    EXPLAN  EXPLAN4
# 7           216    EXPLAN  EXPLAN5
#
#                                                                                                                                       Rule  \
# 0                                  IF checking_status = less 0 AND duration > 17.137553 AND installment_commitment > 2.0 THEN class = good
# 1                                                                      IF duration > 17.020911 AND num_dependents <= 2.0 THEN class = good
# 2                                                               IF duration > 15.532319 AND installment_commitment > 2.0 THEN class = good
# 3                                                               IF duration > 16.172901 AND installment_commitment > 2.0 THEN class = good
# 4                                   IF checking_status = less 0 AND credit_amount > 2782.0 AND savings_status = less 100 THEN class = good
# 5                                       IF checking_status = less 0 AND credit_amount <= 3676.0 AND duration > 16.162435 THEN class = good
# 6               IF checking_status = less 0 AND credit_amount > 2064.0 AND duration > 12.0 AND savings_status = less 100 THEN class = good
# 7  IF checking_status = less 0 AND credit_amount > 2856.018281 AND credit_amount <= 3676.0 AND savings_status = less 100 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.18776    0.04898  0.13043    3       0      50.36485       False
# 1  0.59898    0.50000  0.41738    2       0      45.77380       False
# 2  0.42755    0.31429  0.36754    2       0      44.89234       False
# 3  0.42143    0.31429  0.37288    2       0      65.99754       False
# 4  0.12551    0.05102  0.20325    3       0       2.31527       False
# 5  0.16735    0.05510  0.16463    3       0       2.16545       False
# 6  0.15918    0.04694  0.14744    4       0       3.83095       False
# 7  0.04184    0.02245  0.26829    4       0       2.85504       False
# ### Rules for Instance 216, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer Rule_ID  \
# 0           216      LORE   LORE2
#
#                                                                   Rule  \
# 0  IF duration > 17.020911 AND num_dependents <= 2.0 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.59898        0.5  0.41738    2       0       45.7738       False
# ### Rules for Instance 216, Non-dominated (Cov_class↑, Pre↑, Len↓)
#   Instance_Name Explainer Rule_ID  \
# 0           216      LORE   LORE2
#
#                                                                   Rule  \
# 0  IF duration > 17.020911 AND num_dependents <= 2.0 THEN class = good
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.59898        0.5  0.41738    2       0       45.7738       False
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         0.5
# EXPLAN                                         4.5
# LORE                                           3.9
# LORE_SA                                        0.5
# Overall Average                                9.4
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                  0.000000
# EXPLAN                                  1.000000
# LORE                                    0.600000
# LORE_SA                                 0.555556
# Overall Average                         0.900000
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 2.333333
# EXPLAN                                 4.000000
# LORE                                   2.333333
# LORE_SA                                1.888889
# Overall Average                        4.900000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 2.444444
# EXPLAN                                 4.000000
# LORE                                   1.666667
# LORE_SA                                1.888889
# Overall Average                        4.800000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.857790  0.184335   0.314058  3.444444  0.796296
# LORE_SA         0.809726  0.296568   0.448151  4.729167  0.000000
# LORE            0.417380  0.598980   0.500000  2.000000  0.000000
# Global_Average  0.811961  0.257252   0.383985  3.935185  0.398148
#
#                 Elapsed_time
# ANCHOR              4.505165
# LORE_SA            10.341748
# LORE               45.773800
# Global_Average      9.391904
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.859501  0.177778   0.304137  3.222222  0.398148
# LORE_SA         0.810779  0.296526   0.450298  4.625000  0.000000
# LORE            0.303490  0.350765   0.272450  1.750000  0.000000
# Global_Average  0.780459  0.245986   0.362343  3.657895  0.188596
#
#                 Elapsed_time
# ANCHOR              3.744600
# LORE_SA            10.308088
# LORE               45.467010
# Global_Average     10.900007
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
