# %%
import pandas as pd
pd.set_option('display.max_colwidth', None) 
from parser_main import analyze_results 

rules_log = "adult_simpleNN_rules_30-23_31-05-2025.txt"
entries_log = "adult_simpleNN_entries_30-23_31-05-2025.txt"
analyze_results(rules_log, entries_log, path="../experiments_log/", min_cov = 0.01, min_cov_class = 0.01, min_pre = 0.01)
# Out:
# ## Instance 12758 (Original: <=50K , Predicted: <=50K)
#                           Value
# age                        66.0
# workclass               Private
# education               HS-grad
# education.num                 9
# marital.status          Widowed
# occupation      Priv-house-serv
# relationship      Not-in-family
# race                      White
# sex                      Female
# capital.gain                0.0
# capital.loss                0.0
# hours.per.week             50.0
# native.country          England
# ### Rules for Instance 12758
#    Instance_Name Explainer   Rule_ID  \
# 0          12758    ANCHOR   ANCHOR1
# 1          12758    ANCHOR   ANCHOR2
# 2          12758    ANCHOR   ANCHOR3
# 3          12758    ANCHOR   ANCHOR4
# 4          12758    ANCHOR   ANCHOR5
# 5          12758      LORE     LORE1
# 6          12758      LORE     LORE2
# 7          12758      LORE     LORE3
# 8          12758      LORE     LORE4
# 9          12758      LORE     LORE5
# 10         12758   LORE_SA  LORE_SA1
# 11         12758   LORE_SA  LORE_SA2
# 12         12758   LORE_SA  LORE_SA3
# 13         12758   LORE_SA  LORE_SA4
# 14         12758   LORE_SA  LORE_SA5
# 15         12758    EXPLAN   EXPLAN1
# 16         12758    EXPLAN   EXPLAN2
# 17         12758    EXPLAN   EXPLAN3
# 18         12758    EXPLAN   EXPLAN4
# 19         12758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                      Rule  \
# 0                                                                                                                              IF capital.gain <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 1                                                                                                          IF education = HS-grad AND education.num = 9.0 AND marital.status = Widowed THEN class = <=50K
# 2                                                                                                                              IF capital.loss <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 3                                                                                                                                     IF occupation = Priv-house-serv AND sex = Female THEN class = <=50K
# 4                                                                                                                                     IF race = White AND relationship = Not-in-family THEN class = <=50K
# 5                                                                                                                               IF capital.gain <= 2202.0 AND marital.status = Widowed THEN class = <=50K
# 6                                                                                                                           IF capital.gain <= 3103.0 AND occupation = Priv-house-serv THEN class = <=50K
# 7                                                                                                                          IF capital.gain <= 3824.004198 AND marital.status = Widowed THEN class = <=50K
# 8                                                                                                                               IF capital.gain <= 4386.0 AND marital.status = Widowed THEN class = <=50K
# 9                                                                         IF age <= 66.0 AND capital.gain <= 3190.873871 AND marital.status = Widowed AND relationship = Not-in-family THEN class = <=50K
# 10                                                            IF capital.gain <= 16647.7646484375 AND education != Bachelors AND occupation = Priv-house-serv AND relationship != Wife THEN class = <=50K
# 11                        IF capital.gain <= 18749.35595703125 AND education != Bachelors AND education.num != 13 AND occupation != Machine-op-inspct AND relationship = Not-in-family THEN class = <=50K
# 12                                                                       IF capital.gain <= 2147.4415588378906 AND capital.loss <= 2266.2471923828125 AND occupation = Priv-house-serv THEN class = <=50K
# 13                                                                                        IF capital.gain <= 8438.9453125 AND capital.loss <= 8.51452898979187 AND education.num != 16 THEN class = <=50K
# 14  IF capital.gain <= 3797.6663818359375 AND capital.loss <= 2213.4591064453125 AND education != Prof-school AND marital.status != Married-AF-spouse AND occupation = Priv-house-serv THEN class = <=50K
# 15                                                                                                                                                         IF marital.status = Widowed THEN class = <=50K
# 16                                                                                                                                                                  IF age > 51.358721 THEN class = <=50K
# 17                                                                                                    IF age > 39.201853 AND marital.status = Widowed AND occupation = Priv-house-serv THEN class = <=50K
# 18                                                                                                  IF age > 61.982595 AND hours.per.week > 37.850306 AND relationship = Not-in-family THEN class = <=50K
# 19                                                                                                                                     IF age > 53.993476 AND marital.status = Widowed THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.23684    0.28746  0.92145    2       0       1.01814       False
# 1   0.01272    0.01601  0.95517    3       0       1.18063       False
# 2   0.24324    0.28850  0.90043    2       1       2.86728       False
# 3   0.00430    0.00561  0.98980    2       0       1.10950       False
# 4   0.21727    0.25527  0.89196    2       2       3.17707       False
# 5   0.02900    0.03577  0.93646    2       0      35.39174       False
# 6   0.00434    0.00572  1.00000    2       0      34.43271       False
# 7   0.02953    0.03647  0.93759    2       0      34.69986       False
# 8   0.02953    0.03647  0.93759    2       0      33.75335       False
# 9   0.00956    0.01162  0.92202    4       0      34.02401       False
# 10  0.00390    0.00514  1.00000    4       0      10.35386       False
# 11  0.18721    0.22470  0.91118    5       0      10.21715       False
# 12  0.00426    0.00561  1.00000    3       0       9.95397       False
# 13  0.91703    0.96492  0.79881    3       0      10.14007       False
# 14  0.00434    0.00572  1.00000    5       0       9.93063       False
# 15  0.03054    0.03681  0.91523    1       0       2.69056       False
# 16  0.17831    0.16153  0.68775    1       2       6.33675       False
# 17  0.00088    0.00110  0.95000    3       0       2.85751       False
# 18  0.00724    0.00815  0.85455    3       3       7.33884       False
# 19  0.02084    0.02520  0.91789    2       0       1.73177       False
# ### Rules for Instance 12758, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0          12758    ANCHOR   ANCHOR1
# 1          12758    ANCHOR   ANCHOR2
# 2          12758    ANCHOR   ANCHOR3
# 3          12758    ANCHOR   ANCHOR4
# 4          12758    ANCHOR   ANCHOR5
# 5          12758      LORE     LORE1
# 6          12758      LORE     LORE2
# 7          12758      LORE     LORE3
# 8          12758      LORE     LORE4
# 9          12758      LORE     LORE5
# 10         12758   LORE_SA  LORE_SA1
# 11         12758   LORE_SA  LORE_SA2
# 12         12758   LORE_SA  LORE_SA3
# 13         12758   LORE_SA  LORE_SA4
# 14         12758   LORE_SA  LORE_SA5
# 15         12758    EXPLAN   EXPLAN1
# 16         12758    EXPLAN   EXPLAN2
# 17         12758    EXPLAN   EXPLAN3
# 18         12758    EXPLAN   EXPLAN4
# 19         12758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                      Rule  \
# 0                                                                                                                              IF capital.gain <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 1                                                                                                          IF education = HS-grad AND education.num = 9.0 AND marital.status = Widowed THEN class = <=50K
# 2                                                                                                                              IF capital.loss <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 3                                                                                                                                     IF occupation = Priv-house-serv AND sex = Female THEN class = <=50K
# 4                                                                                                                                     IF race = White AND relationship = Not-in-family THEN class = <=50K
# 5                                                                                                                               IF capital.gain <= 2202.0 AND marital.status = Widowed THEN class = <=50K
# 6                                                                                                                           IF capital.gain <= 3103.0 AND occupation = Priv-house-serv THEN class = <=50K
# 7                                                                                                                          IF capital.gain <= 3824.004198 AND marital.status = Widowed THEN class = <=50K
# 8                                                                                                                               IF capital.gain <= 4386.0 AND marital.status = Widowed THEN class = <=50K
# 9                                                                         IF age <= 66.0 AND capital.gain <= 3190.873871 AND marital.status = Widowed AND relationship = Not-in-family THEN class = <=50K
# 10                                                            IF capital.gain <= 16647.7646484375 AND education != Bachelors AND occupation = Priv-house-serv AND relationship != Wife THEN class = <=50K
# 11                        IF capital.gain <= 18749.35595703125 AND education != Bachelors AND education.num != 13 AND occupation != Machine-op-inspct AND relationship = Not-in-family THEN class = <=50K
# 12                                                                       IF capital.gain <= 2147.4415588378906 AND capital.loss <= 2266.2471923828125 AND occupation = Priv-house-serv THEN class = <=50K
# 13                                                                                        IF capital.gain <= 8438.9453125 AND capital.loss <= 8.51452898979187 AND education.num != 16 THEN class = <=50K
# 14  IF capital.gain <= 3797.6663818359375 AND capital.loss <= 2213.4591064453125 AND education != Prof-school AND marital.status != Married-AF-spouse AND occupation = Priv-house-serv THEN class = <=50K
# 15                                                                                                                                                         IF marital.status = Widowed THEN class = <=50K
# 16                                                                                                                                                                  IF age > 51.358721 THEN class = <=50K
# 17                                                                                                    IF age > 39.201853 AND marital.status = Widowed AND occupation = Priv-house-serv THEN class = <=50K
# 18                                                                                                  IF age > 61.982595 AND hours.per.week > 37.850306 AND relationship = Not-in-family THEN class = <=50K
# 19                                                                                                                                     IF age > 53.993476 AND marital.status = Widowed THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.23684    0.28746  0.92145    2       0       1.01814       False
# 1   0.01272    0.01601  0.95517    3       0       1.18063       False
# 2   0.24324    0.28850  0.90043    2       1       2.86728       False
# 3   0.00430    0.00561  0.98980    2       0       1.10950       False
# 4   0.21727    0.25527  0.89196    2       2       3.17707       False
# 5   0.02900    0.03577  0.93646    2       0      35.39174       False
# 6   0.00434    0.00572  1.00000    2       0      34.43271       False
# 7   0.02953    0.03647  0.93759    2       0      34.69986       False
# 8   0.02953    0.03647  0.93759    2       0      33.75335       False
# 9   0.00956    0.01162  0.92202    4       0      34.02401       False
# 10  0.00390    0.00514  1.00000    4       0      10.35386       False
# 11  0.18721    0.22470  0.91118    5       0      10.21715       False
# 12  0.00426    0.00561  1.00000    3       0       9.95397       False
# 13  0.91703    0.96492  0.79881    3       0      10.14007       False
# 14  0.00434    0.00572  1.00000    5       0       9.93063       False
# 15  0.03054    0.03681  0.91523    1       0       2.69056       False
# 16  0.17831    0.16153  0.68775    1       2       6.33675       False
# 17  0.00088    0.00110  0.95000    3       0       2.85751       False
# 18  0.00724    0.00815  0.85455    3       3       7.33884       False
# 19  0.02084    0.02520  0.91789    2       0       1.73177       False
# ### Rules for Instance 12758, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0          12758    ANCHOR   ANCHOR1
# 1          12758    ANCHOR   ANCHOR2
# 2          12758    ANCHOR   ANCHOR3
# 3          12758    ANCHOR   ANCHOR5
# 4          12758      LORE     LORE1
# 5          12758      LORE     LORE3
# 6          12758      LORE     LORE4
# 7          12758   LORE_SA  LORE_SA2
# 8          12758   LORE_SA  LORE_SA4
# 9          12758    EXPLAN   EXPLAN1
# 10         12758    EXPLAN   EXPLAN2
# 11         12758    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                Rule  \
# 0                                                                                                        IF capital.gain <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 1                                                                                    IF education = HS-grad AND education.num = 9.0 AND marital.status = Widowed THEN class = <=50K
# 2                                                                                                        IF capital.loss <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 3                                                                                                               IF race = White AND relationship = Not-in-family THEN class = <=50K
# 4                                                                                                         IF capital.gain <= 2202.0 AND marital.status = Widowed THEN class = <=50K
# 5                                                                                                    IF capital.gain <= 3824.004198 AND marital.status = Widowed THEN class = <=50K
# 6                                                                                                         IF capital.gain <= 4386.0 AND marital.status = Widowed THEN class = <=50K
# 7   IF capital.gain <= 18749.35595703125 AND education != Bachelors AND education.num != 13 AND occupation != Machine-op-inspct AND relationship = Not-in-family THEN class = <=50K
# 8                                                                   IF capital.gain <= 8438.9453125 AND capital.loss <= 8.51452898979187 AND education.num != 16 THEN class = <=50K
# 9                                                                                                                                    IF marital.status = Widowed THEN class = <=50K
# 10                                                                                                                                            IF age > 51.358721 THEN class = <=50K
# 11                                                                                                               IF age > 53.993476 AND marital.status = Widowed THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.23684    0.28746  0.92145    2       0       1.01814       False
# 1   0.01272    0.01601  0.95517    3       0       1.18063       False
# 2   0.24324    0.28850  0.90043    2       1       2.86728       False
# 3   0.21727    0.25527  0.89196    2       2       3.17707       False
# 4   0.02900    0.03577  0.93646    2       0      35.39174       False
# 5   0.02953    0.03647  0.93759    2       0      34.69986       False
# 6   0.02953    0.03647  0.93759    2       0      33.75335       False
# 7   0.18721    0.22470  0.91118    5       0      10.21715       False
# 8   0.91703    0.96492  0.79881    3       0      10.14007       False
# 9   0.03054    0.03681  0.91523    1       0       2.69056       False
# 10  0.17831    0.16153  0.68775    1       2       6.33675       False
# 11  0.02084    0.02520  0.91789    2       0       1.73177       False
# ### Rules for Instance 12758, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer   Rule_ID  \
# 0         12758    ANCHOR   ANCHOR1
# 1         12758    ANCHOR   ANCHOR2
# 2         12758    ANCHOR   ANCHOR3
# 3         12758      LORE     LORE3
# 4         12758      LORE     LORE4
# 5         12758   LORE_SA  LORE_SA4
#
#                                                                                                               Rule  \
# 0                                       IF capital.gain <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 1                   IF education = HS-grad AND education.num = 9.0 AND marital.status = Widowed THEN class = <=50K
# 2                                       IF capital.loss <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 3                                   IF capital.gain <= 3824.004198 AND marital.status = Widowed THEN class = <=50K
# 4                                        IF capital.gain <= 4386.0 AND marital.status = Widowed THEN class = <=50K
# 5  IF capital.gain <= 8438.9453125 AND capital.loss <= 8.51452898979187 AND education.num != 16 THEN class = <=50K
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23684    0.28746  0.92145    2       0       1.01814       False
# 1  0.01272    0.01601  0.95517    3       0       1.18063       False
# 2  0.24324    0.28850  0.90043    2       1       2.86728       False
# 3  0.02953    0.03647  0.93759    2       0      34.69986       False
# 4  0.02953    0.03647  0.93759    2       0      33.75335       False
# 5  0.91703    0.96492  0.79881    3       0      10.14007       False
# ### Rules for Instance 12758, Non-dominated (Cov_class↑, Pre↑, Len↓)
#   Instance_Name Explainer   Rule_ID  \
# 0         12758    ANCHOR   ANCHOR1
# 1         12758    ANCHOR   ANCHOR2
# 2         12758    ANCHOR   ANCHOR3
# 3         12758      LORE     LORE3
# 4         12758      LORE     LORE4
# 5         12758   LORE_SA  LORE_SA4
# 6         12758    EXPLAN   EXPLAN1
# 7         12758    EXPLAN   EXPLAN2
#
#                                                                                                               Rule  \
# 0                                       IF capital.gain <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 1                   IF education = HS-grad AND education.num = 9.0 AND marital.status = Widowed THEN class = <=50K
# 2                                       IF capital.loss <= 0.0 AND relationship = Not-in-family THEN class = <=50K
# 3                                   IF capital.gain <= 3824.004198 AND marital.status = Widowed THEN class = <=50K
# 4                                        IF capital.gain <= 4386.0 AND marital.status = Widowed THEN class = <=50K
# 5  IF capital.gain <= 8438.9453125 AND capital.loss <= 8.51452898979187 AND education.num != 16 THEN class = <=50K
# 6                                                                   IF marital.status = Widowed THEN class = <=50K
# 7                                                                            IF age > 51.358721 THEN class = <=50K
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.23684    0.28746  0.92145    2       0       1.01814       False
# 1  0.01272    0.01601  0.95517    3       0       1.18063       False
# 2  0.24324    0.28850  0.90043    2       1       2.86728       False
# 3  0.02953    0.03647  0.93759    2       0      34.69986       False
# 4  0.02953    0.03647  0.93759    2       0      33.75335       False
# 5  0.91703    0.96492  0.79881    3       0      10.14007       False
# 6  0.03054    0.03681  0.91523    1       0       2.69056       False
# 7  0.17831    0.16153  0.68775    1       2       6.33675       False
# ## Instance 5759 (Original: <=50K , Predicted: <=50K)
#                          Value
# age                       17.0
# workclass              Private
# education                 10th
# education.num                6
# marital.status   Never-married
# occupation      Prof-specialty
# relationship         Own-child
# race                     White
# sex                       Male
# capital.gain               0.0
# capital.loss               0.0
# hours.per.week            30.0
# native.country   United-States
# ### Rules for Instance 5759
#    Instance_Name Explainer   Rule_ID  \
# 0           5759    ANCHOR   ANCHOR1
# 1           5759    ANCHOR   ANCHOR2
# 2           5759    ANCHOR   ANCHOR3
# 3           5759    ANCHOR   ANCHOR4
# 4           5759    ANCHOR   ANCHOR5
# 5           5759      LORE     LORE1
# 6           5759      LORE     LORE2
# 7           5759      LORE     LORE3
# 8           5759      LORE     LORE4
# 9           5759      LORE     LORE5
# 10          5759   LORE_SA  LORE_SA1
# 11          5759   LORE_SA  LORE_SA2
# 12          5759   LORE_SA  LORE_SA3
# 13          5759   LORE_SA  LORE_SA4
# 14          5759   LORE_SA  LORE_SA5
# 15          5759    EXPLAN   EXPLAN1
# 16          5759    EXPLAN   EXPLAN2
# 17          5759    EXPLAN   EXPLAN3
# 18          5759    EXPLAN   EXPLAN4
# 19          5759    EXPLAN   EXPLAN5
#
#                                                                                                                                                                       Rule  \
# 0                                                                                                     IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                          IF hours.per.week <= 45.0 AND marital.status = Never-married THEN class = <=50K
# 2                                                                                          IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                                          IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                                     IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                    IF capital.gain <= 15024.0 AND workclass = Private THEN class = <=50K
# 6                                                                                                                                   IF age <= 44.447838 THEN class = <=50K
# 7                                                                                                                             IF capital.gain <= 2174.0 THEN class = <=50K
# 8                                                                                                                            IF capital.gain <= 15024.0 THEN class = <=50K
# 9                                                                                                                             IF capital.gain <= 7688.0 THEN class = <=50K
# 10                               IF capital.gain <= 27217.01806640625 AND capital.loss <= 3994.8641357421875 AND education = 10th AND education.num = 6 THEN class = <=50K
# 11                                                                              IF capital.gain <= 227.34576416015625 AND capital.loss <= 3833.95703125 THEN class = <=50K
# 12                                                                          IF capital.gain <= 22686.0908203125 AND hours.per.week <= 31.51327896118164 THEN class = <=50K
# 13                                                                                       IF capital.gain <= 1070.0469360351562 AND education != Masters THEN class = <=50K
# 14  IF capital.gain <= 28973.90234375 AND capital.loss <= 3792.662109375 AND hours.per.week <= 53.4237060546875 AND marital.status != Married-AF-spouse THEN class = <=50K
# 15                                                                                                                       IF hours.per.week <= 30.313546 THEN class = <=50K
# 16                                                                                                                                  IF age <= 29.233878 THEN class = <=50K
# 17                                                                                                                       IF hours.per.week <= 34.284532 THEN class = <=50K
# 18                                                                                                                                       IF age <= 29.0 THEN class = <=50K
# 19                                                                                                                                       IF age <= 31.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       0.94903       False
# 1   0.28212    0.36052  0.97014    2       0       0.73731       False
# 2   0.26378    0.33931  0.97655    2       1       1.52081       False
# 3   0.26378    0.33931  0.97655    2       9       7.84196        True
# 4   0.28102    0.35884  0.96940    2       0       0.69575        True
# 5   0.74754    0.78114  0.79329    2       0      33.83961       False
# 6   0.68335    0.72837  0.80918    1       0      33.96423       False
# 7   0.92282    0.96712  0.79561    1       0      33.38843       False
# 8   0.99162    0.99954  0.76523    1       0      33.50236       False
# 9   0.97306    0.99919  0.77956    1       0      33.99435       False
# 10  0.02843    0.03508  0.93673    4       0      10.10970       False
# 11  0.91602    0.95816  0.79409    2       0      10.49847       False
# 12  0.16199    0.19904  0.93283    2       0      10.12787       False
# 13  0.87377    0.93151  0.80934    2       0      10.27740       False
# 14  0.88974    0.91816  0.78342    4       0      10.20317       False
# 15  0.16234    0.19910  0.93108    1       0       0.77162       False
# 16  0.29870    0.37311  0.94830    1       0       1.48782       False
# 17  0.17296    0.21158  0.92872    1       0       1.28139       False
# 18  0.29870    0.37311  0.94830    1       0       2.03902       False
# 19  0.35319    0.42981  0.92385    1       0       1.79405       False
# ### Rules for Instance 5759, Correct Prediction
#    Instance_Name Explainer   Rule_ID  \
# 0           5759    ANCHOR   ANCHOR1
# 1           5759    ANCHOR   ANCHOR2
# 2           5759    ANCHOR   ANCHOR3
# 3           5759    ANCHOR   ANCHOR4
# 4           5759    ANCHOR   ANCHOR5
# 5           5759      LORE     LORE1
# 6           5759      LORE     LORE2
# 7           5759      LORE     LORE3
# 8           5759      LORE     LORE4
# 9           5759      LORE     LORE5
# 10          5759   LORE_SA  LORE_SA1
# 11          5759   LORE_SA  LORE_SA2
# 12          5759   LORE_SA  LORE_SA3
# 13          5759   LORE_SA  LORE_SA4
# 14          5759   LORE_SA  LORE_SA5
# 15          5759    EXPLAN   EXPLAN1
# 16          5759    EXPLAN   EXPLAN2
# 17          5759    EXPLAN   EXPLAN3
# 18          5759    EXPLAN   EXPLAN4
# 19          5759    EXPLAN   EXPLAN5
#
#                                                                                                                                                                       Rule  \
# 0                                                                                                     IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                          IF hours.per.week <= 45.0 AND marital.status = Never-married THEN class = <=50K
# 2                                                                                          IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                                          IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                                     IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                    IF capital.gain <= 15024.0 AND workclass = Private THEN class = <=50K
# 6                                                                                                                                   IF age <= 44.447838 THEN class = <=50K
# 7                                                                                                                             IF capital.gain <= 2174.0 THEN class = <=50K
# 8                                                                                                                            IF capital.gain <= 15024.0 THEN class = <=50K
# 9                                                                                                                             IF capital.gain <= 7688.0 THEN class = <=50K
# 10                               IF capital.gain <= 27217.01806640625 AND capital.loss <= 3994.8641357421875 AND education = 10th AND education.num = 6 THEN class = <=50K
# 11                                                                              IF capital.gain <= 227.34576416015625 AND capital.loss <= 3833.95703125 THEN class = <=50K
# 12                                                                          IF capital.gain <= 22686.0908203125 AND hours.per.week <= 31.51327896118164 THEN class = <=50K
# 13                                                                                       IF capital.gain <= 1070.0469360351562 AND education != Masters THEN class = <=50K
# 14  IF capital.gain <= 28973.90234375 AND capital.loss <= 3792.662109375 AND hours.per.week <= 53.4237060546875 AND marital.status != Married-AF-spouse THEN class = <=50K
# 15                                                                                                                       IF hours.per.week <= 30.313546 THEN class = <=50K
# 16                                                                                                                                  IF age <= 29.233878 THEN class = <=50K
# 17                                                                                                                       IF hours.per.week <= 34.284532 THEN class = <=50K
# 18                                                                                                                                       IF age <= 29.0 THEN class = <=50K
# 19                                                                                                                                       IF age <= 31.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       0.94903       False
# 1   0.28212    0.36052  0.97014    2       0       0.73731       False
# 2   0.26378    0.33931  0.97655    2       1       1.52081       False
# 3   0.26378    0.33931  0.97655    2       9       7.84196        True
# 4   0.28102    0.35884  0.96940    2       0       0.69575        True
# 5   0.74754    0.78114  0.79329    2       0      33.83961       False
# 6   0.68335    0.72837  0.80918    1       0      33.96423       False
# 7   0.92282    0.96712  0.79561    1       0      33.38843       False
# 8   0.99162    0.99954  0.76523    1       0      33.50236       False
# 9   0.97306    0.99919  0.77956    1       0      33.99435       False
# 10  0.02843    0.03508  0.93673    4       0      10.10970       False
# 11  0.91602    0.95816  0.79409    2       0      10.49847       False
# 12  0.16199    0.19904  0.93283    2       0      10.12787       False
# 13  0.87377    0.93151  0.80934    2       0      10.27740       False
# 14  0.88974    0.91816  0.78342    4       0      10.20317       False
# 15  0.16234    0.19910  0.93108    1       0       0.77162       False
# 16  0.29870    0.37311  0.94830    1       0       1.48782       False
# 17  0.17296    0.21158  0.92872    1       0       1.28139       False
# 18  0.29870    0.37311  0.94830    1       0       2.03902       False
# 19  0.35319    0.42981  0.92385    1       0       1.79405       False
# ### Rules for Instance 5759, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0           5759    ANCHOR   ANCHOR1
# 1           5759    ANCHOR   ANCHOR2
# 2           5759    ANCHOR   ANCHOR3
# 3           5759    ANCHOR   ANCHOR4
# 4           5759    ANCHOR   ANCHOR5
# 5           5759      LORE     LORE1
# 6           5759      LORE     LORE2
# 7           5759      LORE     LORE3
# 8           5759      LORE     LORE4
# 9           5759      LORE     LORE5
# 10          5759   LORE_SA  LORE_SA1
# 11          5759   LORE_SA  LORE_SA2
# 12          5759   LORE_SA  LORE_SA3
# 13          5759   LORE_SA  LORE_SA4
# 14          5759   LORE_SA  LORE_SA5
# 15          5759    EXPLAN   EXPLAN1
# 16          5759    EXPLAN   EXPLAN2
# 17          5759    EXPLAN   EXPLAN3
# 18          5759    EXPLAN   EXPLAN4
# 19          5759    EXPLAN   EXPLAN5
#
#                                                                                                                                                                       Rule  \
# 0                                                                                                     IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 1                                                                                          IF hours.per.week <= 45.0 AND marital.status = Never-married THEN class = <=50K
# 2                                                                                          IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 3                                                                                          IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 4                                                                                                     IF age <= 37.0 AND marital.status = Never-married THEN class = <=50K
# 5                                                                                                    IF capital.gain <= 15024.0 AND workclass = Private THEN class = <=50K
# 6                                                                                                                                   IF age <= 44.447838 THEN class = <=50K
# 7                                                                                                                             IF capital.gain <= 2174.0 THEN class = <=50K
# 8                                                                                                                            IF capital.gain <= 15024.0 THEN class = <=50K
# 9                                                                                                                             IF capital.gain <= 7688.0 THEN class = <=50K
# 10                               IF capital.gain <= 27217.01806640625 AND capital.loss <= 3994.8641357421875 AND education = 10th AND education.num = 6 THEN class = <=50K
# 11                                                                              IF capital.gain <= 227.34576416015625 AND capital.loss <= 3833.95703125 THEN class = <=50K
# 12                                                                          IF capital.gain <= 22686.0908203125 AND hours.per.week <= 31.51327896118164 THEN class = <=50K
# 13                                                                                       IF capital.gain <= 1070.0469360351562 AND education != Masters THEN class = <=50K
# 14  IF capital.gain <= 28973.90234375 AND capital.loss <= 3792.662109375 AND hours.per.week <= 53.4237060546875 AND marital.status != Married-AF-spouse THEN class = <=50K
# 15                                                                                                                       IF hours.per.week <= 30.313546 THEN class = <=50K
# 16                                                                                                                                  IF age <= 29.233878 THEN class = <=50K
# 17                                                                                                                       IF hours.per.week <= 34.284532 THEN class = <=50K
# 18                                                                                                                                       IF age <= 29.0 THEN class = <=50K
# 19                                                                                                                                       IF age <= 31.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28102    0.35884  0.96940    2       0       0.94903       False
# 1   0.28212    0.36052  0.97014    2       0       0.73731       False
# 2   0.26378    0.33931  0.97655    2       1       1.52081       False
# 3   0.26378    0.33931  0.97655    2       9       7.84196        True
# 4   0.28102    0.35884  0.96940    2       0       0.69575        True
# 5   0.74754    0.78114  0.79329    2       0      33.83961       False
# 6   0.68335    0.72837  0.80918    1       0      33.96423       False
# 7   0.92282    0.96712  0.79561    1       0      33.38843       False
# 8   0.99162    0.99954  0.76523    1       0      33.50236       False
# 9   0.97306    0.99919  0.77956    1       0      33.99435       False
# 10  0.02843    0.03508  0.93673    4       0      10.10970       False
# 11  0.91602    0.95816  0.79409    2       0      10.49847       False
# 12  0.16199    0.19904  0.93283    2       0      10.12787       False
# 13  0.87377    0.93151  0.80934    2       0      10.27740       False
# 14  0.88974    0.91816  0.78342    4       0      10.20317       False
# 15  0.16234    0.19910  0.93108    1       0       0.77162       False
# 16  0.29870    0.37311  0.94830    1       0       1.48782       False
# 17  0.17296    0.21158  0.92872    1       0       1.28139       False
# 18  0.29870    0.37311  0.94830    1       0       2.03902       False
# 19  0.35319    0.42981  0.92385    1       0       1.79405       False
# ### Rules for Instance 5759, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer   Rule_ID  \
# 0          5759    ANCHOR   ANCHOR2
# 1          5759    ANCHOR   ANCHOR3
# 2          5759    ANCHOR   ANCHOR4
# 3          5759      LORE     LORE3
# 4          5759      LORE     LORE4
# 5          5759      LORE     LORE5
# 6          5759   LORE_SA  LORE_SA4
# 7          5759    EXPLAN   EXPLAN2
# 8          5759    EXPLAN   EXPLAN4
# 9          5759    EXPLAN   EXPLAN5
#
#                                                                                 Rule  \
# 0    IF hours.per.week <= 45.0 AND marital.status = Never-married THEN class = <=50K
# 1    IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 2    IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 3                                       IF capital.gain <= 2174.0 THEN class = <=50K
# 4                                      IF capital.gain <= 15024.0 THEN class = <=50K
# 5                                       IF capital.gain <= 7688.0 THEN class = <=50K
# 6  IF capital.gain <= 1070.0469360351562 AND education != Masters THEN class = <=50K
# 7                                             IF age <= 29.233878 THEN class = <=50K
# 8                                                  IF age <= 29.0 THEN class = <=50K
# 9                                                  IF age <= 31.0 THEN class = <=50K
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.28212    0.36052  0.97014    2       0       0.73731       False
# 1  0.26378    0.33931  0.97655    2       1       1.52081       False
# 2  0.26378    0.33931  0.97655    2       9       7.84196        True
# 3  0.92282    0.96712  0.79561    1       0      33.38843       False
# 4  0.99162    0.99954  0.76523    1       0      33.50236       False
# 5  0.97306    0.99919  0.77956    1       0      33.99435       False
# 6  0.87377    0.93151  0.80934    2       0      10.27740       False
# 7  0.29870    0.37311  0.94830    1       0       1.48782       False
# 8  0.29870    0.37311  0.94830    1       0       2.03902       False
# 9  0.35319    0.42981  0.92385    1       0       1.79405       False
# ### Rules for Instance 5759, Non-dominated (Cov_class↑, Pre↑, Len↓)
#    Instance_Name Explainer   Rule_ID  \
# 0           5759    ANCHOR   ANCHOR2
# 1           5759    ANCHOR   ANCHOR3
# 2           5759    ANCHOR   ANCHOR4
# 3           5759      LORE     LORE2
# 4           5759      LORE     LORE3
# 5           5759      LORE     LORE4
# 6           5759      LORE     LORE5
# 7           5759   LORE_SA  LORE_SA4
# 8           5759    EXPLAN   EXPLAN2
# 9           5759    EXPLAN   EXPLAN4
# 10          5759    EXPLAN   EXPLAN5
#
#                                                                                  Rule  \
# 0     IF hours.per.week <= 45.0 AND marital.status = Never-married THEN class = <=50K
# 1     IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 2     IF hours.per.week <= 40.0 AND marital.status = Never-married THEN class = <=50K
# 3                                              IF age <= 44.447838 THEN class = <=50K
# 4                                        IF capital.gain <= 2174.0 THEN class = <=50K
# 5                                       IF capital.gain <= 15024.0 THEN class = <=50K
# 6                                        IF capital.gain <= 7688.0 THEN class = <=50K
# 7   IF capital.gain <= 1070.0469360351562 AND education != Masters THEN class = <=50K
# 8                                              IF age <= 29.233878 THEN class = <=50K
# 9                                                   IF age <= 29.0 THEN class = <=50K
# 10                                                  IF age <= 31.0 THEN class = <=50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.28212    0.36052  0.97014    2       0       0.73731       False
# 1   0.26378    0.33931  0.97655    2       1       1.52081       False
# 2   0.26378    0.33931  0.97655    2       9       7.84196        True
# 3   0.68335    0.72837  0.80918    1       0      33.96423       False
# 4   0.92282    0.96712  0.79561    1       0      33.38843       False
# 5   0.99162    0.99954  0.76523    1       0      33.50236       False
# 6   0.97306    0.99919  0.77956    1       0      33.99435       False
# 7   0.87377    0.93151  0.80934    2       0      10.27740       False
# 8   0.29870    0.37311  0.94830    1       0       1.48782       False
# 9   0.29870    0.37311  0.94830    1       0       2.03902       False
# 10  0.35319    0.42981  0.92385    1       0       1.79405       False
# ## Instance 20 (Original: >50K , Predicted: >50K)
#                           Value
# age                        37.0
# workclass               Private
# education             Bachelors
# education.num                13
# marital.status    Never-married
# occupation      Exec-managerial
# relationship      Not-in-family
# race                      White
# sex                        Male
# capital.gain                0.0
# capital.loss             2824.0
# hours.per.week             40.0
# native.country    United-States
# ### Rules for Instance 20
#    Instance_Name Explainer   Rule_ID  \
# 0             20    ANCHOR   ANCHOR1
# 1             20    ANCHOR   ANCHOR2
# 2             20    ANCHOR   ANCHOR3
# 3             20    ANCHOR   ANCHOR4
# 4             20    ANCHOR   ANCHOR5
# 5             20      LORE     LORE1
# 6             20      LORE     LORE2
# 7             20      LORE     LORE3
# 8             20      LORE     LORE4
# 9             20      LORE     LORE5
# 10            20   LORE_SA  LORE_SA1
# 11            20   LORE_SA  LORE_SA2
# 12            20   LORE_SA  LORE_SA3
# 13            20   LORE_SA  LORE_SA4
# 14            20   LORE_SA  LORE_SA5
# 15            20    EXPLAN   EXPLAN1
# 16            20    EXPLAN   EXPLAN2
# 17            20    EXPLAN   EXPLAN3
# 18            20    EXPLAN   EXPLAN4
# 19            20    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Rule  \
# ...
# 6   0.05717    0.20641  0.86953    1       0      33.66446       False
# 7   0.02444    0.09911  0.97666    1       0      33.44772       False
# 8   0.05274    0.19767  0.90266    1       0      33.40533       False
# 9   0.04379    0.17836  0.98096    1       0      33.36703       False
# 10  0.44467    0.84751  0.45900    4       0      11.61302       False
# 11  0.63163    0.91784  0.34996    4       0      11.55579       False
# 12  0.16247    0.27965  0.41453    2       0      12.10420       False
# 13  0.05612    0.17344  0.74433    4       0      12.59609       False
# 14  0.83060    0.92858  0.26924    4       0      11.64347       False
# 15  0.04344    0.17125  0.94949    2       0       5.13870       False
# 16  0.02273    0.09291  0.98456    1       0       3.51994       False
# 17  0.02334    0.09546  0.98496    2       0       3.85725       False
# 18  0.02518    0.10220  0.97735    1       0       3.77840       False
# 19  0.02009    0.08198  0.98253    1       0       4.43945       False
# ### Rules for Instance 1808, Min_treshold (Cov 0.01, Cov_class 0.01, Pre 0.01)
#    Instance_Name Explainer   Rule_ID  \
# 0           1808    ANCHOR   ANCHOR1
# 1           1808    ANCHOR   ANCHOR2
# 2           1808    ANCHOR   ANCHOR3
# 3           1808    ANCHOR   ANCHOR4
# 4           1808    ANCHOR   ANCHOR5
# 5           1808      LORE     LORE1
# 6           1808      LORE     LORE2
# 7           1808      LORE     LORE3
# 8           1808      LORE     LORE4
# 9           1808      LORE     LORE5
# 10          1808   LORE_SA  LORE_SA1
# 11          1808   LORE_SA  LORE_SA2
# 12          1808   LORE_SA  LORE_SA3
# 13          1808   LORE_SA  LORE_SA4
# 14          1808   LORE_SA  LORE_SA5
# 15          1808    EXPLAN   EXPLAN1
# 16          1808    EXPLAN   EXPLAN2
# 17          1808    EXPLAN   EXPLAN3
# 18          1808    EXPLAN   EXPLAN4
# 19          1808    EXPLAN   EXPLAN5
#
#                                                                                                                                                                                             Rule  \
# 0   IF age > 28.0 AND capital.gain > 0.0 AND marital.status = Married-civ-spouse AND native.country = United-States AND race = White AND relationship = Husband AND sex = Male THEN class = >50K
# 1                    IF age > 47.0 AND capital.gain > 0.0 AND marital.status = Married-civ-spouse AND native.country = United-States AND relationship = Husband AND sex = Male THEN class = >50K
# 2                                                             IF capital.gain > 0.0 AND education = Bachelors AND education.num = 13.0 AND marital.status = Married-civ-spouse THEN class = >50K
# 3                                                       IF age > 28.0 AND capital.gain > 0.0 AND marital.status = Married-civ-spouse AND relationship = Husband AND sex = Male THEN class = >50K
# 4                                                           IF capital.gain > 0.0 AND education = Bachelors AND marital.status = Married-civ-spouse AND relationship = Husband THEN class = >50K
# 5                                                                                                                                                        IF capital.gain > 0.0 THEN class = >50K
# 6                                                                                                                                                     IF capital.gain > 4101.0 THEN class = >50K
# 7                                                                                                                                                IF capital.gain > 9972.741585 THEN class = >50K
# 8                                                                                                                                                     IF capital.gain > 4650.0 THEN class = >50K
# 9                                                                                                                                                IF capital.gain > 7213.021034 THEN class = >50K
# 10                                                              IF education != Preschool AND education != 10th AND education.num != 2 AND marital.status = Married-civ-spouse THEN class = >50K
# 11                                                 IF education != Preschool AND education != 11th AND hours.per.week > 16.874725818634033 AND marital.status != Never-married THEN class = >50K
# 12                                                                                                                  IF education = Bachelors AND occupation != Farming-fishing THEN class = >50K
# 13                                       IF capital.gain > 975.2471923828125 AND marital.status = Married-civ-spouse AND native.country != Haiti AND relationship != Own-child THEN class = >50K
# 14                                         IF education != Preschool AND marital.status != Divorced AND native.country != Dominican-Republic AND occupation != Farming-fishing THEN class = >50K
# 15                                                                                                                                 IF age > 29.57797 AND capital.gain > 5178.0 THEN class = >50K
# 16                                                                                                                                                   IF capital.gain > 10566.0 THEN class = >50K
# 17                                                                                                                                IF age > 28.413022 AND capital.gain > 9386.0 THEN class = >50K
# 18                                                                                                                                                    IF capital.gain > 8614.0 THEN class = >50K
# 19                                                                                                                                                   IF capital.gain > 14084.0 THEN class = >50K
#
#         Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0   0.04094    0.13372  0.78671    7       0       3.22819       False
# 1   0.01878    0.05884  0.75467    6       0       3.35264       False
# 2   0.01307    0.04810  0.88591    4       0       3.33913       False
# 3   0.04752    0.15249  0.77285    5       0       2.43496       False
# 4   0.01185    0.04391  0.89259    4       0       3.87094       False
# 5   0.08402    0.21680  0.62141    1       0      33.61061       False
# 6   0.05717    0.20641  0.86953    1       0      33.66446       False
# 7   0.02444    0.09911  0.97666    1       0      33.44772       False
# 8   0.05274    0.19767  0.90266    1       0      33.40533       False
# 9   0.04379    0.17836  0.98096    1       0      33.36703       False
# 10  0.44467    0.84751  0.45900    4       0      11.61302       False
# 11  0.63163    0.91784  0.34996    4       0      11.55579       False
# 12  0.16247    0.27965  0.41453    2       0      12.10420       False
# 13  0.05612    0.17344  0.74433    4       0      12.59609       False
# 14  0.83060    0.92858  0.26924    4       0      11.64347       False
# 15  0.04344    0.17125  0.94949    2       0       5.13870       False
# 16  0.02273    0.09291  0.98456    1       0       3.51994       False
# 17  0.02334    0.09546  0.98496    2       0       3.85725       False
# 18  0.02518    0.10220  0.97735    1       0       3.77840       False
# 19  0.02009    0.08198  0.98253    1       0       4.43945       False
# ### Rules for Instance 1808, Non-dominated (Cov↑, Pre↑)
#   Instance_Name Explainer   Rule_ID  \
# 0          1808      LORE     LORE1
# 1          1808      LORE     LORE2
# 2          1808      LORE     LORE4
# 3          1808      LORE     LORE5
# 4          1808   LORE_SA  LORE_SA1
# 5          1808   LORE_SA  LORE_SA2
# 6          1808   LORE_SA  LORE_SA5
# 7          1808    EXPLAN   EXPLAN3
#
#                                                                                                                                                     Rule  \
# 0                                                                                                                IF capital.gain > 0.0 THEN class = >50K
# 1                                                                                                             IF capital.gain > 4101.0 THEN class = >50K
# 2                                                                                                             IF capital.gain > 4650.0 THEN class = >50K
# 3                                                                                                        IF capital.gain > 7213.021034 THEN class = >50K
# 4                       IF education != Preschool AND education != 10th AND education.num != 2 AND marital.status = Married-civ-spouse THEN class = >50K
# 5          IF education != Preschool AND education != 11th AND hours.per.week > 16.874725818634033 AND marital.status != Never-married THEN class = >50K
# 6  IF education != Preschool AND marital.status != Divorced AND native.country != Dominican-Republic AND occupation != Farming-fishing THEN class = >50K
# 7                                                                                         IF age > 28.413022 AND capital.gain > 9386.0 THEN class = >50K
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.08402    0.21680  0.62141    1       0      33.61061       False
# 1  0.05717    0.20641  0.86953    1       0      33.66446       False
# 2  0.05274    0.19767  0.90266    1       0      33.40533       False
# 3  0.04379    0.17836  0.98096    1       0      33.36703       False
# 4  0.44467    0.84751  0.45900    4       0      11.61302       False
# 5  0.63163    0.91784  0.34996    4       0      11.55579       False
# 6  0.83060    0.92858  0.26924    4       0      11.64347       False
# 7  0.02334    0.09546  0.98496    2       0       3.85725       False
# ### Rules for Instance 1808, Non-dominated (Cov_class↑, Pre↑, Len↓)
#   Instance_Name Explainer   Rule_ID  \
# 0          1808      LORE     LORE1
# 1          1808      LORE     LORE2
# 2          1808      LORE     LORE4
# 3          1808      LORE     LORE5
# 4          1808   LORE_SA  LORE_SA1
# 5          1808   LORE_SA  LORE_SA2
# 6          1808   LORE_SA  LORE_SA3
# 7          1808   LORE_SA  LORE_SA5
# 8          1808    EXPLAN   EXPLAN2
# 9          1808    EXPLAN   EXPLAN3
#
#                                                                                                                                                     Rule  \
# 0                                                                                                                IF capital.gain > 0.0 THEN class = >50K
# 1                                                                                                             IF capital.gain > 4101.0 THEN class = >50K
# 2                                                                                                             IF capital.gain > 4650.0 THEN class = >50K
# 3                                                                                                        IF capital.gain > 7213.021034 THEN class = >50K
# 4                       IF education != Preschool AND education != 10th AND education.num != 2 AND marital.status = Married-civ-spouse THEN class = >50K
# 5          IF education != Preschool AND education != 11th AND hours.per.week > 16.874725818634033 AND marital.status != Never-married THEN class = >50K
# 6                                                                           IF education = Bachelors AND occupation != Farming-fishing THEN class = >50K
# 7  IF education != Preschool AND marital.status != Divorced AND native.country != Dominican-Republic AND occupation != Farming-fishing THEN class = >50K
# 8                                                                                                            IF capital.gain > 10566.0 THEN class = >50K
# 9                                                                                         IF age > 28.413022 AND capital.gain > 9386.0 THEN class = >50K
#
#        Cov  Cov_class      Pre  Len  Reject  Elapsed_time  Iter_Limit
# 0  0.08402    0.21680  0.62141    1       0      33.61061       False
# 1  0.05717    0.20641  0.86953    1       0      33.66446       False
# 2  0.05274    0.19767  0.90266    1       0      33.40533       False
# 3  0.04379    0.17836  0.98096    1       0      33.36703       False
# 4  0.44467    0.84751  0.45900    4       0      11.61302       False
# 5  0.63163    0.91784  0.34996    4       0      11.55579       False
# 6  0.16247    0.27965  0.41453    2       0      12.10420       False
# 7  0.83060    0.92858  0.26924    4       0      11.64347       False
# 8  0.02273    0.09291  0.98456    1       0       3.51994       False
# 9  0.02334    0.09546  0.98496    2       0       3.85725       False
# ### Average Number of Filtered Rules at Each Step
#                  Avg Filtered (Correct Prediction)  \
# Explainer
# ANCHOR                                         0.5
# LORE                                           0.0
# LORE_SA                                        0.0
# EXPLAN                                         0.0
# Overall Average                                0.5
#
#                  Avg Filtered (Threshold Filter)  \
# Explainer
# ANCHOR                                      1.00
# LORE                                        1.50
# LORE_SA                                     2.00
# EXPLAN                                      1.75
# Overall Average                             6.25
#
#                  Avg Filtered (Non-dominated 1)  \
# Explainer
# ANCHOR                                 2.666667
# LORE                                   1.000000
# LORE_SA                                2.333333
# EXPLAN                                 3.000000
# Overall Average                        7.000000
#
#                  Avg Filtered (Non-dominated 2)
# Explainer
# ANCHOR                                 2.666667
# LORE                                   0.750000
# LORE_SA                                2.000000
# EXPLAN                                 2.000000
# Overall Average                        5.750000
# ### Average Metrics for Non-Dominated Rules (Cov↑, Pre↑)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.950048  0.217080   0.271852  2.166667  1.833333
# LORE            0.774426  0.273583   0.330089  1.500000  0.000000
# LORE_SA         0.655850  0.808811   0.931469  3.000000  0.000000
# EXPLAN          0.962555  0.170102   0.243735  1.500000  0.000000
# Global_Average  0.808224  0.390466   0.467812  2.030303  0.333333
#
#                 Elapsed_time
# ANCHOR              2.527688
# LORE               33.702666
# LORE_SA            10.673854
# EXPLAN              2.815440
# Global_Average     16.138044
# ### Average Metrics for Non-Dominated Rules (Cov_class↑, Pre↑, Len↓)
#                      Pre       Cov  Cov_class       Len    Reject  \
# ANCHOR          0.950048  0.217080   0.271852  2.166667  1.833333
# EXPLAN          0.908800  0.148108   0.195122  1.166667  0.333333
# LORE            0.776241  0.256136   0.313824  1.500000  0.000000
# LORE_SA         0.660444  0.769381   0.879942  2.833333  0.000000
# Global_Average  0.809400  0.350931   0.418682  1.861111  0.388889
#
#                 Elapsed_time
# ANCHOR              2.527688
# EXPLAN              3.325293
# LORE               33.723656
# LORE_SA            10.715530
# Global_Average     15.172706
# ## Overall Heatmap – Non-dominated Rules (Cov↑, Pre↑)
# ## Overall Heatmap – Non-dominated Rules (Cov_class↑, Pre↑, Len↓)
